# %% [markdown]
# # Table of Contents
# * &nbsp;
# 	* [imports](#imports)
# 	* [simple functions](#simple-functions)
# * [Load data](#Load-data)
# 	* [setting paths](#setting-paths)
# 	* [parsed content and raw questions and descriptions](#parsed-content-and-raw-questions-and-descriptions)
# 	* [localization and recognition](#localization-and-recognition)
# 	* [building spellings and grammar](#building-spellings-and-grammar)
# * [Clean and prepare data](#Clean-and-prepare-data)
# 	* [extract media links](#extract-media-links)
# 	* [remove non-conforming content](#remove-non-conforming-content)
# 		* [code](#code)
# 		* [run](#run)
# 	* [remove recognition and localization errors](#remove-recognition-and-localization-errors)
# * [Add image annotations](#Add-image-annotations)
# 	* [localization](#localization)
# 	* [recognition](#recognition)
# 		* [code](#code)
# 		* [run](#run)
# 		* [hide](#hide)
# * [Integrate diagram questions and descriptions](#Integrate-diagram-questions-and-descriptions)
# 	* [match diagram topics to lessons](#match-diagram-topics-to-lessons)
# 		* [code](#code)
# 		* [run](#run)
# 		* [hide](#hide)
# 	* [merge questions](#merge-questions)
# 		* [code](#code)
# 		* [run](#run)
# 		* [hide](#hide)
# 	* [merge descriptions](#merge-descriptions)
# 		* [hide](#hide)
# 	* [Apply spelling and grammar fixes](#Apply-spelling-and-grammar-fixes)
# 		* [code](#code)
# 		* [run](#run)
# 		* [hide](#hide)
# * [Topic key collisions](#Topic-key-collisions)
# * [Refinements to make](#Refinements-to-make)
# * [End](#End)

# %% [markdown]
# ## imports

# %%
# %%capture
import matplotlib as mpl
mpl.use("Agg")
import matplotlib.pylab as plt
#%matplotlib notebook
# %matplotlib inline
# %load_ext base16_mplrc
# %base16_mplrc light solarized
# %base16_mplrc dark solarized
plt.rcParams['grid.linewidth'] = 0
plt.rcParams['figure.figsize'] = (16.0, 10.0)

import numpy as np
import pandas as pd
import scipy.stats as st
from scipy.stats.mstats import mode

import itertools
import math
from collections import Counter, defaultdict, OrderedDict
# %load_ext autoreload
# %autoreload 2

import cv2
import pprint
import pickle
import json
import requests
import io
import sys
import os
from binascii import b2a_hex
import base64
from wand.image import Image as WImage
from IPython.display import display
from IPython.core.display import HTML
import PIL.Image as Image
from copy import deepcopy
import glob
import random

import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
import language_check
import enchant
import difflib
import diff_match_patch
import fuzzywuzzy.fuzz as fuzz
import re
import jsonschema
from pdfextraction.ck12_schema import ck12_schema as schema
from pdfextraction.ck12_new_schema import ck12_schema as new_schema

# %% [markdown]
# ## simple functions

# %%
def write_file(filename, data_dict, output_dir='output_data_from_nbs'):
    with open(os.path.join(output_dir, filename), 'w') as f:
        json.dump(data_dict, f, indent=4, sort_keys=True)
        
def get_img_n(image_name):
    return [re.findall("[0-9]+", image_name)][0][0]

def clean_list(dir_path):
    hidden_removed = filter(lambda f: not f.startswith('.'), os.listdir(dir_path))
    return [topic.replace('_diagram', '') for topic in hidden_removed]

# %% [markdown]
# # Load data

# %% [markdown]
# load last_checkpoint

# %%
with open('build_v6.pkl', 'rb') as f:
    latest_checkpoint = pickle.load(f)

# %%
latest_checkpoint.keys()
# Out:
# dict_keys(['earth-science', 'life-science', 'physical-science'])

# %% [markdown]
# ## setting paths

# %%
output_dir = 'output_data_from_nbs/'
raw_data_dir = '../spare5_produced_data/data/'
raw_dq_file = 'ai2_testquestions_20161005.csv'
s5_raw_decriptions = 'ai2_diagramdescriptions_20161018.csv'
ai2_raw_decriptions = 'our_description.csv'
glossary_path = os.path.join(output_dir, 'flexbook_glossary.pkl')

turk_proc_dir = '/Users/schwenk/wrk/stb/diagram_questions/turk_processing/'
metadata_dir = turk_proc_dir + 'store_hit_results_metadata/'
lc_results_dir = 'loc_group_3'
box_loc_joined = 'loc_annotations'
recog_results_dir = 'group_latest_combined'

box_choices_1_dir = 'final_text_boxes_fixed'
box_choices_2_dir = 'final_text_boxes_pass_2'
none_agree = 'no_turkers_agree_lookup.pkl'
two_agree_lookup = 'two_turkers_agree_lookup.pkl'
all_agree_lookup = 'user_diag_loopkup.pkl'

recog_performed = '/Users/schwenk/wrk/stb/diagram_questions/turk_processing/final_diagrams/'
all_dir = '/Users/schwenk/wrk/stb/ai2-vision-textbook-dataset/diagrams/tqa_diagrams_v0.9/'
pruned_dir = '/Users/schwenk/wrk/stb/ai2-vision-textbook-dataset/diagrams/dataset_Sep_27/tqa_diagrams_v0.9_question_images/'
description_dir = '/Users/schwenk/wrk/stb/spare5_produced_data/tqa_diagrams_v0.9_inbook/'

# %% [markdown]
# ## parsed content and raw questions and descriptions

# %%
# %%capture
# load complete text v 3.5, raw diagram questions and descriptions
# now ck12_dataset_text_only_beta_v5_build.json
with open(output_dir + 'ck12_dataset_text_only_beta_v5_build.json', 'r') as f:
    ck12_combined_dataset_raw = json.load(f)
with open(output_dir + 'ck12_flexbook_only_beta_v3.json', 'r') as f:
    flexbook_ds = json.load(f)
with open(output_dir + 'ck12_lessons_only_beta_v3.json', 'r') as f:
    lessons_ds = json.load(f)

# loading questions
desc_df = pd.read_csv(raw_data_dir + s5_raw_decriptions, encoding='latin-1')
desc_df['diagram'] = desc_df['reference_id'].apply(lambda x: x.split('/')[-1])

ai2_raw_decriptions_df = pd.read_csv(raw_data_dir + ai2_raw_decriptions, encoding='latin-1')
ai2_written_df_completed = ai2_raw_decriptions_df[['Topic', 'Image Path', 'Description']]
ai2_written_df_completed['diagram'] = ai2_written_df_completed['Image Path'].apply(lambda x: x.split('/')[-1])
ai2_written_df_completed['topic'] = ai2_written_df_completed['Topic']
del  ai2_written_df_completed['Topic']

#loading questions
# q_col = '03_write_question'
# r_ans_col = '04_write_right_answer'
# w_ans_col = '05_write_wrong_answers'
# data_cols = [q_col, r_ans_col, w_ans_col]
# raw_dq_df = pd.read_csv(raw_data_dir + raw_dq_file, encoding='latin-1')
# dr_proc_df = raw_dq_df.copy()
# dr_proc_df['wac_list'] = dr_proc_df[w_ans_col].apply(lambda x: json.loads(x))
# dr_proc_df['diagram'] = dr_proc_df['reference_id'].apply(lambda x: x.split('/')[-1])
# dr_proc_df['topic'] = dr_proc_df['reference_id'].apply(lambda x: x.split('/')[-1].rsplit('_', maxsplit=1)[0])

dr_proc_df = pd.read_pickle('complete_s5_dq.pkl')
dr_proc_df['diagram'] = dr_proc_df['reference_id'].apply(lambda x: x.split('/')[-1])


with open('../diagram_questions/topic_match_terms.json', 'r') as f:
    topic_term_match = json.load(f)    

with open(glossary_path, 'rb') as f:
    flexbook_glossary = pickle.load(f)

# %% [markdown]
# ### localization and recognition

# %%
loc_res_df = pd.read_pickle(os.path.join(metadata_dir, lc_results_dir, 'complete_df.pkl'))
recog_res_df = pd.read_pickle(os.path.join(metadata_dir, recog_results_dir, 'recog_df.pkl'))

# %% [markdown]
# ## building spellings and grammar

# %%
# loading spelling defs
with open(output_dir + 'ck_12_vocab_words.pkl', 'rb') as f:
    ck_12_vocab = set(pickle.load(f))
with open(output_dir + 'ck_12_all_words.pkl', 'rb') as f:
    ck_12_corp = set(pickle.load(f))
    
with open(output_dir + 'spellings_to_rev.txt', 'r') as f:
    whitelisted_words = f.read().split('\n')[:-1]    
with open(output_dir + './desc_spellings_to_rev.txt', 'r') as f:
    whitelisted_words += f.read().split('\n')[:-1]
with open(output_dir + './ck_12_spelling_rev.txt', 'r') as f:
    whitelisted_words += f.read().split('\n')[:-1]
with open('diagram_rec_corp.pkl', 'rb') as f:
    diagram_rec_corpus = pickle.load(f)
    
ck_12_corp.update(ck_12_vocab)
ck_12_corp.update(whitelisted_words)
ck_12_corp.update(diagram_rec_corpus)

# build spelling dict updated with words from science corpus
edict = enchant.Dict("en_US")
anglo_edict = enchant.Dict("en_UK")
cached_sw = stopwords.words("english") + list(string.punctuation)
for word in ck_12_corp:
    if word.isalpha() and len(word) > 3:
        edict.add(word)
        
# grammaer checker
gram_checker = language_check.LanguageTool('en-US')
gram_checker.disabled = set(['SENT_START_CONJUNCTIVE_LINKING_ADVERB_COMMA', 'POSSESSIVE_APOSTROPHE', 'A_PLURAL'])
gram_checker.disable_spellchecking()

# %% [markdown]
# # Clean and prepare data

# %% [markdown]
# ## extract media links

# %%
ck12_combined_dataset = deepcopy(ck12_combined_dataset_raw)

# %%
pat_str = "(?:https?:\/\/(?:www\.).*?\s)"
web_link_patern=re.compile(pat_str)

def clean_content_text(content_str, web_link_patern):
    removed_links = web_link_patern.findall(content_str)
    if not removed_links:
        return '', ''
    split_txt = web_link_patern.split(content_str)
    cleaned_text = ' '.join([txt for txt in split_txt if txt])
    return cleaned_text, [link.strip() for link in removed_links]

def extract_links(complete_ds):
    for subject, lessons in complete_ds.items():
        for lesson_title, lesson in lessons.items():
            for topic, content in lesson['topics'].items():
                content_str = content['content']['text']
                new_text, links = clean_content_text(content_str, web_link_patern)
                content['content']['mediaLinks'] = []
                if links:
                    content['content']['text'] = new_text
                    content['content']['mediaLinks'].extend(links)

# %%
extract_links(ck12_combined_dataset)

# %% [markdown]
# ## remove non-conforming content

# %% [markdown]
# ### old code (nested)

# %%
def validate_schema(dataset_json, ):
    errors = []
    try:
        validator = jsonschema.Draft4Validator(schema)
        for error in sorted(validator.iter_errors(dataset_json), key=lambda x: x.absolute_path[0]):
            errors.append([error.message, list(error.absolute_path)[:4]])
    except jsonschema.ValidationError as e:
        errors.append("Error in schema --%s-", e.message)
    return errors

def validate_dataset(dataset_json, scheme=schema):
    for subject, flexbook in dataset_json.items():
        schema_errors = validate_schema(flexbook, schema)
        for lesson_name, lesson in flexbook.items():
            ac_errors = check_ac_counts(lesson, subject, lesson_name)
        all_errors = schema_errors + ac_errors
        if not all_errors:
            return 'all validation test passed'
        else:
            return all_errors

def check_ac_counts(lesson_content, subject, lesson_name):
    errors = []
    for qid, question in lesson_content['questions']['nonDiagramQuestions'].items():
        if question['type'] == 'Multiple Choice':
            if len(question['answerChoices']) != 4:
                errors.append([subject, lesson_name, qid + ' mc error'])
        if question['type'] == 'True or False':
            if len(question['answerChoices']) != 2:
                errors.append([subject, lesson_name, qid + ' tf error'])
    return errors

def record_validation_errors(dataset):
    qs_removed = []
    for subject, flexbook in dataset.items():
        validator = jsonschema.Draft4Validator(schema)
        for error in sorted(validator.iter_errors(flexbook), key=lambda x: x.absolute_path[0]):
            lesson, quest, question_class, q_number = list(error.absolute_path)[:4]
            problem_q_section = dataset[subject][lesson][quest][question_class]
            if q_number in problem_q_section.keys():
#                 print(dataset[subject][lesson][quest][question_class].pop(q_number))
                qs_removed.append(dataset[subject][lesson][quest][question_class].pop(q_number))
    return qs_removed

# %%
val_errors = record_validation_errors(ck12_combined_dataset)

# %%
val_errors
# Out:
# [{'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': '',
#     'rawText': 'a. '},
#    'b': {'idStructural': 'b.', 'processedText': '', 'rawText': 'b.'},
#    'c': {'idStructural': 'c.', 'processedText': '', 'rawText': 'c.'},
#    'd': {'idStructural': 'd.', 'processedText': '', 'rawText': 'd.'}},
#   'beingAsked': {'processedText': 'Which of the following lab safety symbols stands for high voltage?',
#    'rawText': '7. Which of the following lab safety symbols stands for high voltage?'},
#   'correctAnswer': {'processedText': 'd', 'rawText': '7. d'},
#   'id': 'q07',
#   'idStructural': '7. ',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'The intertidal zone is covered with water only during __________.',
#    'rawText': '7. The intertidal zone is covered with water only during __________. '},
#   'correctAnswer': {'processedText': '', 'rawText': '7. '},
#   'id': 'q31',
#   'idStructural': '7.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'A compasss needle always points to _____________ north.',
#    'rawText': '12. A compasss needle always points to _____________ north.'},
#   'correctAnswer': {'processedText': {}, 'rawText': {}},
#   'id': 'q07',
#   'idStructural': '12.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'Wastewater from septic tanks, sewers, and yards are part of ____________ pollution.',
#    'rawText': '15. Wastewater from septic tanks, sewers, and yards are part of ____________ pollution.'},
#   'correctAnswer': {'processedText': {}, 'rawText': {}},
#   'id': 'q10',
#   'idStructural': '15.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': '23 1/2 is Earths ____________',
#    'rawText': '15. 23 1/2 is Earths ____________'},
#   'correctAnswer': {'processedText': {}, 'rawText': {}},
#   'id': 'q10',
#   'idStructural': '15.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'The first element to form after the big bang was __________.',
#    'rawText': '5. The first element to form after the big bang was __________.'},
#   'correctAnswer': {'processedText': '', 'rawText': '5. '},
#   'id': 'q05',
#   'idStructural': '5.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'In the 1906 San Francisco earthquake, the most damage was done by __________.',
#    'rawText': '13. In the 1906 San Francisco earthquake, the most damage was done by __________.'},
#   'correctAnswer': {'processedText': {}, 'rawText': {}},
#   'id': 'q08',
#   'idStructural': '13.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': 'take a drink of water',
#     'rawText': 'a. take a drink of water'},
#    'b': {'idStructural': 'b.',
#     'processedText': 'toss the remains of your experiment in the trash',
#     'rawText': 'b. toss the remains of your experiment in the trash'},
#    'c': {'idStructural': 'c.',
#     'processedText': 'wipe down the lab counter where you worked',
#     'rawText': 'c. wipe down the lab counter where you worked'},
#    'd': {'idStructural': 'd.', 'processedText': '', 'rawText': 'd. '}},
#   'beingAsked': {'processedText': 'What is the last thing you should do before leaving a science lab?',
#    'rawText': '8. What is the last thing you should do before leaving a science lab?'},
#   'correctAnswer': {'processedText': 'a', 'rawText': '7. a'},
#   'id': 'q28',
#   'idStructural': '8. ',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'The last ice age occurred during the _________________Period.',
#    'rawText': '7. The last ice age occurred during the _________________Period. '},
#   'correctAnswer': {'processedText': '', 'rawText': '7.'},
#   'id': 'q28',
#   'idStructural': '7.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'The earliest dinosaurs evolved during the _________________Period.',
#    'rawText': '6. The earliest dinosaurs evolved during the _________________Period.'},
#   'correctAnswer': {'processedText': '', 'rawText': '6. '},
#   'id': 'q27',
#   'idStructural': '6.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': '', 'rawText': '10.'},
#   'correctAnswer': {},
#   'id': 'q10',
#   'idStructural': '10.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': '', 'rawText': '10.'},
#   'correctAnswer': {},
#   'id': 'q10',
#   'idStructural': '10.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': '', 'rawText': '10.'},
#   'correctAnswer': {},
#   'id': 'q10',
#   'idStructural': '10.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': 'true',
#     'rawText': 'a. true'},
#    'b': {'idStructural': 'b.',
#     'processedText': 'false',
#     'rawText': 'b. false'}},
#   'beingAsked': {'processedText': 'gametes are diploid cells, with only half the dna present in the haploid parent cell.',
#    'rawText': '2. True or False: Gametes are diploid cells, with only half the DNA present in the haploid parent cell.'},
#   'correctAnswer': {'processedText': ''},
#   'id': 'q02',
#   'idStructural': '2.',
#   'type': 'True or False'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'how much dna is in a zygote? explain your answer,',
#    'rawText': '5. How much DNA is in a zygote? Explain your answer,'},
#   'correctAnswer': {'processedText': ''},
#   'id': 'q05',
#   'idStructural': '5.',
#   'type': 'Short Answer'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'define mitosis.',
#    'rawText': '4. Define mitosis.'},
#   'correctAnswer': {'processedText': ''},
#   'id': 'q04',
#   'idStructural': '4.',
#   'type': 'Short Answer'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'define meiosis.',
#    'rawText': '3. Define meiosis.'},
#   'correctAnswer': {'processedText': ''},
#   'id': 'q03',
#   'idStructural': '3.',
#   'type': 'Short Answer'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': 'true',
#     'rawText': 'a. true'},
#    'b': {'idStructural': 'b.',
#     'processedText': 'false',
#     'rawText': 'b. false'}},
#   'beingAsked': {'processedText': 'meiosis results in genetically unique cells.',
#    'rawText': '1. True or False: Meiosis results in genetically unique cells.'},
#   'correctAnswer': {'processedText': ''},
#   'id': 'q01',
#   'idStructural': '1.',
#   'type': 'True or False'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': '', 'rawText': '10.'},
#   'correctAnswer': {},
#   'id': 'q10',
#   'idStructural': '10.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': '', 'rawText': '10.'},
#   'correctAnswer': {},
#   'id': 'q10',
#   'idStructural': '10.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': '', 'rawText': '10.'},
#   'correctAnswer': {},
#   'id': 'q10',
#   'idStructural': '10.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': '208 Po',
#     'rawText': 'a. 208 Po'},
#    'b': {'idStructural': 'b.',
#     'processedText': '131 I  130 Xe + 0 e + Energy',
#     'rawText': 'b. 131 I  130 Xe + 0 e + Energy'},
#    'c': {'idStructural': 'c.', 'processedText': '1', 'rawText': 'c. 1'},
#    'd': {'idStructural': 'd.', 'processedText': '53', 'rawText': 'd. 53'}},
#   'beingAsked': {'processedText': 'Which of the following nuclear equations is balanced?',
#    'rawText': '8. Which of the following nuclear equations is balanced?'},
#   'id': 'q32',
#   'idStructural': '8. ',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': '',
#     'rawText': 'a. '},
#    'b': {'idStructural': 'b.', 'processedText': '', 'rawText': 'b.'},
#    'c': {'idStructural': 'c.', 'processedText': '', 'rawText': 'c.'},
#    'd': {'idStructural': 'd.', 'processedText': '', 'rawText': 'd.'}},
#   'beingAsked': {'processedText': 'Which pair of forces in question 5 produces a net force of zero?',
#    'rawText': '7. Which pair of forces in question 5 produces a net force of zero?'},
#   'correctAnswer': {'processedText': 'a', 'rawText': '7. a'},
#   'id': 'q07',
#   'idStructural': '7. ',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'The moon has __________ motion because of its forward velocity and acceleration due to Earths gravity.',
#    'rawText': '7. The moon has __________ motion because of its forward velocity and acceleration due to Earths gravity. '},
#   'correctAnswer': {'processedText': '', 'rawText': '7. '},
#   'id': 'q07',
#   'idStructural': '7.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': 'true',
#     'rawText': 'a. true'},
#    'b': {'idStructural': 'b.',
#     'processedText': 'false',
#     'rawText': 'b. false'}},
#   'beingAsked': {'processedText': 'The force applied by a machine is always greater than the force applied to the machine.',
#    'rawText': '10. The force applied by a machine is always greater than the force applied to the machine.'},
#   'id': 'q18',
#   'idStructural': '10.',
#   'type': 'True or False'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': 'true',
#     'rawText': 'a. true'},
#    'b': {'idStructural': 'b.',
#     'processedText': 'false',
#     'rawText': 'b. false'}},
#   'beingAsked': {'processedText': '', 'rawText': '1.'},
#   'correctAnswer': {'processedText': 'true', 'rawText': '8.true'},
#   'id': 'q15',
#   'idStructural': '1.',
#   'type': 'True or False'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'The mean of the numbers 3, 7, 8, and 6 is __________.',
#    'rawText': '7. The mean of the numbers 3, 7, 8, and 6 is __________. '},
#   'correctAnswer': {'processedText': '', 'rawText': '7. '},
#   'id': 'q14',
#   'idStructural': '7.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {},
#   'beingAsked': {'processedText': 'Electromagnetic waves travel __________ quickly through a medium than across space.',
#    'rawText': '7. Electromagnetic waves travel __________ quickly through a medium than across space. '},
#   'correctAnswer': {'processedText': '', 'rawText': '7. '},
#   'id': 'q07',
#   'idStructural': '7.',
#   'type': 'Fill in the Blank'},
#  {'answerChoices': {'a': {'idStructural': 'a.',
#     'processedText': '',
#     'rawText': 'a.'},
#    'b': {'idStructural': 'b.', 'processedText': '', 'rawText': 'b.'},
#    'c': {'idStructural': 'c.', 'processedText': '', 'rawText': 'c.'},
#    'd': {'idStructural': 'd.', 'processedText': '', 'rawText': 'd.'}},
#   'beingAsked': {'processedText': 'What is the power of a device that uses 10 amps of current in a 120-volt circuit?',
#    'rawText': '5. What is the power of a device that uses 10 amps of current in a 120-volt circuit?'},
#   'correctAnswer': {'processedText': 'b', 'rawText': 'b'},
#   'id': 'q05',
#   'idStructural': '5. ',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)',
#     'processedText': 'none of the above',
#     'rawText': 'd) none of the above'}},
#   'beingAsked': {'processedText': 'in a circuit diagram, which symbol represents the source of voltage?',
#    'rawText': '9. In a circuit diagram, which symbol represents the source of voltage?'},
#   'correctAnswer': {'processedText': 'c'},
#   'id': 'q09',
#   'idStructural': '9.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)',
#     'processedText': 'any of the above',
#     'rawText': 'd) any of the above'}},
#   'beingAsked': {'processedText': 'which pair of arrows could represent an action and reaction?',
#    'rawText': '7. Which pair of arrows could represent an action and reaction?'},
#   'correctAnswer': {'processedText': 'c'},
#   'id': 'q07',
#   'idStructural': '7.',
#   'type': 'Multiple Choice'},
#  {'answerChoices': {'a': {'idStructural': 'a)',
#     'processedText': '',
#     'rawText': 'a)'},
#    'b': {'idStructural': 'b)', 'processedText': '', 'rawText': 'b)'},
#    'c': {'idStructural': 'c)', 'processedText': '', 'rawText': 'c)'},
#    'd': {'idStructural': 'd)', 'processedText': '', 'rawText': 'd)'}},
#   'beingAsked': {'processedText': 'which of the following lab safety symbols warns of a hazardous chemical?',
#    'rawText': '2. Which of the following lab safety symbols warns of a hazardous chemical?'},
#   'correctAnswer': {'processedText': ''},
#   'id': 'q02',
#   'idStructural': '2.',
#   'type': 'Multiple Choice'}]

# %% [markdown]
# ### new code (flat)

# %%
def validate_schema(dataset_json, schema):
    errors = []
    try:
        validator = jsonschema.Draft4Validator(schema)
        for error in sorted(list(validator.iter_errors(dataset_json)), key=lambda x: x.absolute_schema_path[0]):
            errors.append([error.message, list(error.absolute_path)[:4]])
    except jsonschema.ValidationError as e:
        errors.append("Error in schema --%s-", e.message)
    return errors

def validate_dataset(dataset_json, val_scheme):
    ac_errors = []
    schema_errors = validate_schema(dataset_json, val_scheme)

    if not all_errors:
        return 'all validation test passed'
    else:
        return all_errors    

def record_validation_errors(dataset, schema):
    qs_removed = []
    validator = jsonschema.Draft4Validator(schema)
    for error in sorted(validator.iter_errors(dataset), key=lambda x: x.absolute_path[0]):
        print(error)
        lesson, quest, question_class, q_number = list(error.absolute_schema_path)[:4]
        problem_q_section = dataset[subject][lesson][quest][question_class]
        if q_number in problem_q_section.keys():
            print(dataset[subject][lesson][quest][question_class].pop(q_number))
            qs_removed.append(dataset[subject][lesson][quest][question_class].pop(q_number))
    return qs_removed

# %% [markdown]
# ### run

# %%
from pdfextraction.ck12_new_schema import ck12_schema as new_schema

# %%
len(complete_flat_ds)
# Out:
# 1076

# %%
NDQ_018942
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-440-e104ac4bef3d> in <module>()
# ----> 1 NDQ_018942
#
# NameError: name 'NDQ_018942' is not defined

# %%
validate_schema(complete_flat_ds, new_schema)
# Out:
# []

# %%
len(errors_returned)
# Out:
# 0

# %%
len(errors_returned[0][0])
# Out:
# 28521075

# %%
errors_returned[0][0][1]
# Out:
# '{'

# %%
len(errors_returned)
# Out:
# 1

# %%
from pdfextraction.ck12_new_schema import ck12_schema as new_schema
validator = jsonschema.Draft4Validator(new_schema)
for error in sorted(validator.iter_errors(complete_flat_ds), key=lambda x: x.absolute_path[0]):
    print(error.message)
    print(error.absolute_path)
    print()

# %%
record_validation_errors(complete_flat_ds, new_schema)
# Out:
# []

# %% [markdown]
# ### hide

# %%
test_flat_ds = complete_flat_ds

# %%
validate_schema(complete_flat_ds, new_schema)
# Out:
# []

# %%
test_flat_ds[0]['questions']['diagramQuestions']['DQ_000031'].keys()
# Out:
# dict_keys(['correctAnswer', 'beingAsked', 'answerChoices', 'imagePath', 'type', 'globalID', 'imageName'])

# %%
qs_rem = record_validation_errors(ck12_combined_dataset)

# %%
len(qs_rem)
# Out:
# 0

# %% [markdown]
# ## remove recognition and localization errors

# %%
diagram_image_names = clean_list(recog_performed)

rec_files = glob.glob(all_dir + '*/*')
more_paths = glob.glob(all_dir + '*/*')
pruned_paths = glob.glob(pruned_dir + '*/*')
more_files = [fp.split('/')[-1] for fp in more_paths]
pruned_files = [fp.split('/')[-1] for fp in pruned_paths]
desc_paths = glob.glob(description_dir + '*/*')
desc_files = [fp.split('/')[-1] for fp in desc_paths]


pruned_nums = set([get_img_n(name) for name in pruned_files])
all_nums = set([get_img_n(name) for name in more_files])
rec_nums = set([get_img_n(name) for name in diagram_image_names])
desc_nums = set([get_img_n(name) for name in desc_files])

removed_images = all_nums.difference(pruned_nums.union(desc_nums))

removed_image_names = []
for img_n in removed_images:
    for image_name in more_files:
        if img_n == get_img_n(image_name):
            removed_image_names.append(image_name)

name_change_lookup = {}
for image_name in more_files:
    img_n = get_img_n(image_name)
    for newer_name in pruned_files:
        if img_n == get_img_n(newer_name) and newer_name != image_name:
            name_change_lookup[image_name] = newer_name

removed_image_names = sorted(removed_image_names)

# %%
blacklisted_topics = ['periodic_table', 'em_spectrum', 'hydrocarbons', 'geologic_time'] + ['lewis_dot_idapgrams', 'circuits']  # correct this mispelling in future round

# %%
len(removed_image_names)
# Out:
# 9

# %% [markdown]
# # Add image annotations

# %% [markdown]
# ## localization

# %%
loc_res_df.head(1)
# Out:
#                diagram                 rectangle  \
# 0  parts_cell_1182.png  [[283, 192], [447, 238]]
#
#                            hit_id                   assignment_id  \
# 0  3SA4EMRVJV39U1MGLCYP6KPFULH0PX  3BDCF01OGXVJNV1XRULS5F5Z4B6LYG
#
#         worker_id
# 0  A1017VP86SLXRB

# %%
loc_anno = clean_list(os.path.join(turk_proc_dir, box_loc_joined))
loc_anno_images = [fig.split('.json')[0]  for fig in loc_anno]
keep_figures = [fig for fig in loc_anno_images if fig not in removed_image_names]

loc_box_path = os.path.join(turk_proc_dir, box_loc_joined)

diag_loc_annotations = {}
for diagram_name in keep_figures:
    anno_file_path = os.path.join(loc_box_path, diagram_name + '.json')
    if not os.path.exists(anno_file_path):
        diagram_name = diagram_name.replace('optics_rays', 'optics_ray_diagrams')
        anno_file_path = os.path.join(loc_box_path, diagram_name  + '.json')
    with open(anno_file_path, 'r') as f:
        diag_loc_annotations[diagram_name] = json.load(f)

combined_master_file_list = pruned_files + desc_files
combined_master_file_list_whitelisted = [file for file in combined_master_file_list if file in keep_figures]
files_still_needing_localisation = sorted(list(set(combined_master_file_list).difference(set(diag_loc_annotations))))
len(files_still_needing_localisation)
# Out:
# 142

# %% [markdown]
# ## recognition

# %% [markdown]
# ### code

# %%
def most_common_strict(image_response):
    """
    returns the consensus response of the three raw response strings for a given image
    """
    most_common = image_response[1]['raw_text'].mode()
    if most_common.empty:
        most_common = 'nonconsensus'
        noncon.append(image_response[1]['raw_text'])
    else:
        most_common = most_common.values[0]
    return most_common

def most_common_lax(image_response, strings_denoting_missing_image=[]):
    """
    returns the consensus response after stripping white space and converting the reponses to lower case
    """
    simple_sanitizer = lambda x : x.lower().strip().lstrip()
    ind_responses = image_response[1]['raw_text'].values
    probobly_blanks = [response for response in ind_responses if response in strings_denoting_missing_image]
    if probobly_blanks:
        return 'skip'
    most_common = image_response[1]['raw_text'].apply(simple_sanitizer).mode()
    if most_common.empty:
        most_common = 'no consensus'
        noncon[image_response[0][0]].extend(image_response[1]['raw_text'])
    else:
        most_common = most_common.values[0]
    return most_common

def find_transcriptions_matches(batch_results_df, response_matcher):
    """
    returns a pandas series with the consunsus response for each image
    """
    agreed_responses = pd.DataFrame()
    for image_response in batch_results_df.groupby(['diagram', 'box_diag_idx']):
        diagram_and_idx = image_response[0]
        most_common = response_matcher(image_response, strings_denoting_missing_image=[])
        if most_common == 'skip':
            continue
        this_row = pd.DataFrame(list(diagram_and_idx) + [most_common, image_response[1]['rectangle'].iloc[0], image_response[1]['assignment_id'].iloc[0]]).T
        agreed_responses = pd.concat([agreed_responses, this_row])
        # The reindex below is needed to match the original df index after the groupby operation
    agreed_responses.columns = ['diagram', 'box_diag_idx', 'consensus_res', 'rectangle', 'assignment_id']
    return agreed_responses

# %% [markdown]
# ### run

# %%
recog_performed_on = set(pd.unique(recog_res_df['diagram']).tolist())
len(recog_performed_on)
# Out:
# 2190

# %%
files_still_needing_recognition = sorted(list(set(pruned_files).difference(set(recog_performed_on))))
print(len(files_still_needing_recognition))
file_with_loc_no_recog = set(files_still_needing_recognition).difference(files_still_needing_localisation)
print(len(file_with_loc_no_recog))
# Out:
# 131
# 7

# %%
noncon = defaultdict(list)
transcription_results_lax = find_transcriptions_matches(recog_res_df, most_common_lax)

# %%
noncon_entries = [entries for entries in noncon.values()]
flattened_noncon = [item for sublist in noncon_entries for item in sublist]

# %%
curated_no_image_strings = set(['*no image showing*', '', ' ', 'NA', '?', 'na', '0', 'No image found', 'blank', 'Nothing showing', "where is the images , i can't see anything", 'NO IMAGE', ''])

# %%
non_blank_no_consensus = {d_name: rec_res for d_name, rec_res in noncon.items() if not curated_no_image_strings.intersection(set(rec_res))}
blank_no_consensus = {d_name: rec_res for d_name, rec_res in noncon.items() if curated_no_image_strings.intersection(set(rec_res))}
print(len(non_blank_no_consensus))
print(len(blank_no_consensus))
# Out:
# 408
# 99

# %%
flattened_noncon_no_blank = [item for sublist in non_blank_no_consensus.values() for item in sublist]
build_diagram_rec_corpus  = [words.split() for words in transcription_results_lax['consensus_res'].values.tolist()]
diagram_rec_corpus = set([item.lower().strip() for sublist in build_diagram_rec_corpus for item in sublist if item.isalpha() and len(item) > 3])

# %%
# transcription_results_lax.to_pickle('recog_proc_checkpoint.pkl')

# %% [markdown]
# ### hide

# %%
# with open('diagram_rec_corp.pkl', 'wb') as f:
#     pickle.dump(diagram_rec_corpus, f)

# %%
# strings_denoting_missing_image = list(pd.Series(flattened_noncon).value_counts()[:20].index)
# Image.open('../ai2-vision-textbook-dataset/diagrams/turk_data/optics_ray_diagrams_9170.png')

# %%
len(diagram_rec_corpus)
# Out:
# 4073

# %% [markdown]
# # Integrate diagram questions and descriptions

# %% [markdown]
# ## match diagram topics to lessons

# %% [markdown]
# first need to match diagram topics to flexbook lessons

# %% [markdown]
# ### code

# %%
def make_topic_matches(topic_list, combined_topics):
    topic_matches = {}
    for diagram_topic in topic_list:
        topic_matches[diagram_topic] = []
        for terms in topic_term_match[diagram_topic]:
            lev_dist_threshed = [topic for topic in combined_topics.keys() if fuzz.ratio(topic, terms) > 85]
            topic_matches[diagram_topic] += lev_dist_threshed
        if not topic_matches[diagram_topic]:
                for terms in topic_term_match[diagram_topic]:
                    lev_dist_threshed = [topic for topic in combined_topics.keys() if fuzz.token_set_ratio(topic, terms) > 80]
                    topic_matches[diagram_topic] += lev_dist_threshed
    return topic_matches

def make_lesson_matches(ck12_dataset, diagram_topic_name, topic_matches):
    lesson_matches = defaultdict(list)
    lessons_seen = set()
    content_topics =  topic_matches[diagram_topic_name]
    for topic in sorted(content_topics):
        associated_lesson =combined_topics[topic]['lesson']
        if associated_lesson not in lessons_seen:
            lessons_seen.add(associated_lesson)
            lesson_matches[diagram_topic_name].append(associated_lesson)
    return dict(lesson_matches)

# %% [markdown]
# ### run

# %% [markdown]
# The pruned directory is the tqa 0.91 set assmbled by Ani on Sept 27th. It should be treated as definitive

# %%
diagram_topic_list = clean_list(pruned_dir)

# %%
es_lesson_names = [item for sublist in [val['topics'].keys() for val in ck12_combined_dataset['earth-science'].values()] for item in sublist]
ps_lesson_names = [item for sublist in [val['topics'].keys() for val in ck12_combined_dataset['physical-science'].values()] for item in sublist]
ls_lesson_names = [item for sublist in [val['topics'].keys() for val in ck12_combined_dataset['life-science'].values()] for item in sublist]

combined_lessons = es_lesson_names + ps_lesson_names + ls_lesson_names
topic_series = pd.Series(combined_lessons).value_counts()
# the 17 here found by inspection- any "topic" appearing many times is something general like review, vocab, etc
topics_to_remove = list(topic_series[:16].index)

# %%
topics_to_remove
# Out:
# ['Summary',
#  'Review',
#  'Explore More',
#  'Lesson Summary',
#  'Lesson Objectives',
#  'Introduction',
#  'Points to Consider',
#  'Recall',
#  'Think Critically',
#  'Apply Concepts',
#  'Resources',
#  'Lesson Vocabulary',
#  'Vocabulary',
#  'Explore More II',
#  'Explore More I',
#  'Explore More III']

# %%
combined_topics = defaultdict(dict)
for subject, book in ck12_combined_dataset.items():
    for lesson, material in book.items():
        for topic, text in material['topics'].items():
            if topic in topics_to_remove:
                continue
            combined_topics[topic.lower()]['lesson'] = lesson

# %%
topic_matches = make_topic_matches(diagram_topic_list, combined_topics)
missing= []
for k, v in topic_matches.items():
    if not v:
        missing.append(k)

# %%
matching_lessons = {}
for topic in diagram_topic_list:
    matched_lessons = make_lesson_matches(ck12_combined_dataset, topic, topic_matches)
    matching_lessons.update(matched_lessons)

# %%
diagram_lesson_lookup = {}
for d_topic, lessons in matching_lessons.items():
    diagram_lesson_lookup[d_topic] = sorted(lessons)[0]

# %%
#manually correct name changes made since diagrams were assembled
diagram_lesson_lookup['lewis_dot_diagrams'] = diagram_lesson_lookup['lewis_dots']
diagram_lesson_lookup['optics_ray_diagrams'] = diagram_lesson_lookup['optics_rays']

# %%
# %page diagram_lesson_lookup

# %%
len(set(diagram_lesson_lookup.values()))
# Out:
# 85

# %%
diagram_lesson_lookup
# Out:
# {'acid_rain_formation': '22.2 Effects of Air Pollution',
#  'aquifers': '13.3 Groundwater',
#  'atomic_mass_number': '5.1 Inside the Atom',
#  'atomic_structure': '5.1 Inside the Atom',
#  'biomes': 'climate zones and biomes',
#  'blastocyst': '22.3 Reproduction and Life Stages',
#  'cell_division': '5.1 Cell Division',
#  'cellular_respiration': '9.4 Biochemical Reactions',
#  'chemical_bonding_covalent': '7.3 Covalent Bonds',
#  'chemical_bonding_ionic': '7.2 Ionic Bonds',
#  'circuits': '23.3 Electric Circuits',
#  'continental_drift': '6.2 Continental Drift',
#  'convection_of_air': '18.2 Transfer of Thermal Energy',
#  'cycle_carbon': '18.2 Cycles of Matter',
#  'cycle_nitrogen': '18.2 Cycles of Matter',
#  'cycle_rock': '4.1 Types of Rocks',
#  'cycle_water': '24.2 Cycles of Matter',
#  'dna': 'nucleic acid classification',
#  'earth_day_night': 'rotation of earth',
#  'earth_eclipses': 'eclipses',
#  'earth_magnetic_field': '24.2 Earth as a Magnet',
#  'earth_moon_phases': '24.4 The Sun and the EarthMoon System',
#  'earth_parts': '6.1 Inside Earth',
#  'earth_poles': 'revolutions of earth',
#  'electromagnetism': '25.2 Using Electromagnetism',
#  'em_spectrum': '21.3 The Electromagnetic Spectrum',
#  'erosion': '10.1 Erosion and Deposition by Flowing Water',
#  'eukaryotic_cell_cycles': '5.1 Cell Division',
#  'evaporation_and_sublimation': '4.3 Changes of State',
#  'faults': '7.1 Stress in Earths Crust',
#  'food_chains_webs': '24.1 Flow of Energy',
#  'fossils': '11.1 Fossils',
#  'fungi_reproduction': '9.2 Fungi',
#  'geologic_time': '7.4 History of Life on Earth',
#  'glaciers': '10.4 Erosion and Deposition by Glaciers',
#  'greenhouse_effect': 'greenhouse effect',
#  'hair_follicles': '16.2 The Integumentary System',
#  'human_system_circulatory': '18.1 Overview of the Cardiovascular System',
#  'human_system_digestive': '17.3 The Digestive System',
#  'human_system_ear': '20.2 The Senses',
#  'human_system_excretory': 'excretion',
#  'human_system_eye': 'vision and the eye',
#  'human_system_immune': '21.4 Immune System Defenses',
#  'human_system_muscular': '16.4 The Muscular System',
#  'human_system_nervous': '20.1 The Nervous System',
#  'human_system_reproductory': '22.1 Male Reproductive System',
#  'human_system_respiratory': '19.1 The Respiratory System',
#  'hydrocarbons': '9.2 Hydrocarbons',
#  'isotopes': '5.1 Inside the Atom',
#  'layers_of_atmosphere': '15.3 Layers of the Atmosphere',
#  'lewis_dot_diagrams': '7.1 Introduction to Chemical Bonds',
#  'lewis_dots': '7.1 Introduction to Chemical Bonds',
#  'life_cycles': '12.4 Insects and Other Arthropods',
#  'muscle_fiber': '16.4 The Muscular System',
#  'nuclear_energy': '11.3 Nuclear Energy',
#  'ocean_currents': 'surface ocean currents',
#  'ocean_waves': '14.2 Ocean Movements',
#  'ocean_zones': '14.1 Introduction to the Oceans',
#  'optics_lense_types': '22.2 Optics',
#  'optics_ray_diagrams': 'law of reflection',
#  'optics_rays': 'law of reflection',
#  'optics_reflection': 'law of reflection',
#  'optics_refraction': '22.2 Optics',
#  'ozone_formation': '22.1 Air Pollution',
#  'parts_cell': '3.2 Cell Structures',
#  'parts_chordate_body': '12.5 Echinoderms and Invertebrate Chordates',
#  'parts_fish': '13.2 Fish',
#  'parts_flower': '10.2 Evolution and Classification of Plants',
#  'parts_leaf': '10.1 Introduction to Plants',
#  'parts_microscope': '1.4 The Microscope',
#  'parts_neuron': '20.1 The Nervous System',
#  'parts_ocean_floor': '14.3 The Ocean Floor',
#  'parts_plant': '10.1 Introduction to Plants',
#  'parts_seed': '10.2 Evolution and Classification of Plants',
#  'parts_skeleton': '16.3 The Skeletal System',
#  'parts_telescope': '22.2 Optics',
#  'parts_worm': '12.2 Flatworms and Roundworms',
#  'periodic_table': '6.1 How Elements Are Organized',
#  'phagocytosis': '21.3 First Two Lines of Defense',
#  'photosynthesis': '4.2 Photosynthesis',
#  'protozoa': '9.1 Protists',
#  'radioactive_decay': 'radioactive decay as a measure of age',
#  'rain_shadow': '17.1 Climate and Its Causes',
#  'seafloor_spreading': '6.3 Seafloor Spreading',
#  'seasons': 'seasons',
#  'seismic_waves': '6.1 Inside Earth',
#  'simple_machines': '16.3 Simple Machines',
#  'skin_cross_section': '16.2 The Integumentary System',
#  'soil_horizons': '9.2 Soils',
#  'solar_system': '25.1 Introduction to the Solar System',
#  'state_change': '4.3 Changes of State',
#  'states_of_matter': '4.1 Solids Liquids Gases and Plasmas',
#  'stratigraphy': '11.2 Relative Ages of Rocks',
#  'sun_layers': '24.3 The Sun',
#  'tectonic_plates': '6.4 Theory of Plate Tectonics',
#  'tectonic_plates_motion': '6.4 Theory of Plate Tectonics',
#  'tides': '14.2 Ocean Movements',
#  'types_cells': 'cell biology',
#  'types_clouds': 'clouds',
#  'types_leaves': '10.1 Introduction to Plants',
#  'velocity_time_graphs': '12.3 Acceleration',
#  'volcanoes': '8.3 Types of Volcanoes',
#  'waves': '19.2 Measuring Waves',
#  'waves_interactions_interference': 'wave interference'}

# %%
# %page meta_lesson_id_lookup

# %%
meta_lesson_assignments
# Out:
# {'einsteins concept of gravity': 'concept',
#  'calculating acceleration from velocity and time': 'time',
#  'protons': 'proton',
#  'screw': 'screw',
#  'hypothesis': 'hypothesis',
#  'protists': 'protist',
#  'components of blood': 'component',
#  'refraction': 'refraction',
#  'development of hypotheses': 'development',
#  'atomic nucleus': 'nucleus',
#  'early space exploration': 'exploration',
#  'scientific graphing': 'scientific',
#  'the electromagnetic spectrum': 'spectrum',
#  'conservation of mass and energy in nuclear reactions': 'nuclear',
#  'cardiovascular system': 'cardiovascular',
#  'processes of breathing': 'process',
#  'musical instruments': 'instrument',
#  'properties of solutions': 'solution',
#  'muscles and exercise': 'muscle',
#  'electrons': 'electron',
#  'tornadoes': 'tornado',
#  'bathymetric evidence for seafloor spreading': 'seafloor',
#  'condensation': 'condensation',
#  'supervolcanoes': 'supervolcanoes',
#  'obtaining energy resources': 'resource',
#  'accuracy and precision': 'accuracy precision',
#  'population growth patterns': 'growth',
#  'wind power': 'wind',
#  'ionic bonds': 'ionic',
#  'electron cloud atomic model': 'cloud',
#  'mining and using minerals': 'mineral',
#  'social behavior of animals': 'behavior',
#  'physical change': 'physical',
#  'carbon bonding': 'bonding',
#  'correlation using relative ages': 'relative',
#  'elements': 'element',
#  'plant reproduction and life cycle': 'reproduction',
#  'bacteria reproduction': 'bacteria',
#  'evolution acts on the phenotype': 'evolution',
#  'salamanders': 'salamander',
#  'electric charge': 'charge',
#  'flatworms': 'flatworm',
#  'tropisms': 'tropism',
#  'lens': 'lens',
#  'predicting earthquakes': 'earthquake',
#  'agriculture and human population growth': 'agriculture',
#  'world climates': 'climate',
#  'elastic force': 'elastic',
#  'air masses': 'mass',
#  'nuclear energy': 'nuclear',
#  'heat': 'heat',
#  'long term climate change': 'term',
#  'using electromagnetism': 'electromagnetism',
#  'human egg cells': 'cell',
#  'nature of earthquakes': 'nature',
#  'velocity time graphs': 'graph',
#  'introduction to groundwater': 'groundwater',
#  'measuring and predicting earthquakes': 'earthquake',
#  'scientific experiments': 'experiment',
#  'soil horizons and profiles': 'soil',
#  'echinoderms': 'echinoderm',
#  'divergent plate boundaries in the oceans': 'divergent',
#  'neutrons': 'neutron',
#  'formation of minerals': 'formation',
#  'momentum': 'momentum',
#  'distance and direction': 'distance',
#  'groups with metalloids': 'metalloids',
#  'venus': 'venus',
#  'acceleration': 'acceleration',
#  'landforms from erosion and deposition by gravity': 'landforms',
#  'mollusks and annelids': 'mollusk',
#  'respiratory system organs': 'organ',
#  'nature of science': 'nature',
#  'introduction to earths surface': 'surface',
#  'sources of visible light': 'visible',
#  'classification of living things': 'thing',
#  'energy conversion': 'energy conversion',
#  'human causes of extinction': 'cause',
#  'calculating acceleration from force and mass': 'acceleration',
#  'wedge': 'wedge',
#  'air quality': 'air',
#  'forms of energy': 'form',
#  'scientific measuring devices': 'device',
#  'topographic maps': 'map',
#  'protecting the water supply': 'supply',
#  'formation of earth': 'formation',
#  'preventing noninfectious diseases': 'noninfectious',
#  'types of animal behavior': 'behavior',
#  'testing hypotheses': 'hypothesis',
#  'geothermal power': 'geothermal',
#  'cellular respiration reactions': 'cellular',
#  'energy resources': 'resource',
#  'isomers': 'isomer',
#  'soils': 'soil',
#  'saturated hydrocarbons': 'hydrocarbon',
#  'fungi': 'fungi',
#  'introduction to the human body': 'body',
#  'rocks': 'rock',
#  'non renewable energy resources': 'non',
#  'types of rocks': 'rock',
#  'succession': 'succession',
#  'collecting weather data': 'weather',
#  'birds': 'bird',
#  'layers of the atmosphere': 'layer',
#  'daltons atomic theory': 'theory',
#  'effect of continental position on climate': 'position',
#  'humans and the water supply': 'supply',
#  'mollusks': 'mollusk',
#  'heat conduction': 'heat',
#  'wegener and the continental drift hypothesis': 'drift',
#  'introduction to the oceans': 'ocean',
#  'carbon and living things': 'thing',
#  'buoyancy': 'buoyancy',
#  'skin': 'skin',
#  'predicting volcanic eruptions': 'volcanic',
#  'energy pyramids': 'energy pyramid',
#  'blood': 'blood',
#  'cell cycle': 'cycle',
#  'mechanical advantage': 'mechanical',
#  'distance between stars': 'distance',
#  'air movement': 'movement',
#  'circulation and the lymphatic system': 'lymphatic',
#  'characteristics of waves': 'characteristic',
#  'development of theories': 'development',
#  'types of matter': 'matter',
#  'planet earth': 'planet',
#  'compound machine': 'machine',
#  'using thermal energy': 'thermal',
#  'safety of water': 'safety',
#  'mendeleevs periodic table': 'table',
#  'dna structure and replication': 'replication',
#  'heat transfer in the atmosphere': 'transfer',
#  'materials humans use': 'material',
#  'inside earth': 'earth',
#  'earths interior material': 'interior',
#  'types of friction': 'friction',
#  'what are biomes': 'biome',
#  'history of earths life forms': 'form',
#  'earth history and clues from fossils': 'fossil',
#  'blood diseases': 'blood',
#  'loss of soil': 'loss',
#  'inertia': 'inertia',
#  'energy in the atmosphere': 'atmosphere',
#  'effects of water pollution': 'effect',
#  'vision': 'vision',
#  'vertebrate characteristics': 'vertebrate',
#  'surface water': 'surface',
#  'the universe': 'universe',
#  'electronic signal': 'electronic',
#  'asexual vs. sexual reproduction': 'reproduction',
#  'electronic device': 'device',
#  'flow of matter in ecosystems': 'flow',
#  'hydrogen and alkali metals': 'hydrogen',
#  'minerals': 'mineral',
#  'non infectious reproductive system disorders': 'infectious',
#  'lizards and snakes': 'lizard snake',
#  'kinetic theory of matter': 'kinetic',
#  'discovery of electromagnetism': 'discovery',
#  'natural resources': 'natural',
#  'cardiovascular system health': 'cardiovascular',
#  'scientific ways of thinking': 'way',
#  'location and direction': 'direction',
#  'age of earth': 'age',
#  'liquids': 'liquid',
#  'democrituss idea of the atom': 'atom',
#  'what is ecology': 'ecology',
#  'alkaline earth metals': 'metal',
#  'mendels laws and genetics': 'mendel',
#  'seeds and seed dispersal': 'seed',
#  'air pollution': 'air',
#  'alloys': 'alloy',
#  'states of water': 'state',
#  'measuring earthquake magnitude': 'magnitude',
#  'communication in science': 'communication',
#  'electric current': 'current',
#  'archaea': 'archaea',
#  'tree rings ice cores and varves': 'core',
#  'inner planets': 'inner',
#  'outer planets': 'outer',
#  'metamorphic rocks': 'metamorphic',
#  'weather versus climate': 'weather',
#  'volcanic landforms': 'volcanic',
#  'sublimation': 'sublimation',
#  'darwins theory of evolution': 'darwin',
#  'nature of technology': 'nature',
#  'mass extinctions': 'extinction',
#  'nerve cells and nerve impulses': 'nerve',
#  'density': 'density',
#  'rna': 'rna',
#  'history of the atom': 'atom',
#  'food webs': 'food',
#  'cartilaginous fish': 'fish',
#  'acceleration due to gravity': 'acceleration',
#  'activation energy': 'activation energy',
#  'competition': 'competition',
#  'reptiles': 'reptile',
#  'innate behavior of animals': 'behavior',
#  'origins of life': 'origin',
#  'importance of the oceans': 'ocean',
#  'intensity and loudness of sound': 'sound',
#  'microwaves': 'microwave',
#  'importance of seedless plants': 'seedless',
#  'ions': 'ion',
#  'chemical and solar cells': 'solar',
#  'radioactivity': 'radioactivity',
#  'energy from biomass': 'energy biomass',
#  'respiration': 'respiration',
#  'reduce reuse and recycle': 'reuse recycle',
#  'types of mollusks': 'mollusk',
#  'amphibians': 'amphibian',
#  'the scientific method': 'method',
#  'metals': 'metal',
#  'nuclear power': 'nuclear',
#  'electricity and magnetism': 'magnetism',
#  'earthquake zones': 'zone',
#  'crustaceans': 'crustacean',
#  'human vision': 'vision',
#  'mineral groups': 'group',
#  'primates': 'primate',
#  'law of reflection': 'law',
#  'big bang': 'big bang',
#  'causes of air pollution': 'cause',
#  'molecular evidence for evolution': 'molecular',
#  'reproductive behavior of animals': 'behavior',
#  'evolution of simple cells': 'simple',
#  'plant cell structures': 'structure',
#  'vascular seedless plants': 'seedless',
#  'noble gases': 'gas',
#  'scope of physical science': 'scope',
#  'distance': 'distance',
#  'science skills': 'science skill',
#  'effects of air pollution on human health': 'health',
#  'nonmetals': 'nonmetal',
#  'satellites shuttles and space stations': 'satellite',
#  'thomsons atomic model': 'model',
#  'heart': 'heart',
#  'nuclear fusion': 'nuclear',
#  'cycles of matter': 'matter',
#  'hearing and balance': 'balance',
#  'electric conductors and insulators': 'insulator',
#  'dna the genetic material': 'genetic',
#  'importance of mollusks': 'mollusk',
#  'deposition': 'deposition',
#  'hearing sound': 'sound',
#  'law of conservation of momentum': 'momentum',
#  'human genome project': 'human',
#  'diversity of birds': 'bird',
#  'inflammatory response': 'response',
#  'mountain building': 'building',
#  'natural selection': 'natural',
#  'keeping the nervous system healthy': 'healthy',
#  'earths shape': 'earth shape',
#  'first two lines of defense': 'defense',
#  'other objects in the solar system': 'solar',
#  'speed of sound': 'speed',
#  'cleaning up groundwater': 'groundwater',
#  'characteristics of living organisms': 'organism',
#  'dark matter': 'matter',
#  'scope of physics': 'scope',
#  'how ocean currents moderate climate': 'current',
#  'electric generators': 'electric',
#  'wave interactions and interference': 'interference',
#  'enzymes in the digestive system': 'enzyme',
#  'buoyancy of fluids': 'buoyancy',
#  'electronic component': 'component',
#  'technological design process': 'design',
#  'temperature of the atmosphere': 'temperature',
#  'heating systems': 'heating system',
#  'mid latitude cyclones': 'latitude',
#  'light': 'light',
#  'safety in life science research': 'safety',
#  'biodiversity and extinction': 'biodiversity',
#  'health of the digestive system': 'digestive',
#  'ocean garbage patch': 'ocean',
#  'protein synthesis and gene expression': 'gene',
#  'properties of bases': 'base',
#  'pascals law': 'law',
#  'symbiosis': 'symbiosis',
#  'solids': 'solid',
#  'classes of elements': 'element',
#  'observation': 'observation',
#  'volcanoes at hotspots': 'volcano',
#  'types of echinoderms': 'echinoderm',
#  'impact of continued global warming': 'warming',
#  'seasonal changes in plants': 'change',
#  'genetic disorders': 'genetic',
#  'mineral identification': 'identification',
#  'how fossilization creates fossils': 'fossilization',
#  'the digestive system': 'digestive',
#  'earth as a magnet': 'magnet',
#  'solute and solvent': 'solute solvent',
#  'clouds': 'cloud',
#  'friction': 'friction',
#  'relative ages of rocks': 'relative',
#  'transcription of dna to rna': 'rna',
#  'intrusive and extrusive igneous rocks': 'igneous',
#  'wavelength': 'wavelength',
#  'the scale of evolution': 'scale',
#  'hearing loss': 'loss',
#  'male reproductive system': 'male',
#  'formation of the sun and planets': 'sun',
#  'introduction to prokaryotes': 'introduction',
#  'coastal pollution': 'coastal pollution',
#  'safety in the life sciences': 'safety',
#  'reproduction and life stages': 'reproduction',
#  'communities': 'community',
#  'history of life on earth': 'history',
#  'scientific investigation': 'investigation',
#  'igneous rocks': 'igneous',
#  'chemical bonding': 'bonding',
#  'pregnancy and childbirth': 'pregnancy childbirth',
#  'atoms': 'atom',
#  'introduction to ecology': 'ecology',
#  'determining relative ages': 'relative',
#  'scientific method': 'method',
#  'chemical reactions and energy': 'chemical',
#  'bacteria in the digestive system': 'digestive',
#  'paleozoic and mesozoic seas': 'paleozoic',
#  'humans and primates': 'primate',
#  'cooling systems': 'system',
#  'producers': 'producer',
#  'chemistry of compounds': 'chemistry',
#  'organelles': 'organelle',
#  'igneous landforms and geothermal activ': 'geothermal',
#  'boyles law': 'law',
#  'ocean zones': 'zone',
#  'ecosystems': 'ecosystem',
#  'cell transport': 'transport',
#  'weather maps': 'map',
#  'observations and experiments': 'observation',
#  'polygenic traits': 'polygenic trait',
#  'rotation of earth': 'rotation earth',
#  'male reproductive structures': 'male',
#  'principles of relative dating': 'principle',
#  'groundwater depletion': 'depletion',
#  'early earth': 'early',
#  'climate change in earth history': 'history',
#  'effusive eruptions': 'eruption',
#  'adaptation and evolution of populations': 'adaptation',
#  'fungi classification': 'fungi',
#  'precipitation': 'precipitation',
#  'climate and its causes': 'cause',
#  'invertebrates': 'invertebrate',
#  'types of air pollution': 'air',
#  'the hertzsprung russell diagra': 'hertzsprung russell diagra',
#  'what is force': 'force',
#  'technology and society': 'technology',
#  'magnets': 'magnet',
#  'exothermic reactions': 'exothermic reaction',
#  'surface wave': 'surface',
#  'introduction to chemical bonds': 'bond',
#  'boiling': 'aaa_none',
#  'female reproductive system': 'female',
#  'types of soils': 'soil',
#  'the carbon cycle': 'carbon',
#  'mixtures': 'mixture',
#  'carbon monomers and polymers': 'carbon',
#  'solar power': 'solar',
#  'combustion reactions': 'combustion',
#  'centipedes and millipedes': 'centipede millipede',
#  'atomic number': 'atomic',
#  'cloning': 'aaa_none',
#  'plasma': 'plasma',
#  'paleozoic plate tectonics': 'paleozoic',
#  'characteristics and origins of life': 'origin',
#  'protein classification': 'protein',
#  'the sun and the earthmoon system': 'sun',
#  'chemical reaction overview': 'overview',
#  'ultrasound': 'ultrasound',
#  'sponges and cnidarians': 'sponge',
#  'formation of the moon': 'moon',
#  'water distribution': 'distribution',
#  'climate zones and biomes': 'biome',
#  'locating earthquake epicenters': 'earthquake',
#  'uses of water': 'water',
#  'stratosphere': 'stratosphere',
#  'sexually transmitted infections': 'sexually infection',
#  'star power': 'star',
#  'turtles': 'turtle',
#  'moon': 'moon',
#  'electric fields': 'field',
#  'amontonss law': 'law',
#  'environmental impacts of mining': 'mining',
#  'efficiency': 'efficiency',
#  'human digestive system': 'digestive',
#  'climate change': 'change',
#  'gamma rays': 'gamma',
#  'photosynthesis reactions': 'photosynthesis',
#  'groundwater aquifers': 'groundwater',
#  'menstrual cycle': 'cycle',
#  'segmented worms': 'worm',
#  'electromagnetic induction': 'induction',
#  'covalent bonds': 'covalent',
#  'unsaturated hydrocarbons': 'hydrocarbon',
#  'magnetic evidence for seafloor spreading': 'seafloor',
#  'cnidarians': 'cnidarian',
#  'uranus': 'uranus',
#  'importance of birds': 'bird',
#  'human sperm': 'human',
#  'plant hormones': 'plant',
#  'advances in genetics': 'genetics',
#  'energy use': 'use',
#  'growth of human populations': 'growth',
#  'stars': 'star',
#  'natural resource conservation': 'natural',
#  'what are animals': 'animal',
#  'direction': 'direction',
#  'levels of ecological organization': 'level',
#  'coal power': 'power',
#  'thermal conductors and insulators': 'conductor',
#  'plant like protists': 'protist',
#  'fresh water ecosystems': 'ecosystem',
#  'internal combustion engines': 'engine',
#  'color': 'color',
#  'seawater chemistry': 'chemistry',
#  'central nervous system': 'nervous',
#  'earthquake safe structures': 'safe',
#  'the nature of science': 'nature',
#  'evolution and classification of plants': 'evolution',
#  'peripheral nervous system': 'nervous',
#  'mammal reproduction': 'mammal',
#  'staying safe in an earthquake': 'safe',
#  'surface ocean currents': 'surface',
#  'transition metals': 'metal',
#  'chemical bond': 'bond',
#  'viruses': 'virus',
#  'solubility and concentration': 'solubility',
#  'introduction to chemical reactions': 'introduction',
#  'reducing ozone destruction': 'destruction',
#  'plants adaptations for life on land': 'land',
#  'extinction and radiation of life': 'radiation',
#  'plate tectonics through earth history': 'tectonics',
#  'wave interactions': 'interaction',
#  'how elements are organized': 'element',
#  'harmful bacteria': 'bacteria',
#  'blood types': 'blood',
#  'mammals': 'mammal',
#  'the origin of earth': 'origin',
#  'earths mantle': 'earth mantle',
#  'scales that represent earthquake magnitude': 'magnitude',
#  'barriers to pathogens': 'pathogen',
#  'overview of the cardiovascular system': 'overview',
#  'chemical weathering': 'weathering',
#  'the light we see': 'light',
#  'saturation': 'saturation',
#  'lithification of sedimentary rocks': 'sedimentary',
#  'impacts of hazardous waste': 'waste',
#  'muscles bones and movement': 'muscle',
#  'deep ocean currents': 'current',
#  'nervous system': 'nervous',
#  'protist characteristics': 'protist',
#  'surface features of the sun': 'feature',
#  'ionic compounds': 'ionic',
#  'universe': 'universe',
#  'dangers and uses of radiation': 'radiation',
#  'energy level': 'level',
#  'keeping skin healthy': 'skin',
#  'artificial light': 'light',
#  'how animals evolved': 'animal',
#  'branches of earth science': 'branch',
#  'optics': 'optic',
#  'diseases of the nervous system': 'nervous',
#  'cellular respiration': 'cellular',
#  'calculating derived quantities': 'quantity',
#  'seismic waves': 'seismic wave',
#  'behavior of gases': 'gas',
#  'the nervous system': 'nervous',
#  'earths core': 'core',
#  'acids and bases': 'base',
#  'metallic bonding': 'metallic',
#  'inner vs. outer planets': 'outer',
#  'wind waves': 'wind',
#  'newtons law of gravity': 'newton',
#  'natural gas power': 'natural',
#  'external combustion engines': 'engine',
#  'intraplate activity': 'intraplate',
#  'insects and other arthropods': 'arthropod',
#  'arthropods': 'arthropod',
#  'water pollution': 'water pollution',
#  'gases': 'gas',
#  'measuring waves': 'wave',
#  'mendels pea plants': 'mendel',
#  'conservation of mass': 'mass',
#  'weather fronts': 'weather',
#  'technology and science': 'technology',
#  'biomes': 'biome',
#  'frequency and pitch of sound': 'frequency',
#  'dwarf planets': 'planet',
#  'optical instruments': 'instrument',
#  'properties of electromagnetic waves': 'electromagnetic',
#  'newtons second law': 'second',
#  'earths tectonic plates': 'plate',
#  'prokaryotic and eukaryotic cells': 'cell',
#  'earthquake characteristics': 'characteristic',
#  'sound waves': 'sound',
#  'the muscular system': 'muscular system',
#  'solutions': 'solution',
#  'bird reproduction': 'bird',
#  'greenhouse effect': 'effect',
#  'insects': 'insect',
#  'cell biology': 'cell',
#  'ph concept': 'concept',
#  'identification of minerals': 'identification',
#  'halogens': 'halogen',
#  'atomic forces': 'atomic',
#  'chemistry of living things': 'thing',
#  'habitat destruction': 'destruction',
#  'speed': 'speed',
#  'arachnids': 'arachnid',
#  'scientific theory': 'theory',
#  'tides': 'tide',
#  'types of archaea': 'archaea',
#  'convection': 'convection',
#  'chemical properties of matter': 'property',
#  'comets': 'comet',
#  'erosion and deposition by flowing water': 'erosion',
#  'the atmosphere': 'atmosphere',
#  'soil erosion': 'soil',
#  'volcanoes at plate boundaries': 'boundary',
#  'recombinant dna': 'dna',
#  'ionic bonding': 'ionic',
#  'weathering': 'aaa_none',
#  'jawless fish': 'fish',
#  'cardiovascular diseases': 'cardiovascular',
#  'planet orbits in the solar system': 'solar',
#  'faults': 'fault',
#  'endothermic reactions': 'endothermic reaction',
#  'seafloor spreading': 'seafloor',
#  'interior of the sun': 'interior',
#  'decomposition reactions': 'decomposition reaction',
#  'changes of state': 'state',
#  'power': 'power',
#  'b and t cell response': 'response',
#  'short term climate change': 'term',
#  'radiometric dating': 'radiometric',
#  'electrical grid': 'electrical',
#  'hydrogen bonding': 'hydrogen',
#  'groundwater pollution': 'groundwater',
#  'history of mesozoic life': 'mesozoic',
#  'mitosis vs. meiosis': 'mitosis',
#  'covalent bonding': 'covalent',
#  'direct and alternating current': 'current',
#  'erosion and deposition by gravity': 'gravity',
#  'using satellites and computers': 'satellite',
#  'photosynthesis': 'photosynthesis',
#  'local winds': 'wind',
#  'simple machines': 'simple',
#  'bacteria characteristics': 'bacteria',
#  'reproduction in seedless plants': 'seedless',
#  'electric transformers': 'electric',
#  'enzymes as catalysts': 'catalyst',
#  'introduction to solutions': 'solution',
#  'overpopulation and over consumption': 'overpopulation consumption',
#  'nails and hair': 'nail hair',
#  'projectile motion': 'motion',
#  'rate of dissolving': 'rate',
#  'chemical reaction rate': 'rate',
#  'skeletal system joints': 'joint',
#  'weather and water in the atmosphere': 'weather',
#  'modern periodic table': 'table',
#  'glaciers': 'glacier',
#  'asteroids': 'asteroid',
#  'ocean life': 'ocean',
#  'vision and the eye': 'eye',
#  'mechanical weathering': 'weathering',
#  'the scope of physical science': 'scope',
#  'visible light and matter': 'visible',
#  'radioisotopes': 'radioisotope',
#  'exoplanets': 'exoplanets',
#  'why earth is a magnet': 'magnet',
#  'use and conservation of energy': 'use',
#  'modern atomic theory': 'modern',
#  'keeping bones and joints healthy': 'joint',
#  'electric charge and electric force': 'charge',
#  'the skeletal system': 'skeletal',
#  'carbohydrate classification': 'classification',
#  'safety in science': 'safety',
#  'saturn': 'saturn',
#  'biochemical reaction chemistry': 'biochemical',
#  'ocean ecosystems': 'ecosystem',
#  'protists nutrition': 'nutrition',
#  'earths energy': 'earth energy',
#  'nonrenewable resources': 'nonrenewable',
#  'chemical formula': 'chemical',
#  'machines': 'machine',
#  'nuclear fission': 'nuclear',
#  'heat budget of planet earth': 'heat',
#  'biochemical compound classification': 'biochemical',
#  'mineral formation': 'formation',
#  'health hazards of air pollution': 'health',
#  'fossils': 'fossil',
#  'hiv and aids': 'hiv aid',
#  'electric circuits': 'circuit',
#  'biotechnology in agriculture': 'agriculture',
#  'lymphatic system': 'lymphatic',
#  'pressure of fluids': 'fluid',
#  'female reproductive structures': 'female',
#  'urinary system': 'urinary system',
#  'weather forecasting': 'weather',
#  'doppler effect': 'effect',
#  'modeling earths surface': 'surface',
#  'influences on weathering': 'influence',
#  'ocean movements': 'movement',
#  'earths moon': 'moon',
#  'temperature and heat in the atmosphere': 'temperature',
#  'hazardous waste': 'waste',
#  'magnetic field reversal': 'magnetic',
#  'heat waves and droughts': 'heat',
#  'changing weather': 'weather',
#  'scientific modeling': 'scientific',
#  'mutations': 'mutation',
#  'using earths magnetic field': 'magnetic',
#  'thermal energy': 'thermal',
#  'injuries of the nervous system': 'nervous',
#  'chemical equations': 'equation',
#  'conserving water': 'water',
#  'electromagnetic spectrum': 'spectrum',
#  'animal like protists': 'protist',
#  'renewable resources and alternative energy sources': 'renewable',
#  'principle of uniformitarianism': 'principle',
#  'ohms law': 'law',
#  'radioactive decay': 'radioactive',
#  'immunity': 'immunity',
#  'using sound': 'sound',
#  'microevolution and macroevolution': 'microevolution macroevolution',
#  'puberty and adolescence': 'puberty adolescence',
#  'introduction to genetics': 'genetics',
#  'origin of species': 'origin',
#  'reactants and products': 'reactant product',
#  'mirrors': 'mirror',
#  'preserving water sources': 'source',
#  'thermal radiation': 'radiation',
#  'solubility': 'solubility',
#  'troposphere': 'troposphere',
#  'predation': 'predation',
#  'specific heat': 'heat',
#  'fermentation': 'fermentation',
#  'stress in earths crust': 'crust',
#  'history of paleozoic life': 'paleozoic',
#  'potential energy': 'potential energy',
#  'preventing infectious diseases': 'infectious',
#  'effects of air pollution': 'effect',
#  'bernoullis law': 'law',
#  'earths crust': 'crust',
#  'principle of horizontality': 'principle',
#  'lipid classification': 'classification',
#  'use and conservation of resources': 'use',
#  'soil formation': 'formation',
#  'punnett squares': 'punnett',
#  'volcanic eruptions': 'volcanic',
#  'kidneys': 'kidney',
#  'electromagnetic energy in the atmosphere': 'electromagnetic',
#  'metallic bonds': 'metallic',
#  'expansion of the universe': 'universe',
#  'folds': 'fold',
#  'human skeletal system': 'skeletal',
#  'preventing hazardous waste problems': 'waste',
#  'limiting factors to population growth': 'growth',
#  'mesozoic plate tectonics': 'mesozoic',
#  'plant responses and special adaptations': 'response',
#  'mitosis and cytokinesis': 'mitosis',
#  'finding and mining ores': 'mining',
#  'star classification': 'star',
#  'the sun': 'sun',
#  'fish': 'fish',
#  'erosion and deposition by wind': 'wind',
#  'ethics in science': 'ethic science',
#  'eclipses': 'eclipse',
#  'energy': 'energy',
#  'importance of the atmosphere': 'importance',
#  'ponds and lakes': 'pond lake',
#  'history of science': 'history',
#  'the endocrine system': 'endocrine system',
#  'diabetes': 'diabetes',
#  'non mendelian inheritance': 'inheritance',
#  'food and nutrients': 'nutrient',
#  'earths magnetic field': 'magnetic',
#  'scientific induction': 'induction',
#  'organization of the human body': 'body',
#  'significant figures': 'significant figure',
#  'respiratory system health': 'respiratory',
#  'active transport': 'transport',
#  'maps': 'map',
#  'introduction to the solar system': 'solar',
#  'connecting cellular respiration and photosynthesis': 'cellular',
#  'predicting weather': 'weather',
#  'autoimmune diseases': 'disease',
#  'animal behaviors': 'behavior',
#  'vision correction': 'vision',
#  'gravity': 'gravity',
#  'echinoderms and invertebrate chordates': 'invertebrate',
#  'groundwater': 'groundwater',
#  'kinetic energy': 'kinetic',
#  'wave interference': 'interference',
#  'organization of living things': 'organization',
#  'bohrs atomic model': 'model',
#  'roundworms': 'roundworm',
#  'technology': 'technology',
#  'the respiratory system': 'respiratory',
#  'fertilization': 'fertilization',
#  'modern biodiversity': 'biodiversity',
#  'divergent plate boundaries': 'divergent',
#  'acid rain': 'acid',
#  'electric resistance': 'electric',
#  'noninfectious diseases': 'noninfectious',
#  'light reactions of photosynthesis': 'photosynthesis',
#  'global warming': 'warming',
#  'structural evidence for evolution': 'evidence',
#  'hurricanes': 'hurricane',
#  'newtons third law': 'third',
#  'wheel and axle': 'wheel axle',
#  'fungi structure': 'fungi',
#  'blood pressure': 'pressure',
#  'flow of energy': 'flow',
#  'introduction to plants': 'introduction',
#  'flatworms and roundworms': 'roundworm',
#  'cell division': 'division',
#  'electronics': 'electronics',
#  'importance of mammals': 'mammal',
#  'crystalline carbon': 'carbon',
#  'recent space exploration': 'exploration',
#  'role of amphibians': 'role',
#  'population size': 'population',
#  'nitrogen cycle in ecosystems': 'nitrogen',
#  'electromagnet': 'electromagnet',
#  'mars': 'mar',
#  'domains of life': 'domain life',
#  'electric power and electrical energy use': 'electrical',
#  'biological communities': 'community',
#  'volcanic activity': 'activity',
#  'temperature and heat': 'temperature',
#  'types of nutrients': 'nutrient',
#  'soil characteristics': 'soil',
#  'weathering and erosion': 'erosion',
#  'scientific explanations and interpretations': 'scientific',
#  'landforms from groundwater erosion and deposition': 'landforms',
#  'states of matter': 'state',
#  'availability of natural resources': 'natural',
#  'scientific theories': 'theory',
#  'types of energy': 'type',
#  'scientific community': 'community',
#  'oceanic pressure': 'pressure',
#  'importance of echinoderms': 'echinoderm',
#  'metabolism and replication': 'replication',
#  'excretion': 'excretion',
#  'solenoid': 'solenoid',
#  'erosion and deposition by waves': 'erosion',
#  'sedimentary rocks': 'sedimentary',
#  'cell membrane': 'cell',
#  'the integumentary system': 'integumentary system',
#  'air pressure and altitude': 'pressure',
#  'sustainable development': 'development',
#  'fungi reproduction': 'fungi',
#  'adulthood and aging': 'adulthood',
#  'replacement reactions': 'replacement reaction',
#  'protein synthesis': 'synthesis',
#  'the biosphere': 'biosphere',
#  'solar energy on earth': 'solar',
#  'work': 'work',
#  'types of marine organisms': 'organism',
#  'insect reproduction and life cycle': 'insect',
#  'earth science and its branches': 'branch',
#  'control of insects': 'insect',
#  'properties of acids': 'acid',
#  'homeostasis': 'homeostasis',
#  'gravity in the solar system': 'gravity',
#  'earthquakes at transform plate boundaries': 'transform',
#  'bacteria': 'bacteria',
#  'fossil fuel formation': 'fuel',
#  'ferromagnetic material': 'material',
#  'how the eye works': 'eye',
#  'heart and blood vessels': 'heart',
#  'nonrenewable energy resources': 'nonrenewable',
#  'protecting water from pollution': 'water pollution',
#  'galaxies': 'galaxy',
#  'force': 'force',
#  'transform plate boundaries': 'transform',
#  'scientific models': 'model',
#  'changes in matter': 'change',
#  'pressure in fluids': 'fluid',
#  'vision problems and corrective lenses': 'lens',
#  'avoiding soil loss': 'loss',
#  'neptune': 'neptune',
#  'mammal characteristics': 'mammal',
#  'wave amplitude': 'wave amplitude',
#  'effects of air pollution on the environment': 'effect',
#  'beta decay': 'decay',
#  'compounds': 'compound',
#  'radio waves': 'radio wave',
#  'electric safety': 'safety',
#  'habitat and niche': 'habitat',
#  'mammal classification': 'mammal',
#  'choosing healthy foods': 'healthy',
#  'infectious diseases': 'infectious',
#  'scientific law': 'scientific',
#  'cell structures': 'structure',
#  'what is science': 'science',
#  'technological design constraints': 'design',
#  'evaporation': 'evaporation',
#  'process of cellular respiration': 'cellular',
#  'cyclic behavior of animals': 'behavior',
#  'what is life science': 'life science',
#  'sex linked inheritance': 'inheritance',
#  'tsunami': 'tsunami',
#  'conservation of mass in chemical reactions': 'mass',
#  'groups of elements': 'group',
#  'importance of insects': 'insect',
#  'jupiter': 'jupiter',
#  'field study': 'field',
#  'water on earth': 'water earth',
#  'mercury': 'mercury',
#  'synthesis reactions': 'synthesis',
#  'chordates': 'chordate',
#  'staying safe in earthquakes': 'safe',
#  'pulley': 'pulley',
#  'transverse wave': 'transverse wave',
#  'lever': 'lever',
#  'international system of units': 'international system unit',
#  'isotopes': 'isotope',
#  'electromagnetic waves': 'electromagnetic',
#  'indoor air pollution': 'air',
#  'milky way': 'way',
#  'types of volcanoes': 'volcano',
#  'characteristics of life': 'characteristic',
#  'inside the atom': 'atom',
#  'compound machines': 'machine',
#  'alligators and crocodiles': 'alligator crocodile',
#  'telescopes': 'telescope',
#  'the history of astronom': 'history',
#  'the water cycle': 'cycle',
#  'nonvascular plants': 'plant',
#  'cenozoic plate tectonics': 'cenozoic',
#  'bond polarity': 'polarity',
#  'generating and using electricity': 'electricity',
#  'longitudinal wave': 'longitudinal wave',
#  'processes of the water cycle': 'process',
#  'scope of chemistry': 'scope',
#  'chemical change': 'change',
#  'introduction to vertebrates': 'vertebrate',
#  'transfer of thermal energy': 'transfer',
#  'helpful bacteria': 'bacteria',
#  'mercury pollution': 'mercury',
#  'metamorphic rock classification': 'metamorphic',
#  'static electricity and static discharge': 'static',
#  'continental drift': 'drift',
#  'angiosperms': 'angiosperm',
#  'newtons first law': 'first',
#  'magnets and magnetism': 'magnetism',
#  'immune system defenses': 'defense',
#  'taste and smell': 'taste smell',
#  'acid base neutralization': 'base',
#  'freezing': 'aaa_none',
#  'descriptive statistics': 'descriptive statistic',
#  'fundamental particles': 'particle',
#  'temperature': 'temperature',
#  'velocity': 'velocity',
#  'charless law': 'law',
#  'theory of plate tectonics': 'tectonics',
#  'mechanical wave': 'mechanical',
#  'importance of reptiles': 'reptile',
#  'earths layers': 'layer',
#  'thermosphere and beyond': 'thermosphere',
#  'blood vessels': 'vessel',
#  'motion': 'motion',
#  'cancer': 'cancer',
#  'the nitrogen cycle': 'nitrogen',
#  'lifes building blocks': 'building',
#  'characteristics of sound': 'sound',
#  'types of fossilization': 'fossilization',
#  'timeline of evolution': 'evolution',
#  'scientific process': 'process',
#  'century tsunami': 'tsunami',
#  'ozone depletion': 'ozone',
#  'basic and applied science': 'basic science',
#  'reproductive system health': 'health',
#  'gene therapy': 'gene',
#  'gymnosperms': 'gymnosperm',
#  'oil spills': 'oil spill',
#  'global wind belts': 'global',
#  'electromagnetism': 'electromagnetism',
#  'aquatic biomes': 'biome',
#  'influences on darwin': 'darwin',
#  'terrestrial biomes': 'biome',
#  'ecosystem change': 'ecosystem',
#  'properties of matter': 'property',
#  'balancing chemical equations': 'equation',
#  'wave speed': 'speed',
#  'the senses': 'sens',
#  'reproduction': 'reproduction',
#  'importance of protists': 'protist',
#  'alpha decay': 'decay',
#  'precambrian plate tectonics': 'precambrian',
#  'respiratory system diseases': 'respiratory',
#  'transfer of electric charge': 'charge',
#  'wave frequency': 'frequency',
#  'types of chemical reactions': 'type',
#  'hardy weinberg theorem': 'hardy weinberg theorem',
#  'pollution of the land': 'land',
#  'pathogens': 'pathogen',
#  'mendels discoveries': 'discovery',
#  'energy conservation': 'conservation',
#  'pressure and density of the atmosphere': 'density',
#  'landforms from glacial erosion and deposition': 'landforms',
#  'the excretory system': 'excretory',
#  'petroleum power': 'power',
#  'conservation of energy in chemical reactions': 'conservation',
#  'radioactive decay as a measure of age': 'radioactive',
#  'streams and rivers': 'stream river',
#  'bacteria nutrition': 'nutrition',
#  'explosive eruptions': 'eruption',
#  'importance of arthropods': 'arthropod',
#  'renewable energy resources': 'renewable',
#  'planets of the solar system': 'solar',
#  'populations': 'population',
#  'geologic time scale': 'scale',
#  'bony fish': 'fish',
#  'absolute ages of rocks': 'age',
#  'outdoor air pollution': 'air',
#  'nucleic acid classification': 'acid',
#  'chromosomal disorders': 'disorder',
#  'gamma decay': 'gamma',
#  'earthquakes at convergent plate boundaries': 'boundary',
#  'learned behavior of animals': 'behavior',
#  'human population': 'population',
#  'reducing air pollution': 'air',
#  'position time graphs': 'position',
#  'volcano characteristics': 'volcano',
#  'archimedes law': 'law',
#  'meiosis': 'meiosis',
#  'evolution plate tectonics and climate change': 'tectonics',
#  'plant characteristics': 'characteristic',
#  'translation of rna to protein': 'rna',
#  'combining forces': 'force',
#  'carbon cycle and climate': 'carbon',
#  'the human population': 'population',
#  'erosion and deposition by glaciers': 'glacier',
#  'early atmosphere and oceans': 'early',
#  'roles in an ecosystem': 'role',
#  'distribution of water on earth': 'distribution',
#  'passive transport': 'transport',
#  'human evolution': 'evolution',
#  'metalloids': 'metalloids',
#  'coriolis effect': 'effect',
#  'wave particle theory': 'particle',
#  'thunderstorms': 'thunderstorm',
#  'sources of water pollution': 'source',
#  'biochemical reactions': 'biochemical',
#  'composition of the atmosphere': 'composition',
#  'physical properties of matter': 'physical',
#  'hot springs and geysers': 'hot spring geyser',
#  'meteors': 'meteor',
#  'fungus like protists': 'protist',
#  'importance of biodiversity': 'biodiversity',
#  'catalysts': 'catalyst',
#  'earthquake damage': 'earthquake',
#  'sedimentary rock classification': 'sedimentary',
#  'star constellations': 'star',
#  'pedigree analysis': 'pedigree analysis',
#  'touch': 'touch',
#  'magnetic polarity evidence for continental drift': 'polarity',
#  'mesosphere': 'mesosphere',
#  'geological stresses': 'stress',
#  'vitamins and minerals': 'mineral',
#  'the microscope': 'microscope',
#  'history of cenozoic life': 'cenozoic',
#  'valence electrons': 'electron',
#  'flooding': 'aaa_none',
#  'properties of carbon': 'carbon',
#  'diffusion': 'diffusion',
#  'seafloor spreading hypothesis': 'seafloor',
#  'speed and velocity': 'speed',
#  'fossil fuel reserves': 'fuel',
#  'revolutions of earth': 'revolution earth',
#  'physical science careers': 'career',
#  'electromagnetic devices': 'device',
#  'cell nucleus': 'nucleus',
#  'effect of latitude on climate': 'latitude',
#  'microscopes': 'microscope',
#  'magma composition at volcanoes': 'composition',
#  'precambrian continents': 'precambrian',
#  'inclined plane': 'inclined plane',
#  'blizzards': 'blizzard',
#  'digestive system organs': 'organ',
#  'human uses of fungi': 'human',
#  'melting': 'aaa_none',
#  'the ocean floor': 'ocean',
#  'plant classification': 'classification',
#  'intraplate earthquakes': 'intraplate',
#  'sponges': 'sponge',
#  'rocks and processes of the rock cycle': 'process',
#  'matter mass and volume': 'mass',
#  'rutherfords atomic model': 'model',
#  'storms': 'storm',
#  'chemistry of life': 'chemistry',
#  'organic compounds': 'compound',
#  'solution concentration': 'concentration',
#  'features of populations': 'feature',
#  'frogs and toads': 'frog toad',
#  'calculating work': 'work',
#  'recognizing chemical reactions': 'chemical',
#  ...}

# %% [markdown]
# ### hide

# %%
lessons_seen = []
dupe_lessons = []
for k, v in diagram_lesson_lookup.items():
    if v not in lessons_seen:
        lessons_seen.append(v)
    else:
        dupe_lessons.append(v)

# %%
dupe_topics = defaultdict(list)
for k, v in diagram_lesson_lookup.items():
    if v in dupe_lessons:
        dupe_topics[v].append(k)
# dupe_topics

# %%
missing
# Out:
# []

# %%
len(diagram_lesson_lookup.keys())

len(set(diagram_lesson_lookup.values()))

for k, v in sorted(matching_lessons.items()):
    print(k)
    print(sorted(v))
    print()
# Out:
# acid_rain_formation
# ['22.2 Effects of Air Pollution']
#
# aquifers
# ['13.3 Groundwater']
#
# atomic_mass_number
# ['5.1 Inside the Atom', 'atomic number', 'matter mass and volume']
#
# atomic_structure
# ['5.1 Inside the Atom']
#
# biomes
# ['climate zones and biomes']
#
# blastocyst
# ['22.3 Reproduction and Life Stages']
#
# cell_division
# ['5.1 Cell Division']
#
# cellular_respiration
# ['9.4 Biochemical Reactions']
#
# chemical_bonding_covalent
# ['7.3 Covalent Bonds']
#
# chemical_bonding_ionic
# ['7.2 Ionic Bonds']
#
# circuits
# ['23.3 Electric Circuits']
#
# continental_drift
# ['6.2 Continental Drift']
#
# convection_of_air
# ['18.2 Transfer of Thermal Energy']
#
# cycle_carbon
# ['18.2 Cycles of Matter']
#
# cycle_nitrogen
# ['18.2 Cycles of Matter']
#
# cycle_rock
# ['4.1 Types of Rocks', 'rocks and processes of the rock cycle']
#
# cycle_water
# ['24.2 Cycles of Matter']
#
# dna
# ['nucleic acid classification']
#
# earth_day_night
# ['rotation of earth']
#
# earth_eclipses
# ['eclipses']
#
# earth_magnetic_field
# ['24.2 Earth as a Magnet']
#
# earth_moon_phases
# ['24.4 The Sun and the EarthMoon System']
#
# earth_parts
# ['6.1 Inside Earth']
#
# earth_poles
# ['revolutions of earth']
#
# electromagnetism
# ['25.2 Using Electromagnetism']
#
# em_spectrum
# ['21.3 The Electromagnetic Spectrum', '23.1 Telescopes', 'electromagnetic spectrum', 'radio waves']
#
# erosion
# ['10.1 Erosion and Deposition by Flowing Water', '10.2 Erosion and Deposition by Waves', '10.3 Erosion and Deposition by Wind', '10.4 Erosion and Deposition by Glaciers', '19.1 Loss of Soil', 'avoiding soil loss', 'landforms from groundwater erosion and deposition', 'rocks and processes of the rock cycle', 'soil erosion']
#
# eukaryotic_cell_cycles
# ['5.1 Cell Division']
#
# evaporation_and_sublimation
# ['4.3 Changes of State']
#
# faults
# ['faults']
#
# food_chains_webs
# ['24.1 Flow of Energy']
#
# fossils
# ['11.1 Fossils']
#
# fungi_reproduction
# ['9.2 Fungi']
#
# geologic_time
# ['7.4 History of Life on Earth']
#
# glaciers
# ['10.4 Erosion and Deposition by Glaciers', 'glaciers']
#
# greenhouse_effect
# ['greenhouse effect']
#
# hair_follicles
# ['nails and hair']
#
# human_system_circulatory
# ['18.1 Overview of the Cardiovascular System']
#
# human_system_digestive
# ['17.3 The Digestive System']
#
# human_system_ear
# ['20.2 The Senses']
#
# human_system_excretory
# ['19.2 The Excretory System']
#
# human_system_eye
# ['22.3 Vision']
#
# human_system_immune
# ['21.4 Immune System Defenses']
#
# human_system_muscular
# ['16.4 The Muscular System']
#
# human_system_nervous
# ['20.1 The Nervous System', 'central nervous system', 'diseases of the nervous system', 'injuries of the nervous system', 'keeping the nervous system healthy', 'nervous system', 'peripheral nervous system']
#
# human_system_reproductory
# ['22.1 Male Reproductive System', '22.2 Female Reproductive System', '22.4 Reproductive System Health', 'female reproductive system', 'male reproductive system', 'reproductive system health']
#
# human_system_respiratory
# ['19.1 The Respiratory System', 'respiratory system organs']
#
# hydrocarbons
# ['9.2 Hydrocarbons', 'combustion reactions', 'hydrocarbons', 'saturated hydrocarbons', 'unsaturated hydrocarbons']
#
# isotopes
# ['5.1 Inside the Atom']
#
# layers_of_atmosphere
# ['15.3 Layers of the Atmosphere']
#
# lewis_dots
# ['7.1 Introduction to Chemical Bonds']
#
# life_cycles
# ['12.4 Insects and Other Arthropods']
#
# muscle_fiber
# ['16.4 The Muscular System', 'muscles and exercise']
#
# nuclear_energy
# ['11.3 Nuclear Energy']
#
# ocean_currents
# ['14.2 Ocean Movements']
#
# ocean_waves
# ['14.2 Ocean Movements', '19.1 Characteristics of Waves', 'gamma rays', 'transverse wave']
#
# ocean_zones
# ['14.1 Introduction to the Oceans']
#
# optics_lense_types
# ['22.2 Optics']
#
# optics_rays
# ['law of reflection']
#
# optics_reflection
# ['law of reflection']
#
# optics_refraction
# ['22.2 Optics']
#
# ozone_formation
# ['22.1 Air Pollution']
#
# parts_cell
# ['3.2 Cell Structures', '4.1 Transport', 'cell transport']
#
# parts_chordate_body
# ['12.5 Echinoderms and Invertebrate Chordates', 'chordates']
#
# parts_fish
# ['13.2 Fish']
#
# parts_flower
# ['10.2 Evolution and Classification of Plants']
#
# parts_leaf
# ['10.1 Introduction to Plants']
#
# parts_microscope
# ['1.4 The Microscope', 'microscopes', 'optical instruments']
#
# parts_neuron
# ['20.1 The Nervous System']
#
# parts_ocean_floor
# ['14.3 The Ocean Floor']
#
# parts_plant
# ['10.1 Introduction to Plants', '10.2 Evolution and Classification of Plants', '10.3 Plant Responses and Special Adaptations', '14.2 Mammals', '5.2 Nonrenewable Energy Resources', '5.3 Renewable Energy Resources', '6.2 Continental Drift', '9.1 Weathering', 'chemical weathering', 'electrical grid', 'fungi classification', 'nonvascular plants', 'plant characteristics', 'reproduction in seedless plants', 'seeds and seed dispersal', 'symbiotic relationships of fungi', 'types of marine organisms', 'vascular seedless plants']
#
# parts_seed
# ['10.2 Evolution and Classification of Plants']
#
# parts_skeleton
# ['16.3 The Skeletal System']
#
# parts_telescope
# ['22.2 Optics', 'optical instruments']
#
# parts_worm
# ['12.2 Flatworms and Roundworms', 'roundworms']
#
# periodic_table
# ['6.1 How Elements Are Organized']
#
# phagocytosis
# ['21.3 First Two Lines of Defense']
#
# photosynthesis
# ['4.2 Photosynthesis']
#
# protozoa
# ['9.1 Protists']
#
# radioactive_decay
# ['11.3 Absolute Ages of Rocks']
#
# rain_shadow
# ['17.1 Climate and Its Causes']
#
# seafloor_spreading
# ['magnetic evidence for seafloor spreading']
#
# seasons
# ['seasons']
#
# seismic_waves
# ['6.1 Inside Earth']
#
# simple_machines
# ['16.3 Simple Machines']
#
# skin_cross_section
# ['16.2 The Integumentary System']
#
# soil_horizons
# ['9.2 Soils', 'processes of the water cycle']
#
# solar_system
# ['25.1 Introduction to the Solar System']
#
# state_change
# ['changes of state']
#
# states_of_matter
# ['4.1 Solids Liquids Gases and Plasmas', 'kinetic theory of matter', 'solutions', 'states of water']
#
# stratigraphy
# ['11.2 Relative Ages of Rocks']
#
# sun_layers
# ['24.3 The Sun']
#
# tectonic_plates
# ['6.4 Theory of Plate Tectonics']
#
# tectonic_plates_motion
# ['6.4 Theory of Plate Tectonics', 'venus']
#
# tides
# ['14.2 Ocean Movements']
#
# types_cells
# ['cell biology']
#
# types_clouds
# ['clouds']
#
# types_leaves
# ['10.1 Introduction to Plants']
#
# velocity_time_graphs
# ['12.3 Acceleration']
#
# volcanoes
# ['8.3 Types of Volcanoes']
#
# waves
# ['19.2 Measuring Waves']
#
# waves_interactions_interference
# ['19.3 Wave Interactions and Interference']

# %%
# pprint.pprint(dict(dupe_topics))

# %% [markdown]
# ## merge questions

# %% [markdown]
# ### code

# %%
dq_image_folder = 'diagram-question-images/'
td_image_folder = 'diagram-teaching-images/'

def make_question_entry(qdf_row):
    ask = qdf_row[qdf_row.index == '03_write_question'].values[0]
    answer = qdf_row[qdf_row.index == '04_write_right_answer'].values[0]
    wrong_answers = qdf_row[qdf_row.index == 'wac_list'].values[0]
    q_topic = qdf_row[qdf_row.index == 'lesson_assigned_to'].values[0]
    image_uri = qdf_row[qdf_row.index == 's3_uri'].values[0]
    image_name = qdf_row[qdf_row.index == 'diagram'].values[0]
    
    def make_answer_choices(answer_choices):
        build_answer_choices = {}
        letter_options = list('abcd')
        random.shuffle(answer_choices)
        for idx, answer_choice in enumerate(answer_choices):
            answer_choice_dict = {
                "idStructural": letter_options[idx] + '.',
                "rawText": answer_choice,
                "processedText": answer_choice
            }
            build_answer_choices[letter_options[idx]] = answer_choice_dict
        return build_answer_choices
    a_choices = make_answer_choices(wrong_answers + [answer])
    single_q_dict = {
        "id": 'q',
        "type": 
            "Diagram Multiple Choice",
        "beingAsked": {
            "rawText": ask,
            "processedText": ask.encode('ascii', 'ignore').decode('utf-8')
        },
        "correctAnswer": {
            "rawText": answer,
            "processedText": answer.encode('ascii', 'ignore').decode('utf-8')
        },
        "answerChoices": a_choices,
        "imageUri": image_uri,
        "imageName": image_name
    }
    build_questions[q_topic].append(single_q_dict)
    
    
def refine_question_formats(raw_questions):
    reformatted_dq_ds = {}
    for topic, topic_questions in raw_questions.items():
        reformatted_topic = {topic: {'questions': {'diagramQuestions': {}}}}
        reformatted_questions = {}
        for idx, question in enumerate(topic_questions):
            question = deepcopy(question)
            question['id'] += str(idx + 1).zfill(4)
            reformatted_questions[question['id']] = question
        reformatted_topic[topic]['questions']['diagramQuestions'] = reformatted_questions
        reformatted_dq_ds.update(reformatted_topic)
    return reformatted_dq_ds

s3_base = 'https://s3.amazonaws.com/ai2-vision-textbook-dataset/diagrams/' + dq_image_folder
s3_base_descriptions = 'https://s3.amazonaws.com/ai2-vision-textbook-dataset/diagrams/' + td_image_folder

def make_image_link(old_url, s3_base=s3_base):
    image_name = old_url.split('/')[-1]
    new_url = s3_base + image_name
    return new_url

# %% [markdown]
# ### run

# %%
dr_proc_df['s3_uri'] = dr_proc_df['reference_id'].apply(make_image_link)
dr_proc_df['lesson_assigned_to'] = dr_proc_df['topic'].apply(lambda x: diagram_lesson_lookup[x])

# %%
build_questions = defaultdict(list)
_ = dr_proc_df.apply(make_question_entry, axis=1)

# %%
refined_questions = refine_question_formats(build_questions)

# %%
for subject, lessons in ck12_combined_dataset.items():
    for l_name, lesson in lessons.items():
        if l_name in refined_questions.keys():        
            lesson['questions']['diagramQuestions'] = refined_questions[l_name]['questions']['diagramQuestions']
        else:
            lesson['questions']['diagramQuestions']  = {}

# %% [markdown]
# ### hide

# %%
refined_questions = dict(refine_question_formats(build_questions))

refined_questions['10.4 Erosion and Deposition by Glaciers']['questions'].keys()
# Out:
# dict_keys(['diagramQuestions'])

# %%
refined_questions['10.4 Erosion and Deposition by Glaciers']

len(ck12_combined_dataset['earth-science']['10.4 Erosion and Deposition by Glaciers']['questions']['diagramQuestions'])

len(ck12_combined_dataset['earth-science']['10.4 Erosion and Deposition by Glaciers']['questions']['nonDiagramQuestions'])

val_counts=dr_proc_df['lesson_assigned_to'].value_counts()

# %%
val_counts
# Out:
# 10.1 Introduction to Plants                     1146
# 24.1 Flow of Energy                             1006
# 3.2 Cell Structures                              916
# 12.4 Insects and Other Arthropods                719
# 17.3 The Digestive System                        569
# 6.1 Inside Earth                                 405
# 20.1 The Nervous System                          337
# seasons                                          306
# 19.1 The Respiratory System                      291
# 10.2 Evolution and Classification of Plants      281
# 24.4 The Sun and the EarthMoon System            278
# 22.3 Vision                                      267
# 8.3 Types of Volcanoes                           213
# 25.1 Introduction to the Solar System            197
# 11.3 Nuclear Energy                              192
# 18.1 Overview of the Cardiovascular System       181
# 4.2 Photosynthesis                               177
# 14.2 Ocean Movements                             172
# 22.1 Male Reproductive System                    165
# 5.1 Inside the Atom                              164
# 23.3 Electric Circuits                           163
# 16.4 The Muscular System                         147
# 9.1 Protists                                     145
# 1.4 The Microscope                               136
# 22.2 Optics                                      128
# 24.2 Cycles of Matter                            120
# 6.4 Theory of Plate Tectonics                    120
# 5.1 Cell Division                                117
# 19.2 The Excretory System                        111
# eclipses                                         111
#                                                 ...
# 17.1 Climate and Its Causes                       59
# revolutions of earth                              55
# 14.1 Introduction to the Oceans                   54
# 21.3 First Two Lines of Defense                   53
# 15.3 Layers of the Atmosphere                     53
# 22.3 Reproduction and Life Stages                 53
# 7.4 History of Life on Earth                      50
# cell biology                                      49
# 12.3 Acceleration                                 45
# 7.3 Covalent Bonds                                45
# rotation of earth                                 44
# 9.2 Hydrocarbons                                  44
# 24.2 Earth as a Magnet                            43
# 9.4 Biochemical Reactions                         41
# 7.1 Introduction to Chemical Bonds                39
# 10.1 Erosion and Deposition by Flowing Water      38
# 9.2 Fungi                                         37
# 21.3 The Electromagnetic Spectrum                 35
# 14.3 The Ocean Floor                              35
# 25.2 Using Electromagnetism                       34
# greenhouse effect                                 34
# 18.2 Transfer of Thermal Energy                   33
# 10.4 Erosion and Deposition by Glaciers           33
# 11.1 Fossils                                      28
# 19.3 Wave Interactions and Interference           26
# 22.2 Effects of Air Pollution                     25
# magnetic evidence for seafloor spreading          25
# 11.2 Relative Ages of Rocks                       24
# 7.2 Ionic Bonds                                   21
# 22.1 Air Pollution                                19
# Name: lesson_assigned_to, dtype: int64

# %% [markdown]
# ## merge descriptions

# %%
def make_description_entry(qdf_row):
    description = qdf_row[qdf_row.index == 'Description'].values[0]
    q_topic = qdf_row[qdf_row.index == 'lesson_assigned_to'].values[0]
    image_uri = qdf_row[qdf_row.index == 's3_uri'].values[0]
    image_name = qdf_row[qdf_row.index == 'diagram'].values[0]
    image_key = image_name.replace('.png', '')
    single_desc_dict = {
        "imageUri": image_uri,
        "imageName": image_name,
        "rawText": description,
        "processedText": description.encode('ascii', 'ignore').decode('utf-8')
        }
    if image_key not in build_descriptions[q_topic].keys():
        build_descriptions[q_topic].update({image_key: single_desc_dict})
    # I've found the longest description is usually best
    elif len(single_desc_dict['processedText']) > len(build_descriptions[q_topic][image_key]['processedText']):
        build_descriptions[q_topic].update({image_key: single_desc_dict})

# %%
# %%capture
ai2_written_df_completed['lesson_assigned_to'] = ai2_written_df_completed['topic'].apply(lambda x: diagram_lesson_lookup[x])
ai2_written_df_completed['s3_uri'] = ai2_written_df_completed['Image Path'].apply(make_image_link)
ai2_written_df_completed = ai2_written_df_completed.dropna()

desc_df['topic'] = desc_df['diagram'].apply(lambda x: x.rsplit('_', maxsplit=1)[0])
desc_df['lesson_assigned_to'] = desc_df['topic'].apply(lambda x: diagram_lesson_lookup[x])
desc_df['s3_uri'] = desc_df['reference_id'].apply(make_image_link)
desc_df['Description'] = desc_df['01_write_description']

# %%
build_descriptions = defaultdict(dict)
_ = desc_df.apply(make_description_entry, axis=1)
_ = ai2_written_df_completed.apply(make_description_entry, axis=1)

# %%
len(build_descriptions.keys())
# Out:
# 85

# %%
# this adds the descriptions to the combined dataset
for subject, lessons in ck12_combined_dataset.items():
    for l_name, lesson in lessons.items():
        if l_name in build_descriptions.keys():
            lesson['instructionalDiagrams'] = build_descriptions[l_name]
        else:
            lesson['instructionalDiagrams'] = {}

# %%
dimages = []
for vals in build_descriptions.values():
    for img in vals.values():
        dimages.append(img['imageName'])

# %%
len(set(dimages))
# Out:
# 276

# %%
len(dimages)
# Out:
# 276

# %%
desc_corpus = ''
for lesson, descriptions in build_descriptions.items():
    for dd in descriptions.values():
        desc_corpus += ' ' + dd['processedText']

# %%
'the' in cached_sw
# Out:
# True

# %%
d_corp = [lmtizer.lemmatize(word.lower()) for word in desc_corpus.split() if len(word) > 2 and word.lower() not in cached_sw]

# %%
tb_freq_d = nltk.FreqDist(d_corp)
most_common_fb_words = tb_freq_d.most_common()

# %% [markdown]
# ### hide

# %%
pd.unique(desc_df['lesson_assigned_to']).shape
# Out:
# (85,)

# %%
build_descriptions.keys()
# Out:
# dict_keys(['12.4 Insects and Other Arthropods', '14.3 The Ocean Floor', '16.3 Simple Machines', 'cell biology', '10.2 Evolution and Classification of Plants', '9.2 Hydrocarbons', '18.1 Overview of the Cardiovascular System', '15.3 Layers of the Atmosphere', 'climate zones and biomes', '19.2 The Excretory System', '5.1 Cell Division', '10.1 Introduction to Plants', 'faults', 'eclipses', '24.3 The Sun', '4.2 Photosynthesis', '25.2 Using Electromagnetism', '22.2 Optics', 'revolutions of earth', '7.4 History of Life on Earth', 'changes of state', '1.4 The Microscope', '24.2 Earth as a Magnet', 'nucleic acid classification', '18.2 Cycles of Matter', '20.2 The Senses', '12.2 Flatworms and Roundworms', 'rotation of earth', '17.3 The Digestive System', '7.3 Covalent Bonds', 'law of reflection', '13.3 Groundwater', '18.2 Transfer of Thermal Energy', '4.3 Changes of State', 'clouds', '12.5 Echinoderms and Invertebrate Chordates', '13.2 Fish', '21.3 First Two Lines of Defense', '9.2 Soils', '6.4 Theory of Plate Tectonics', '6.1 How Elements Are Organized', '11.3 Absolute Ages of Rocks', '9.4 Biochemical Reactions', '22.3 Vision', '3.2 Cell Structures', 'greenhouse effect', '21.3 The Electromagnetic Spectrum', '16.2 The Integumentary System', '11.2 Relative Ages of Rocks', '7.2 Ionic Bonds', '24.1 Flow of Energy', '19.3 Wave Interactions and Interference', '24.2 Cycles of Matter', '11.3 Nuclear Energy', '9.2 Fungi', 'seasons', '14.2 Ocean Movements', '23.3 Electric Circuits', '12.3 Acceleration', '25.1 Introduction to the Solar System', '7.1 Introduction to Chemical Bonds', '6.2 Continental Drift', '22.3 Reproduction and Life Stages', '17.1 Climate and Its Causes', '8.3 Types of Volcanoes', '20.1 The Nervous System', '16.3 The Skeletal System', '21.4 Immune System Defenses', '4.1 Types of Rocks', '4.1 Solids Liquids Gases and Plasmas', 'nails and hair', '19.2 Measuring Waves', '14.1 Introduction to the Oceans', '22.1 Male Reproductive System', '6.1 Inside Earth', '9.1 Protists', 'magnetic evidence for seafloor spreading', '10.4 Erosion and Deposition by Glaciers', '19.1 The Respiratory System', '16.4 The Muscular System', '22.2 Effects of Air Pollution', '5.1 Inside the Atom', '10.1 Erosion and Deposition by Flowing Water', '11.1 Fossils', '24.4 The Sun and the EarthMoon System', '22.1 Air Pollution'])

# %%
# with open(output_dir + 'ck12_dataset_beta_v4.json', 'w') as f:
#     json.dump(ck12_combined_dataset, f, indent=4, sort_keys=True)

# %%
# with open(output_dir + 'ck12_dataset_beta_v4.json', 'r') as f:
#     ck12_combined_dataset = json.load(f)

# %% [markdown]
# ## Test spelling and grammar fixes

# %% [markdown]
# ### code

# %%
def check_mispelled(word):
    return word and word.isalpha() and not (edict.check(word) or anglo_edict.check(word) or edict.check(word[0].upper() + word[1:]))

def correct_spelling_error(misspelled_word, suggested_spellings):
    highest_ratio = 0
    closest_match = None
    for word in suggested_spellings:
        match_r = fuzz.ratio(misspelled_word, word)
        if match_r >= highest_ratio and (word[0] == misspelled_word[0] or not check_mispelled(word[0] + misspelled_word)) and len(misspelled_word) <= len(word):
            highest_ratio = match_r
            closest_match = word
            break
#     spell_changes[misspelled_word] = closest_match
    return closest_match

def apply_spelling_fix(orig_text):
    orig_text_tokens = orig_text.split()
    processed_tokens = []
    for token in orig_text_tokens:
        norm_token = token.lower()
        if len(norm_token) < 4:
            processed_tokens.append(token)
            continue
        if check_mispelled(norm_token):
            suggested_replacements = edict.suggest(token)
            replacement_text = correct_spelling_error(norm_token, suggested_replacements)
            if replacement_text:
                if norm_token[0].isupper():
                    replacement_text = upper(replacement_text[0]) + replaced_text[1:]
                processed_tokens.append(replacement_text)
            else:
                processed_tokens.append(token)
        else:
            processed_tokens.append(token)
    return ' '.join(processed_tokens)

def diff_corrected_text(orig_text, corrected_text):
    diff = dmp.diff_main(orig_text, corrected_text)
    return HTML(dmp.diff_prettyHtml(diff))

def specify_lesson_q_path(lesson):
    pass

# %% [markdown]
# ### run

# %%
dmp = diff_match_patch.diff_match_patch()

# %%
ck12_spell_gramm_fix_test = deepcopy(ck12_combined_dataset)

# %%
gram_checker = language_check.LanguageTool('en-US')
gram_checker.disabled = set(['SENT_START_CONJUNCTIVE_LINKING_ADVERB_COMMA', 'POSSESSIVE_APOSTROPHE', 'A_PLURAL'])
gram_checker.disable_spellchecking()

punc_set_space = set([',', ':', ';', '/"'])
punc_set_nospace = set(['-', '\'', '-', '?', '.', '!'])
question_enders = set(['.', '?', ':'])

# %%
#check descriptions
spell_changes = {}
unaltered_text = []
replaced_text = []
for lesson in list(ck12_spell_gramm_fix_test['life-science'].values()):
    if lesson['instructionalDiagrams']:
        for diagram, description in lesson['instructionalDiagrams'].items():
            orig_text = description['processedText']
            spell_fixed_text = apply_spelling_fix(orig_text)
            for punc_char in punc_set_nospace:
                spell_fixed_text = spell_fixed_text.replace(' ' + punc_char + ' ' , punc_char)
            for punc_char in punc_set_space:
                spell_fixed_text = spell_fixed_text.replace(' ' + punc_char + ' ' , punc_char + ' ')
            gram_fixed = gram_checker.correct(spell_fixed_text)
            if gram_fixed != orig_text:
                unaltered_text.append(orig_text)
                replaced_text.append(gram_fixed)

# %%
spell_changes = {}
unaltered_text = []
replaced_text = []
for lesson in list(ck12_spell_gramm_fix_test['life-science'].values()):
    if lesson['questions']['nonDiagramQuestions']:
        for diagram, description in lesson['questions']['diagramQuestions'].items():
            orig_text = description['beingAsked']['processedText']
            spell_fixed_text = apply_spelling_fix(orig_text)
            gram_fixed = gram_checker.correct(spell_fixed_text)
            for punc_char in punc_set_nospace:
                gram_fixed = gram_fixed.replace(' ' + punc_char + ' ' , punc_char)
                gram_fixed = gram_fixed.replace(' ' + punc_char, punc_char)
            for punc_char in punc_set_space:
                gram_fixed = gram_fixed.replace(' ' + punc_char + ' ' , punc_char + ' ')
            if gram_fixed[-1] not in question_enders:
                if gram_fixed.split()[0] in ['Identify', 'Name'] or '__' in gram_fixed:
                    gram_fixed += '.'
                else:
                    gram_fixed += '?'
            if gram_fixed != orig_text:
                unaltered_text.append(orig_text)
                replaced_text.append(gram_fixed)

# %%
comp_text = list(zip(unaltered_text, replaced_text))

print(len(spell_changes))
print(len(comp_text))
# spell_changes
# Out:
# 21
# 1207

# %%
rand_idx = np.random.randint(len(comp_text))
print(unaltered_text[rand_idx])
print()
print(replaced_text[rand_idx])
diff_corrected_text(*comp_text[rand_idx])
# Out:
# where is the thymus?
#
# Where is the thymus?
# <del style="background:#ffe6e6;">w</del><ins style="background:#e6ffe6;">W</ins><span>here is the thymus?</span>

# %% [markdown]
# ### hide

# %%
# with open(output_dir + 'ck12_dataset_beta_v4.json', 'r') as f:
#     ck12_combined_dataset = json.load(f)

# %% [markdown]
# # Topic key collisions

# %% [markdown]
# ### old nested structure

# %%
flexbook_ds.keys()
# Out:
# dict_keys(['earth-science', 'physical-science', 'life-science'])

# %%
build_website_lessons = [list(lesson.keys()) for lesson in lessons_ds.values()]
website_lessons= sorted([item for sublist in build_website_lessons for item in sublist])

build_flexbook_lessons = [list(lesson.keys()) for lesson in flexbook_ds.values()]
flexbook_lessons= [item for sublist in build_flexbook_lessons for item in sublist]
flexbook_lessons = sorted([lesson.split(maxsplit=1)[1].strip().lower() for lesson in flexbook_lessons])
fbls = set(flexbook_lessons)
wsls = set(website_lessons)

# %%
n_dd_lessons = len(fbls.union(wsls))

# %%
n_all_lessons = len(website_lessons + flexbook_lessons)

# %%
n_all_lessons - n_dd_lessons
# Out:
# 52

# %%
len(flexbook_lessons)
# Out:
# 247

# %%
print(len(flexbook_lessons))
print(len(set(flexbook_lessons)))
# Out:
# 247
# 243

# %%
# pd.Series(flexbook_lessons).value_counts()

# %%
combined_lesson_series = pd.Series(flexbook_lessons + website_lessons)
lessons_with_name_dupes = combined_lesson_series.value_counts()[combined_lesson_series.value_counts() > 1].index.tolist()

# %%
# lessons_with_name_dupes

# %%
print(len(website_lessons))
print(len(set(website_lessons)))
# Out:
# 829
# 829

# %%
len(set(website_lessons).union(set(flexbook_lessons)))
# Out:
# 1024

# %%
build_website_topics = [list(lesson.keys()) for lesson in lessons_ds.values()]
website_topics= sorted([item for sublist in build_website_lessons for item in sublist])

# build_flexbook_topics = [list(lesson.keys()) for lesson in flexbook_ds.values()]
# flexbook_topics= [item for sublist in build_flexbook_lessons for item in sublist]
# flexbook_lessons = sorted([lesson.split(maxsplit=1)[1].strip().lower() for lesson in flexbook_lessons])
# fbls = set(flexbook_lessons)
# wsls = set(website_lessons)

# %% [markdown]
# ### with new flat dataset

# %% [markdown]
# ### hide

# %%
topic_list = []
for lesson in complete_flat_ds:
#     for t_id, topic in lesson['topics'].items():
    topic_list.append(lesson['lessonName'].lower())

topic_tokens = {idx: [word for word in val.split() if word not in cached_sw] for idx, val in enumerate(topic_list)}

token_to_topic_index = defaultdict(list)
for k, vals in topic_tokens.items():
    for v in vals:
        token_to_topic_index[v].append(k)

# %%
collision_dict = {token: topic_idxs for token, topic_idxs in token_to_topic_index.items() if len(topic_idxs) < 50 and len(topic_idxs) > 10}
build_topics_collision_idxs = collision_dict.values()
topics_collision_idxs = [item for sublist in build_topics_collision_idxs for item in sublist]
topics_w_collisions_set = set(topics_collision_idxs)

# %%
for k, v in collision_dict.items():
    for topic_idx in v:
        print(topic_list[topic_idx])
    print()

# %%
lmtizer.stem('plants')

# %% [markdown]
# ### code

# %%
with open('./output_data_from_nbs/build_v5_5f.json', 'r') as f:
    complete_flat_ds = json.load(f)

# %%
lesson_names = [lesson['lessonName'].lower() for lesson in complete_flat_ds]
lesson_idx_lookup = {v: k for k, v in enumerate(lesson_names)}

# %%
lmtizer = WordNetLemmatizer()

# %%
# ignore_tokens = ['introduction', 'form', 'component', 'destruction', 'destruction', 'components', 'characteristic', 'classification']
ignore_tokens = ['introduction', 'form', 'component', 'destruction', 'destruction', 'components', 'characteristic', 
                 'classification', 'design', 'effect', 'first', 'form', 'introduction', 'model', 'modern', 'non', 
                 'nature', 'process', 'science', 'thing', 'use']

# %%
cached_sw = stopwords.words("english") + list(string.punctuation)
def find_meta_lessons(complete_ds):
    meta_lesson_id = 0
    meta_lesson_prefix = 'MT_'

    lesson_names = [lesson['lessonName'].lower() for lesson in complete_ds]
    lesson_tokens = {idx: filter_tokens(val) for idx, val in enumerate(lesson_names)}
    token_to_lesson_index = defaultdict(list)
    
    for k, vals in lesson_tokens.items():
        for v in vals:
            token_to_lesson_index[v].append(k)
            
    collision_dict = {token: topic_idxs for token, topic_idxs in token_to_lesson_index.items() if len(topic_idxs) < 20 and len(topic_idxs) > 1}
    return collision_dict

def pick_rarest_metalesson(metalessons):
    return sorted({k: meta_topic_sizes[k] for k in metalessons}.items(), key=lambda x: x[1])[0][0]

def filter_pos(token_list):
    tagged_tokens = nltk.pos_tag(token_list)
    filtered_tokes = [toke[0] for toke in tagged_tokens if toke[1] in ['NN', 'RB', 'NNS', 'JJ']]
    if filtered_tokes:
        return filtered_tokes
    else:
        return ['aaa_none']

def filter_tokens(tokens):
    return filter_pos([lmtizer.lemmatize(toke) for toke in tokens.split() if toke not in cached_sw])

# %%
col_dict = find_meta_lessons(complete_flat_ds)

meta_topic_sizes = {v[0]: len(v[1])for v in sorted(col_dict.items(), key=lambda x: len(x[1]), reverse=True)}

token_to_lesson_index = defaultdict(list)
for k, vals in col_dict.items():
    for v in vals:
        token_to_lesson_index[v].append(k)

# %%
meta_lesson_assignments = {}
for lesson in lesson_names:
    associated_metalessons = token_to_lesson_index[lesson_idx_lookup[lesson]]
    if associated_metalessons:
        meta_lesson_assignments[lesson] = pick_rarest_metalesson(associated_metalessons)
    else:
        meta_lesson_assignments[lesson] = ' '.join(filter_tokens(lesson))

meta_lesson_string_ids = set(meta_lesson_assignments.values())
meta_lesson_id_lookup =  {val: idx for idx, val in enumerate(meta_lesson_string_ids)}
meta_lesson_id_assignments = {k: meta_lesson_id_lookup[v] for k, v in meta_lesson_assignments.items()}

# %%
# print(len(token_to_lesson_index.keys()))

# match_seq = pd.Series([len(tokens) for tokens in token_to_lesson_index.values()])
# match_seq.value_counts()

# %%
linked_lessons = defaultdict(list)
for k, v in meta_lesson_assignments.items():
    linked_lessons[v].append(k)
linked_lessons = dict(linked_lessons)

# %%
meta_lesson_assignments
# Out:
# {'einsteins concept of gravity': 'concept',
#  'calculating acceleration from velocity and time': 'time',
#  'protons': 'proton',
#  'screw': 'screw',
#  'hypothesis': 'hypothesis',
#  'protists': 'protist',
#  'components of blood': 'component',
#  'refraction': 'refraction',
#  'development of hypotheses': 'development',
#  'atomic nucleus': 'nucleus',
#  'early space exploration': 'exploration',
#  'scientific graphing': 'scientific',
#  'the electromagnetic spectrum': 'spectrum',
#  'conservation of mass and energy in nuclear reactions': 'nuclear',
#  'cardiovascular system': 'cardiovascular',
#  'processes of breathing': 'process',
#  'musical instruments': 'instrument',
#  'properties of solutions': 'solution',
#  'muscles and exercise': 'muscle',
#  'electrons': 'electron',
#  'tornadoes': 'tornado',
#  'bathymetric evidence for seafloor spreading': 'seafloor',
#  'condensation': 'condensation',
#  'supervolcanoes': 'supervolcanoes',
#  'obtaining energy resources': 'resource',
#  'accuracy and precision': 'accuracy precision',
#  'population growth patterns': 'growth',
#  'wind power': 'wind',
#  'ionic bonds': 'ionic',
#  'electron cloud atomic model': 'cloud',
#  'mining and using minerals': 'mineral',
#  'social behavior of animals': 'behavior',
#  'physical change': 'physical',
#  'carbon bonding': 'bonding',
#  'correlation using relative ages': 'relative',
#  'elements': 'element',
#  'plant reproduction and life cycle': 'reproduction',
#  'bacteria reproduction': 'bacteria',
#  'evolution acts on the phenotype': 'evolution',
#  'salamanders': 'salamander',
#  'electric charge': 'charge',
#  'flatworms': 'flatworm',
#  'tropisms': 'tropism',
#  'lens': 'lens',
#  'predicting earthquakes': 'earthquake',
#  'agriculture and human population growth': 'agriculture',
#  'world climates': 'climate',
#  'elastic force': 'elastic',
#  'air masses': 'mass',
#  'nuclear energy': 'nuclear',
#  'heat': 'heat',
#  'long term climate change': 'term',
#  'using electromagnetism': 'electromagnetism',
#  'human egg cells': 'cell',
#  'nature of earthquakes': 'nature',
#  'velocity time graphs': 'graph',
#  'introduction to groundwater': 'groundwater',
#  'measuring and predicting earthquakes': 'earthquake',
#  'scientific experiments': 'experiment',
#  'soil horizons and profiles': 'soil',
#  'echinoderms': 'echinoderm',
#  'divergent plate boundaries in the oceans': 'divergent',
#  'neutrons': 'neutron',
#  'formation of minerals': 'formation',
#  'momentum': 'momentum',
#  'distance and direction': 'distance',
#  'groups with metalloids': 'metalloids',
#  'venus': 'venus',
#  'acceleration': 'acceleration',
#  'landforms from erosion and deposition by gravity': 'landforms',
#  'mollusks and annelids': 'mollusk',
#  'respiratory system organs': 'organ',
#  'nature of science': 'nature',
#  'introduction to earths surface': 'surface',
#  'sources of visible light': 'visible',
#  'classification of living things': 'thing',
#  'energy conversion': 'energy conversion',
#  'human causes of extinction': 'cause',
#  'calculating acceleration from force and mass': 'acceleration',
#  'wedge': 'wedge',
#  'air quality': 'air',
#  'forms of energy': 'form',
#  'scientific measuring devices': 'device',
#  'topographic maps': 'map',
#  'protecting the water supply': 'supply',
#  'formation of earth': 'formation',
#  'preventing noninfectious diseases': 'noninfectious',
#  'types of animal behavior': 'behavior',
#  'testing hypotheses': 'hypothesis',
#  'geothermal power': 'geothermal',
#  'cellular respiration reactions': 'cellular',
#  'energy resources': 'resource',
#  'isomers': 'isomer',
#  'soils': 'soil',
#  'saturated hydrocarbons': 'hydrocarbon',
#  'fungi': 'fungi',
#  'introduction to the human body': 'body',
#  'rocks': 'rock',
#  'non renewable energy resources': 'non',
#  'types of rocks': 'rock',
#  'succession': 'succession',
#  'collecting weather data': 'weather',
#  'birds': 'bird',
#  'layers of the atmosphere': 'layer',
#  'daltons atomic theory': 'theory',
#  'effect of continental position on climate': 'position',
#  'humans and the water supply': 'supply',
#  'mollusks': 'mollusk',
#  'heat conduction': 'heat',
#  'wegener and the continental drift hypothesis': 'drift',
#  'introduction to the oceans': 'ocean',
#  'carbon and living things': 'thing',
#  'buoyancy': 'buoyancy',
#  'skin': 'skin',
#  'predicting volcanic eruptions': 'volcanic',
#  'energy pyramids': 'energy pyramid',
#  'blood': 'blood',
#  'cell cycle': 'cycle',
#  'mechanical advantage': 'mechanical',
#  'distance between stars': 'distance',
#  'air movement': 'movement',
#  'circulation and the lymphatic system': 'lymphatic',
#  'characteristics of waves': 'characteristic',
#  'development of theories': 'development',
#  'types of matter': 'matter',
#  'planet earth': 'planet',
#  'compound machine': 'machine',
#  'using thermal energy': 'thermal',
#  'safety of water': 'safety',
#  'mendeleevs periodic table': 'table',
#  'dna structure and replication': 'replication',
#  'heat transfer in the atmosphere': 'transfer',
#  'materials humans use': 'material',
#  'inside earth': 'earth',
#  'earths interior material': 'interior',
#  'types of friction': 'friction',
#  'what are biomes': 'biome',
#  'history of earths life forms': 'form',
#  'earth history and clues from fossils': 'fossil',
#  'blood diseases': 'blood',
#  'loss of soil': 'loss',
#  'inertia': 'inertia',
#  'energy in the atmosphere': 'atmosphere',
#  'effects of water pollution': 'effect',
#  'vision': 'vision',
#  'vertebrate characteristics': 'vertebrate',
#  'surface water': 'surface',
#  'the universe': 'universe',
#  'electronic signal': 'electronic',
#  'asexual vs. sexual reproduction': 'reproduction',
#  'electronic device': 'device',
#  'flow of matter in ecosystems': 'flow',
#  'hydrogen and alkali metals': 'hydrogen',
#  'minerals': 'mineral',
#  'non infectious reproductive system disorders': 'infectious',
#  'lizards and snakes': 'lizard snake',
#  'kinetic theory of matter': 'kinetic',
#  'discovery of electromagnetism': 'discovery',
#  'natural resources': 'natural',
#  'cardiovascular system health': 'cardiovascular',
#  'scientific ways of thinking': 'way',
#  'location and direction': 'direction',
#  'age of earth': 'age',
#  'liquids': 'liquid',
#  'democrituss idea of the atom': 'atom',
#  'what is ecology': 'ecology',
#  'alkaline earth metals': 'metal',
#  'mendels laws and genetics': 'mendel',
#  'seeds and seed dispersal': 'seed',
#  'air pollution': 'air',
#  'alloys': 'alloy',
#  'states of water': 'state',
#  'measuring earthquake magnitude': 'magnitude',
#  'communication in science': 'communication',
#  'electric current': 'current',
#  'archaea': 'archaea',
#  'tree rings ice cores and varves': 'core',
#  'inner planets': 'inner',
#  'outer planets': 'outer',
#  'metamorphic rocks': 'metamorphic',
#  'weather versus climate': 'weather',
#  'volcanic landforms': 'volcanic',
#  'sublimation': 'sublimation',
#  'darwins theory of evolution': 'darwin',
#  'nature of technology': 'nature',
#  'mass extinctions': 'extinction',
#  'nerve cells and nerve impulses': 'nerve',
#  'density': 'density',
#  'rna': 'rna',
#  'history of the atom': 'atom',
#  'food webs': 'food',
#  'cartilaginous fish': 'fish',
#  'acceleration due to gravity': 'acceleration',
#  'activation energy': 'activation energy',
#  'competition': 'competition',
#  'reptiles': 'reptile',
#  'innate behavior of animals': 'behavior',
#  'origins of life': 'origin',
#  'importance of the oceans': 'ocean',
#  'intensity and loudness of sound': 'sound',
#  'microwaves': 'microwave',
#  'importance of seedless plants': 'seedless',
#  'ions': 'ion',
#  'chemical and solar cells': 'solar',
#  'radioactivity': 'radioactivity',
#  'energy from biomass': 'energy biomass',
#  'respiration': 'respiration',
#  'reduce reuse and recycle': 'reuse recycle',
#  'types of mollusks': 'mollusk',
#  'amphibians': 'amphibian',
#  'the scientific method': 'method',
#  'metals': 'metal',
#  'nuclear power': 'nuclear',
#  'electricity and magnetism': 'magnetism',
#  'earthquake zones': 'zone',
#  'crustaceans': 'crustacean',
#  'human vision': 'vision',
#  'mineral groups': 'group',
#  'primates': 'primate',
#  'law of reflection': 'law',
#  'big bang': 'big bang',
#  'causes of air pollution': 'cause',
#  'molecular evidence for evolution': 'molecular',
#  'reproductive behavior of animals': 'behavior',
#  'evolution of simple cells': 'simple',
#  'plant cell structures': 'structure',
#  'vascular seedless plants': 'seedless',
#  'noble gases': 'gas',
#  'scope of physical science': 'scope',
#  'distance': 'distance',
#  'science skills': 'science skill',
#  'effects of air pollution on human health': 'health',
#  'nonmetals': 'nonmetal',
#  'satellites shuttles and space stations': 'satellite',
#  'thomsons atomic model': 'model',
#  'heart': 'heart',
#  'nuclear fusion': 'nuclear',
#  'cycles of matter': 'matter',
#  'hearing and balance': 'balance',
#  'electric conductors and insulators': 'insulator',
#  'dna the genetic material': 'genetic',
#  'importance of mollusks': 'mollusk',
#  'deposition': 'deposition',
#  'hearing sound': 'sound',
#  'law of conservation of momentum': 'momentum',
#  'human genome project': 'human',
#  'diversity of birds': 'bird',
#  'inflammatory response': 'response',
#  'mountain building': 'building',
#  'natural selection': 'natural',
#  'keeping the nervous system healthy': 'healthy',
#  'earths shape': 'earth shape',
#  'first two lines of defense': 'defense',
#  'other objects in the solar system': 'solar',
#  'speed of sound': 'speed',
#  'cleaning up groundwater': 'groundwater',
#  'characteristics of living organisms': 'organism',
#  'dark matter': 'matter',
#  'scope of physics': 'scope',
#  'how ocean currents moderate climate': 'current',
#  'electric generators': 'electric',
#  'wave interactions and interference': 'interference',
#  'enzymes in the digestive system': 'enzyme',
#  'buoyancy of fluids': 'buoyancy',
#  'electronic component': 'component',
#  'technological design process': 'design',
#  'temperature of the atmosphere': 'temperature',
#  'heating systems': 'heating system',
#  'mid latitude cyclones': 'latitude',
#  'light': 'light',
#  'safety in life science research': 'safety',
#  'biodiversity and extinction': 'biodiversity',
#  'health of the digestive system': 'digestive',
#  'ocean garbage patch': 'ocean',
#  'protein synthesis and gene expression': 'gene',
#  'properties of bases': 'base',
#  'pascals law': 'law',
#  'symbiosis': 'symbiosis',
#  'solids': 'solid',
#  'classes of elements': 'element',
#  'observation': 'observation',
#  'volcanoes at hotspots': 'volcano',
#  'types of echinoderms': 'echinoderm',
#  'impact of continued global warming': 'warming',
#  'seasonal changes in plants': 'change',
#  'genetic disorders': 'genetic',
#  'mineral identification': 'identification',
#  'how fossilization creates fossils': 'fossilization',
#  'the digestive system': 'digestive',
#  'earth as a magnet': 'magnet',
#  'solute and solvent': 'solute solvent',
#  'clouds': 'cloud',
#  'friction': 'friction',
#  'relative ages of rocks': 'relative',
#  'transcription of dna to rna': 'rna',
#  'intrusive and extrusive igneous rocks': 'igneous',
#  'wavelength': 'wavelength',
#  'the scale of evolution': 'scale',
#  'hearing loss': 'loss',
#  'male reproductive system': 'male',
#  'formation of the sun and planets': 'sun',
#  'introduction to prokaryotes': 'introduction',
#  'coastal pollution': 'coastal pollution',
#  'safety in the life sciences': 'safety',
#  'reproduction and life stages': 'reproduction',
#  'communities': 'community',
#  'history of life on earth': 'history',
#  'scientific investigation': 'investigation',
#  'igneous rocks': 'igneous',
#  'chemical bonding': 'bonding',
#  'pregnancy and childbirth': 'pregnancy childbirth',
#  'atoms': 'atom',
#  'introduction to ecology': 'ecology',
#  'determining relative ages': 'relative',
#  'scientific method': 'method',
#  'chemical reactions and energy': 'chemical',
#  'bacteria in the digestive system': 'digestive',
#  'paleozoic and mesozoic seas': 'paleozoic',
#  'humans and primates': 'primate',
#  'cooling systems': 'system',
#  'producers': 'producer',
#  'chemistry of compounds': 'chemistry',
#  'organelles': 'organelle',
#  'igneous landforms and geothermal activ': 'geothermal',
#  'boyles law': 'law',
#  'ocean zones': 'zone',
#  'ecosystems': 'ecosystem',
#  'cell transport': 'transport',
#  'weather maps': 'map',
#  'observations and experiments': 'observation',
#  'polygenic traits': 'polygenic trait',
#  'rotation of earth': 'rotation earth',
#  'male reproductive structures': 'male',
#  'principles of relative dating': 'principle',
#  'groundwater depletion': 'depletion',
#  'early earth': 'early',
#  'climate change in earth history': 'history',
#  'effusive eruptions': 'eruption',
#  'adaptation and evolution of populations': 'adaptation',
#  'fungi classification': 'fungi',
#  'precipitation': 'precipitation',
#  'climate and its causes': 'cause',
#  'invertebrates': 'invertebrate',
#  'types of air pollution': 'air',
#  'the hertzsprung russell diagra': 'hertzsprung russell diagra',
#  'what is force': 'force',
#  'technology and society': 'technology',
#  'magnets': 'magnet',
#  'exothermic reactions': 'exothermic reaction',
#  'surface wave': 'surface',
#  'introduction to chemical bonds': 'bond',
#  'boiling': 'aaa_none',
#  'female reproductive system': 'female',
#  'types of soils': 'soil',
#  'the carbon cycle': 'carbon',
#  'mixtures': 'mixture',
#  'carbon monomers and polymers': 'carbon',
#  'solar power': 'solar',
#  'combustion reactions': 'combustion',
#  'centipedes and millipedes': 'centipede millipede',
#  'atomic number': 'atomic',
#  'cloning': 'aaa_none',
#  'plasma': 'plasma',
#  'paleozoic plate tectonics': 'paleozoic',
#  'characteristics and origins of life': 'origin',
#  'protein classification': 'protein',
#  'the sun and the earthmoon system': 'sun',
#  'chemical reaction overview': 'overview',
#  'ultrasound': 'ultrasound',
#  'sponges and cnidarians': 'sponge',
#  'formation of the moon': 'moon',
#  'water distribution': 'distribution',
#  'climate zones and biomes': 'biome',
#  'locating earthquake epicenters': 'earthquake',
#  'uses of water': 'water',
#  'stratosphere': 'stratosphere',
#  'sexually transmitted infections': 'sexually infection',
#  'star power': 'star',
#  'turtles': 'turtle',
#  'moon': 'moon',
#  'electric fields': 'field',
#  'amontonss law': 'law',
#  'environmental impacts of mining': 'mining',
#  'efficiency': 'efficiency',
#  'human digestive system': 'digestive',
#  'climate change': 'change',
#  'gamma rays': 'gamma',
#  'photosynthesis reactions': 'photosynthesis',
#  'groundwater aquifers': 'groundwater',
#  'menstrual cycle': 'cycle',
#  'segmented worms': 'worm',
#  'electromagnetic induction': 'induction',
#  'covalent bonds': 'covalent',
#  'unsaturated hydrocarbons': 'hydrocarbon',
#  'magnetic evidence for seafloor spreading': 'seafloor',
#  'cnidarians': 'cnidarian',
#  'uranus': 'uranus',
#  'importance of birds': 'bird',
#  'human sperm': 'human',
#  'plant hormones': 'plant',
#  'advances in genetics': 'genetics',
#  'energy use': 'use',
#  'growth of human populations': 'growth',
#  'stars': 'star',
#  'natural resource conservation': 'natural',
#  'what are animals': 'animal',
#  'direction': 'direction',
#  'levels of ecological organization': 'level',
#  'coal power': 'power',
#  'thermal conductors and insulators': 'conductor',
#  'plant like protists': 'protist',
#  'fresh water ecosystems': 'ecosystem',
#  'internal combustion engines': 'engine',
#  'color': 'color',
#  'seawater chemistry': 'chemistry',
#  'central nervous system': 'nervous',
#  'earthquake safe structures': 'safe',
#  'the nature of science': 'nature',
#  'evolution and classification of plants': 'evolution',
#  'peripheral nervous system': 'nervous',
#  'mammal reproduction': 'mammal',
#  'staying safe in an earthquake': 'safe',
#  'surface ocean currents': 'surface',
#  'transition metals': 'metal',
#  'chemical bond': 'bond',
#  'viruses': 'virus',
#  'solubility and concentration': 'solubility',
#  'introduction to chemical reactions': 'introduction',
#  'reducing ozone destruction': 'destruction',
#  'plants adaptations for life on land': 'land',
#  'extinction and radiation of life': 'radiation',
#  'plate tectonics through earth history': 'tectonics',
#  'wave interactions': 'interaction',
#  'how elements are organized': 'element',
#  'harmful bacteria': 'bacteria',
#  'blood types': 'blood',
#  'mammals': 'mammal',
#  'the origin of earth': 'origin',
#  'earths mantle': 'earth mantle',
#  'scales that represent earthquake magnitude': 'magnitude',
#  'barriers to pathogens': 'pathogen',
#  'overview of the cardiovascular system': 'overview',
#  'chemical weathering': 'weathering',
#  'the light we see': 'light',
#  'saturation': 'saturation',
#  'lithification of sedimentary rocks': 'sedimentary',
#  'impacts of hazardous waste': 'waste',
#  'muscles bones and movement': 'muscle',
#  'deep ocean currents': 'current',
#  'nervous system': 'nervous',
#  'protist characteristics': 'protist',
#  'surface features of the sun': 'feature',
#  'ionic compounds': 'ionic',
#  'universe': 'universe',
#  'dangers and uses of radiation': 'radiation',
#  'energy level': 'level',
#  'keeping skin healthy': 'skin',
#  'artificial light': 'light',
#  'how animals evolved': 'animal',
#  'branches of earth science': 'branch',
#  'optics': 'optic',
#  'diseases of the nervous system': 'nervous',
#  'cellular respiration': 'cellular',
#  'calculating derived quantities': 'quantity',
#  'seismic waves': 'seismic wave',
#  'behavior of gases': 'gas',
#  'the nervous system': 'nervous',
#  'earths core': 'core',
#  'acids and bases': 'base',
#  'metallic bonding': 'metallic',
#  'inner vs. outer planets': 'outer',
#  'wind waves': 'wind',
#  'newtons law of gravity': 'newton',
#  'natural gas power': 'natural',
#  'external combustion engines': 'engine',
#  'intraplate activity': 'intraplate',
#  'insects and other arthropods': 'arthropod',
#  'arthropods': 'arthropod',
#  'water pollution': 'water pollution',
#  'gases': 'gas',
#  'measuring waves': 'wave',
#  'mendels pea plants': 'mendel',
#  'conservation of mass': 'mass',
#  'weather fronts': 'weather',
#  'technology and science': 'technology',
#  'biomes': 'biome',
#  'frequency and pitch of sound': 'frequency',
#  'dwarf planets': 'planet',
#  'optical instruments': 'instrument',
#  'properties of electromagnetic waves': 'electromagnetic',
#  'newtons second law': 'second',
#  'earths tectonic plates': 'plate',
#  'prokaryotic and eukaryotic cells': 'cell',
#  'earthquake characteristics': 'characteristic',
#  'sound waves': 'sound',
#  'the muscular system': 'muscular system',
#  'solutions': 'solution',
#  'bird reproduction': 'bird',
#  'greenhouse effect': 'effect',
#  'insects': 'insect',
#  'cell biology': 'cell',
#  'ph concept': 'concept',
#  'identification of minerals': 'identification',
#  'halogens': 'halogen',
#  'atomic forces': 'atomic',
#  'chemistry of living things': 'thing',
#  'habitat destruction': 'destruction',
#  'speed': 'speed',
#  'arachnids': 'arachnid',
#  'scientific theory': 'theory',
#  'tides': 'tide',
#  'types of archaea': 'archaea',
#  'convection': 'convection',
#  'chemical properties of matter': 'property',
#  'comets': 'comet',
#  'erosion and deposition by flowing water': 'erosion',
#  'the atmosphere': 'atmosphere',
#  'soil erosion': 'soil',
#  'volcanoes at plate boundaries': 'boundary',
#  'recombinant dna': 'dna',
#  'ionic bonding': 'ionic',
#  'weathering': 'aaa_none',
#  'jawless fish': 'fish',
#  'cardiovascular diseases': 'cardiovascular',
#  'planet orbits in the solar system': 'solar',
#  'faults': 'fault',
#  'endothermic reactions': 'endothermic reaction',
#  'seafloor spreading': 'seafloor',
#  'interior of the sun': 'interior',
#  'decomposition reactions': 'decomposition reaction',
#  'changes of state': 'state',
#  'power': 'power',
#  'b and t cell response': 'response',
#  'short term climate change': 'term',
#  'radiometric dating': 'radiometric',
#  'electrical grid': 'electrical',
#  'hydrogen bonding': 'hydrogen',
#  'groundwater pollution': 'groundwater',
#  'history of mesozoic life': 'mesozoic',
#  'mitosis vs. meiosis': 'mitosis',
#  'covalent bonding': 'covalent',
#  'direct and alternating current': 'current',
#  'erosion and deposition by gravity': 'gravity',
#  'using satellites and computers': 'satellite',
#  'photosynthesis': 'photosynthesis',
#  'local winds': 'wind',
#  'simple machines': 'simple',
#  'bacteria characteristics': 'bacteria',
#  'reproduction in seedless plants': 'seedless',
#  'electric transformers': 'electric',
#  'enzymes as catalysts': 'catalyst',
#  'introduction to solutions': 'solution',
#  'overpopulation and over consumption': 'overpopulation consumption',
#  'nails and hair': 'nail hair',
#  'projectile motion': 'motion',
#  'rate of dissolving': 'rate',
#  'chemical reaction rate': 'rate',
#  'skeletal system joints': 'joint',
#  'weather and water in the atmosphere': 'weather',
#  'modern periodic table': 'table',
#  'glaciers': 'glacier',
#  'asteroids': 'asteroid',
#  'ocean life': 'ocean',
#  'vision and the eye': 'eye',
#  'mechanical weathering': 'weathering',
#  'the scope of physical science': 'scope',
#  'visible light and matter': 'visible',
#  'radioisotopes': 'radioisotope',
#  'exoplanets': 'exoplanets',
#  'why earth is a magnet': 'magnet',
#  'use and conservation of energy': 'use',
#  'modern atomic theory': 'modern',
#  'keeping bones and joints healthy': 'joint',
#  'electric charge and electric force': 'charge',
#  'the skeletal system': 'skeletal',
#  'carbohydrate classification': 'classification',
#  'safety in science': 'safety',
#  'saturn': 'saturn',
#  'biochemical reaction chemistry': 'biochemical',
#  'ocean ecosystems': 'ecosystem',
#  'protists nutrition': 'nutrition',
#  'earths energy': 'earth energy',
#  'nonrenewable resources': 'nonrenewable',
#  'chemical formula': 'chemical',
#  'machines': 'machine',
#  'nuclear fission': 'nuclear',
#  'heat budget of planet earth': 'heat',
#  'biochemical compound classification': 'biochemical',
#  'mineral formation': 'formation',
#  'health hazards of air pollution': 'health',
#  'fossils': 'fossil',
#  'hiv and aids': 'hiv aid',
#  'electric circuits': 'circuit',
#  'biotechnology in agriculture': 'agriculture',
#  'lymphatic system': 'lymphatic',
#  'pressure of fluids': 'fluid',
#  'female reproductive structures': 'female',
#  'urinary system': 'urinary system',
#  'weather forecasting': 'weather',
#  'doppler effect': 'effect',
#  'modeling earths surface': 'surface',
#  'influences on weathering': 'influence',
#  'ocean movements': 'movement',
#  'earths moon': 'moon',
#  'temperature and heat in the atmosphere': 'temperature',
#  'hazardous waste': 'waste',
#  'magnetic field reversal': 'magnetic',
#  'heat waves and droughts': 'heat',
#  'changing weather': 'weather',
#  'scientific modeling': 'scientific',
#  'mutations': 'mutation',
#  'using earths magnetic field': 'magnetic',
#  'thermal energy': 'thermal',
#  'injuries of the nervous system': 'nervous',
#  'chemical equations': 'equation',
#  'conserving water': 'water',
#  'electromagnetic spectrum': 'spectrum',
#  'animal like protists': 'protist',
#  'renewable resources and alternative energy sources': 'renewable',
#  'principle of uniformitarianism': 'principle',
#  'ohms law': 'law',
#  'radioactive decay': 'radioactive',
#  'immunity': 'immunity',
#  'using sound': 'sound',
#  'microevolution and macroevolution': 'microevolution macroevolution',
#  'puberty and adolescence': 'puberty adolescence',
#  'introduction to genetics': 'genetics',
#  'origin of species': 'origin',
#  'reactants and products': 'reactant product',
#  'mirrors': 'mirror',
#  'preserving water sources': 'source',
#  'thermal radiation': 'radiation',
#  'solubility': 'solubility',
#  'troposphere': 'troposphere',
#  'predation': 'predation',
#  'specific heat': 'heat',
#  'fermentation': 'fermentation',
#  'stress in earths crust': 'crust',
#  'history of paleozoic life': 'paleozoic',
#  'potential energy': 'potential energy',
#  'preventing infectious diseases': 'infectious',
#  'effects of air pollution': 'effect',
#  'bernoullis law': 'law',
#  'earths crust': 'crust',
#  'principle of horizontality': 'principle',
#  'lipid classification': 'classification',
#  'use and conservation of resources': 'use',
#  'soil formation': 'formation',
#  'punnett squares': 'punnett',
#  'volcanic eruptions': 'volcanic',
#  'kidneys': 'kidney',
#  'electromagnetic energy in the atmosphere': 'electromagnetic',
#  'metallic bonds': 'metallic',
#  'expansion of the universe': 'universe',
#  'folds': 'fold',
#  'human skeletal system': 'skeletal',
#  'preventing hazardous waste problems': 'waste',
#  'limiting factors to population growth': 'growth',
#  'mesozoic plate tectonics': 'mesozoic',
#  'plant responses and special adaptations': 'response',
#  'mitosis and cytokinesis': 'mitosis',
#  'finding and mining ores': 'mining',
#  'star classification': 'star',
#  'the sun': 'sun',
#  'fish': 'fish',
#  'erosion and deposition by wind': 'wind',
#  'ethics in science': 'ethic science',
#  'eclipses': 'eclipse',
#  'energy': 'energy',
#  'importance of the atmosphere': 'importance',
#  'ponds and lakes': 'pond lake',
#  'history of science': 'history',
#  'the endocrine system': 'endocrine system',
#  'diabetes': 'diabetes',
#  'non mendelian inheritance': 'inheritance',
#  'food and nutrients': 'nutrient',
#  'earths magnetic field': 'magnetic',
#  'scientific induction': 'induction',
#  'organization of the human body': 'body',
#  'significant figures': 'significant figure',
#  'respiratory system health': 'respiratory',
#  'active transport': 'transport',
#  'maps': 'map',
#  'introduction to the solar system': 'solar',
#  'connecting cellular respiration and photosynthesis': 'cellular',
#  'predicting weather': 'weather',
#  'autoimmune diseases': 'disease',
#  'animal behaviors': 'behavior',
#  'vision correction': 'vision',
#  'gravity': 'gravity',
#  'echinoderms and invertebrate chordates': 'invertebrate',
#  'groundwater': 'groundwater',
#  'kinetic energy': 'kinetic',
#  'wave interference': 'interference',
#  'organization of living things': 'organization',
#  'bohrs atomic model': 'model',
#  'roundworms': 'roundworm',
#  'technology': 'technology',
#  'the respiratory system': 'respiratory',
#  'fertilization': 'fertilization',
#  'modern biodiversity': 'biodiversity',
#  'divergent plate boundaries': 'divergent',
#  'acid rain': 'acid',
#  'electric resistance': 'electric',
#  'noninfectious diseases': 'noninfectious',
#  'light reactions of photosynthesis': 'photosynthesis',
#  'global warming': 'warming',
#  'structural evidence for evolution': 'evidence',
#  'hurricanes': 'hurricane',
#  'newtons third law': 'third',
#  'wheel and axle': 'wheel axle',
#  'fungi structure': 'fungi',
#  'blood pressure': 'pressure',
#  'flow of energy': 'flow',
#  'introduction to plants': 'introduction',
#  'flatworms and roundworms': 'roundworm',
#  'cell division': 'division',
#  'electronics': 'electronics',
#  'importance of mammals': 'mammal',
#  'crystalline carbon': 'carbon',
#  'recent space exploration': 'exploration',
#  'role of amphibians': 'role',
#  'population size': 'population',
#  'nitrogen cycle in ecosystems': 'nitrogen',
#  'electromagnet': 'electromagnet',
#  'mars': 'mar',
#  'domains of life': 'domain life',
#  'electric power and electrical energy use': 'electrical',
#  'biological communities': 'community',
#  'volcanic activity': 'activity',
#  'temperature and heat': 'temperature',
#  'types of nutrients': 'nutrient',
#  'soil characteristics': 'soil',
#  'weathering and erosion': 'erosion',
#  'scientific explanations and interpretations': 'scientific',
#  'landforms from groundwater erosion and deposition': 'landforms',
#  'states of matter': 'state',
#  'availability of natural resources': 'natural',
#  'scientific theories': 'theory',
#  'types of energy': 'type',
#  'scientific community': 'community',
#  'oceanic pressure': 'pressure',
#  'importance of echinoderms': 'echinoderm',
#  'metabolism and replication': 'replication',
#  'excretion': 'excretion',
#  'solenoid': 'solenoid',
#  'erosion and deposition by waves': 'erosion',
#  'sedimentary rocks': 'sedimentary',
#  'cell membrane': 'cell',
#  'the integumentary system': 'integumentary system',
#  'air pressure and altitude': 'pressure',
#  'sustainable development': 'development',
#  'fungi reproduction': 'fungi',
#  'adulthood and aging': 'adulthood',
#  'replacement reactions': 'replacement reaction',
#  'protein synthesis': 'synthesis',
#  'the biosphere': 'biosphere',
#  'solar energy on earth': 'solar',
#  'work': 'work',
#  'types of marine organisms': 'organism',
#  'insect reproduction and life cycle': 'insect',
#  'earth science and its branches': 'branch',
#  'control of insects': 'insect',
#  'properties of acids': 'acid',
#  'homeostasis': 'homeostasis',
#  'gravity in the solar system': 'gravity',
#  'earthquakes at transform plate boundaries': 'transform',
#  'bacteria': 'bacteria',
#  'fossil fuel formation': 'fuel',
#  'ferromagnetic material': 'material',
#  'how the eye works': 'eye',
#  'heart and blood vessels': 'heart',
#  'nonrenewable energy resources': 'nonrenewable',
#  'protecting water from pollution': 'water pollution',
#  'galaxies': 'galaxy',
#  'force': 'force',
#  'transform plate boundaries': 'transform',
#  'scientific models': 'model',
#  'changes in matter': 'change',
#  'pressure in fluids': 'fluid',
#  'vision problems and corrective lenses': 'lens',
#  'avoiding soil loss': 'loss',
#  'neptune': 'neptune',
#  'mammal characteristics': 'mammal',
#  'wave amplitude': 'wave amplitude',
#  'effects of air pollution on the environment': 'effect',
#  'beta decay': 'decay',
#  'compounds': 'compound',
#  'radio waves': 'radio wave',
#  'electric safety': 'safety',
#  'habitat and niche': 'habitat',
#  'mammal classification': 'mammal',
#  'choosing healthy foods': 'healthy',
#  'infectious diseases': 'infectious',
#  'scientific law': 'scientific',
#  'cell structures': 'structure',
#  'what is science': 'science',
#  'technological design constraints': 'design',
#  'evaporation': 'evaporation',
#  'process of cellular respiration': 'cellular',
#  'cyclic behavior of animals': 'behavior',
#  'what is life science': 'life science',
#  'sex linked inheritance': 'inheritance',
#  'tsunami': 'tsunami',
#  'conservation of mass in chemical reactions': 'mass',
#  'groups of elements': 'group',
#  'importance of insects': 'insect',
#  'jupiter': 'jupiter',
#  'field study': 'field',
#  'water on earth': 'water earth',
#  'mercury': 'mercury',
#  'synthesis reactions': 'synthesis',
#  'chordates': 'chordate',
#  'staying safe in earthquakes': 'safe',
#  'pulley': 'pulley',
#  'transverse wave': 'transverse wave',
#  'lever': 'lever',
#  'international system of units': 'international system unit',
#  'isotopes': 'isotope',
#  'electromagnetic waves': 'electromagnetic',
#  'indoor air pollution': 'air',
#  'milky way': 'way',
#  'types of volcanoes': 'volcano',
#  'characteristics of life': 'characteristic',
#  'inside the atom': 'atom',
#  'compound machines': 'machine',
#  'alligators and crocodiles': 'alligator crocodile',
#  'telescopes': 'telescope',
#  'the history of astronom': 'history',
#  'the water cycle': 'cycle',
#  'nonvascular plants': 'plant',
#  'cenozoic plate tectonics': 'cenozoic',
#  'bond polarity': 'polarity',
#  'generating and using electricity': 'electricity',
#  'longitudinal wave': 'longitudinal wave',
#  'processes of the water cycle': 'process',
#  'scope of chemistry': 'scope',
#  'chemical change': 'change',
#  'introduction to vertebrates': 'vertebrate',
#  'transfer of thermal energy': 'transfer',
#  'helpful bacteria': 'bacteria',
#  'mercury pollution': 'mercury',
#  'metamorphic rock classification': 'metamorphic',
#  'static electricity and static discharge': 'static',
#  'continental drift': 'drift',
#  'angiosperms': 'angiosperm',
#  'newtons first law': 'first',
#  'magnets and magnetism': 'magnetism',
#  'immune system defenses': 'defense',
#  'taste and smell': 'taste smell',
#  'acid base neutralization': 'base',
#  'freezing': 'aaa_none',
#  'descriptive statistics': 'descriptive statistic',
#  'fundamental particles': 'particle',
#  'temperature': 'temperature',
#  'velocity': 'velocity',
#  'charless law': 'law',
#  'theory of plate tectonics': 'tectonics',
#  'mechanical wave': 'mechanical',
#  'importance of reptiles': 'reptile',
#  'earths layers': 'layer',
#  'thermosphere and beyond': 'thermosphere',
#  'blood vessels': 'vessel',
#  'motion': 'motion',
#  'cancer': 'cancer',
#  'the nitrogen cycle': 'nitrogen',
#  'lifes building blocks': 'building',
#  'characteristics of sound': 'sound',
#  'types of fossilization': 'fossilization',
#  'timeline of evolution': 'evolution',
#  'scientific process': 'process',
#  'century tsunami': 'tsunami',
#  'ozone depletion': 'ozone',
#  'basic and applied science': 'basic science',
#  'reproductive system health': 'health',
#  'gene therapy': 'gene',
#  'gymnosperms': 'gymnosperm',
#  'oil spills': 'oil spill',
#  'global wind belts': 'global',
#  'electromagnetism': 'electromagnetism',
#  'aquatic biomes': 'biome',
#  'influences on darwin': 'darwin',
#  'terrestrial biomes': 'biome',
#  'ecosystem change': 'ecosystem',
#  'properties of matter': 'property',
#  'balancing chemical equations': 'equation',
#  'wave speed': 'speed',
#  'the senses': 'sens',
#  'reproduction': 'reproduction',
#  'importance of protists': 'protist',
#  'alpha decay': 'decay',
#  'precambrian plate tectonics': 'precambrian',
#  'respiratory system diseases': 'respiratory',
#  'transfer of electric charge': 'charge',
#  'wave frequency': 'frequency',
#  'types of chemical reactions': 'type',
#  'hardy weinberg theorem': 'hardy weinberg theorem',
#  'pollution of the land': 'land',
#  'pathogens': 'pathogen',
#  'mendels discoveries': 'discovery',
#  'energy conservation': 'conservation',
#  'pressure and density of the atmosphere': 'density',
#  'landforms from glacial erosion and deposition': 'landforms',
#  'the excretory system': 'excretory',
#  'petroleum power': 'power',
#  'conservation of energy in chemical reactions': 'conservation',
#  'radioactive decay as a measure of age': 'radioactive',
#  'streams and rivers': 'stream river',
#  'bacteria nutrition': 'nutrition',
#  'explosive eruptions': 'eruption',
#  'importance of arthropods': 'arthropod',
#  'renewable energy resources': 'renewable',
#  'planets of the solar system': 'solar',
#  'populations': 'population',
#  'geologic time scale': 'scale',
#  'bony fish': 'fish',
#  'absolute ages of rocks': 'age',
#  'outdoor air pollution': 'air',
#  'nucleic acid classification': 'acid',
#  'chromosomal disorders': 'disorder',
#  'gamma decay': 'gamma',
#  'earthquakes at convergent plate boundaries': 'boundary',
#  'learned behavior of animals': 'behavior',
#  'human population': 'population',
#  'reducing air pollution': 'air',
#  'position time graphs': 'position',
#  'volcano characteristics': 'volcano',
#  'archimedes law': 'law',
#  'meiosis': 'meiosis',
#  'evolution plate tectonics and climate change': 'tectonics',
#  'plant characteristics': 'characteristic',
#  'translation of rna to protein': 'rna',
#  'combining forces': 'force',
#  'carbon cycle and climate': 'carbon',
#  'the human population': 'population',
#  'erosion and deposition by glaciers': 'glacier',
#  'early atmosphere and oceans': 'early',
#  'roles in an ecosystem': 'role',
#  'distribution of water on earth': 'distribution',
#  'passive transport': 'transport',
#  'human evolution': 'evolution',
#  'metalloids': 'metalloids',
#  'coriolis effect': 'effect',
#  'wave particle theory': 'particle',
#  'thunderstorms': 'thunderstorm',
#  'sources of water pollution': 'source',
#  'biochemical reactions': 'biochemical',
#  'composition of the atmosphere': 'composition',
#  'physical properties of matter': 'physical',
#  'hot springs and geysers': 'hot spring geyser',
#  'meteors': 'meteor',
#  'fungus like protists': 'protist',
#  'importance of biodiversity': 'biodiversity',
#  'catalysts': 'catalyst',
#  'earthquake damage': 'earthquake',
#  'sedimentary rock classification': 'sedimentary',
#  'star constellations': 'star',
#  'pedigree analysis': 'pedigree analysis',
#  'touch': 'touch',
#  'magnetic polarity evidence for continental drift': 'polarity',
#  'mesosphere': 'mesosphere',
#  'geological stresses': 'stress',
#  'vitamins and minerals': 'mineral',
#  'the microscope': 'microscope',
#  'history of cenozoic life': 'cenozoic',
#  'valence electrons': 'electron',
#  'flooding': 'aaa_none',
#  'properties of carbon': 'carbon',
#  'diffusion': 'diffusion',
#  'seafloor spreading hypothesis': 'seafloor',
#  'speed and velocity': 'speed',
#  'fossil fuel reserves': 'fuel',
#  'revolutions of earth': 'revolution earth',
#  'physical science careers': 'career',
#  'electromagnetic devices': 'device',
#  'cell nucleus': 'nucleus',
#  'effect of latitude on climate': 'latitude',
#  'microscopes': 'microscope',
#  'magma composition at volcanoes': 'composition',
#  'precambrian continents': 'precambrian',
#  'inclined plane': 'inclined plane',
#  'blizzards': 'blizzard',
#  'digestive system organs': 'organ',
#  'human uses of fungi': 'human',
#  'melting': 'aaa_none',
#  'the ocean floor': 'ocean',
#  'plant classification': 'classification',
#  'intraplate earthquakes': 'intraplate',
#  'sponges': 'sponge',
#  'rocks and processes of the rock cycle': 'process',
#  'matter mass and volume': 'mass',
#  'rutherfords atomic model': 'model',
#  'storms': 'storm',
#  'chemistry of life': 'chemistry',
#  'organic compounds': 'compound',
#  'solution concentration': 'concentration',
#  'features of populations': 'feature',
#  'frogs and toads': 'frog toad',
#  'calculating work': 'work',
#  'recognizing chemical reactions': 'chemical',
#  ...}

# %%
meta_lesson_id_assignments
# Out:
# {'einsteins concept of gravity': 178,
#  'calculating acceleration from velocity and time': 72,
#  'chemical properties of matter': 501,
#  'screw': 174,
#  'hypothesis': 2,
#  'protists': 266,
#  'electric charge': 85,
#  'development of hypotheses': 371,
#  'early space exploration': 159,
#  'scientific graphing': 114,
#  'microscopes': 240,
#  'the electromagnetic spectrum': 438,
#  'conservation of mass and energy in nuclear reactions': 10,
#  'flatworms and roundworms': 320,
#  'cardiovascular system': 491,
#  'processes of breathing': 222,
#  'musical instruments': 59,
#  'neptune': 393,
#  'properties of solutions': 346,
#  'comets': 183,
#  'cell structures': 440,
#  'types of friction': 150,
#  'bathymetric evidence for seafloor spreading': 18,
#  'condensation': 16,
#  'supervolcanoes': 17,
#  'food and nutrients': 190,
#  'accuracy and precision': 110,
#  'population growth patterns': 408,
#  'wind power': 505,
#  'ionic bonds': 48,
#  'technological design process': 306,
#  'mining and using minerals': 253,
#  'social behavior of animals': 380,
#  'physical change': 340,
#  'correlation using relative ages': 350,
#  'elements': 305,
#  'organization of the human body': 92,
#  'bacteria reproduction': 388,
#  'evolution acts on the phenotype': 344,
#  'salamanders': 274,
#  'components of blood': 84,
#  'flatworms': 237,
#  'tropisms': 384,
#  'lens': 31,
#  'predicting earthquakes': 365,
#  'agriculture and human population growth': 234,
#  'world climates': 475,
#  'boyles law': 437,
#  'air masses': 458,
#  'nuclear energy': 10,
#  'heat': 32,
#  'long term climate change': 435,
#  'human egg cells': 392,
#  'nature of earthquakes': 106,
#  'velocity time graphs': 308,
#  'introduction to groundwater': 355,
#  'measuring and predicting earthquakes': 365,
#  'scientific experiments': 184,
#  'soil horizons and profiles': 419,
#  'echinoderms': 269,
#  'divergent plate boundaries in the oceans': 484,
#  'neutrons': 331,
#  'electric charge and electric force': 85,
#  'groups with metalloids': 469,
#  'venus': 37,
#  'acceleration': 38,
#  'landforms from erosion and deposition by gravity': 449,
#  'planet orbits in the solar system': 508,
#  'respiratory system organs': 118,
#  'active transport': 503,
#  'nature of science': 106,
#  'introduction to earths surface': 405,
#  'sources of visible light': 289,
#  'weather versus climate': 0,
#  'faults': 125,
#  'energy conversion': 43,
#  'human causes of extinction': 451,
#  'hydrogen bonding': 459,
#  'wedge': 177,
#  'air quality': 452,
#  'introduction to the solar system': 508,
#  'seafloor spreading': 18,
#  'topographic maps': 272,
#  'protecting the water supply': 399,
#  'connecting cellular respiration and photosynthesis': 246,
#  'formation of earth': 22,
#  'preventing noninfectious diseases': 217,
#  'volcanoes at plate boundaries': 268,
#  'testing hypotheses': 2,
#  'chemical reaction overview': 498,
#  'cellular respiration reactions': 246,
#  'energy resources': 113,
#  'isomers': 103,
#  'rate of dissolving': 398,
#  'saturated hydrocarbons': 252,
#  'fungi': 46,
#  'introduction to the human body': 92,
#  'outdoor air pollution': 452,
#  'rocks': 76,
#  'importance of reptiles': 385,
#  'non renewable energy resources': 139,
#  'types of rocks': 76,
#  'succession': 54,
#  'vision correction': 79,
#  'birds': 34,
#  'layers of the atmosphere': 284,
#  'daltons atomic theory': 98,
#  'effect of continental position on climate': 20,
#  'mollusks': 285,
#  'seasons': 368,
#  'heat conduction': 32,
#  'wegener and the continental drift hypothesis': 146,
#  'introduction to the oceans': 267,
#  'carbon and living things': 333,
#  'buoyancy': 61,
#  'skin': 63,
#  'predicting volcanic eruptions': 315,
#  'energy pyramids': 224,
#  'acid rain': 161,
#  'blood': 66,
#  'cell cycle': 124,
#  'cartilaginous fish': 335,
#  'air movement': 230,
#  'circulation and the lymphatic system': 363,
#  'characteristics of waves': 191,
#  'development of theories': 371,
#  'types of matter': 318,
#  'compound machine': 445,
#  'using thermal energy': 367,
#  'safety of water': 91,
#  'uses of water': 425,
#  'dna structure and replication': 280,
#  'mendeleevs periodic table': 431,
#  'heat transfer in the atmosphere': 193,
#  'star constellations': 357,
#  'materials humans use': 141,
#  'inside earth': 70,
#  'earths interior material': 420,
#  'tornadoes': 360,
#  'what are biomes': 470,
#  'history of earths life forms': 101,
#  'earth history and clues from fossils': 239,
#  'blood diseases': 66,
#  'loss of soil': 441,
#  'inertia': 77,
#  'energy in the atmosphere': 436,
#  'effects of water pollution': 455,
#  'vision': 79,
#  'vertebrate characteristics': 58,
#  'surface water': 405,
#  'the universe': 216,
#  'electronic signal': 88,
#  'asexual vs. sexual reproduction': 443,
#  'reducing air pollution': 452,
#  'flow of matter in ecosystems': 434,
#  'hydrogen and alkali metals': 459,
#  'lifes building blocks': 90,
#  'non infectious reproductive system disorders': 442,
#  'lizards and snakes': 430,
#  'technology': 361,
#  'discovery of electromagnetism': 341,
#  'natural resources': 270,
#  'cardiovascular system health': 491,
#  'scientific ways of thinking': 483,
#  'location and direction': 202,
#  'age of earth': 424,
#  'liquids': 136,
#  'democrituss idea of the atom': 423,
#  'what is ecology': 485,
#  'alkaline earth metals': 334,
#  'mendels laws and genetics': 87,
#  'galaxies': 140,
#  'seeds and seed dispersal': 275,
#  'air pollution': 452,
#  'alloys': 238,
#  'states of water': 218,
#  'measuring earthquake magnitude': 500,
#  'communication in science': 47,
#  'archaea': 95,
#  'tree rings ice cores and varves': 7,
#  'inner planets': 93,
#  'divergent plate boundaries': 484,
#  'metamorphic rocks': 182,
#  'formation of minerals': 22,
#  'volcanic landforms': 315,
#  'mitosis vs. meiosis': 322,
#  'electrons': 402,
#  'nature of technology': 106,
#  'mass extinctions': 220,
#  'nerve cells and nerve impulses': 338,
#  'density': 102,
#  'rna': 104,
#  'history of the atom': 423,
#  'food webs': 86,
#  'distance between stars': 127,
#  'activation energy': 107,
#  'competition': 108,
#  'reptiles': 385,
#  'innate behavior of animals': 380,
#  'erosion and deposition by gravity': 353,
#  'electronic device': 265,
#  'intensity and loudness of sound': 176,
#  'microwaves': 387,
#  'importance of seedless plants': 12,
#  'ions': 359,
#  'chemical and solar cells': 508,
#  'electron cloud atomic model': 283,
#  'energy from biomass': 429,
#  'respiration': 115,
#  'reproduction': 443,
#  'using electromagnetism': 439,
#  'types of mollusks': 285,
#  'amphibians': 474,
#  'the scientific method': 296,
#  'metals': 334,
#  'nuclear power': 10,
#  'earthquake zones': 356,
#  'crustaceans': 11,
#  'specific heat': 32,
#  'mineral groups': 65,
#  'primates': 396,
#  'solute and solvent': 404,
#  'big bang': 122,
#  'causes of air pollution': 451,
#  'molecular evidence for evolution': 223,
#  'reproductive behavior of animals': 380,
#  'evolution of simple cells': 422,
#  'plant cell structures': 440,
#  'early earth': 206,
#  'reproduction in seedless plants': 12,
#  'scope of physical science': 117,
#  'distance': 127,
#  'science skills': 504,
#  'effects of air pollution on human health': 144,
#  'nonmetals': 377,
#  'thomsons atomic model': 314,
#  'effect of latitude on climate': 465,
#  'heart': 129,
#  'nuclear fusion': 10,
#  'cycles of matter': 318,
#  'hearing and balance': 169,
#  'electric conductors and insulators': 348,
#  'dna the genetic material': 494,
#  'importance of mollusks': 285,
#  'deposition': 21,
#  'law of conservation of momentum': 493,
#  'human genome project': 247,
#  'diversity of birds': 34,
#  'inflammatory response': 461,
#  'mountain building': 90,
#  'natural selection': 270,
#  'the nature of science': 106,
#  'keeping the nervous system healthy': 413,
#  'optics': 186,
#  'first two lines of defense': 349,
#  'acids and bases': 123,
#  'speed of sound': 44,
#  'cleaning up groundwater': 355,
#  'characteristics of living organisms': 45,
#  'dark matter': 318,
#  'how ocean currents moderate climate': 482,
#  'electric generators': 30,
#  'scope of chemistry': 117,
#  'enzymes in the digestive system': 208,
#  'electric current': 482,
#  'electronic component': 84,
#  'temperature of the atmosphere': 219,
#  'properties of bases': 123,
#  'mid latitude cyclones': 465,
#  'light': 143,
#  'human vision': 79,
#  'biodiversity and extinction': 96,
#  'importance of mammals': 258,
#  'ocean garbage patch': 267,
#  'protein synthesis and gene expression': 198,
#  'immune system defenses': 349,
#  'symbiosis': 145,
#  'solids': 263,
#  'light reactions of photosynthesis': 262,
#  'classes of elements': 305,
#  'sound waves': 176,
#  'chromosomal disorders': 407,
#  'types of echinoderms': 269,
#  'seasonal changes in plants': 64,
#  'genetic disorders': 494,
#  'mineral identification': 201,
#  'solubility': 149,
#  'the digestive system': 403,
#  'clouds': 283,
#  'weather and water in the atmosphere': 0,
#  'relative ages of rocks': 350,
#  'availability of natural resources': 270,
#  'transcription of dna to rna': 104,
#  'intrusive and extrusive igneous rocks': 293,
#  'wavelength': 152,
#  'electricity and magnetism': 119,
#  'hearing loss': 441,
#  'male reproductive system': 241,
#  'formation of the sun and planets': 243,
#  'introduction to prokaryotes': 164,
#  'coastal pollution': 155,
#  'safety in the life sciences': 91,
#  'covalent bonding': 310,
#  'communities': 495,
#  'history of life on earth': 4,
#  'precambrian plate tectonics': 192,
#  'igneous rocks': 293,
#  'chemical bonding': 60,
#  'eclipses': 433,
#  'respiratory system diseases': 6,
#  'atoms': 423,
#  'introduction to ecology': 485,
#  'determining relative ages': 350,
#  'scientific method': 296,
#  'bacteria in the digestive system': 403,
#  'paleozoic and mesozoic seas': 142,
#  'humans and primates': 396,
#  'cooling systems': 128,
#  'adaptation and evolution of populations': 354,
#  'organelles': 337,
#  'igneous landforms and geothermal activ': 468,
#  'elastic force': 130,
#  'ocean zones': 356,
#  'ecosystems': 235,
#  'cell transport': 503,
#  'weather maps': 272,
#  'features of populations': 292,
#  'polygenic traits': 3,
#  'rotation of earth': 211,
#  'male reproductive structures': 241,
#  'principles of relative dating': 456,
#  'groundwater depletion': 499,
#  'vascular seedless plants': 12,
#  'climate change in earth history': 4,
#  'effusive eruptions': 324,
#  'fungi classification': 46,
#  'precipitation': 167,
#  'climate and its causes': 451,
#  'invertebrates': 181,
#  'nonvascular plants': 154,
#  'temperature and heat': 219,
#  'types of air pollution': 452,
#  'the hertzsprung russell diagra': 165,
#  'what is force': 390,
#  'technology and society': 361,
#  'magnets': 94,
#  'soil characteristics': 419,
#  'surface wave': 405,
#  'introduction to chemical bonds': 409,
#  'boiling': 286,
#  'female reproductive system': 502,
#  'types of soils': 419,
#  'the carbon cycle': 391,
#  'soil erosion': 419,
#  'energy conservation': 188,
#  'solar power': 508,
#  'landforms from groundwater erosion and deposition': 449,
#  'centipedes and millipedes': 1,
#  'atomic number': 257,
#  'natural resource conservation': 270,
#  'cloning': 286,
#  'plasma': 175,
#  'paleozoic plate tectonics': 142,
#  'characteristics and origins of life': 51,
#  'protein classification': 207,
#  'the sun and the earthmoon system': 243,
#  'ultrasound': 180,
#  'sponges and cnidarians': 432,
#  'formation of the moon': 185,
#  'water distribution': 476,
#  'locating earthquake epicenters': 365,
#  'keeping bones and joints healthy': 507,
#  'stratosphere': 195,
#  'sexually transmitted infections': 370,
#  'star power': 357,
#  'mechanical advantage': 374,
#  'moon': 185,
#  'electric fields': 249,
#  'amontonss law': 437,
#  'environmental impacts of mining': 74,
#  'efficiency': 203,
#  'human digestive system': 403,
#  'climate change': 64,
#  'photosynthesis reactions': 262,
#  'wave interactions and interference': 121,
#  'menstrual cycle': 124,
#  'segmented worms': 463,
#  'solution concentration': 416,
#  'streams and rivers': 233,
#  'magnetic evidence for seafloor spreading': 18,
#  'cnidarians': 134,
#  'uranus': 196,
#  'importance of birds': 34,
#  'human sperm': 247,
#  'energy use': 481,
#  'growth of human populations': 408,
#  'stars': 357,
#  'gamma rays': 225,
#  'importance of arthropods': 260,
#  'lithification of sedimentary rocks': 148,
#  'what are animals': 199,
#  'direction': 202,
#  'levels of ecological organization': 75,
#  'coal power': 256,
#  'thermal conductors and insulators': 227,
#  'plant like protists': 266,
#  'plants adaptations for life on land': 345,
#  'fresh water ecosystems': 235,
#  'planets of the solar system': 508,
#  'color': 205,
#  'plate tectonics through earth history': 49,
#  'central nervous system': 23,
#  'erosion and deposition by waves': 68,
#  'significant figures': 497,
#  'evolution and classification of plants': 344,
#  'peripheral nervous system': 23,
#  'mammal reproduction': 258,
#  'pregnancy and childbirth': 25,
#  'diseases of the nervous system': 23,
#  'surface ocean currents': 405,
#  'chemical bond': 409,
#  'viruses': 137,
#  'geologic time scale': 170,
#  'introduction to chemical reactions': 164,
#  'reducing ozone destruction': 5,
#  'lymphatic system': 363,
#  'extinction and radiation of life': 375,
#  'wave interactions': 173,
#  'how elements are organized': 305,
#  'harmful bacteria': 388,
#  'blood types': 66,
#  'groundwater pollution': 355,
#  'the origin of earth': 51,
#  'earths mantle': 336,
#  'using satellites and computers': 414,
#  'chemical reaction rate': 398,
#  'barriers to pathogens': 303,
#  'ocean life': 267,
#  'chemical weathering': 251,
#  'modern atomic theory': 273,
#  'reduce reuse and recycle': 214,
#  'impacts of hazardous waste': 19,
#  'muscles bones and movement': 297,
#  'heat budget of planet earth': 32,
#  'nervous system': 23,
#  'protist characteristics': 266,
#  'surface features of the sun': 292,
#  'ionic compounds': 48,
#  'universe': 216,
#  'dangers and uses of radiation': 375,
#  'protein synthesis': 39,
#  'keeping skin healthy': 63,
#  'metallic bonds': 462,
#  'preventing hazardous waste problems': 19,
#  'earths shape': 316,
#  'hearing sound': 176,
#  'cellular respiration': 246,
#  'calculating derived quantities': 472,
#  'seismic waves': 57,
#  'behavior of gases': 347,
#  'the nervous system': 23,
#  'producers': 426,
#  'other objects in the solar system': 508,
#  'metallic bonding': 462,
#  'inner vs. outer planets': 36,
#  'wind waves': 505,
#  'newtons law of gravity': 446,
#  'natural gas power': 270,
#  'external combustion engines': 454,
#  'calculating acceleration from force and mass': 38,
#  'insects and other arthropods': 260,
#  'arthropods': 260,
#  'blood pressure': 244,
#  'water pollution': 232,
#  'gases': 347,
#  'measuring waves': 132,
#  'mendels pea plants': 87,
#  'conservation of mass': 458,
#  'weather fronts': 0,
#  'biomes': 470,
#  'volcano characteristics': 383,
#  'dwarf planets': 13,
#  'optical instruments': 59,
#  'types of marine organisms': 45,
#  'earths tectonic plates': 153,
#  'insect reproduction and life cycle': 364,
#  'earthquake characteristics': 191,
#  'the muscular system': 97,
#  'staying safe in an earthquake': 116,
#  'solutions': 346,
#  'bird reproduction': 34,
#  'greenhouse effect': 455,
#  'insects': 364,
#  'cell biology': 392,
#  'ph concept': 178,
#  'identification of minerals': 201,
#  'halogens': 457,
#  'atomic forces': 257,
#  'chemistry of living things': 333,
#  'habitat destruction': 5,
#  'speed': 44,
#  'arachnids': 29,
#  'tides': 212,
#  'types of archaea': 95,
#  'convection': 248,
#  'protons': 254,
#  'predation': 309,
#  'the biosphere': 488,
#  'muscles and exercise': 297,
#  'erosion and deposition by flowing water': 68,
#  'the atmosphere': 436,
#  'heating systems': 400,
#  'types of animal behavior': 380,
#  'recombinant dna': 245,
#  'ionic bonding': 48,
#  'weathering': 286,
#  'jawless fish': 335,
#  'distance and direction': 127,
#  'mollusks and annelids': 285,
#  'classification of living things': 333,
#  'endothermic reactions': 26,
#  'scientific measuring devices': 265,
#  'interior of the sun': 420,
#  'carbon cycle and climate': 391,
#  'power': 256,
#  'b and t cell response': 461,
#  'short term climate change': 435,
#  'radiometric dating': 172,
#  'electrical grid': 62,
#  'mammals': 258,
#  'safety in life science research': 91,
#  'modeling earths surface': 405,
#  'sublimation': 259,
#  'direct and alternating current': 482,
#  'origins of life': 51,
#  'radioactivity': 261,
#  'passive transport': 503,
#  'photosynthesis': 262,
#  'local winds': 505,
#  'bacteria characteristics': 388,
#  'noble gases': 347,
#  'electric transformers': 30,
#  'enzymes as catalysts': 506,
#  'introduction to solutions': 346,
#  'ocean movements': 230,
#  'nails and hair': 417,
#  'projectile motion': 33,
#  'scales that represent earthquake magnitude': 500,
#  'skeletal system joints': 507,
#  'soils': 419,
#  'modern periodic table': 431,
#  'glaciers': 471,
#  'fossil fuel formation': 204,
#  'volcanoes at hotspots': 383,
#  'overview of the cardiovascular system': 498,
#  'vision and the eye': 490,
#  'understanding animal behavior': 380,
#  'mechanical weathering': 251,
#  'how the eye works': 490,
#  'visible light and matter': 289,
#  'radioisotopes': 298,
#  'exoplanets': 276,
#  'why earth is a magnet': 94,
#  'use and conservation of energy': 481,
#  'saturation': 279,
#  'plant hormones': 154,
#  'the skeletal system': 467,
#  'carbohydrate classification': 290,
#  'safety in science': 91,
#  'saturn': 282,
#  'biochemical reaction chemistry': 250,
#  'ocean ecosystems': 235,
#  'mirrors': 366,
#  'earths energy': 111,
#  'nonrenewable resources': 271,
#  'chemical formula': 197,
#  'machines': 445,
#  'nuclear fission': 10,
#  'deep ocean currents': 482,
#  'biochemical compound classification': 250,
#  'meiosis': 168,
#  'mineral formation': 22,
#  'choosing healthy foods': 413,
#  'health hazards of air pollution': 144,
#  'fossils': 239,
#  'hiv and aids': 27,
#  'electric circuits': 215,
#  'biotechnology in agriculture': 234,
#  'pressure of fluids': 229,
#  'female reproductive structures': 502,
#  'urinary system': 299,
#  'touch': 478,
#  'changes of state': 218,
#  'doppler effect': 455,
#  'history of mesozoic life': 105,
#  'influences on weathering': 453,
#  'overpopulation and over consumption': 52,
#  'cardiovascular diseases': 491,
#  'earths moon': 185,
#  'temperature and heat in the atmosphere': 219,
#  'hazardous waste': 19,
#  'magnetic field reversal': 78,
#  'heat waves and droughts': 32,
#  'changing weather': 0,
#  'scientific modeling': 114,
#  'mutations': 294,
#  'using earths magnetic field': 78,
#  'thermal energy': 367,
#  'injuries of the nervous system': 23,
#  'chemical equations': 28,
#  'transition metals': 334,
#  'animal like protists': 266,
#  'renewable resources and alternative energy sources': 42,
#  'principle of uniformitarianism': 456,
#  'ohms law': 437,
#  'combustion reactions': 80,
#  'immunity': 311,
#  'microevolution and macroevolution': 326,
#  'puberty and adolescence': 41,
#  'introduction to genetics': 450,
#  'origin of species': 51,
#  'reactants and products': 135,
#  'preserving water sources': 151,
#  'thermal radiation': 375,
#  'how fossilization creates fossils': 8,
#  'troposphere': 313,
#  'conserving water': 425,
#  'fermentation': 317,
#  'stress in earths crust': 330,
#  'history of paleozoic life': 142,
#  'potential energy': 319,
#  'preventing infectious diseases': 442,
#  'effects of air pollution': 455,
#  'bernoullis law': 437,
#  'composition of the atmosphere': 71,
#  'earths crust': 330,
#  'principle of horizontality': 456,
#  'friction': 150,
#  'use and conservation of resources': 481,
#  'soil formation': 22,
#  'catalysts': 506,
#  'punnett squares': 496,
#  'earthquake damage': 365,
#  'kidneys': 99,
#  'the light we see': 143,
#  'electromagnetic energy in the atmosphere': 171,
#  'how animals evolved': 199,
#  'expansion of the universe': 216,
#  'folds': 287,
#  'human skeletal system': 467,
#  'branches of earth science': 460,
#  'limiting factors to population growth': 408,
#  'mesozoic plate tectonics': 105,
#  'plant responses and special adaptations': 461,
#  'mitosis and cytokinesis': 322,
#  'finding and mining ores': 74,
#  'jupiter': 162,
#  'star classification': 357,
#  'the sun': 243,
#  'fish': 335,
#  'erosion and deposition by wind': 505,
#  'ethics in science': 210,
#  'energy': 339,
#  'importance of the atmosphere': 112,
#  'ponds and lakes': 147,
#  'history of science': 4,
#  'the endocrine system': 264,
#  'diabetes': 342,
#  'solar energy on earth': 508,
#  'non mendelian inheritance': 15,
#  'obtaining energy resources': 113,
#  'earths magnetic field': 78,
#  'mesosphere': 479,
#  'plant reproduction and life cycle': 443,
#  'geological stresses': 133,
#  'scientific community': 495,
#  'respiratory system health': 6,
#  'darwins theory of evolution': 352,
#  'habitat and niche': 486,
#  'forms of energy': 101,
#  'radioactive decay': 158,
#  'predicting weather': 0,
#  'mammal classification': 258,
#  'animal behaviors': 380,
#  'collecting weather data': 0,
#  'gravity': 353,
#  'echinoderms and invertebrate chordates': 181,
#  'groundwater': 355,
#  'kinetic energy': 179,
#  'wave interference': 121,
#  'sponges': 432,
#  'organization of living things': 213,
#  'bohrs atomic model': 314,
#  'roundworms': 320,
#  'kinetic theory of matter': 179,
#  'the respiratory system': 6,
#  'fertilization': 362,
#  'infectious diseases': 442,
#  'outer planets': 36,
#  'law of reflection': 437,
#  'electric resistance': 30,
#  'acceleration due to gravity': 38,
#  'carbon monomers and polymers': 391,
#  'global warming': 73,
#  'structural evidence for evolution': 378,
#  'hurricanes': 281,
#  'newtons third law': 138,
#  'wheel and axle': 473,
#  'fungi structure': 46,
#  'satellites shuttles and space stations': 414,
#  'flow of energy': 434,
#  'introduction to plants': 164,
#  'buoyancy of fluids': 61,
#  'cell division': 300,
#  'electronics': 369,
#  'health of the digestive system': 403,
#  'crystalline carbon': 391,
#  'recent space exploration': 159,
#  'role of amphibians': 427,
#  'properties of carbon': 391,
#  'population size': 67,
#  'nitrogen cycle in ecosystems': 447,
#  'electromagnet': 372,
#  'chemical reactions and energy': 197,
#  'domains of life': 321,
#  'electric power and electrical energy use': 62,
#  'biological communities': 495,
#  'volcanic activity': 466,
#  'reproduction and life stages': 443,
#  'types of nutrients': 190,
#  'exothermic reactions': 312,
#  'weathering and erosion': 68,
#  'scientific explanations and interpretations': 114,
#  'planet earth': 13,
#  'states of matter': 218,
#  'refraction': 376,
#  'scientific theories': 98,
#  'types of energy': 83,
#  'using sound': 176,
#  'importance of echinoderms': 269,
#  'metabolism and replication': 280,
#  'excretion': 379,
#  'cyclic behavior of animals': 380,
#  'solenoid': 69,
#  'earthquake safe structures': 116,
#  'what is life science': 156,
#  'cell membrane': 392,
#  'the integumentary system': 131,
#  'air pressure and altitude': 244,
#  'sustainable development': 371,
#  'fungi reproduction': 46,
#  'replacement reactions': 50,
#  'energy level': 75,
#  'scope of physics': 117,
#  'observation': 381,
#  'properties of electromagnetic waves': 171,
#  'prokaryotic and eukaryotic cells': 392,
#  'earth science and its branches': 460,
#  'control of insects': 364,
#  'properties of acids': 161,
#  'homeostasis': 386,
#  'alpha decay': 389,
#  'gravity in the solar system': 353,
#  'earthquakes at transform plate boundaries': 444,
#  'bacteria': 388,
#  'asteroids': 397,
#  'ferromagnetic material': 141,
#  'the scope of physical science': 117,
#  'protists nutrition': 55,
#  'nonrenewable energy resources': 271,
#  'protecting water from pollution': 232,
#  'scientific investigation': 40,
#  'force': 390,
#  'transform plate boundaries': 444,
#  'scientific models': 314,
#  'changes in matter': 64,
#  'pressure in fluids': 229,
#  'vision problems and corrective lenses': 31,
#  'avoiding soil loss': 441,
#  'lipid classification': 290,
#  'mammal characteristics': 258,
#  'wave amplitude': 394,
#  'effects of air pollution on the environment': 455,
#  'compounds': 209,
#  'radio waves': 120,
#  'electric safety': 91,
#  'maps': 272,
#  'autoimmune diseases': 157,
#  'humans and the water supply': 399,
#  'modern biodiversity': 96,
#  'scientific law': 114,
#  'earth as a magnet': 94,
#  'what is science': 200,
#  'technological design constraints': 306,
#  'evaporation': 329,
#  'process of cellular respiration': 246,
#  'newtons second law': 255,
#  'sedimentary rocks': 148,
#  'sex linked inheritance': 15,
#  'pollution of the land': 345,
#  'tsunami': 401,
#  'conservation of mass in chemical reactions': 458,
#  'mercury': 406,
#  'importance of insects': 364,
#  'intraplate activity': 295,
#  'field study': 249,
#  'calculating work': 327,
#  'water on earth': 351,
#  'groups of elements': 65,
#  'synthesis reactions': 39,
#  'chordates': 236,
#  'staying safe in earthquakes': 116,
#  'pulley': 410,
#  'transverse wave': 411,
#  'lever': 35,
#  'international system of units': 194,
#  'isotopes': 415,
#  'indoor air pollution': 452,
#  'milky way': 483,
#  'types of volcanoes': 383,
#  'characteristics of life': 191,
#  'inside the atom': 423,
#  'compound machines': 445,
#  'alligators and crocodiles': 277,
#  'telescopes': 395,
#  'the water cycle': 124,
#  'climate zones and biomes': 470,
#  'carbon bonding': 60,
#  'bond polarity': 307,
#  'generating and using electricity': 412,
#  'longitudinal wave': 228,
#  'processes of the water cycle': 222,
#  'chemical change': 64,
#  'introduction to vertebrates': 58,
#  'transfer of thermal energy': 193,
#  'pascals law': 437,
#  'mercury pollution': 406,
#  'metamorphic rock classification': 182,
#  'static electricity and static discharge': 82,
#  'electromagnetic induction': 382,
#  'angiosperms': 100,
#  'newtons first law': 14,
#  'magnets and magnetism': 119,
#  'atomic nucleus': 302,
#  'taste and smell': 373,
#  'acid base neutralization': 123,
#  'freezing': 286,
#  'descriptive statistics': 332,
#  'fundamental particles': 291,
#  'temperature': 219,
#  'velocity': 226,
#  'charless law': 437,
#  'theory of plate tectonics': 49,
#  'mechanical wave': 374,
#  'importance of the oceans': 267,
#  'earths layers': 284,
#  'thermosphere and beyond': 9,
#  'hardy weinberg theorem': 328,
#  'blood vessels': 89,
#  'motion': 33,
#  'cancer': 428,
#  'the nitrogen cycle': 447,
#  'minerals': 253,
#  'characteristics of sound': 176,
#  'types of fossilization': 8,
#  'timeline of evolution': 344,
#  'century tsunami': 401,
#  'ozone depletion': 163,
#  'basic and applied science': 492,
#  'fungus like protists': 266,
#  'reproductive system health': 144,
#  'gene therapy': 198,
#  'noninfectious diseases': 217,
#  'oil spills': 166,
#  'global wind belts': 278,
#  'turtles': 81,
#  'electromagnetism': 439,
#  'aquatic biomes': 470,
#  'influences on darwin': 352,
#  'terrestrial biomes': 470,
#  'ecosystem change': 235,
#  'properties of matter': 501,
#  'balancing chemical equations': 28,
#  'the senses': 288,
#  'seawater chemistry': 418,
#  'importance of protists': 266,
#  'geothermal power': 468,
#  'oceanic pressure': 244,
#  'work': 327,
#  'transfer of electric charge': 85,
#  'wave frequency': 464,
#  'types of chemical reactions': 83,
#  'observations and experiments': 381,
#  'heart and blood vessels': 129,
#  'pathogens': 303,
#  'mendels discoveries': 341,
#  'mixtures': 160,
#  'pressure and density of the atmosphere': 102,
#  'landforms from glacial erosion and deposition': 449,
#  'the excretory system': 448,
#  'petroleum power': 256,
#  'conservation of energy in chemical reactions': 188,
#  'radioactive decay as a measure of age': 158,
#  'bacteria nutrition': 55,
#  'covalent bonds': 310,
#  'unsaturated hydrocarbons': 252,
#  'explosive eruptions': 324,
#  'the scale of evolution': 170,
#  'renewable energy resources': 42,
#  'internal combustion engines': 454,
#  'populations': 67,
#  'organic compounds': 209,
#  'solubility and concentration': 149,
#  'bony fish': 335,
#  'absolute ages of rocks': 424,
#  'weather forecasting': 0,
#  'nucleic acid classification': 161,
#  'impact of continued global warming': 73,
#  'gamma decay': 225,
#  'earthquakes at convergent plate boundaries': 268,
#  'learned behavior of animals': 380,
#  'human population': 67,
#  'chemistry of compounds': 418,
#  'position time graphs': 20,
#  'frequency and pitch of sound': 464,
#  'archimedes law': 437,
#  'scientific theory': 98,
#  'evolution plate tectonics and climate change': 49,
#  'plant characteristics': 191,
#  'translation of rna to protein': 104,
#  'combining forces': 390,
#  'decomposition reactions': 109,
#  'the human population': 67,
#  'erosion and deposition by glaciers': 471,
#  'early atmosphere and oceans': 206,
#  'transport': 503,
#  'roles in an ecosystem': 427,
#  'distribution of water on earth': 476,
#  'groundwater aquifers': 355,
#  'human evolution': 344,
#  'metalloids': 469,
#  'modern genetics': 450,
#  'wave particle theory': 291,
#  'thunderstorms': 221,
#  'sources of water pollution': 151,
#  'biochemical reactions': 250,
#  'electromagnetic spectrum': 438,
#  'physical properties of matter': 340,
#  'hot springs and geysers': 301,
#  'meteors': 56,
#  'artificial light': 143,
#  'importance of biodiversity': 96,
#  'continental drift': 146,
#  'volcanic eruptions': 315,
#  'sedimentary rock classification': 148,
#  'the history of astronom': 4,
#  'pedigree analysis': 477,
#  'simple machines': 422,
#  'magnetic polarity evidence for continental drift': 307,
#  'scientific induction': 382,
#  'cenozoic plate tectonics': 304,
#  'vitamins and minerals': 253,
#  'the microscope': 240,
#  'history of cenozoic life': 304,
#  'symbiotic relationships of fungi': 46,
#  'flooding': 286,
#  'beta decay': 389,
#  'diffusion': 480,
#  'seafloor spreading hypothesis': 18,
#  'speed and velocity': 44,
#  'fossil fuel reserves': 204,
#  'mars': 358,
#  'physical science careers': 325,
#  'insect food': 364,
#  'cell nucleus': 302,
#  'electromagnetic waves': 171,
#  'adulthood and aging': 421,
#  'magma composition at volcanoes': 71,
#  'precambrian continents': 192,
#  'inclined plane': 487,
#  'digestive system organs': 118,
#  'human uses of fungi': 247,
#  'melting': 286,
#  'the ocean floor': 267,
#  'plant classification': 290,
#  'intraplate earthquakes': 295,
#  'momentum': 493,
#  'rocks and processes of the rock cycle': 222,
#  'matter mass and volume': 458,
#  'rutherfords atomic model': 314,
#  'storms': 126,
#  'fields in the life sciences': 249,
#  'chemistry of life': 418,
#  'advances in genetics': 450,
#  'technology and science': 361,
#  'helpful bacteria': 388,
#  'frogs and toads': 343,
#  'wave speed': 44,
#  'recognizing chemical reactions': 197,
#  'orbital motion': 33,
#  ...}

# %%
len(set(meta_lesson_assignments.values()))
# Out:
# 509

# %%
# %page linked_lessons

# %% [markdown]
# ### hide

# %%
ttl = ['respiration', 'reproductive', 'animal']

# %%
filter_pos(ttl)

# %%
nltk.pos_tag([' current', 'test'])

# %% [markdown]
# # Refinements to make

# %% [markdown]
# ### todo

# %% [markdown]
# get viz working
# return annotations to ds
# fix lessons missing topics

# %% [markdown]
# ### file i/o

# %%
write_file('build_v6.json', complete_flat_ds)

# %%
# write_file('build_v5_prior_to_refinement.json', ck12_combined_dataset)

# %%
with open('../dataset_releases/data_release_beta5/inter/tqa_dataset_beta5.json', 'r') as f:
    prev_v5 = json.load(f)

# %%
# with open('build_v5.pkl', 'wb') as f:
#     pickle.dump(ck12_combined_dataset ,f)

# %%
with open('build_v5.pkl', 'rb') as f:
    ck12_combined_dataset = pickle.load(f)

# %%
# with open('output_data_from_nbs/build_v5_prior_to_refinement.json', 'w') as f:
#       json.dump(ck12_combined_dataset, f)

# %%
with open('output_data_from_nbs/build_v5_prior_to_refinement.json', 'r') as f:
     ck12_latest = json.load(f)

# %% [markdown]
# ### code

# %%
#print(topics_to_remove) #specicied in match topics section above, explictly set here

structural_topics = ['Summary', 'Review', 'References', 'Explore More', 'Lesson Summary', 'Lesson Objectives', 'Points to Consider', 'Introduction',
                    'Recall', 'Apply Concepts', 'Think Critically', 'Resources', 'Explore More II', 'Explore More I', 'Explore More III']

vocab_topics = ['Lesson Vocabulary', 'Vocabulary']

# %%
def iterate_over_all_material(complete_ds, apply_function):
    lesson_returns = []
    for subject, lessons in sorted(complete_ds.items(), key= lambda x: x[0]):
        for lesson_name, lesson_content in sorted(lessons.items(), key= lambda x: x[0]):
            response = apply_function(lesson_name, lesson_content)
            if response:
                lesson_returns.append(response)
    return lesson_returns
        

def apply_fixes(lesson_name, lesson_content):
    struct_content, vocab_content = iterate_over_text(lesson_content['topics'], lesson_name)
    lesson_content['adjunctTopics'] = struct_content
    lesson_content['adjunctTopics']['Vocabulary'] = vocab_content
    iterate_over_text_questions(lesson_content['questions']['nonDiagramQuestions'])
    if lesson_content['instructionalDiagrams']:
        if not lesson_content['questions']['diagramQuestions']:
            print(lesson_name + ' missing questions')
        iterate_over_diagram_questions(lesson_content['questions']['diagramQuestions'])
        iterate_over_diagram_descriptions(lesson_content['instructionalDiagrams'])
        
def iterate_over_text(topic_sections, lesson_name=None):
    structural_content = {}
    vocab_section = {}
    topics_to_remove = []
    for topic, content in sorted(topic_sections.items(), key= lambda x: x[1]['orderID']):
        if content['content']['figures']:
            iterate_over_textbook_figs(content['content']['figures'], lesson_name)
        if topic in vocab_topics:
            vocab_section.update(add_defintions_to_vocab(content))
            topics_to_remove.append(topic)
        elif topic in structural_topics:
            structural_content[topic] = content
            topics_to_remove.append(topic)
    for topic in topics_to_remove:
        topic_sections.pop(topic)
    return structural_content, vocab_section
    

def iterate_over_text_questions(text_questions):
    qs_to_del = []
    replace_local_ids_w_global(text_questions, 'text', True, 'id')
    for question_id, question_content in text_questions.items():
        if not question_content['correctAnswer']:
            print(question_content['globalID'])
            qs_to_del.append(question_content['globalID'])
            continue
        check_type_assignments(question_content)
        change_q_type_key(question_content)
        check_raw_text_present(question_content)
    for qid in qs_to_del:
        del text_questions[qid]
        
def iterate_over_diagram_questions(diagram_questions):
    for qid, question in diagram_questions.items():
        replace_uri_with_path(question, 'question_images')
        orig_question= question['beingAsked']['processedText']
        fixed_question = apply_spelling_and_grammar_fixes(orig_question)
        if fixed_question:
            question['beingAsked']['processedText'] = fixed_question
        if detect_abc_question(question):
            standardize_abc_question(question)
        change_q_type_key(question)
    replace_local_ids_w_global(diagram_questions, 'diagram', True, 'id')

def iterate_over_diagram_descriptions(diagram_descriptions, description_path_prefix=None):
    for diagram_name, diagram_content in diagram_descriptions.items():
        replace_uri_with_path(diagram_content, 'teaching_images')
        orig_description = diagram_content['processedText']
        fixed_description = apply_spelling_and_grammar_fixes(orig_description)
        if fixed_description:
            diagram_content['processedText'] = fixed_description
    replace_local_ids_w_global(diagram_descriptions, 'description', True, z_pad=4)

            
def add_defintions_to_vocab(vocab_section): #done
    lesson_vocab = {}
    for word in vocab_section['content']['text'].split('\n'):
        if word in flexbook_glossary.keys():
            lesson_vocab[word] = flexbook_glossary[word]
        elif word:
            lesson_vocab[word] = ''
    return lesson_vocab

def add_global_ids(data_object, object_type, zero_padding=6): #done
    id_prefix = {'text': 'NDQ_', 'diagram': 'DQ_', 'lesson': 'L_', 'description': 'DD_', 'topics': 'T_'}
    global_ids_counters[object_type] += 1
    data_object['globalID'] = id_prefix[object_type] + str(global_ids_counters[object_type]).zfill(zero_padding)

def detect_abc_question(question):
    image_name = question['imageName']
    image_number = int(image_name.split('_')[-1].replace('.png', ''))
    return image_number >= 10000

def standardize_abc_question(question): #done
    question['imagePath'] = question['imagePath'].replace('question_images', 'abc_question_images')
    question['correctAnswer']['processedText'] = question['correctAnswer']['processedText'].upper()
    for ac in question['answerChoices'].values():
        ac['processedText'] = ac['processedText'].upper()
    
def iterate_over_textbook_figs(figure_content, lesson_n): # done
    for figure in sorted(figure_content, key= lambda x: x['image_uri'].split('/')[-1]):
        replace_uri_with_path(figure, 'textbook_images', lesson_n)
        
def replace_uri_with_path(image_content, path_prefix, lesson_name=None): # done
    image_key_str = 'imageUri'
    if 'image_uri' in image_content.copy().keys():
        image_key_str = 'image_uri'
    image_name = image_content[image_key_str].split('/')[-1]
    image_number = image_name.split('_')[-1].split('.')[0]
    del image_content[image_key_str]
    if lesson_name:
        global_ids_counters['image'] += 1
        prev_image_name = deepcopy(image_name)
        image_name =  rename_lesson(lesson_name).replace(' ', '_') + '_' + str(global_ids_counters['image']) + '.png'
        record_image_name_changes[os.path.join(path_prefix, prev_image_name)] = os.path.join(path_prefix, image_name)
    image_content['imagePath'] = os.path.join(path_prefix, image_name)
      
def apply_spelling_and_grammar_fixes(orig_text): #done
    spell_fixed_text = apply_spelling_fix(orig_text)
    for punc_char in punc_set_nospace:
        spell_fixed_text = spell_fixed_text.replace(' ' + punc_char + ' ' , punc_char)
    for punc_char in punc_set_space:
        spell_fixed_text = spell_fixed_text.replace(' ' + punc_char + ' ' , punc_char + ' ')
    gram_fixed = gram_checker.correct(spell_fixed_text)
    if gram_fixed != orig_text:
        return gram_fixed
    else:
        return None
    
def standardize_true_false_question(question):
    replacement_text = {'true': 'a', 'false': 'b'}
    if question['correctAnswer']['processedText'] not in (['true', 'false']):
        print('p', question['correctAnswer']['processedText'])
    if question['correctAnswer']['rawText'] not in (['true', 'false']):
        print('r', question['correctAnswer']['rawText'])
    question['correctAnswer']['processedText'] = replacement_text[question['correctAnswer']['processedText']]

def check_raw_text_present(question):
    if 'rawText' not in question['correctAnswer'].keys():
        question['correctAnswer']['rawText'] = question['correctAnswer']['processedText']

def check_type_assignments(question):
    if question['type'] == "True or False":
        if question['correctAnswer']['processedText'] not in ['true', 'false']:
            print(question['correctAnswer']['processedText'])
            if '__' in question['beingAsked']['processedText']:
                question['type'] = 'Fill in the Blank'
                del question['answerChoices']

def replace_local_ids_w_global(data_unit, unit_type, keys_too=False, id_key='', z_pad=6):
    if id_key:
        objs_to_iterate = sorted(data_unit.items(), key=lambda x: x[1][id_key])
    else:
        objs_to_iterate = data_unit.items()
    for k, v in objs_to_iterate:
        if(unit_type == 'description'):
            global_ids_counters['dds_count'] += 1 
        add_global_ids(v, unit_type, zero_padding=z_pad)
        if id_key:
            v.pop(id_key)
    for k, v in objs_to_iterate:
        if keys_too:
            data_unit[v['globalID']] = data_unit.pop(k)
            if unit_type == 'topics':
                name_field = unit_type[:-1] + 'Name'
                v[name_field] = k
    pass

def rename_lesson(lesson_name):
    if lesson_name[0].isdigit():
        return lesson_name.split(maxsplit=1)[1].strip().lower()
    else:
        return lesson_name

def flatten_complete_ds(lesson_name, lesson_content):
    lesson_content['lessonName'] =lesson_name
    add_global_ids(lesson_content, 'lesson', 4)
    lesson_content['lessonName'] = rename_lesson(lesson_name)
    obj_key = 'topics'
    replace_local_ids_w_global(lesson_content[obj_key], obj_key, True, 'orderID', 4)
    return lesson_content

def add_metalesson_ids(lesson, meta_lesson_assignments):
    lesson['metaLessonID'] = 'ML_' + str(meta_lesson_assignments[lesson['lessonName']]).zfill(4)
    
def change_q_type_key(question):
    multi_choice_types = ["True or False", "Multiple Choice", "Matching"]
    if question['type'] == 'Diagram Multiple Choice':
        question['questionType'] = 'Diagram Multiple Choice'
    elif question['type'] in multi_choice_types:
        question['questionSubType'] = question['type']
        question['questionType'] = "Multiple Choice"
    else:
        question['questionSubType'] = question['type']
        question['questionType'] = "Direct Answer"
    question.pop('type')

# %%
def standardize_answer_choices(question):
    if not question['answerChoices']:
        return None
    correct_answer_text = question['correctAnswer']['processedText']
    if question['questionSubType'] == 'True or False':
        if 'true' in correct_answer_text:
            question['correctAnswer']['processedText'] = 'a'
            return question
        elif 'false' in correct_answer_text:
            question['correctAnswer']['processedText'] = 'b'
            return question
        else:
            return None
    elif correct_answer_text.replace('.', '') in list(string.ascii_letters)[:9]:
        question['correctAnswer']['processedText'] = correct_answer_text.replace('.', '')
        return question
    else:
        for ac_id, ac in question['answerChoices'].items():
            ac_text = ac['processedText']
            if ac_text in correct_answer_text:  
                question['correctAnswer']['processedText'] = ac_id
                return question
        else:
            print(correct_answer_text)
            print(question['answerChoices'])
            
def standardize_answer_choices_diagram(question):
    correct_answer_text = question['correctAnswer']['processedText']
    if len(correct_answer_text) > 300:
        return
    if correct_answer_text.replace('.', '') in list(string.ascii_letters)[:3]:
        question['correctAnswer']['processedText'] = correct_answer_text.replace('.', '')
        return question
    else:
        for ac_id, ac in question['answerChoices'].items():
            ac_text = ac['processedText']
            if ac_text in correct_answer_text:  
                question['correctAnswer']['processedText'] = ac_id
                return question
        else:
            return
            print(question['correctAnswer'])
            print()
            print(question['answerChoices'])

# %%
complete_flat_ds_kc_fix = deepcopy(complete_flat_ds)

# %%
new_complete_flat_ds_kc_fix = []
for lesson in complete_flat_ds_kc_fix:
    new_lesson = deepcopy(lesson)
    for qid, question in new_lesson['questions']['nonDiagramQuestions'].copy().items():
        if question['questionType'] == 'Multiple Choice':
            new_question = standardize_answer_choices(question)
            if new_question:
                new_lesson['questions']['nonDiagramQuestions'][qid] = new_question
            else:
                del new_lesson['questions']['nonDiagramQuestions'][qid]
    new_complete_flat_ds_kc_fix.append(new_lesson)

# %%
new_w_dw_complete_flat_ds_kc_all_fix = []
for lesson in new_complete_flat_ds_kc_fix:
    new_lesson = deepcopy(lesson)
    if new_lesson['questions']['diagramQuestions']:
        for qid, question in new_lesson['questions']['diagramQuestions'].copy().items():
            new_question = standardize_answer_choices_diagram(question)
            if new_question:
                new_lesson['questions']['diagramQuestions'][qid] = new_question
            else:
                del new_lesson['questions']['diagramQuestions'][qid]
        new_w_dw_complete_flat_ds_kc_all_fix.append(new_lesson)
    else:
        new_w_dw_complete_flat_ds_kc_all_fix.append(new_lesson)

# %%
ca_series = []
for lesson in new_w_dw_complete_flat_ds_kc_all_fix:
    for qid, question in lesson['questions']['nonDiagramQuestions'].items():
        if question['questionType'] == 'Multiple Choice':
            ca_series.append(question['correctAnswer']['processedText'])

# %%
dq_ca_series = []
for lesson in new_w_dw_complete_flat_ds_kc_all_fix:
    for qid, question in lesson['questions']['diagramQuestions'].items():
        dq_ca_series.append(question['correctAnswer']['processedText'])

# %%
pd.Series(dq_ca_series).value_counts()
# Out:
# c    3183
# a    3173
# b    3141
# d    3070
# dtype: int64

# %%
pd.Series(ca_series).value_counts()
# Out:
# b    4423
# a    4379
# d    2334
# c    1833
# e     247
# f     243
# g     234
# dtype: int64

# %%
non_diagram_questions = [list(dict_key_extract('nonDiagramQuestions', lesson)) for lesson in new_w_dw_complete_flat_ds_kc_all_fix]

nd_questions = {}
for lesson in non_diagram_questions:
    for lesson_questions in lesson:
        for question_id, question in lesson_questions.items():
            nd_questions[question_id] = question

# %%
len(nd_questions)
# Out:
# 18929

# %%
write_file('beta7_5_final_fixed.json', new_w_dw_complete_flat_ds_kc_all_fix)

# %% [markdown]
# ### run

# %%
ck12_combined_dataset

# %%
# ck12_combined_dataset = 
full_test_ds = deepcopy(ck12_combined_dataset)
test_vals= {k: v  for k, v in list(full_test_ds['earth-science'].items())[:20]}
buid_test_cds = {}
buid_test_cds['earth-science'] = test_vals
test_cds = deepcopy(buid_test_cds)

# %%
# %%time
dq_gid = 0
ndq_gid = 0
l_id = 0
t_id = 0
dd_id = 0
pd_image = 20000
n_ddds_seen = 0


record_image_name_changes = {}
global_ids_counters = {'text': ndq_gid, 'diagram': ndq_gid, 'lesson': l_id, 'topics': t_id, 'description': dd_id, 'image':pd_image , 'dds_count': n_ddds_seen}

dataset_build_3p5 = full_test_ds
_ = iterate_over_all_material(dataset_build_3p5, apply_fixes)
complete_flat_ds = iterate_over_all_material(dataset_build_3p5, flatten_complete_ds)

for lesson in complete_flat_ds:
    add_metalesson_ids(lesson, meta_lesson_id_assignments)
# Out:
# false sources figure 1: ck-12: http://www.ck12.org/earth-science/determining-relative- ages/lesson/determining-relative-ages/
# NDQ_004805
# false
# NDQ_011496
# NDQ_011500
# NDQ_011498
# NDQ_011499
# NDQ_011497
# the sporophyte produces spores that will develop into gametophytes.
# false
# orbitals
# 5000
# CPU times: user 13.6 s, sys: 2.9 s, total: 16.5 s
# Wall time: 1min 10s

# %%
complete_flat_ds[2]['instructionalDiagrams']
# Out:
# {'DD_0001': {'globalID': 'DD_0001',
#   'imageName': 'erosion_6859.png',
#   'imagePath': 'teaching_images/erosion_6859.png',
#   'processedText': 'The diagram represents the coastal Erosion of a headland. A headland is an area of hard rock which sticks out into the sea. Headlands form in areas of alternating hard and soft rock. Where the soft rock erodes, bays are formed on either side of the headland. As the headland becomes more exposed to the wind and waves the rate of its erosion increases. When headlands erode they create distinct features such as caves, arches, stacks and stumps. The sequence in the erosion of a headland is as follows: 1. Waves attack a weakness in the headland. 2. A cave is formed. 3. Eventually the cave erodes through the headland to form an arch. 4. The roof of the arch collapses leaving a column of rock called a stack. 5. The stack collapses leaving a stump.',
#   'rawText': 'The diagram represents the coastal Erosion of a headland. A headland is an area of hard rock which sticks out into the sea. Headlands form in areas of alternating hard and soft rock. Where the soft rock erodes, bays are formed on either side of the headland. As the headland becomes more exposed to the wind and waves the rate of its erosion increases. When headlands erode they create distinct features such as caves, arches, stacks and stumps. The sequence in the erosion of a headland is as follows : 1.\tWaves attack a weakness in the headland. 2.\tA cave is formed. 3.\tEventually the cave erodes through the headland to form an arch. 4.\tThe roof of the arch collapses leaving a column of rock called a stack. 5.\tThe stack collapses leaving a stump.'},
#  'DD_0002': {'globalID': 'DD_0002',
#   'imageName': 'erosion_8064.png',
#   'imagePath': 'teaching_images/erosion_8064.png',
#   'processedText': 'The diagram shows how a waterfall is formed by erosion. Waterfalls begin with mountain streams that begin high up in mountains. These streams flow down very quickly because of the steep slope, and flowing water, especially fast-moving water, erodes soil and rocks. Soft rock erodes more quickly than hard rock. When soft rock erodes, the stream bed can collapse, causing an abrupt drop in the stream. This sudden drop is what creates a waterfall. In the diagram, the overhang is where the stream bed collapsed to create the waterfall. Because of the flowing water, the soft rock at the side of the waterfall will continue to erode. This continued erosion will cause more of the stream bed to collapse. The waterfall overhang will then retreat upstream and create a higher waterfall.',
#   'rawText': 'The diagram shows how a waterfall is formed by erosion. Waterfalls begin with mountain streams that begin high up in mountains. These streams flow down very quickly because of the steep slope, and flowing water, especially fast-moving water, erodes soil and rocks. Soft rock erodes more quickly than hard rock. When soft rock erodes, the stream bed can collapse, causing an abrupt drop in the stream. This sudden drop is what creates a waterfall. In the diagram, the overhang is where the stream bed collapsed to create the waterfall. Because of the flowing water, the soft rock at the side of the waterfall will continue to erode. This continued erosion will cause more of the stream bed to collapse. The waterfall overhang will then retreat upstream and create a higher waterfall.'}}

# %%
def dict_key_extract(key, var):
    if hasattr(var, 'items'):
        for k, v in var.items():
            if k == key:
                yield v
            if isinstance(v, dict):
                for result in dict_key_extract(key, v):
                    yield result
            elif isinstance(v, list):
                for d in v:
                    for result in dict_key_extract(key, d):
                        yield result

# %%
non_diagram_questions = [list(dict_key_extract('nonDiagramQuestions', lesson)) for lesson in complete_flat_ds]

nd_questions = {}
for lesson in non_diagram_questions:
    for lesson_questions in lesson:
        for question_id, question in lesson_questions.items():
            nd_questions[question_id] = question

# %%
len(nd_questions)
# Out:
# 18938

# %%
len(record_image_name_changes)
# Out:
# 3176

# %%
# [lesson for lesson in complete_flat_ds if lesson['lessonName'] == 'soils'][0]['questions']['diagramQuestions']

# %%
global_ids_counters['dds_count']
# Out:
# 276

# %%
complete_flat_ds[3]['questions']
# Out:
# {'diagramQuestions': {},
#  'nonDiagramQuestions': {'NDQ_000139': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'type of cloud that forms in low, horizontal layers',
#     'rawText': '1. type of cloud that forms in low, horizontal layers'},
#    'correctAnswer': {'processedText': 'e', 'rawText': '1. e'},
#    'globalID': 'NDQ_000139',
#    'idStructural': '1.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000140': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'measure of what the temperature feels like because of humidity',
#     'rawText': '2. measure of what the temperature feels like because of humidity'},
#    'correctAnswer': {'processedText': 'd', 'rawText': '2.d'},
#    'globalID': 'NDQ_000140',
#    'idStructural': '2.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000141': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'type of cloud that is white and puffy',
#     'rawText': '3. type of cloud that is white and puffy'},
#    'correctAnswer': {'processedText': 'b', 'rawText': '3.b'},
#    'globalID': 'NDQ_000141',
#    'idStructural': '3.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000142': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'temperature at which water vapor condenses out of the air',
#     'rawText': '4. temperature at which water vapor condenses out of the air'},
#    'correctAnswer': {'processedText': 'c', 'rawText': '4.c'},
#    'globalID': 'NDQ_000142',
#    'idStructural': '4.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000143': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'type of precipitation that consists of small, clear ice pellets',
#     'rawText': '5. type of precipitation that consists of small, clear ice pellets'},
#    'correctAnswer': {'processedText': 'g', 'rawText': '5.g'},
#    'globalID': 'NDQ_000143',
#    'idStructural': '5.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000144': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'type of cloud that is thin and wispy',
#     'rawText': '6. type of cloud that is thin and wispy'},
#    'correctAnswer': {'processedText': 'a', 'rawText': '6.a'},
#    'globalID': 'NDQ_000144',
#    'idStructural': '6.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000145': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cirrus',
#      'rawText': 'a. cirrus'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'cumulus',
#      'rawText': 'b. cumulus'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'dew point',
#      'rawText': 'c. dew point'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'heat index',
#      'rawText': 'd. heat index'},
#     'e': {'idStructural': 'e.',
#      'processedText': 'stratus',
#      'rawText': 'e. stratus'},
#     'f': {'idStructural': 'f.',
#      'processedText': 'freezing rain',
#      'rawText': 'f. freezing rain'},
#     'g': {'idStructural': 'g.',
#      'processedText': 'sleet',
#      'rawText': 'g. sleet'}},
#    'beingAsked': {'processedText': 'type of precipitation that falls as liquid water but freezes on surfaces',
#     'rawText': '7. type of precipitation that falls as liquid water but freezes on surfaces'},
#    'correctAnswer': {'processedText': 'f', 'rawText': '7.f'},
#    'globalID': 'NDQ_000145',
#    'idStructural': '7.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000146': {'answerChoices': {},
#    'beingAsked': {'processedText': '__________ refers to the conditions of the atmosphere at a given time and place.',
#     'rawText': '1. __________ refers to the conditions of the atmosphere at a given time and place.'},
#    'correctAnswer': {'processedText': 'Weather', 'rawText': '1. Weather'},
#    'globalID': 'NDQ_000146',
#    'idStructural': '1.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000147': {'answerChoices': {},
#    'beingAsked': {'processedText': 'The type of precipitation that falls when rain freezes into balls of ice is __________.',
#     'rawText': '2. The type of precipitation that falls when rain freezes into balls of ice is __________.'},
#    'correctAnswer': {'processedText': 'hail', 'rawText': '2. hail'},
#    'globalID': 'NDQ_000147',
#    'idStructural': '2.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000148': {'answerChoices': {},
#    'beingAsked': {'processedText': 'The amount of water vapor in the air is called __________.',
#     'rawText': '3. The amount of water vapor in the air is called __________.'},
#    'correctAnswer': {'processedText': 'humidity', 'rawText': '3. humidity'},
#    'globalID': 'NDQ_000148',
#    'idStructural': '3.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000149': {'answerChoices': {},
#    'beingAsked': {'processedText': 'A cloud that forms on the ground is referred to as __________.',
#     'rawText': '4. A cloud that forms on the ground is referred to as __________.'},
#    'correctAnswer': {'processedText': 'fog', 'rawText': '4. fog'},
#    'globalID': 'NDQ_000149',
#    'idStructural': '4.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000150': {'answerChoices': {},
#    'beingAsked': {'processedText': '__________ is the percent of water vapor in the air relative to the total amount the air can hold.',
#     'rawText': '5. __________ is the percent of water vapor in the air relative to the total amount the air can hold.'},
#    'correctAnswer': {'processedText': 'Relative humidity',
#     'rawText': '5. Relative humidity'},
#    'globalID': 'NDQ_000150',
#    'idStructural': '5.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000151': {'answerChoices': {},
#    'beingAsked': {'processedText': 'Cumulus clouds that produce rain are known as __________ clouds.',
#     'rawText': '6. Cumulus clouds that produce rain are known as __________ clouds.'},
#    'correctAnswer': {'processedText': 'cumulonimbus',
#     'rawText': '6. cumulonimbus'},
#    'globalID': 'NDQ_000151',
#    'idStructural': '6.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000152': {'answerChoices': {},
#    'beingAsked': {'processedText': '__________ falls when water vapor condenses as ice crystals that remain frozen all the way to the ground.',
#     'rawText': '7. __________ falls when water vapor condenses as ice crystals that remain frozen all the way to the ground. '},
#    'correctAnswer': {'processedText': 'Snow', 'rawText': '7. Snow '},
#    'globalID': 'NDQ_000152',
#    'idStructural': '7.',
#    'questionSubType': 'Direct Answer',
#    'questionType': 'Direct Answer'},
#   'NDQ_000153': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Weather occurs because of unequal heating of the atmosphere.',
#     'rawText': '1. Weather occurs because of unequal heating of the atmosphere.'},
#    'correctAnswer': {'processedText': 'true', 'rawText': '1.true'},
#    'globalID': 'NDQ_000153',
#    'idStructural': '1.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000154': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'The water cycle plays an important role in weather.',
#     'rawText': '2. The water cycle plays an important role in weather.'},
#    'correctAnswer': {'processedText': 'true', 'rawText': '2.true'},
#    'globalID': 'NDQ_000154',
#    'idStructural': '2.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000155': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Warm air always sinks toward Earths surface.',
#     'rawText': '3. Warm air always sinks toward Earths surface.'},
#    'correctAnswer': {'processedText': 'false', 'rawText': '3.false'},
#    'globalID': 'NDQ_000155',
#    'idStructural': '3.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000156': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'If the relative humidity is 100 percent, it must be raining.',
#     'rawText': '4. If the relative humidity is 100 percent, it must be raining.'},
#    'correctAnswer': {'processedText': 'false', 'rawText': '4.false'},
#    'globalID': 'NDQ_000156',
#    'idStructural': '4.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000157': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Cumulus clouds may grow very tall because of high air pressure.',
#     'rawText': '5. Cumulus clouds may grow very tall because of high air pressure.'},
#    'correctAnswer': {'processedText': 'false', 'rawText': '5.false'},
#    'globalID': 'NDQ_000157',
#    'idStructural': '5.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000158': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Stratus clouds are clouds that form in the stratosphere.',
#     'rawText': '6. Stratus clouds are clouds that form in the stratosphere.'},
#    'correctAnswer': {'processedText': 'false', 'rawText': '6.false'},
#    'globalID': 'NDQ_000158',
#    'idStructural': '6.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000159': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Altostratus clouds form higher in the atmosphere than stratus clouds.',
#     'rawText': '7. Altostratus clouds form higher in the atmosphere than stratus clouds.'},
#    'correctAnswer': {'processedText': 'true', 'rawText': '7.true'},
#    'globalID': 'NDQ_000159',
#    'idStructural': '7.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000160': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'A single raindrop consists of millions of water molecules.',
#     'rawText': '8. A single raindrop consists of millions of water molecules.'},
#    'correctAnswer': {'processedText': 'true', 'rawText': '8.true'},
#    'globalID': 'NDQ_000160',
#    'idStructural': '8.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000161': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Freezing rain falls through the air as tiny pellets of frozen water.',
#     'rawText': '9. Freezing rain falls through the air as tiny pellets of frozen water.'},
#    'correctAnswer': {'processedText': 'false', 'rawText': '9.false'},
#    'globalID': 'NDQ_000161',
#    'idStructural': '9.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000162': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'true',
#      'rawText': 'a. true'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'false',
#      'rawText': 'b. false'}},
#    'beingAsked': {'processedText': 'Snow forms when rain falls through a layer of freezing air before it reaches the ground.',
#     'rawText': '10. Snow forms when rain falls through a layer of freezing air before it reaches the ground.'},
#    'correctAnswer': {'processedText': 'false', 'rawText': '10.false'},
#    'globalID': 'NDQ_000162',
#    'idStructural': '10.',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000163': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'density.',
#      'rawText': 'a. density.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'pressure.',
#      'rawText': 'b. pressure.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'movement.',
#      'rawText': 'c. movement.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'temperature.',
#      'rawText': 'd. temperature.'}},
#    'beingAsked': {'processedText': 'The amount of water vapor that the air can hold depends mainly on air',
#     'rawText': '1. The amount of water vapor that the air can hold depends mainly on air'},
#    'correctAnswer': {'processedText': 'd', 'rawText': '1. d'},
#    'globalID': 'NDQ_000163',
#    'idStructural': '1. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000164': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'dew point.',
#      'rawText': 'a. dew point.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'tropopause.',
#      'rawText': 'b. tropopause.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'freezing point.',
#      'rawText': 'c. freezing point.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'convection point.',
#      'rawText': 'd. convection point.'}},
#    'beingAsked': {'processedText': 'Clouds form when air in the atmosphere reaches the',
#     'rawText': '2. Clouds form when air in the atmosphere reaches the'},
#    'correctAnswer': {'processedText': 'a', 'rawText': '2. a'},
#    'globalID': 'NDQ_000164',
#    'idStructural': '2. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000165': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'form high in the troposphere.',
#      'rawText': 'a. form high in the troposphere.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'always produce precipitation.',
#      'rawText': 'b. always produce precipitation.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'are made of ice crystals.',
#      'rawText': 'c. are made of ice crystals.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'two of the above',
#      'rawText': 'd. two of the above'}},
#    'beingAsked': {'processedText': 'Cirrus clouds',
#     'rawText': '3. Cirrus clouds'},
#    'correctAnswer': {'processedText': 'd', 'rawText': '3. d'},
#    'globalID': 'NDQ_000165',
#    'idStructural': '3. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000166': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'tall.',
#      'rawText': 'a. tall.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'rain.',
#      'rawText': 'b. rain.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'cold.',
#      'rawText': 'c. cold.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'snow.',
#      'rawText': 'd. snow.'}},
#    'beingAsked': {'processedText': 'The prefix nimbo- means',
#     'rawText': '4. The prefix nimbo- means'},
#    'correctAnswer': {'processedText': 'b', 'rawText': '4. b'},
#    'globalID': 'NDQ_000166',
#    'idStructural': '4. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000167': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'cumulonimbus clouds.',
#      'rawText': 'a. cumulonimbus clouds.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'nimbostratus clouds.',
#      'rawText': 'b. nimbostratus clouds.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'cirrocumulus clouds.',
#      'rawText': 'c. cirrocumulus clouds.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'cirrostratus clouds.',
#      'rawText': 'd. cirrostratus clouds.'}},
#    'beingAsked': {'processedText': 'Hail forms only in',
#     'rawText': '5. Hail forms only in'},
#    'correctAnswer': {'processedText': 'a', 'rawText': '5. a'},
#    'globalID': 'NDQ_000167',
#    'idStructural': '5. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000168': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'freezing rain.',
#      'rawText': 'a. freezing rain.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'sleet.',
#      'rawText': 'b. sleet.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'hail.',
#      'rawText': 'c. hail.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'two of the above',
#      'rawText': 'd. two of the above'}},
#    'beingAsked': {'processedText': 'Types of precipitation that form when water vapor condenses as ice crystals include',
#     'rawText': '6. Types of precipitation that form when water vapor condenses as ice crystals include'},
#    'correctAnswer': {'processedText': 'b', 'rawText': '6. b'},
#    'globalID': 'NDQ_000168',
#    'idStructural': '6. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'},
#   'NDQ_000169': {'answerChoices': {'a': {'idStructural': 'a.',
#      'processedText': 'humidity.',
#      'rawText': 'a. humidity.'},
#     'b': {'idStructural': 'b.',
#      'processedText': 'precipitation.',
#      'rawText': 'b. precipitation.'},
#     'c': {'idStructural': 'c.',
#      'processedText': 'cloud formation.',
#      'rawText': 'c. cloud formation.'},
#     'd': {'idStructural': 'd.',
#      'processedText': 'all of the above',
#      'rawText': 'd. all of the above'}},
#    'beingAsked': {'processedText': 'Weather factors that are part of the water cycle include',
#     'rawText': '7. Weather factors that are part of the water cycle include'},
#    'correctAnswer': {'processedText': 'd', 'rawText': '7. d'},
#    'globalID': 'NDQ_000169',
#    'idStructural': '7. ',
#    'questionSubType': 'Multiple Choice',
#    'questionType': 'Multiple Choice'}}}

# %% [markdown]
# ### hide

# %%
for lessons in list(ck12_combined_dataset.values())[:20]:
    for lid, lesson in lessons.items():
        for qid, question in lesson['questions']['nonDiagramQuestions'].items():
            if question['type'] == 'True or False':
                if 'processedText' not in question['correctAnswer'].keys():
                    pass
                elif 'rawText' not in question['correctAnswer'].keys():
                    pass
                elif question['correctAnswer']['rawText'].split('.')[-1].strip() not in (['true', 'false']):
                    print('p', question['correctAnswer'])

# %%
for lessons in list(ck12_combined_dataset.values())[:20]:
    for lid, lesson in lessons.items():
        for qid, question in lesson['questions']['nonDiagramQuestions'].items():
            if '___' in question['beingAsked']['processedText']:
                if question['type'] == 'True or False':
                    if question['correctAnswer']['processedText'] not in ['true', 'false']:
                        print(question['correctAnswer'])
# Out:
# {'processedText': '5000'}
# {'processedText': 'orbitals'}

# %%
original_image_uris = []
for lessons in list(ck12_combined_dataset.values()):
    for lid, lesson in lessons.items():
        for topic_name, topic in lesson['topics'].items():
            for figure in topic['content']['figures']:
                original_image_uris.append(figure['image_uri'])

# %%
len(record_image_name_changes_name_only)
# Out:
# 3176

# %%
len(original_image_uris)
# Out:
# 3181

# %%
for lessons in complete_flat_ds:
    for qid, question in lesson['questions']['nonDiagramQuestions'].items():
        if 'processedText' not in question['correctAnswer'].keys():
            print('question')
        elif 'rawText' not in question['correctAnswer'].keys():
            pass

# %%
complete_flat_ds[3]['instructionalDiagrams'].keys()

# _ = iterate_over_all_material(full_test_ds, iterate_over_diagram_questions)

prob_image = 'tectonic_plates_9275.png'

prob_lesson = []
for lesson in complete_flat_ds:
    if lesson['lessonName'] == 'theory of plate tectonics':
        prob_lesson.append(lesson)

prob_nest_lesson = {'es': {}}
for subject, lessons in sorted(ck12_combined_dataset.items(), key= lambda x: x[0]):
        for lesson_name, lesson_content in sorted(lessons.items(), key= lambda x: x[0]):
            if lesson_name == "6.4 Theory of Plate Tectonics":
                prob_nest_lesson['es'][lesson_name] = lesson_content

prob_nest_lesson

prob_lesson[0]['instructionalDiagrams']

id_seq = []
for lesson in complete_flat_ds:
    for val in lesson['instructionalDiagrams'].values():
        if 'globalID' in val.keys():
            id_seq.append(val['globalID'])
#         print(val['imageName'])
#         if val['imageName'] == 'optics_reflection_9179.png':
#             print(val.keys())

sorted_ids = sorted([int(idn.split('_')[-1]) for idn in id_seq])

sorted_ids[-1]

complete_flat_ds = iterate_over_all_material(full_test_ds, flatten_complete_ds)

new_l_set = [len(lesson['questions']['nonDiagramQuestions']) for lesson in complete_flat_ds]
# old_l_set = [len(lesson['questions']['nonDiagramQuestions'])  for lesson in prev_v5]

pd.Series(new_l_set).sum()
# Out:
# dict_keys([])

# %%
# complete_flat_ds[0].keys()
# complete_flat_ds[0]['questions']
# sorted(complete_flat_ds[9]['instructionalDiagrams'].items(), key=lambda x: x[1]['globalID'])
# sorted(complete_flat_ds[0]['questions']['nonDiagramQuestions'].items(), key=lambda x: x[1]['globalID'])
# complete_flat_ds[0]['adjunctTopics']
# list(complete_flat_ds[0]['topics'].items())[5]
# complete_flat_ds[9]

# %%
t_ids_seen = []
q_ids_seen = []
for lesson in list(list(test_cds.values())[0].values()):
    for que in lesson['questions']['nonDiagramQuestions'].values():
        t_ids_seen.append(que['globalID'])  
for lesson in list(list(test_cds.values())[0].values()):
    for que in lesson['questions']['diagramQuestions'].values():
        q_ids_seen.append(que['globalID'])

# %%
# list(test_cds['earth-science'].values())[0]['topics']

# %%
# list(test_cds['earth-science'].values())[0]['adjunctTopics']

# %%
#             print(lesson_content['topics'].keys())

# %% [markdown]
# # renaming diagram image files

# %%
image_base = '/Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/'

# %%
len(missing)
# Out:
# 0

# %%
len(record_image_name_changes)
# Out:
# 3176

# %%
d_image = 'textbook_images/biotechnology_in_agriculture_21732.png'

# %%
# list(record_image_name_changes.values())

# %%
image_base
# Out:
# '/Users/schwenk/wrk/stb/dataset_releases/data_release_beta_5_p5_11_7/'

# %%
missing = []
for old_name, new_name in list(record_image_name_changes.items()):
    try:
        old_path = os.path.join(image_base, old_name)
        new_path = os.path.join(image_base, new_name)
        if not os.path.exists(new_path):
            print(new_path)
#         os.rename(old_path, new_path)
    except FileNotFoundError:
        missing.append(old_path)

# %%
with open('/Users/schwenk/Downloads/textbook_image_old_file_names.json', 'r') as f:
    list_images_ani = json.load(f)

# %%
len(list_images_ani)
# Out:
# 2027

# %%
missing_image_example = '1.1_Scientific_Ways_of_Thinking_Scientific_Theories_and_Scientific_Laws_0013_fig_1.2.png'

# %%
record_image_name_changes_name_only[missing_image_example]
# Out:
# 'scientific_ways_of_thinking_21250.png'

# %%
sorted(record_image_name_changes_name_only.keys())
# Out:
# ['1.1_Scientific_Ways_of_Thinking_Scientific_Theories_and_Scientific_Laws_0013_fig_1.2.png',
#  '1.1_Scientific_Ways_of_Thinking_Scientific_Theories_and_Scientific_Laws_0013_fig_1.3.png',
#  '1.1_Scientific_Ways_of_Thinking_Thinking_Like_a_Scientist_0012_fig_1.1.png',
#  '1.1_The_Nature_of_Science_Data_and_Experimental_Error_0012_fig_1.4.png',
#  '1.1_The_Nature_of_Science_Ideas_as_Models_0014_fig_1.6.png',
#  '1.1_The_Nature_of_Science_Inside_the_Science_Laboratory_0016_fig_1.8.png',
#  '1.1_The_Nature_of_Science_Lesson_Summary_0017_fig_1.9.png',
#  '1.1_The_Nature_of_Science_Physical_Models_0014_fig_1.5.png',
#  '1.1_The_Nature_of_Science_Questions_0010_fig_1.1.png',
#  '1.1_The_Nature_of_Science_Questions_0010_fig_1.2.png',
#  '1.1_The_Nature_of_Science_Research_0011_fig_1.3.png',
#  '1.1_The_Nature_of_Science_Safety_in_Science_0015_fig_1.7.png',
#  '1.1_What_Is_Science_How_Science_Advances_0011_fig_1.3.png',
#  '1.1_What_Is_Science_Induction_0010_fig_1.1.png',
#  '1.1_What_Is_Science_Induction_0010_fig_1.2.png',
#  '1.1_What_Is_Science_Scientific_Theories_0012_fig_1.4.png',
#  '1.2_Earth_Science_and_Its_Branches_Climatology_and_Meteorology_0022_fig_1.14.png',
#  '1.2_Earth_Science_and_Its_Branches_Climatology_and_Meteorology_0022_fig_1.15.png',
#  '1.2_Earth_Science_and_Its_Branches_Environmental_Science_0023_fig_1.16.png',
#  '1.2_Earth_Science_and_Its_Branches_Geology_0020_fig_1.11.png',
#  '1.2_Earth_Science_and_Its_Branches_Introduction_0019_fig_1.10.png',
#  '1.2_Earth_Science_and_Its_Branches_Lesson_Summary_0024_fig_1.17.png',
#  '1.2_Earth_Science_and_Its_Branches_Oceanography_0021_fig_1.12.png',
#  '1.2_Earth_Science_and_Its_Branches_Oceanography_0021_fig_1.13.png',
#  '1.2_The_Scope_of_Physical_Science_Careers_in_Physical_Science_0020_fig_1.6.png',
#  '24.4_The_Sun_and_the_EarthMoon_System_Solar_Eclipses_0614_fig_24.20.png',
#  '24.4_The_Sun_and_the_EarthMoon_System_Solar_Eclipses_0614_fig_24.21.png',
#  '25.1_Air_Pollution_Acid_Rain_0597_fig_25.1.png',
#  ...]

# %%
text_only_starting_names = [name.split('/')[-1] for name in original_image_uris]

# %%
text_only_starting_names
# Out:
# ['Continental_Drift_Wegeners_Evidence_0004_fig_1.1.png',
#  'Continental_Drift_Wegeners_Evidence_0005_fig_1.2.png',
#  '14.2_Ocean_Movements_Surface_Currents_0361_fig_14.15.png',
#  '14.2_Ocean_Movements_Tsunamis_0358_fig_14.11.png',
#  '14.2_Ocean_Movements_Spring_Tides_and_Neap_Tides_0360_fig_14.13.png',
#  '14.2_Ocean_Movements_Spring_Tides_and_Neap_Tides_0360_fig_14.14.png',
#  '14.2_Ocean_Movements_Upwelling_0363_fig_14.18.png',
#  '14.2_Ocean_Movements_Tides_0359_fig_14.12.png',
#  '14.2_Ocean_Movements_Waves_0357_fig_14.8.png',
#  '14.2_Ocean_Movements_Waves_0357_fig_14.9.png',
#  '14.2_Ocean_Movements_Deep_Currents_0362_fig_14.16.png',
#  '14.2_Ocean_Movements_Deep_Currents_0362_fig_14.17.png',
#  '14.2_Ocean_Movements_Breaking_Waves_0358_fig_14.10.png',
#  'Comets_Comets_0004_fig_1.1.png',
#  'Soil_Erosion_Grazing_0004_fig_1.2.png',
#  'Soil_Erosion_Farming_0004_fig_1.1.png',
#  'Soil_Erosion_Recreational_Activities_0006_fig_1.4.png',
#  'Soil_Erosion_Recreational_Activities_0006_fig_1.5.png',
#  'Soil_Erosion_Recreational_Activities_0007_fig_1.6.png',
#  'Soil_Erosion_Recreational_Activities_0007_fig_1.7.png',
#  'Soil_Erosion_Logging_and_Mining_0005_fig_1.3.png',
#  'Planet_Orbits_in_the_Solar_System_The_Size_and_Shape_of_Orbits_0004_fig_1.1.png',
#  'Faults_Faults_0004_fig_1.2.png',
#  'Faults_Joints_0004_fig_1.1.png',
#  'Faults_StrikeSlip_Faults_0006_fig_1.5.png',
#  'Faults_DipSlip_Faults_0005_fig_1.3.png',
#  'Faults_DipSlip_Faults_0005_fig_1.4.png',
#  '6.4_Theory_of_Plate_Tectonics_How_Plates_Move_0156_fig_6.16.png',
#  '6.4_Theory_of_Plate_Tectonics_Earthquake_Locations_0155_fig_6.13.png',
#  '6.4_Theory_of_Plate_Tectonics_Earthquakes_and_Plate_Boundaries_0155_fig_6.14.png',
#  '6.4_Theory_of_Plate_Tectonics_Earthquakes_and_Plate_Boundaries_0156_fig_6.15.png',
#  '6.4_Theory_of_Plate_Tectonics_Mountain_Building_0161_fig_6.23.png',
#  '6.4_Theory_of_Plate_Tectonics_Mountain_Building_0161_fig_6.24.png',
#  '6.4_Theory_of_Plate_Tectonics_Hotspots_in_the_Oceans_0163_fig_6.27.png',
#  '6.4_Theory_of_Plate_Tectonics_OceanOcean_Convergence_0159_fig_6.19.png',
#  '6.4_Theory_of_Plate_Tectonics_OceanOcean_Convergence_0159_fig_6.20.png',
#  'Ocean_Ecosystems_Oceanic_Zone_0005_fig_1.2.png',
#  'Ocean_Ecosystems_Oceanic_Zone_0005_fig_1.3.png',
#  'Ocean_Ecosystems_Oceanic_Zone_0005_fig_1.4.png',
#  '22.1_Air_Pollution_Secondary_Pollutants_0544_fig_22.2.png',
#  '22.1_Air_Pollution_Evaporation_of_VOCs_0546_fig_22.4.png',
#  '22.1_Air_Pollution_Sources_of_Air_Pollution_0545_fig_22.3.png',
#  '22.1_Air_Pollution_Primary_Pollutants_0544_fig_22.1.png',
#  'Deep_Ocean_Currents_Upwelling_0005_fig_1.2.png',
#  'Deep_Ocean_Currents_Downwelling_0004_fig_1.1.png',
#  'Mineral_Formation_Formation_from_Magma_0004_fig_1.1.png',
#  'Mineral_Formation_Minerals_Under_Pressure_0007_fig_1.6.png',
#  'Mineral_Formation_Minerals_from_Salt_Water_0005_fig_1.2.png',
#  'Mineral_Formation_Minerals_from_Salt_Water_0005_fig_1.3.png',
#  'Mineral_Formation_Minerals_from_Hot_Underground_Water_0006_fig_1.4.png',
#  'Mineral_Formation_Minerals_from_Hot_Underground_Water_0006_fig_1.5.png',
#  'Natural_Gas_Power_Consequences_of_Natural_Gas_Use_0005_fig_1.2.png',
#  'Natural_Gas_Power_Natural_Gas_Formation_0004_fig_1.1.png',
#  'Air_Quality_Photochemical_Smog_0004_fig_1.2.png',
#  'Air_Quality_Smog_0004_fig_1.1.png',
#  '24.2_Earths_Moon_Lunar_Maria_0604_fig_24.14.png',
#  '24.2_Earths_Moon_Lunar_Maria_0604_fig_24.15.png',
#  '24.2_Earths_Moon_Lunar_Characteristics_0603_fig_24.13.png',
#  'Formation_of_Earth_Early_Solar_System_Materials_0005_fig_1.2.png',
#  'Formation_of_Earth_Differentiation_0004_fig_1.1.png',
#  'Volcanoes_at_Plate_Boundaries_Continental_Rifting_0005_fig_1.1.png',
#  'Volcanoes_at_Plate_Boundaries_Review_0006_fig_1.2.png',
#  'Volcanoes_at_Plate_Boundaries_Review_0006_fig_1.3.png',
#  'Volcanoes_at_Plate_Boundaries_Explore_More_0007_fig_1.4.png',
#  '4.4_Metamorphic_Rocks_Metamorphism_0112_fig_4.14.png',
#  '4.4_Metamorphic_Rocks_Metamorphism_0112_fig_4.15.png',
#  '4.4_Metamorphic_Rocks_Uses_of_Metamorphic_Rocks_0112_fig_4.16.png',
#  'History_of_Mesozoic_Life_Dinosaurs_0004_fig_1.1.png',
#  'History_of_Mesozoic_Life_Summary_0005_fig_1.2.png',
#  'History_of_Mesozoic_Life_Summary_0005_fig_1.3.png',
#  'History_of_Mesozoic_Life_Summary_0006_fig_1.4.png',
#  'History_of_Mesozoic_Life_Summary_0006_fig_1.5.png',
#  'Influences_on_Weathering_Resources_from_Weathering_0005_fig_1.2.png',
#  'Influences_on_Weathering_Rock_and_Mineral_Type_0004_fig_1.1.png',
#  'Overpopulation_and_OverConsumption_Pollution_0004_fig_1.1.png',
#  'Overpopulation_and_OverConsumption_OverConsumption_0005_fig_1.2.png',
#  'Overpopulation_and_OverConsumption_Summary_0006_fig_1.3.png',
#  '11.2_Relative_Ages_of_Rocks_Law_of_Lateral_Continuity_0290_fig_11.8.png',
#  '11.2_Relative_Ages_of_Rocks_Divisions_of_the_Geologic_Time_Scale_0293_fig_11.13.png',
#  '11.2_Relative_Ages_of_Rocks_Life_and_the_Geologic_Time_Scale_0294_fig_11.14.png',
#  '11.2_Relative_Ages_of_Rocks_Law_of_Superposition_0289_fig_11.6.png',
#  '11.2_Relative_Ages_of_Rocks_Law_of_Superposition_0289_fig_11.7.png',
#  '11.2_Relative_Ages_of_Rocks_Using_Index_Fossils_0292_fig_11.12.png',
#  '11.2_Relative_Ages_of_Rocks_Unconformities_0291_fig_11.9.png',
#  '11.2_Relative_Ages_of_Rocks_Unconformities_0291_fig_11.10.png',
#  'Metamorphic_Rocks_Texture_0004_fig_1.1.png',
#  'Weather_versus_Climate_What_is_Climate_0004_fig_1.1.png',
#  'Volcanic_Landforms_Lava_Domes_0004_fig_1.1.png',
#  'Volcanic_Landforms_Lava_Domes_0004_fig_1.2.png',
#  'Volcanic_Landforms_Lava_Domes_0004_fig_1.3.png',
#  'Volcanic_Landforms_Lava_Plateaus_0005_fig_1.4.png',
#  'Volcanic_Landforms_Land_0005_fig_1.5.png',
#  'Volcanic_Landforms_Land_0006_fig_1.6.png',
#  'Volcanic_Landforms_Landforms_from_Magma_0006_fig_1.7.png',
#  'Predicting_Weather_Numerical_Weather_Prediction_0004_fig_1.1.png',
#  'Predicting_Weather_Numerical_Weather_Prediction_0004_fig_1.2.png',
#  'Avoiding_Soil_Loss_Soil_Erosion_0004_fig_1.1.png',
#  'Avoiding_Soil_Loss_Preventing_Soil_Erosion_0005_fig_1.2.png',
#  'Avoiding_Soil_Loss_Preventing_Soil_Erosion_0005_fig_1.3.png',
#  'Collecting_Weather_Data_Radar_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Weather_Stations_0004_fig_1.1.png',
#  'Collecting_Weather_Data_Satellites_0006_fig_1.3.png',
#  'Distance_Between_Stars_Parallax_0004_fig_1.1.png',
#  'Divergent_Plate_Boundaries_Plate_Divergence_on_Land_0004_fig_1.1.png',
#  'Divergent_Plate_Boundaries_Summary_0005_fig_1.2.png',
#  'Branches_of_Earth_Science_Astronomy_0005_fig_1.3.png',
#  'Branches_of_Earth_Science_Geology_0004_fig_1.1.png',
#  'Branches_of_Earth_Science_Climatology_and_Meteorology_0004_fig_1.2.png',
#  'Acid_Rain_pH_and_Acid_Rain_0004_fig_1.1.png',
#  'Acid_Rain_pH_and_Acid_Rain_0004_fig_1.2.png',
#  'Acid_Rain_pH_and_Acid_Rain_0005_fig_1.3.png',
#  'Acid_Rain_Effects_of_Acid_Rain_0006_fig_1.4.png',
#  'Seafloor_Spreading_Hypothesis_Seafloor_Spreading_0004_fig_1.1.png',
#  'Energy_from_Biomass_Biomass_0004_fig_1.1.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0004_fig_1.2.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0005_fig_1.3.png',
#  'Effects_of_Air_Pollution_on_Human_Health_Human_Illnesses_from_Air_Pollution_0004_fig_1.1.png',
#  'Scientific_Explanations_and_Interpretations_An_Analysis_0005_fig_1.2.png',
#  'Scientific_Explanations_and_Interpretations_Facts_Observations_Opinions_0004_fig_1.1.png',
#  'Landforms_from_Groundwater_Erosion_and_Deposition_Sinkholes_0004_fig_1.1.png',
#  'Landforms_from_Groundwater_Erosion_and_Deposition_Sinkholes_0004_fig_1.2.png',
#  'Landforms_from_Groundwater_Erosion_and_Deposition_Groundwater_Deposition_0005_fig_1.3.png',
#  'Landforms_from_Groundwater_Erosion_and_Deposition_Groundwater_Deposition_0005_fig_1.4.png',
#  '3.2_Identification_of_Minerals_Cleavage_0078_fig_3.14.png',
#  '3.2_Identification_of_Minerals_Cleavage_0079_fig_3.15.png',
#  '3.2_Identification_of_Minerals_Mohs_Hardness_Scale_0077_fig_3.13.png',
#  '3.2_Identification_of_Minerals_How_are_Minerals_Identified_0074_fig_3.10.png',
#  '3.2_Identification_of_Minerals_Streak_0075_fig_3.11.png',
#  '3.2_Identification_of_Minerals_Streak_0075_fig_3.12.png',
#  '3.2_Identification_of_Minerals_Other_Identifying_Characteristics_0080_fig_3.16.png',
#  'Cleaning_Up_Groundwater_Monitoring_the_Extent_of_the_Pollutant_0004_fig_1.1.png',
#  'Availability_of_Natural_Resources_Waste_0005_fig_1.2.png',
#  'Availability_of_Natural_Resources_Waste_0005_fig_1.3.png',
#  'Availability_of_Natural_Resources_Price_0004_fig_1.1.png',
#  'Groundwater_Aquifers_Features_of_an_Aquifer_0004_fig_1.1.png',
#  'Groundwater_Aquifers_Wells_0005_fig_1.2.png',
#  'Groundwater_Aquifers_Wells_0005_fig_1.3.png',
#  'Groundwater_Aquifers_Wells_0006_fig_1.4.png',
#  'Effect_of_Latitude_on_Climate_Temperature_with_Latitude_0004_fig_1.1.png',
#  'Earthquake_Safe_Structures_New_Construction_0004_fig_1.1.png',
#  'Earthquake_Safe_Structures_Cost_Considerations_0005_fig_1.3.png',
#  'Earthquake_Safe_Structures_Retrofitting_0004_fig_1.2.png',
#  '5.3_Renewable_Energy_Resources_Wind_Power_0133_fig_5.11.png',
#  '5.3_Renewable_Energy_Resources_Consequences_of_Solar_Energy_Use_0131_fig_5.8.png',
#  '5.3_Renewable_Energy_Resources_Consequences_of_Solar_Energy_Use_0131_fig_5.9.png',
#  '5.3_Renewable_Energy_Resources_Energy_from_the_Sun_0130_fig_5.7.png',
#  '5.3_Renewable_Energy_Resources_Water_Power_0132_fig_5.10.png',
#  'Mountain_Building_Subducting_Oceanic_Plates_0004_fig_1.2.png',
#  'Mountain_Building_Diverging_Plates_0005_fig_1.3.png',
#  'Mountain_Building_Converging_Continental_Plates_0004_fig_1.1.png',
#  'Sustainable_Development_Sustainable_Development_0003_fig_1.1.png',
#  'Wind_Waves_Shape_of_a_Wave_0004_fig_1.1.png',
#  'Earths_Shape_Summary_0004_fig_1.1.png',
#  'Earths_Core_Core_0004_fig_1.1.png',
#  'How_Fossilization_Creates_Fossils_Fossils_Were_Parts_of_Living_Organisms_0004_fig_1.1.png',
#  'How_Fossilization_Creates_Fossils_Exceptional_Preservation_0008_fig_1.8.png',
#  'Clouds_Types_of_Clouds_0005_fig_1.2.png',
#  'Clouds_Fog_0006_fig_1.3.png',
#  'Clouds_Humidity_0004_fig_1.1.png',
#  'Neptune_Neptunes_Rings_and_Moons_0005_fig_1.3.png',
#  'Neptune_Extremes_of_Cold_and_Wind_0005_fig_1.2.png',
#  'Neptune_Neptune_0004_fig_1.1.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Extrusive_Igneous_Rocks_0005_fig_1.3.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Extrusive_Igneous_Rocks_0005_fig_1.4.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Extrusive_Igneous_Rocks_0006_fig_1.5.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Intrusive_Igneous_Rocks_0004_fig_1.1.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Intrusive_Igneous_Rocks_0004_fig_1.2.png',
#  '10.5_Erosion_and_Deposition_by_Gravity_Landslides_0277_fig_10.30.png',
#  '10.5_Erosion_and_Deposition_by_Gravity_Creep_0278_fig_10.33.png',
#  '10.5_Erosion_and_Deposition_by_Gravity_Mudslides_0277_fig_10.31.png',
#  '10.5_Erosion_and_Deposition_by_Gravity_Slump_0278_fig_10.32.png',
#  'Maps_Bathymetric_Maps_0004_fig_1.2.png',
#  'Maps_Bathymetric_Maps_0005_fig_1.3.png',
#  'Maps_Topographic_Maps_0004_fig_1.1.png',
#  'Population_Size_Limiting_Factors_0004_fig_1.1.png',
#  'Population_Size_Limiting_Factors_0005_fig_1.2.png',
#  'Modern_Biodiversity_Adaptations_0004_fig_1.1.png',
#  'Modern_Biodiversity_Adaptations_0004_fig_1.2.png',
#  'Modern_Biodiversity_Adaptations_0004_fig_1.3.png',
#  'Formation_of_the_Sun_and_Planets_Formation_of_the_Sun_and_Planets_0004_fig_1.1.png',
#  '12.3_History_of_Earths_Life_Forms_Introduction_0314_fig_12.9.png',
#  '12.3_History_of_Earths_Life_Forms_Moving_onto_Land_0319_fig_12.13.png',
#  '12.3_History_of_Earths_Life_Forms_Moving_onto_Land_0319_fig_12.14.png',
#  '12.3_History_of_Earths_Life_Forms_Ways_to_Live_in_the_Environment_0315_fig_12.10.png',
#  '12.3_History_of_Earths_Life_Forms_Paleozoic_Era_0318_fig_12.12.png',
#  '12.3_History_of_Earths_Life_Forms_The_Mesozoic_Era_0320_fig_12.15.png',
#  '12.3_History_of_Earths_Life_Forms_Mutations_0316_fig_12.11.png',
#  '12.3_History_of_Earths_Life_Forms_The_Cenozoic_Era_0320_fig_12.16.png',
#  '14.3_The_Ocean_Floor_Nonliving_Resources_0369_fig_14.23.png',
#  '14.3_The_Ocean_Floor_Using_Sonar_0366_fig_14.19.png',
#  '14.3_The_Ocean_Floor_Using_Sonar_0366_fig_14.20.png',
#  '14.3_The_Ocean_Floor_Features_on_the_Ocean_Floor_0368_fig_14.22.png',
#  '9.2_Soils_Topsoil_0242_fig_9.8.png',
#  '9.2_Soils_Soil_Texture_0241_fig_9.7.png',
#  '9.2_Soils_Laterite_0244_fig_9.12.png',
#  '9.2_Soils_Harmful_Practices_0245_fig_9.13.png',
#  'Geothermal_Power_Geothermal_Energy_0004_fig_1.1.png',
#  '15.1_The_Atmosphere_Altitude_and_Density_0382_fig_15.4.png',
#  '15.1_The_Atmosphere_Properties_of_Air_0382_fig_15.3.png',
#  '15.1_The_Atmosphere_The_Atmosphere_and_the_Suns_Rays_0380_fig_15.1.png',
#  '15.1_The_Atmosphere_Altitude_and_Air_Pressure_0383_fig_15.5.png',
#  '15.1_The_Atmosphere_The_Atmosphere_and_Earths_Water_0380_fig_15.2.png',
#  'Formation_of_the_Moon_Moons_Birth_Story_0004_fig_1.1.png',
#  'Water_Distribution_Droughts_0004_fig_1.2.png',
#  'Water_Distribution_Water_Shortages_0004_fig_1.1.png',
#  'Water_Distribution_Conflicts_Over_Water_0006_fig_1.3.png',
#  'Thermosphere_and_Beyond_Aurora_0004_fig_1.1.png',
#  'Locating_Earthquake_Epicenters_Finding_the_Epicenter_0004_fig_1.1.png',
#  'Uses_of_Water_Agriculture_0004_fig_1.1.png',
#  'Uses_of_Water_Aquaculture_Problems_0006_fig_1.4.png',
#  'Uses_of_Water_Aquaculture_0005_fig_1.3.png',
#  'Uses_of_Water_Environmental_Use_0007_fig_1.5.png',
#  'Uses_of_Water_Why_Not_Change_0005_fig_1.2.png',
#  'Minerals_Chemical_Composition_0005_fig_1.2.png',
#  'Minerals_Crystalline_Solid_0004_fig_1.1.png',
#  '2.1_Introduction_to_Earths_Surface_Lesson_Summary_0035_fig_2.12.png',
#  '2.1_Introduction_to_Earths_Surface_Topography_0030_fig_2.2.png',
#  '2.1_Introduction_to_Earths_Surface_Topography_0030_fig_2.3.png',
#  '2.1_Introduction_to_Earths_Surface_Topography_0031_fig_2.4.png',
#  '2.1_Introduction_to_Earths_Surface_Topography_0031_fig_2.5.png',
#  '2.1_Introduction_to_Earths_Surface_Continents_and_Landforms_0032_fig_2.6.png',
#  '2.1_Introduction_to_Earths_Surface_Continents_and_Landforms_0032_fig_2.7.png',
#  '2.1_Introduction_to_Earths_Surface_Continents_and_Landforms_0033_fig_2.8.png',
#  '2.1_Introduction_to_Earths_Surface_Direction_0029_fig_2.1.png',
#  '2.1_Introduction_to_Earths_Surface_Ocean_Basins_0033_fig_2.9.png',
#  '2.1_Introduction_to_Earths_Surface_Ocean_Basins_0034_fig_2.10.png',
#  '2.1_Introduction_to_Earths_Surface_Ocean_Basins_0034_fig_2.11.png',
#  'Types_of_Fossilization_Permineralization_0004_fig_1.1.png',
#  'Types_of_Fossilization_Permineralization_0004_fig_1.2.png',
#  'Star_Power_Nuclear_Fusion_0004_fig_1.1.png',
#  'Star_Power_Particle_Accelerators_0005_fig_1.2.png',
#  'Star_Power_Particle_Accelerators_0005_fig_1.3.png',
#  'Moon_Lunar_Characteristics_0004_fig_1.1.png',
#  'Moon_Interior_of_the_Moon_0006_fig_1.3.png',
#  'Energy_Use_Oil_Use_by_Nation_0004_fig_1.1.png',
#  'Energy_Use_Oil_Use_by_Nation_0004_fig_1.2.png',
#  'Growth_of_Human_Populations_The_Rate_of_Growth_0004_fig_1.1.png',
#  'Growth_of_Human_Populations_The_Rate_of_Growth_0004_fig_1.2.png',
#  'Energy_Conservation_Conserving_Energy_at_Home_0004_fig_1.2.png',
#  'Energy_Conservation_Conserving_Energy_at_Home_0005_fig_1.3.png',
#  'Energy_Conservation_Conserving_Energy_in_Transportation_0004_fig_1.1.png',
#  'Pressure_and_Density_of_the_Atmosphere_Pressure_0004_fig_1.1.png',
#  'Natural_Resource_Conservation_Conserving_Natural_Resources_0004_fig_1.1.png',
#  '8.1_Volcanic_Activity_Volcanic_Hot_Spots_0209_fig_8.3.png',
#  '8.1_Volcanic_Activity_Volcanic_Hot_Spots_0209_fig_8.4.png',
#  '8.1_Volcanic_Activity_Convergent_Plate_Boundaries_0208_fig_8.2.png',
#  '8.1_Volcanic_Activity_Where_Volcanoes_Are_Found_0207_fig_8.1.png',
#  'Petroleum_Power_Consequences_of_Oil_Use_0006_fig_1.3.png',
#  'Petroleum_Power_Consequences_of_Oil_Use_0006_fig_1.4.png',
#  'Petroleum_Power_Oil_Production_0004_fig_1.1.png',
#  'Petroleum_Power_Summary_0007_fig_1.5.png',
#  'Petroleum_Power_Oil_Use_0005_fig_1.2.png',
#  '23.2_Early_Space_Exploration_Satellites_0573_fig_23.13.png',
#  '23.2_Early_Space_Exploration_Satellites_0573_fig_23.14.png',
#  '23.2_Early_Space_Exploration_Satellites_0574_fig_23.15.png',
#  '23.2_Early_Space_Exploration_Satellites_0574_fig_23.16.png',
#  '23.2_Early_Space_Exploration_How_Rockets_Work_0572_fig_23.12.png',
#  '23.2_Early_Space_Exploration_The_Race_Is_On_0577_fig_23.19.png',
#  '23.2_Early_Space_Exploration_Reaching_the_Moon_0578_fig_23.20.png',
#  '23.2_Early_Space_Exploration_Reaching_the_Moon_0578_fig_23.21.png',
#  '23.2_Early_Space_Exploration_How_Satellites_Stay_in_Orbit_0575_fig_23.17.png',
#  '23.2_Early_Space_Exploration_Types_of_Orbits_0576_fig_23.18.png',
#  'Coal_Power_Consequences_of_Coal_Use_0005_fig_1.2.png',
#  'Coal_Power_Explore_More_0007_fig_1.4.png',
#  'Coal_Power_Coal_0004_fig_1.1.png',
#  'Coal_Power_Summary_0006_fig_1.3.png',
#  'Radioactive_Decay_as_a_Measure_of_Age_HalfLives_0005_fig_1.2.png',
#  'Radioactive_Decay_as_a_Measure_of_Age_Radioactive_Isotopes_0004_fig_1.1.png',
#  'Streams_and_Rivers_Divides_0006_fig_1.5.png',
#  'Streams_and_Rivers_Divides_0006_fig_1.6.png',
#  'Streams_and_Rivers_Parts_of_a_Stream_0004_fig_1.1.png',
#  'Streams_and_Rivers_Parts_of_a_Stream_0004_fig_1.2.png',
#  'Streams_and_Rivers_Stages_of_Streams_0005_fig_1.3.png',
#  'Streams_and_Rivers_Stages_of_Streams_0005_fig_1.4.png',
#  'Explosive_Eruptions_Volcanic_Gases_0006_fig_1.5.png',
#  'Explosive_Eruptions_Cascades_Volcanoes_0005_fig_1.4.png',
#  'Explosive_Eruptions_Causes_of_the_Explosion_0004_fig_1.1.png',
#  'Explosive_Eruptions_Pyroclastic_Material_0004_fig_1.2.png',
#  'Explosive_Eruptions_Pyroclastic_Material_0005_fig_1.3.png',
#  'Venus_Motion_0004_fig_1.1.png',
#  'Venus_Extreme_Atmosphere_0004_fig_1.2.png',
#  'Venus_Venuss_Surface_0005_fig_1.3.png',
#  'Venus_Venuss_Surface_0006_fig_1.4.png',
#  'Fresh_Water_Ecosystems_Marshes_0005_fig_1.2.png',
#  'Fresh_Water_Ecosystems_Ecological_Role_of_Wetlands_0006_fig_1.3.png',
#  'Fresh_Water_Ecosystems_Lake_Ecosystems_0004_fig_1.1.png',
#  'Ocean_Garbage_Patch_The_Great_Pacific_Garbage_Patch_0005_fig_1.2.png',
#  'Ocean_Garbage_Patch_The_Great_Pacific_Garbage_Patch_0005_fig_1.3.png',
#  'Ocean_Garbage_Patch_Sources_of_Trash_0004_fig_1.1.png',
#  'Geologic_Time_Scale_The_Geologic_Time_Scale_0004_fig_1.1.png',
#  'Plate_Tectonics_through_Earth_History_Supercontinent_Cycle_0004_fig_1.1.png',
#  'Plate_Tectonics_through_Earth_History_Supercontinent_Cycle_0005_fig_1.2.png',
#  '21st_Century_Tsunami_Tsunami_Warning_Systems_0005_fig_1.4.png',
#  '21st_Century_Tsunami_Japan_Tsunami_2011_0004_fig_1.2.png',
#  '21st_Century_Tsunami_Japan_Tsunami_2011_0005_fig_1.3.png',
#  '21st_Century_Tsunami_Boxing_Day_Tsunami_2004_0004_fig_1.1.png',
#  '5.1_Earths_Energy_Fuel_0118_fig_5.1.png',
#  '5.1_Earths_Energy_Types_of_Energy_Resources_0119_fig_5.2.png',
#  'Earthquakes_at_Convergent_Plate_Boundaries_OceanOcean_Japan_0004_fig_1.1.png',
#  'Earthquakes_at_Convergent_Plate_Boundaries_OceanOcean_Japan_0004_fig_1.2.png',
#  'Earthquakes_at_Convergent_Plate_Boundaries_ContinentContinent_Asia_0005_fig_1.3.png',
#  'Surface_Ocean_Currents_Gyres_0005_fig_1.1.png',
#  'Surface_Ocean_Currents_Gyres_0005_fig_1.2.png',
#  'Surface_Ocean_Currents_Local_Surface_Currents_0006_fig_1.3.png',
#  '10.3_Erosion_and_Deposition_by_Wind_Loess_0269_fig_10.25.png',
#  '10.3_Erosion_and_Deposition_by_Wind_How_the_Wind_Moves_Particles_0267_fig_10.21.png',
#  '10.3_Erosion_and_Deposition_by_Wind_Introduction_0266_fig_10.20.png',
#  '10.3_Erosion_and_Deposition_by_Wind_How_Sand_Dunes_Form_0268_fig_10.24.png',
#  '10.3_Erosion_and_Deposition_by_Wind_Lesson_Summary_0270_fig_10.26.png',
#  '10.3_Erosion_and_Deposition_by_Wind_Deposition_of_Sand_0268_fig_10.22.png',
#  '10.3_Erosion_and_Deposition_by_Wind_Deposition_of_Sand_0268_fig_10.23.png',
#  ...]

# %%
lookup_for_ani = {}
missing_image_list = []
for image_n in list_images_ani:
    if image_n not in record_image_name_changes_name_only:
        missing_image_list.append(image_n)
        new_name = missing_image_lookup[image_n]
        if new_name == 'MISSING':
            lookup_for_ani[image_n] = new_name
        else:
            lookup_for_ani[image_n] = record_image_name_changes_name_only[new_name]
    else:
        lookup_for_ani[image_n] = record_image_name_changes_name_only[image_n]

# %%
len(lookup_for_ani)
# Out:
# 2027

# %%
lookup_for_ani
# Out:
# {'16.1_Weather_and_Water_in_the_Atmosphere_Points_to_Consider_0412_fig_16.5.png': 'weather_and_water_in_the_atmosphere_20160.png',
#  '2.2_Modeling_Earths_Surface_Gnomonic_Projection_0040_fig_2.17.png': 'modeling_earths_surface_20257.png',
#  'Earthquake_Zones_Earthquake_Zones_0004_fig_1.2.png': 'earthquake_zones_20710.png',
#  '7.3_The_Scale_of_Evolution_Macroevolution_0175_fig_7.14.png': 'the_scale_of_evolution_21650.png',
#  'Friction_Why_Friction_Occurs_0004_fig_1.2.png': 'friction_22853.png',
#  '18.1_Ecosystems_How_Matter_Moves_Through_Ecosystems_0470_fig_18.9.png': 'ecosystems_20216.png',
#  'Noble_Gases_Review_0007_fig_1.4.png': 'noble_gases_22981.png',
#  'OverConsumption_OverConsumption_0005_fig_1.2.png': 'overpopulation_and_over_consumption_21013.png',
#  '20.1_Characteristics_of_Sound_Loudness_0455_fig_20.3.png': 'characteristics_of_sound_22409.png',
#  '17.2_Choosing_Healthy_Foods_MyPlate_0422_fig_17.6.png': 'choosing_healthy_foods_21422.png',
#  'Circulation_on_Climate_The_ITCZ_0004_fig_1.1.png': 'MISSING',
#  '18.3_Blood_Blood_Type_0450_fig_18.9.png': 'blood_21440.png',
#  '24.1_Planet_Earth_Earths_Revolution_0599_fig_24.12.png': 'planet_earth_20375.png',
#  'Properties_of_Solutions_Freezing_Point_Depression_0004_fig_1.2.png': 'properties_of_solutions_23041.png',
#  '14.1_Introduction_to_the_Oceans_Zones_Based_on_Distance_from_Shore_0353_fig_14.6.png': 'introduction_to_the_oceans_20109.png',
#  'Energy_Level_The_Outermost_Level_0005_fig_1.3.png': 'energy_level_22828.png',
#  '15.1_Pressure_of_Fluids_Pascals_Law_0339_fig_15.9.png': 'pressure_of_fluids_22299.png',
#  '17.3_Climate_Change_How_Will_Climate_Change_in_the_Future_0456_fig_17.22.png': 'climate_change_20203.png',
#  '12.3_History_of_Earths_Life_Forms_The_Cenozoic_Era_0320_fig_12.16.png': 'history_of_earths_life_forms_20084.png',
#  '12.3_Mollusks_and_Annelids_Traits_of_Mollusks_0294_fig_12.16.png': 'mollusks_and_annelids_21320.png',
#  '17.2_World_Climates_Temperate_Climates_0448_fig_17.12.png': 'world_climates_20193.png',
#  'Things_Modern_Classification_0005_fig_1.3.png': 'organization_of_living_things_22027.png',
#  'Friction_Factors_That_Affect_Friction_0005_fig_1.3.png': 'friction_22854.png',
#  'Determining_Relative_Ages_Determining_the_Relative_Ages_of_Rocks_0004_fig_1.1.png': 'determining_relative_ages_20689.png',
#  'Tracing_Evolution_Evolutionary_Trees_0004_fig_1.1.png': 'tracing_evolution_22173.png',
#  '8.2_Volcanic_Eruptions_Lava_0214_fig_8.8.png': 'volcanic_eruptions_20572.png',
#  '16.4_The_Muscular_System_Types_of_Muscle_Tissue_0408_fig_16.17.png': 'the_muscular_system_21411.png',
#  'Cardiovascular_System_Functions_of_the_Cardiovascular_System_0004_fig_1.1.png': 'cardiovascular_system_21750.png',
#  'PositionTime_Graphs_Slope_Equals_Velocity_0004_fig_1.2.png': 'position_time_graphs_23021.png',
#  '19.1_The_Respiratory_System_Gas_Exchange_Between_the_Air_and_Blood_0459_fig_19.3.png': 'the_respiratory_system_21444.png',
#  'Uses_of_Water_Agriculture_0004_fig_1.1.png': 'uses_of_water_21201.png',
#  '3.2_Cell_Structures_Structure_of_the_Cell_Membrane_0073_fig_3.8.png': 'cell_structures_21578.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.2.png': 'chemical_bonding_20652.png',
#  'Revolutions_of_Earth_The_Heliocentric_Universe_0005_fig_1.2.png': 'revolutions_of_earth_21069.png',
#  'Protein_Translation_0005_fig_1.3.png': 'translation_of_rna_to_protein_22178.png',
#  '9.1_Weathering_Ice_Wedging_0233_fig_9.2.png': 'weathering_20589.png',
#  'Momentum_References_0006_fig_1.2.png': 'MISSING',
#  '4.1_Solids_Liquids_Gases_and_Plasmas_Energy_and_Matter_0082_fig_4.7.png': 'solids_liquids_gases_and_plasmas_22540.png',
#  '13.4_Elastic_Force_Introduction_0309_fig_13.24.png': 'elastic_force_22277.png',
#  'Simple_Machines_Simple_and_Compound_Machines_0006_fig_1.4.png': 'simple_machines_23079.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0004_fig_1.2.png': 'forms_of_energy_22845.png',
#  '22.1_Air_Pollution_Secondary_Pollutants_0544_fig_22.2.png': 'air_pollution_20320.png',
#  'Lens_References_0005_fig_1.2.png': 'MISSING',
#  'Hearing_and_Balance_Explore_More_0006_fig_1.4.png': 'hearing_and_balance_21878.png',
#  '6.3_Advances_in_Genetics_Lesson_Summary_0153_fig_6.17.png': 'advances_in_genetics_21636.png',
#  '16.3_Storms_Lesson_Summary_0427_fig_16.19.png': 'storms_20174.png',
#  '5.2_Reproduction_Binary_Fission_0114_fig_5.9.png': 'reproduction_21607.png',
#  '6.2_Continental_Drift_Magnetic_Evidence_0147_fig_6.8.png': 'continental_drift_20502.png',
#  '14.2_Ocean_Movements_Deep_Currents_0362_fig_14.17.png': 'ocean_movements_20120.png',
#  '24.1_Flow_of_Energy_Food_Webs_0580_fig_24.5.png': 'flow_of_energy_21544.png',
#  'Types_of_Friction_Fluid_Friction_0005_fig_1.3.png': 'types_of_friction_23134.png',
#  'Electric_Fields_Interacting_Electric_Fields_0004_fig_1.1.png': 'electric_fields_22787.png',
#  '12.1_Sponges_and_Cnidarians_Specialized_Cells_in_Sponges_0282_fig_12.4.png': 'sponges_and_cnidarians_21308.png',
#  'Geological_Stresses_Responses_to_Stress_0005_fig_1.3.png': 'geological_stresses_20803.png',
#  '21.1_Infectious_Diseases_Types_of_Pathogens_0497_fig_21.1.png': 'infectious_diseases_21485.png',
#  'Diffusion_Diffusion_0004_fig_1.1.png': 'diffusion_21800.png',
#  '3.1_Minerals_Physical_Properties_0068_fig_3.5.png': 'minerals_20446.png',
#  '17.1_Climate_and_Its_Causes_Lesson_Summary_0443_fig_17.7.png': 'climate_and_its_causes_20188.png',
#  '5.1_Inside_the_Atom_Ions_0103_fig_5.5.png': 'inside_the_atom_22562.png',
#  'Microwaves_Defining_Electromagnetic_Waves_0003_fig_1.1.png': 'microwaves_22949.png',
#  'Petroleum_Power_Consequences_of_Oil_Use_0006_fig_1.3.png': 'petroleum_power_21023.png',
#  '16.4_The_Muscular_System_Skeletal_Muscles_Work_in_Pairs_0410_fig_16.20.png': 'the_muscular_system_21414.png',
#  '11.2_Radioactive_Decay_Comparing_Types_of_Radiation_0256_fig_11.8.png': 'radioactive_decay_22230.png',
#  '4.1_Transport_Simple_Diffusion_0084_fig_4.2.png': 'transport_21584.png',
#  '12.1_Distance_and_Direction_Frame_of_Reference_0272_fig_12.1.png': 'distance_and_direction_22241.png',
#  'Timeline_of_Evolution_Geologic_Time_Scale_0004_fig_1.1.png': 'timeline_of_evolution_22170.png',
#  'Population_Growth_The_Green_Revolution_0006_fig_1.5.png': 'agriculture_and_human_population_growth_20611.png',
#  '4.3_Cellular_Respiration_Cellular_Respiration_and_Photosynthesis_0098_fig_4.14.png': 'cellular_respiration_21596.png',
#  'Combining_Forces_Forces_Acting_in_the_Same_Direction_0005_fig_1.4.png': 'MISSING',
#  'Nails_and_Hair_Hair_0004_fig_1.1.png': 'nails_and_hair_22003.png',
#  '9.3_Carbon_and_Living_Things_Fatty_Acids_0214_fig_9.21.png': 'carbon_and_living_things_22644.png',
#  'Erosion_and_Deposition_Wave_Deposition_0005_fig_1.4.png': 'MISSING',
#  '6.2_Introduction_to_Genetics_Lesson_Summary_0145_fig_6.12.png': 'introduction_to_genetics_21631.png',
#  '17.2_Forms_of_Energy_Electromagnetic_Energy_0391_fig_17.14.png': 'forms_of_energy_22344.png',
#  'Natural_Selection_The_Galpagos_Islands_0005_fig_1.4.png': 'MISSING',
#  '9.2_Hydrocarbons_Isomers_0202_fig_9.9.png': 'hydrocarbons_22632.png',
#  'Reactions_Examples_of_Chemical_Reactions_0004_fig_1.2.png': 'recognizing_chemical_reactions_23053.png',
#  'Nuclear_Fission_Using_Energy_from_Nuclear_Fission_0005_fig_1.3.png': 'nuclear_fission_22986.png',
#  '5.1_Inside_the_Atom_Parts_of_the_Atom_0100_fig_5.1.png': 'inside_the_atom_22558.png',
#  '18.2_Cycles_of_Matter_Recall_0476_fig_18.14.png': 'cycles_of_matter_20221.png',
#  'Paleozoic_Plate_Tectonics_Review_0005_fig_1.2.png': 'paleozoic_plate_tectonics_21020.png',
#  '16.4_The_Muscular_System_Structure_and_Function_of_Skeletal_Muscles_0409_fig_16.19.png': 'the_muscular_system_21413.png',
#  'Mercury_Pollution_Mad_As_a_Hatter_0005_fig_1.2.png': 'mercury_pollution_20934.png',
#  '25.1_Introduction_to_the_Solar_System_The_Sun_at_the_Center_of_the_Universe_0620_fig_25.2.png': 'introduction_to_the_solar_system_20387.png',
#  '14.3_The_Ocean_Floor_Traveling_to_the_Ocean_Floor_0367_fig_14.21.png': 'the_ocean_floor_20124.png',
#  '24.1_Magnets_and_Magnetism_Magnetism_and_Materials_0556_fig_24.5.png': 'magnets_and_magnetism_22488.png',
#  'Plants_Reproduction_in_Seedless_Vascular_Plants_0004_fig_1.1.png': 'reproduction_in_seedless_plants_22102.png',
#  'Natural_Selection_Giant_Tortoises_0006_fig_1.5.png': 'MISSING',
#  '25.2_Inner_Planets_Oceans_and_Atmosphere_0633_fig_25.14.png': 'inner_planets_20399.png',
#  'Protein_Translation_0004_fig_1.1.png': 'translation_of_rna_to_protein_22176.png',
#  'Intraplate_Activity_Intraplate_Activity_on_the_Continents_0005_fig_1.3.png': 'intraplate_activity_20868.png',
#  'Heat_Cooling_Down_by_Heating_Up_0004_fig_1.1.png': 'heat_22878.png',
#  '13.2_Friction_Apply_Concepts_0300_fig_13.14.png': 'friction_22267.png',
#  'Thermal_Energy_Thermal_Energy_Temperature_and_Mass_0004_fig_1.1.png': 'thermal_energy_23117.png',
#  'Soil_Characteristics_Classification_0005_fig_1.3.png': 'soil_characteristics_21114.png',
#  'Wind_Power_Summary_0005_fig_1.2.png': 'wind_power_21247.png',
#  '13.2_Surface_Water_Importance_of_Wetlands_0336_fig_13.9.png': 'surface_water_20093.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.1.png': 'chemical_and_solar_cells_22712.png',
#  '13.3_Amphibians_Larvae_and_Metamorphosis_0331_fig_13.15.png': 'amphibians_21350.png',
#  '13.1_What_Is_Force_Combining_Forces_0291_fig_13.3.png': 'what_is_force_22256.png',
#  '20.1_Use_and_Conservation_of_Resources_Recycling_Resources_0511_fig_20.6.png': 'use_and_conservation_of_resources_20286.png',
#  '8.2_Bacteria_Lesson_Summary_0204_fig_8.14.png': 'bacteria_21675.png',
#  'Plate_Boundaries_California_0004_fig_1.1.png': 'earthquakes_at_transform_plate_boundaries_20714.png',
#  '15.2_Buoyancy_of_Fluids_Density_and_Buoyant_Force_0344_fig_15.13.png': 'buoyancy_of_fluids_22303.png',
#  'Cycle_Human_Uses_0006_fig_1.3.png': 'processes_of_the_water_cycle_21057.png',
#  '20.2_Hearing_Sound_Hearing_Loss_0461_fig_20.9.png': 'hearing_sound_22415.png',
#  '15.2_Types_of_Animal_Behavior_How_Humans_Communicate_0379_fig_15.13.png': 'types_of_animal_behavior_21388.png',
#  'on_Land_Explore_More_0005_fig_1.2.png': 'plants_adaptations_for_life_on_land_22066.png',
#  '2.2_Modeling_Earths_Surface_Polar_Coordinate_System_0043_fig_2.22.png': 'modeling_earths_surface_20262.png',
#  'Density_Defining_Density_0004_fig_1.1.png': 'density_22765.png',
#  'Wave_Frequency_Wave_Frequency_and_Energy_0004_fig_1.2.png': 'wave_frequency_23165.png',
#  '2.2_Modeling_Earths_Surface_Mercator_Projection_0039_fig_2.16.png': 'modeling_earths_surface_20256.png',
#  'Protist_Characteristics_Summary_0005_fig_1.2.png': 'protist_characteristics_22091.png',
#  'Wavelength_Wavelength_and_Wave_Energy_0004_fig_1.3.png': 'wavelength_23174.png',
#  '10.1_Erosion_and_Deposition_by_Flowing_Water_Caves_0257_fig_10.9.png': 'erosion_and_deposition_by_flowing_water_20026.png',
#  '18.2_Transfer_of_Thermal_Energy_KQED_Darfur_Stoves_Project_0415_fig_18.7.png': 'transfer_of_thermal_energy_22361.png',
#  '4.3_Changes_of_State_Vaporization_0093_fig_4.20.png': 'changes_of_state_22553.png',
#  'Carbon_Bonding_How_Carbon_Forms_Bonds_0004_fig_1.2.png': 'carbon_bonding_22700.png',
#  'Photosynthesis_The_Chemical_Reaction_0005_fig_1.2.png': 'light_reactions_of_photosynthesis_21953.png',
#  '10.1_Introduction_to_Plants_Roots_0235_fig_10.4.png': 'introduction_to_plants_21266.png',
#  'Coal_Power_Consequences_of_Coal_Use_0005_fig_1.2.png': 'coal_power_20668.png',
#  'Simple_Machines_Increasing_Force_0004_fig_1.1.png': 'simple_machines_23076.png',
#  '12.1_Sponges_and_Cnidarians_Special_Features_of_Cnidarians_0284_fig_12.7.png': 'sponges_and_cnidarians_21311.png',
#  '10.1_Introduction_to_Solutions_Rate_of_Dissolving_0228_fig_10.1.png': 'introduction_to_solutions_22211.png',
#  'Archimedes_Law_Floating_Objects_and_Archimedes_Law_0004_fig_1.1.png': 'archimedes_law_22664.png',
#  'Erosion_and_Deposition_Stream_Deposition_0005_fig_1.2.png': 'MISSING',
#  '24.1_Flow_of_Energy_Trophic_Levels_and_Energy_0581_fig_24.6.png': 'flow_of_energy_21545.png',
#  'Fish_Characteristics_of_Fish_0004_fig_1.1.png': 'fish_21834.png',
#  '11.3_Nuclear_Energy_Using_Nuclear_Fusion_0266_fig_11.17.png': 'nuclear_energy_22239.png',
#  'Evaporation_From_Liquid_to_Gas_Without_Boiling_0003_fig_1.1.png': 'evaporation_22833.png',
#  '3.2_Types_of_Matter_Elements_0061_fig_3.7.png': 'types_of_matter_22521.png',
#  '9.2_Hydrocarbons_Aromatic_Hydrocarbons_0205_fig_9.14.png': 'hydrocarbons_22637.png',
#  'Discharge_How_Lightning_Occurs_0004_fig_1.1.png': 'static_electricity_and_static_discharge_23101.png',
#  'Properties_of_Bases_Detecting_Bases_0004_fig_1.1.png': 'properties_of_bases_23037.png',
#  'Infections_Bacterial_STIs_0004_fig_1.1.png': 'sexually_transmitted_infections_22137.png',
#  '7.3_Measuring_and_Predicting_Earthquakes_Finding_the_Epicenter_0193_fig_7.35.png': 'measuring_and_predicting_earthquakes_20557.png',
#  'Solubility_Factors_That_Affect_Solubility_0004_fig_1.1.png': 'solubility_23085.png',
#  'Energy_Use_Oil_Use_by_Nation_0004_fig_1.1.png': 'energy_use_20746.png',
#  '6.4_Theory_of_Plate_Tectonics_Mountain_Building_0161_fig_6.23.png': 'theory_of_plate_tectonics_20517.png',
#  '3.2_Identification_of_Minerals_Mohs_Hardness_Scale_0077_fig_3.13.png': 'identification_of_minerals_20454.png',
#  '23.2_Early_Space_Exploration_Satellites_0573_fig_23.14.png': 'early_space_exploration_20348.png',
#  '1.1_The_Nature_of_Science_Safety_in_Science_0015_fig_1.7.png': 'the_nature_of_science_20007.png',
#  'Physical_Science_Careers_Summary_0004_fig_1.1.png': 'physical_science_careers_23018.png',
#  '6.2_Continental_Drift_Introduction_0145_fig_6.6.png': 'continental_drift_20500.png',
#  '21.1_Electromagnetic_Waves_Wave_or_Particle_0476_fig_21.3.png': 'electromagnetic_waves_22424.png',
#  '14.2_Ocean_Movements_Breaking_Waves_0358_fig_14.10.png': 'ocean_movements_20113.png',
#  '6.1_Inside_Earth_Oceanic_Crust_0141_fig_6.3.png': 'inside_earth_20497.png',
#  'Frogs_and_Toads_How_Do_Frogs_Eat_0005_fig_1.2.png': 'frogs_and_toads_21848.png',
#  '10.2_Erosion_and_Deposition_by_Waves_Longshore_Drift_0262_fig_10.15.png': 'erosion_and_deposition_by_waves_20032.png',
#  '12.2_Flatworms_and_Roundworms_Roundworms_0290_fig_12.13.png': 'flatworms_and_roundworms_21317.png',
#  'Angiosperms_The_Parts_of_a_Flower_0006_fig_1.3.png': 'angiosperms_21701.png',
#  '9.2_Hydrocarbons_Saturated_Hydrocarbons_0201_fig_9.7.png': 'hydrocarbons_22630.png',
#  '14.1_Newtons_First_Law_Force_and_Motion_0316_fig_14.2.png': 'newtons_first_law_22281.png',
#  '25.3_Generating_and_Using_Electricity_Electromagnetic_Induction_0580_fig_25.9.png': 'generating_and_using_electricity_22508.png',
#  'Wheel_and_Axle_Round_and_Round_It_Goes_0003_fig_1.1.png': 'wheel_and_axle_23178.png',
#  '5.1_Cell_Division_Prokaryotic_Cell_Division_0109_fig_5.4.png': 'cell_division_21602.png',
#  '9.2_Hydrocarbons_Shapes_of_Alkanes_0202_fig_9.8.png': 'hydrocarbons_22631.png',
#  '20.1_Use_and_Conservation_of_Resources_Recall_0512_fig_20.7.png': 'use_and_conservation_of_resources_20287.png',
#  'Diseases_Avoiding_Pathogens_0004_fig_1.1.png': 'preventing_infectious_diseases_22078.png',
#  '12.1_Distance_and_Direction_Direction_0274_fig_12.4.png': 'distance_and_direction_22244.png',
#  'Digestive_System_Organs_Mouth_Esophagus_and_Stomach_0005_fig_1.2.png': 'digestive_system_organs_21803.png',
#  'Human_Sperm_Sperm_0004_fig_1.1.png': 'human_sperm_21894.png',
#  'Population_Growth_Patterns_Births_Deaths_and_Migration_0004_fig_1.1.png': 'population_growth_patterns_22068.png',
#  '10.2_Evolution_and_Classification_of_Plants_Early_Seed_Plants_0248_fig_10.16.png': 'evolution_and_classification_of_plants_21278.png',
#  'Skeletal_System_Joints_Joints_and_How_They_Move_0004_fig_1.2.png': 'skeletal_system_joints_22140.png',
#  'Interior_of_the_Sun_The_Outer_Layers_0005_fig_1.2.png': 'MISSING',
#  '25.3_Outer_Planets_Saturns_Rings_0642_fig_25.23.png': 'outer_planets_20408.png',
#  'Reproduction_Sexual_Reproduction_0005_fig_1.1.png': 'asexual_vs._sexual_reproduction_21713.png',
#  'Visible_Light_and_Matter_Reflection_0004_fig_1.1.png': 'visible_light_and_matter_23152.png',
#  'Nonrenewable_Resources_Nonrenewable_Resources_0004_fig_1.2.png': 'nonrenewable_resources_22014.png',
#  'Outdoor_Air_Pollution_Outdoor_Air_Pollution_0004_fig_1.1.png': 'outdoor_air_pollution_22036.png',
#  'Atoms_Neutrons_0005_fig_1.2.png': 'wave_interactions_23167.png',
#  '25.3_Generating_and_Using_Electricity_Electric_Generators_0581_fig_25.11.png': 'generating_and_using_electricity_22510.png',
#  'Faults_StrikeSlip_Faults_0006_fig_1.5.png': 'faults_20768.png',
#  '12.3_Acceleration_Introduction_0282_fig_12.10.png': 'acceleration_22250.png',
#  '23.2_Early_Space_Exploration_How_Rockets_Work_0572_fig_23.12.png': 'early_space_exploration_20346.png',
#  'Distance_Using_Maps_to_Measure_Distance_0004_fig_1.1.png': 'distance_22772.png',
#  '12.1_The_Origin_of_Earth_Earth_Forms_0306_fig_12.4.png': 'the_origin_of_earth_20072.png',
#  'Scientific_Method_Answer_a_Question_0005_fig_1.1.png': 'scientific_method_21093.png',
#  '20.1_Use_and_Conservation_of_Resources_Reducing_Resource_Use_0510_fig_20.5.png': 'use_and_conservation_of_resources_20285.png',
#  'Electromagnetism_Right_Hand_Rule_0004_fig_1.1.png': 'electromagnetism_22806.png',
#  '8.1_Introduction_to_Prokaryotes_Flagella_0194_fig_8.4.png': 'introduction_to_prokaryotes_21665.png',
#  'Groups_with_Metalloids_Group_16_Oxygen_Group_0006_fig_1.5.png': 'groups_with_metalloids_22869.png',
#  '2.2_Chemistry_of_Living_Things_Photosynthesis_and_Cellular_Respiration_0053_fig_2.14.png': 'chemistry_of_living_things_21464.png',
#  'Electrical_Grid_Transmission_Lines_0004_fig_1.1.png': 'electrical_grid_22795.png',
#  'Energy_from_Biomass_Biomass_0004_fig_1.1.png': 'energy_from_biomass_20745.png',
#  'Human_Vision_Seeing_in_Three_Dimensions_0004_fig_1.2.png': 'human_vision_21898.png',
#  '1_ShortTerm_Climate_Change_El_Nio_0004_fig_1.2.png': 'short_term_climate_change_21110.png',
#  'Impulses_The_Synapse_0005_fig_1.2.png': 'nerve_cells_and_nerve_impulses_22007.png',
#  '19.2_The_Excretory_System_Lesson_Summary_0466_fig_19.8.png': 'the_excretory_system_21449.png',
#  'Folds_Syncline_0005_fig_1.3.png': 'folds_20781.png',
#  '16.1_Weather_and_Water_in_the_Atmosphere_Dew_Point_0408_fig_16.2.png': 'weather_and_water_in_the_atmosphere_20157.png',
#  'Wave_Amplitude_What_Is_Wave_Amplitude_0004_fig_1.1.png': 'wave_amplitude_23161.png',
#  '19.1_Characteristics_of_Waves_Surface_Waves_0433_fig_19.8.png': 'characteristics_of_waves_22378.png',
#  '7.2_Ionic_Bonds_Lesson_Summary_0152_fig_7.6.png': 'ionic_bonds_22595.png',
#  '17.2_Choosing_Healthy_Foods_Using_Ingredients_Lists_0424_fig_17.8.png': 'choosing_healthy_foods_21424.png',
#  '11.3_Absolute_Ages_of_Rocks_Decay_of_Unstable_Isotopes_0299_fig_11.17.png': 'absolute_ages_of_rocks_20067.png',
#  'Population_Growth_Summary_0007_fig_1.6.png': 'agriculture_and_human_population_growth_20612.png',
#  '5.3_Modern_Atomic_Theory_Energy_Levels_in_Action_0116_fig_5.16.png': 'modern_atomic_theory_22573.png',
#  'Electronic_Component_Semiconductors_0004_fig_1.1.png': 'electronic_component_22810.png',
#  '6.4_Theory_of_Plate_Tectonics_Earthquakes_and_Plate_Boundaries_0156_fig_6.15.png': 'theory_of_plate_tectonics_20509.png',
#  '16.3_The_Skeletal_System_Fractures_0404_fig_16.14.png': 'the_skeletal_system_21408.png',
#  'for_Continental_Drift_Wegener_Was_Right_0006_fig_1.4.png': 'magnetic_polarity_evidence_for_continental_drift_20917.png',
#  '24.3_The_Sun_The_Photosphere_0609_fig_24.17.png': 'the_sun_20380.png',
#  '3.1_Lifes_Building_Blocks_Discovery_of_Cells_and_the_Cell_Theory_0065_fig_3.1.png': 'lifes_building_blocks_21571.png',
#  'Projectile_Motion_Another_Example_of_Projectile_Motion_0004_fig_1.2.png': 'projectile_motion_23032.png',
#  '1_Carbohydrate_Classification_Sugars_0004_fig_1.1.png': 'carbohydrate_classification_22696.png',
#  '8.4_Chemical_Reactions_and_Energy_Activation_Energy_0187_fig_8.15.png': 'chemical_reactions_and_energy_22620.png',
#  '2.4_Using_Satellites_and_Computers_Scientific_Satellites_0056_fig_2.35.png': 'using_satellites_and_computers_20275.png',
#  'Multicellular_Life_Ediacara_Fauna_0004_fig_1.1.png': 'MISSING',
#  '19.1_Characteristics_of_Waves_S_Waves_0430_fig_19.2.png': 'characteristics_of_waves_22372.png',
#  '21.4_Immune_System_Defenses_Immunity_and_Vaccination_0519_fig_21.17.png': 'immune_system_defenses_21501.png',
#  '2.1_Scientific_Investigation_Doing_Experiments_0027_fig_2.1.png': 'scientific_investigation_22392.png',
#  'Heating_Systems_How_a_Thermostat_Works_0005_fig_1.2.png': 'heating_systems_22882.png',
#  'Scientific_Notation_Using_Scientific_Notation_0004_fig_1.1.png': 'MISSING',
#  'Light_Let_There_Be_Light_0004_fig_1.1.png': 'light_22922.png',
#  'Projectile_Motion_Another_Example_of_Projectile_Motion_0004_fig_1.3.png': 'projectile_motion_23033.png',
#  'Surface_Ocean_Currents_Gyres_0005_fig_1.1.png': 'surface_ocean_currents_21149.png',
#  'Motion_Frame_of_Reference_0004_fig_1.2.png': 'motion_22964.png',
#  '6.3_Advances_in_Genetics_The_Human_Genome_Project_0148_fig_6.13.png': 'advances_in_genetics_21632.png',
#  'Projectile_Motion_Another_Example_of_Projectile_Motion_0004_fig_1.1.png': 'projectile_motion_23031.png',
#  '7.2_Nature_of_Earthquakes_Transform_Plate_Boundaries_0183_fig_7.24.png': 'nature_of_earthquakes_20546.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0004_fig_1.2.png': 'MISSING',
#  '22.2_Optics_Refraction_of_Light_0508_fig_22.14.png': 'optics_22449.png',
#  '16.2_Changing_Weather_Lesson_Summary_0417_fig_16.10.png': 'changing_weather_20165.png',
#  'Hydrogen_Bonding_Hydrogen_Bonding_0004_fig_1.1.png': 'hydrogen_bonding_22892.png',
#  '16.1_Work_Calculating_Work_0351_fig_16.3.png': 'work_22308.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.3.png': 'compounds_22742.png',
#  ...}

# %%
missing = []
for old_name, new_name in list(lookup_for_ani.items()):
    try:
        old_path = os.path.join(image_base, old_name)
        new_path = os.path.join(image_base, 'textbook_images', new_name)
        if not os.path.exists(new_path):
            print(new_path)
#         os.rename(old_path, new_path)
    except FileNotFoundError:
        missing.append(old_path)
# Out:
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING
# /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images/MISSING

# %%
len(lookup_for_ani)
# Out:
# 1783

# %%
len(missing_image_list)
# Out:
# 244

# %%
len(missing_image_list)
# Out:
# 244

# %%
missing_image_list[0]
# Out:
# 'Atmosphere_Air_Pressure_Zones_0004_fig_1.1.png'

# %%
words_to_check = missing_image_list[4].split('_')
words_to_check
# Out:
# ['Atmosphere', 'Layers', '0004', 'fig', '1.2.png']

# %%
len(missing_image_list)
# Out:
# 244

# %%
missing_image_lookup = {}

# %%
for missing_image in missing_image_list:
    for image in record_image_name_changes_name_only.keys(): 
        if missing_image in image:
            missing_image_lookup[missing_image] = image
            break
        else:
            missing_image_lookup[missing_image] = 'MISSING'

# %%
with open('textbook_image_lookup.pkl' , 'wb')as f:
    pickle.dump(lookup_for_ani, f)

# %%
len(missing_image_lookup)
# Out:
# 164

# %%
'Atmosphere_Air_Pressure_Zones_0004_fig_1.1.png' in 'Circulation_in_the_Atmosphere_Air_Pressure_Zones_0004_fig_1.1.png'
# Out:
# True

# %%
[lesson['lessonName'] for lesson in complete_flat_ds if 'atmosphere' in lesson['lessonName']]
# Out:
# ['the atmosphere',
#  'energy in the atmosphere',
#  'layers of the atmosphere',
#  'weather and water in the atmosphere',
#  'composition of the atmosphere',
#  'early atmosphere and oceans',
#  'electromagnetic energy in the atmosphere',
#  'heat transfer in the atmosphere',
#  'importance of the atmosphere',
#  'pressure and density of the atmosphere',
#  'temperature and heat in the atmosphere',
#  'temperature of the atmosphere']

# %%
sorted(list([k for k in record_image_name_changes_name_only.keys() if k[0] == 'C']))
# Out:
# ['Calculating_Acceleration_from_Force_and_Mass_Calculating_Force_0004_fig_1.1.png',
#  'Calculating_Acceleration_from_Force_and_Mass_Review_0005_fig_1.2.png',
#  'Calculating_Acceleration_from_Velocity_and_Time_Accelerating_on_a_Bike_0004_fig_1.1.png',
#  'Calculating_Work_Calculating_Force_or_Distance_When_Work_Is_Known_0004_fig_1.1.png',
#  'Cancer_Chemicals_0004_fig_1.1.png',
#  'Cancer_Chemicals_0004_fig_1.2.png',
#  'Cancer_Common_Types_of_Cancer_0005_fig_1.3.png',
#  'Carbon_Bonding_CarbonCarbon_Bonds_0005_fig_1.3.png',
#  'Carbon_Bonding_How_Carbon_Forms_Bonds_0004_fig_1.2.png',
#  'Carbon_Bonding_Valence_Electrons_in_Carbon_0004_fig_1.1.png',
#  'Carbon_Cycle_and_Climate_Atmospheric_Carbon_Dioxide_0005_fig_1.2.png',
#  'Carbon_Cycle_and_Climate_Human_Actions_Impact_the_Carbon_Cycle_0006_fig_1.3.png',
#  'Carbon_Cycle_and_Climate_Respiration_0004_fig_1.1.png',
#  'Carbon_Monomers_and_Polymers_Natural_Carbon_Polymers_0004_fig_1.1.png',
#  'Carbon_Monomers_and_Polymers_Natural_Carbon_Polymers_0004_fig_1.2.png',
#  'Carbon_Monomers_and_Polymers_Synthetic_Carbon_Polymers_0005_fig_1.3.png',
#  'Carbon_Monomers_and_Polymers_Synthetic_Carbon_Polymers_0005_fig_1.4.png',
#  'Cardiovascular_Diseases_Cardiovascular_Diseases_0004_fig_1.1.png',
#  'Cardiovascular_Diseases_Summary_0005_fig_1.2.png',
#  'Cardiovascular_System_Functions_of_the_Cardiovascular_System_0004_fig_1.1.png',
#  'Cardiovascular_System_Health_Keeping_Your_Cardiovascular_System_Healthy_0004_fig_1.1.png',
#  'Cardiovascular_System_Health_What_is_bad_cholesterol_0005_fig_1.2.png',
#  'Cartilaginous_Fish_Explore_More_I_0005_fig_1.1.png',
#  'Catalysts_Catalysts_in_Living_Things_0004_fig_1.2.png',
#  'Catalysts_How_Catalysts_Work_0004_fig_1.1.png',
#  'Causes_Of_Air_Pollution_Evaporation_0005_fig_1.2.png',
#  'Causes_Of_Air_Pollution_Evaporation_0005_fig_1.3.png',
#  'Causes_Of_Air_Pollution_Fossil_Fuels_0004_fig_1.1.png',
#  'Cell_Biology_Levels_of_Organization_0005_fig_1.4.png',
#  'Cell_Biology_Observing_Cells_0004_fig_1.1.png',
#  'Cell_Biology_Observing_Cells_0004_fig_1.2.png',
#  'Cell_Biology_Specialized_Cells_0005_fig_1.3.png',
#  'Cell_Cycle_Cell_Cycle_0004_fig_1.1.png',
#  'Cell_Division_Why_Cells_Divide_0004_fig_1.1.png',
#  'Cell_Membrane_The_Plasma_Membrane_0004_fig_1.1.png',
#  'Cell_Nucleus_Nucleolus_0004_fig_1.1.png',
#  'Cell_Transport_Composition_of_the_Cell_Membrane_0004_fig_1.1.png',
#  'Cellular_Respiration_ATP_0004_fig_1.1.png',
#  'Cellular_Respiration_Reactions_What_is_Cellular_Respiration_0004_fig_1.1.png',
#  'Cenozoic_Plate_Tectonics_Evolution_of_the_San_Andreas_Fault_0004_fig_1.1.png',
#  'Cenozoic_Plate_Tectonics_Ice_Ages_0005_fig_1.2.png',
#  'Centipedes_and_Millipedes_Centipedes_0004_fig_1.1.png',
#  'Central_Nervous_System_The_Brain_0004_fig_1.1.png',
#  'Central_Nervous_System_The_Brain_0005_fig_1.2.png',
#  'Changes_of_State_The_Role_of_Energy_in_Changes_of_State_0004_fig_1.1.png',
#  'Changes_of_State_The_Role_of_Energy_in_Changes_of_State_0004_fig_1.2.png',
#  'Characteristics_and_Origins_of_Life_MillerUrey_Experiment_0005_fig_1.1.png',
#  'Characteristics_and_Origins_of_Life_MillerUrey_Experiment_0005_fig_1.2.png',
#  'Characteristics_of_Life_Living_Things_Are_Made_of_Cells_0005_fig_1.2.png',
#  'Characteristics_of_Life_Living_Things_Are_Made_of_Cells_0005_fig_1.3.png',
#  'Characteristics_of_Life_Living_Things_Grow_and_Reproduce_0006_fig_1.4.png',
#  'Characteristics_of_Life_Living_Things_Maintain_Stable_Internal_Conditions_0006_fig_1.5.png',
#  'Characteristics_of_Life_Living_Things_Need_Resources_and_Energy_0004_fig_1.1.png',
#  'Charless_Law_Review_0004_fig_1.1.png',
#  'Chemical_Bond_Summary_0005_fig_1.2.png',
#  'Chemical_Bond_Why_Bonds_Form_0004_fig_1.1.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.1.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.2.png',
#  'Chemical_Bonding_Chemical_Bonding_0005_fig_1.3.png',
#  'Chemical_Bonding_Chemical_Bonding_0005_fig_1.4.png',
#  'Chemical_Change_Identifying_Chemical_Changes_0004_fig_1.1.png',
#  'Chemical_Equations_Using_Chemical_Symbols_and_Formulas_0004_fig_1.1.png',
#  'Chemical_Properties_of_Matter_Flammability_0004_fig_1.1.png',
#  'Chemical_Reaction_Overview_Same_Atoms_New_Bonds_0004_fig_1.2.png',
#  'Chemical_Reaction_Overview_What_Is_a_Chemical_Reaction_0004_fig_1.1.png',
#  'Chemical_Reaction_Rate_Concentration_of_Reactants_0004_fig_1.2.png',
#  'Chemical_Reaction_Rate_Surface_Area_of_Reactants_0005_fig_1.3.png',
#  'Chemical_Reaction_Rate_Temperature_of_Reactants_0004_fig_1.1.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Carbonic_Acid_0005_fig_1.3.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Oxygen_0005_fig_1.4.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Water_0004_fig_1.2.png',
#  'Chemical_Weathering_Clay_0004_fig_1.1.png',
#  'Chemical_Weathering_Mechanical_and_Chemical_Weathering_0006_fig_1.5.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.1.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.2.png',
#  'Chemistry_of_Compounds_Same_Elements_Different_Compounds_0004_fig_1.2.png',
#  'Chemistry_of_Compounds_Same_Elements_Different_Compounds_0005_fig_1.3.png',
#  'Chemistry_of_Compounds_What_Are_Compounds_0004_fig_1.1.png',
#  'Chemistry_of_Life_Chemical_Reactions_0005_fig_1.2.png',
#  'Chemistry_of_Life_The_Elements_0004_fig_1.1.png',
#  'Choosing_Healthy_Foods_Explore_More_0008_fig_1.4.png',
#  'Choosing_Healthy_Foods_MyPlate_0005_fig_1.2.png',
#  'Choosing_Healthy_Foods_MyPyramid_0004_fig_1.1.png',
#  'Choosing_Healthy_Foods_Using_Nutrition_Facts_Labels_0006_fig_1.3.png',
#  'Chordates_Characteristics_of_the_Chordates_0004_fig_1.1.png',
#  'Chordates_Classification_of_the_Chordates_0004_fig_1.2.png',
#  'Chromosomal_Disorders_Extra_Chromosomes_0004_fig_1.1.png',
#  'Chromosomal_Disorders_Extra_Chromosomes_0004_fig_1.2.png',
#  'Circulation_and_the_Lymphatic_System_Role_of_the_Lymphatic_System_in_Circulation_0005_fig_1.2.png',
#  'Circulation_and_the_Lymphatic_System_The_Lymphatic_System_and_Circulation_0004_fig_1.1.png',
#  'Cleaning_Up_Groundwater_Monitoring_the_Extent_of_the_Pollutant_0004_fig_1.1.png',
#  'Climate_Change_in_Earth_History_Climate_Change_in_Earth_History_0004_fig_1.1.png',
#  'Climate_Change_in_Earth_History_Climate_Change_in_Earth_History_0005_fig_1.2.png',
#  'Climate_Zones_and_Biomes_Major_Climate_Groups_0004_fig_1.1.png',
#  'Cloning_Cloning_0004_fig_1.1.png',
#  'Clouds_Fog_0006_fig_1.3.png',
#  'Clouds_Humidity_0004_fig_1.1.png',
#  'Clouds_Types_of_Clouds_0005_fig_1.2.png',
#  'Cnidarians_Cnidarian_Colonies_0004_fig_1.1.png',
#  'Coal_Power_Coal_0004_fig_1.1.png',
#  'Coal_Power_Consequences_of_Coal_Use_0005_fig_1.2.png',
#  'Coal_Power_Explore_More_0007_fig_1.4.png',
#  'Coal_Power_Summary_0006_fig_1.3.png',
#  'Coastal_Pollution_Ocean_Pollution_0004_fig_1.1.png',
#  'Coastal_Pollution_Review_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Radar_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Satellites_0006_fig_1.3.png',
#  'Collecting_Weather_Data_Weather_Stations_0004_fig_1.1.png',
#  'Color_Colors_of_Objects_0004_fig_1.3.png',
#  'Color_Colors_of_Objects_0005_fig_1.4.png',
#  'Color_Review_0006_fig_1.6.png',
#  'Color_Separating_Colors_of_Light_0004_fig_1.1.png',
#  'Color_Separating_Colors_of_Light_0004_fig_1.2.png',
#  'Color_The_Colors_We_See_0005_fig_1.5.png',
#  'Combustion_Reactions_Combustion_of_Hydrocarbons_0004_fig_1.2.png',
#  'Combustion_Reactions_What_Is_A_Combustion_Reaction_0004_fig_1.1.png',
#  'Comets_Comets_0004_fig_1.1.png',
#  'Communication_in_Science_How_Scientists_Communicate_0004_fig_1.1.png',
#  'Competition_Competition_0004_fig_1.1.png',
#  'Components_of_Blood_Components_of_Blood_0004_fig_1.1.png',
#  'Components_of_Blood_Red_Blood_Cells_0004_fig_1.2.png',
#  'Components_of_Blood_Summary_0006_fig_1.4.png',
#  'Components_of_Blood_White_Blood_Cells_0005_fig_1.3.png',
#  'Composition_of_the_Atmosphere_Nitrogen_and_Oxygen_0004_fig_1.1.png',
#  'Composition_of_the_Atmosphere_Particulates_0005_fig_1.2.png',
#  'Compound_Machine_Corkscrew_0004_fig_1.1.png',
#  'Compound_Machine_Corkscrew_0004_fig_1.2.png',
#  'Compound_Machine_Review_0005_fig_1.3.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.2.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.3.png',
#  'Compounds_What_Is_a_Compound_0004_fig_1.1.png',
#  'Condensation_Dew_Point_0004_fig_1.1.png',
#  'Condensation_Dew_Point_0004_fig_1.2.png',
#  'Condensation_Summary_0005_fig_1.3.png',
#  'Connecting_Cellular_Respiration_and_Photosynthesis_Connecting_Cellular_Respiration_and_Photosynthesis_0004_fig_1.1.png',
#  'Conservation_of_Energy_in_Chemical_Reactions_Conservation_of_Energy_0004_fig_1.1.png',
#  'Conservation_of_Mass_Law_of_Conservation_of_Mass_0004_fig_1.1.png',
#  'Conservation_of_Mass_in_Chemical_Reactions_Lavoisier_and_Conservation_of_Mass_0004_fig_1.1.png',
#  'Conserving_Water_How_You_Can_Conserve_Water_0004_fig_1.1.png',
#  'Consumers_and_Decomposers_Consumers_and_Decomposers_0004_fig_1.1.png',
#  'Consumers_and_Decomposers_Decomposers_and_Stability_0004_fig_1.2.png',
#  'Continental_Drift_Wegeners_Evidence_0004_fig_1.1.png',
#  'Continental_Drift_Wegeners_Evidence_0005_fig_1.2.png',
#  'Control_of_Insects_Biological_Control_0004_fig_1.1.png',
#  'Convection_Examples_of_Convection_0005_fig_1.2.png',
#  'Convection_How_Does_Convection_Occur_0004_fig_1.1.png',
#  'Cooling_Systems_The_Refrigerant_0004_fig_1.1.png',
#  'Coriolis_Effect_Coriolis_Effect_0004_fig_1.1.png',
#  'Correlation_Using_Relative_Ages_Index_Fossils_0004_fig_1.1.png',
#  'Correlation_Using_Relative_Ages_Key_Beds_0005_fig_1.2.png',
#  'Covalent_Bonding_Covalent_Compounds_and_Diatomic_Elements_0004_fig_1.1.png',
#  'Covalent_Bonding_Covalent_Compounds_and_Diatomic_Elements_0004_fig_1.2.png',
#  'Crustaceans_Can_Crustaceans_Move_0005_fig_1.2.png',
#  'Crustaceans_Classes_of_Crustaceans_0005_fig_1.1.png',
#  'Crystalline_Carbon_Diamond_0004_fig_1.1.png',
#  'Crystalline_Carbon_Diamond_0005_fig_1.2.png',
#  'Crystalline_Carbon_Fullerene_0006_fig_1.4.png',
#  'Crystalline_Carbon_Graphite_0005_fig_1.3.png',
#  'Cyclic_Behavior_of_Animals_Daily_Cycles_0005_fig_1.2.png',
#  'Cyclic_Behavior_of_Animals_Yearly_Cycles_0004_fig_1.1.png']

# %%
missing_image_list[4]
# Out:
# 'Atmosphere_Layers_0004_fig_1.2.png'

# %%
len(missing_image_list)
# Out:
# 1783

# %%
old_original_image_names = !ls /Users/schwenk/wrk/stb/flexbook_image_extraction/pdf_pages/single_page_pdfs/figures_first_run
new_original_image_names = !ls /Users/schwenk/wrk/stb/flexbook_image_extraction/pdf_pages/single_page_pdfs/figures

# %%
new_original_image_names
# Out:
# ['1_Carbohydrate_Classification_Cellulose_0005_fig_1.2.png',
#  '1_Carbohydrate_Classification_Cellulose_0005_fig_1.3.png',
#  '1_Carbohydrate_Classification_Sugars_0004_fig_1.1.png',
#  '1_Excretory_System_Problems_Kidney_Stones_0004_fig_1.1.png',
#  '1_Excretory_System_Problems_Kidney_failure_0004_fig_1.2.png',
#  '1_Igneous_Rock_Classification_Igneous_Rock_Classification_0004_fig_1.1.png',
#  '1_Importance_of_Echinoderms_Ecological_Role_0004_fig_1.1.png',
#  '1_Seasonal_Changes_in_Plants_Seasonal_Changes_0004_fig_1.1.png',
#  '1_ShortTerm_Climate_Change_El_Nio_0004_fig_1.1.png',
#  '1_ShortTerm_Climate_Change_El_Nio_0004_fig_1.2.png',
#  '1_ShortTerm_Climate_Change_La_Nia_0005_fig_1.3.png',
#  '1_Surface_Features_of_the_Sun_Solar_Flares_0004_fig_1.1.png',
#  '1_Surface_Features_of_the_Sun_Solar_Flares_0004_fig_1.2.png',
#  '1_Surface_Features_of_the_Sun_Solar_Prominences_0005_fig_1.3.png',
#  '1_Transform_Plate_Boundaries_Transform_Faults_On_Land_0004_fig_1.1.png',
#  '21st_Century_Tsunami_Boxing_Day_Tsunami_2004_0004_fig_1.1.png',
#  '21st_Century_Tsunami_Japan_Tsunami_2011_0004_fig_1.2.png',
#  '21st_Century_Tsunami_Japan_Tsunami_2011_0005_fig_1.3.png',
#  '21st_Century_Tsunami_Tsunami_Warning_Systems_0005_fig_1.4.png',
#  'Acceleration_Due_to_Gravity_Mass_and_Acceleration_Due_to_Gravity_0004_fig_1.1.png',
#  'Acceleration_Examples_of_Acceleration_0004_fig_1.1.png',
#  'Accuracy_and_Precision_Resources_0005_fig_1.1.png',
#  'AcidBase_Neutralization_Reactions_of_Acids_and_Bases_0004_fig_1.1.png',
#  'Acid_Rain_Effects_of_Acid_Rain_0006_fig_1.4.png',
#  'Acid_Rain_pH_and_Acid_Rain_0004_fig_1.1.png',
#  'Acid_Rain_pH_and_Acid_Rain_0004_fig_1.2.png',
#  'Acid_Rain_pH_and_Acid_Rain_0005_fig_1.3.png',
#  'Activation_Energy_Activating_Endothermic_and_Exothermic_Reactions_0004_fig_1.1.png',
#  'Active_Transport_Active_Transport_0004_fig_1.1.png',
#  'Adaptation_and_Evolution_of_Populations_Natural_Selection_0004_fig_1.1.png',
#  'Adulthood_and_Aging_Late_Adulthood_0004_fig_1.1.png',
#  'Agriculture_and_Human_Population_Growth_Farming_0004_fig_1.2.png',
#  'Agriculture_and_Human_Population_Growth_Farming_0005_fig_1.3.png',
#  'Agriculture_and_Human_Population_Growth_Hunters_and_Gatherers_0004_fig_1.1.png',
#  'Agriculture_and_Human_Population_Growth_Summary_0007_fig_1.6.png',
#  'Agriculture_and_Human_Population_Growth_The_Green_Revolution_0006_fig_1.5.png',
#  'Agriculture_and_Human_Population_Growth_The_Industrial_Revolution_0005_fig_1.4.png',
#  'Air_Masses_Air_Mass_Formation_0004_fig_1.1.png',
#  'Air_Pressure_and_Altitude_Explaining_Changes_in_Air_Pressure_with_Altitude_0004_fig_1.1.png',
#  'Air_Pressure_and_Altitude_How_We_Use_Air_Pressure_0004_fig_1.2.png',
#  'Air_Pressure_and_Altitude_How_We_Use_Air_Pressure_0005_fig_1.3.png',
#  'Air_Quality_Photochemical_Smog_0004_fig_1.2.png',
#  'Air_Quality_Smog_0004_fig_1.1.png',
#  'Alkaline_Earth_Metals_Summary_0005_fig_1.1.png',
#  'Alkaline_Earth_Metals_Summary_0006_fig_1.2.png',
#  'Alligators_and_Crocodiles_Characteristics_of_Crocodiles_0004_fig_1.1.png',
#  'Alloys_Examples_of_Alloys_0004_fig_1.1.png',
#  'Alpha_Decay_Equations_for_Alpha_Decay_0004_fig_1.1.png',
#  'Amontons_Law_References_0006_fig_1.1.png',
#  'Amontonss_Law_Explore_More_0005_fig_1.1.png',
#  'Amphibians_How_did_Amphibians_Adapt_to_Living_on_Land_0004_fig_1.1.png',
#  'Angiosperms_The_Parts_of_a_Flower_0004_fig_1.1.png',
#  'Angiosperms_The_Parts_of_a_Flower_0004_fig_1.2.png',
#  'Angiosperms_The_Parts_of_a_Flower_0006_fig_1.3.png',
#  'Animal_Behaviors_Examples_of_Animal_Behavior_0004_fig_1.1.png',
#  'Animal_Communication_Communication_with_Sight_0004_fig_1.1.png',
#  'Animal_Communication_Communication_with_Sight_0004_fig_1.2.png',
#  'Animal_Communication_Human_Communication_0005_fig_1.3.png',
#  'Animallike_Protists_Different_Kinds_of_Animallike_Protists_0004_fig_1.1.png',
#  'Aquatic_Biomes_Freshwater_Biomes_0005_fig_1.2.png',
#  'Aquatic_Biomes_Marine_Biomes_0004_fig_1.1.png',
#  'Arachnids_Characteristics_of_Arachnids_0004_fig_1.1.png',
#  'Archaea_What_are_Archaea_0004_fig_1.1.png',
#  'Archimedes_Law_Floating_Objects_and_Archimedes_Law_0004_fig_1.1.png',
#  'Arthropods_Characteristics_of_Arthropods_0005_fig_1.2.png',
#  'Arthropods_Types_of_Arthropods_0004_fig_1.1.png',
#  'Artificial_Light_Fluorescent_Light_0004_fig_1.1.png',
#  'Artificial_Light_Fluorescent_Light_0004_fig_1.2.png',
#  'Artificial_Light_Neon_Light_0005_fig_1.3.png',
#  'Artificial_Light_Summary_0006_fig_1.5.png',
#  'Artificial_Light_Vapor_Light_0005_fig_1.4.png',
#  'Asexual_vs._Sexual_Reproduction_Sexual_Reproduction_0005_fig_1.1.png',
#  'Asexual_vs._Sexual_Reproduction_Sexual_Reproduction_0005_fig_1.2.png',
#  'Asexual_vs._Sexual_Reproduction_Sexual_Reproduction_0006_fig_1.3.png',
#  'Asexual_vs._Sexual_Reproduction_Sexual_Reproduction_0006_fig_1.4.png',
#  'Asteroids_Asteroid_Missions_0006_fig_1.4.png',
#  'Asteroids_NearEarth_Asteroids_0005_fig_1.3.png',
#  'Asteroids_The_Asteroid_Belt_0004_fig_1.1.png',
#  'Asteroids_The_Asteroid_Belt_0004_fig_1.2.png',
#  'Atomic_Forces_Electromagnetic_Force_0004_fig_1.1.png',
#  'Atomic_Forces_Strong_Nuclear_Force_0005_fig_1.2.png',
#  'Atomic_Forces_Weak_Nuclear_Force_0005_fig_1.3.png',
#  'Atomic_Nucleus_Size_and_Mass_of_the_Nucleus_0004_fig_1.1.png',
#  'Atomic_Number_Atomic_Number_0005_fig_1.2.png',
#  'Atomic_Number_Telling_Atoms_Apart_0004_fig_1.1.png',
#  'Atoms_Neutrons_0005_fig_1.2.png',
#  'Atoms_Parts_of_the_Atom_0004_fig_1.1.png',
#  'Atoms_Review_0006_fig_1.3.png',
#  'Atoms_Size_of_Atoms_0004_fig_1.1.png',
#  'Atoms_Subatomic_Particles_0005_fig_1.2.png',
#  'Atoms_to_Molecules_Parts_of_an_Atom_0004_fig_1.1.png',
#  'Autoimmune_Diseases_Allergies_0004_fig_1.1.png',
#  'Autoimmune_Diseases_Summary_0005_fig_1.2.png',
#  'Availability_of_Natural_Resources_Price_0004_fig_1.1.png',
#  'Availability_of_Natural_Resources_Waste_0005_fig_1.2.png',
#  'Availability_of_Natural_Resources_Waste_0005_fig_1.3.png',
#  'Avoiding_Soil_Loss_Preventing_Soil_Erosion_0005_fig_1.2.png',
#  'Avoiding_Soil_Loss_Preventing_Soil_Erosion_0005_fig_1.3.png',
#  'Avoiding_Soil_Loss_Soil_Erosion_0004_fig_1.1.png',
#  'B_and_T_Cell_Response_B_Cell_Response_0004_fig_1.1.png',
#  'B_and_T_Cell_Response_T_Cell_Response_0005_fig_1.2.png',
#  'Bacteria_Characteristics_Flagella_0005_fig_1.3.png',
#  'Bacteria_Characteristics_Similarities_to_Eukaryotes_0004_fig_1.2.png',
#  'Bacteria_Characteristics_Size_and_Shape_0004_fig_1.1.png',
#  'Bacteria_Nutrition_Mutualism_0004_fig_1.1.png',
#  'Bacteria_Reproduction_Exchanging_DNA_0004_fig_1.1.png',
#  'Bacteria_in_the_Digestive_System_Bacteria_in_the_Digestive_System_0004_fig_1.1.png',
#  'Barriers_to_Pathogens_Chemicals_0005_fig_1.2.png',
#  'Barriers_to_Pathogens_Skin_and_Mucous_Membranes_0004_fig_1.1.png',
#  'Basic_and_Applied_Science_Basic_and_Applied_Science_0004_fig_1.1.png',
#  'Basic_and_Applied_Science_Basic_and_Applied_Science_0004_fig_1.2.png',
#  'Bathymetric_Evidence_for_Seafloor_Spreading_Features_of_the_Seafloor_0005_fig_1.2.png',
#  'Bathymetric_Evidence_for_Seafloor_Spreading_Life_at_Sea_0004_fig_1.1.png',
#  'Bathymetric_Evidence_for_Seafloor_Spreading_Summary_0006_fig_1.3.png',
#  'Bernoullis_Law_Using_Air_Pressure_to_Fly_0004_fig_1.1.png',
#  'Beta_Decay_What_Is_Beta_Decay_0004_fig_1.1.png',
#  'Big_Bang_Background_Radiation_0005_fig_1.2.png',
#  'Big_Bang_Review_0006_fig_1.3.png',
#  'Big_Bang_The_Big_Bang_Theory_0004_fig_1.1.png',
#  'Biochemical_Compound_Classification_Introduction_to_Biochemical_Compounds_0004_fig_1.1.png',
#  'Biochemical_Reaction_Chemistry_Photosynthesis_and_Cellular_Respiration_0004_fig_1.1.png',
#  'Biological_Communities_Ecosystems_0004_fig_1.1.png',
#  'Biological_Communities_Habitat_0005_fig_1.3.png',
#  'Biological_Communities_Niches_0005_fig_1.2.png',
#  'Biotechnology_in_Agriculture_Biotechnology_in_Agriculture_0004_fig_1.1.png',
#  'Bird_Reproduction_Parental_Care_0005_fig_1.2.png',
#  'Bird_Reproduction_Protecting_Offspring_0004_fig_1.1.png',
#  'Birds_Adaptations_for_Flight_0005_fig_1.2.png',
#  'Birds_Adaptations_for_Flight_0005_fig_1.3.png',
#  'Birds_Adaptations_for_Flight_0006_fig_1.4.png',
#  'Birds_Characteristics_of_Birds_0004_fig_1.1.png',
#  'Blizzards_Formation_0004_fig_1.1.png',
#  'Blizzards_Formation_0004_fig_1.2.png',
#  'Blizzards_LakeEffect_Snow_0005_fig_1.3.png',
#  'Blood_Diseases_SickleCell_Anemia_0004_fig_1.1.png',
#  'Blood_Pressure_Healthy_Blood_Pressure_Ranges_0004_fig_1.1.png',
#  'Blood_Types_Blood_Types_0004_fig_1.1.png',
#  'Blood_Vessels_Blood_Vessels_and_Blood_Circulation_0004_fig_1.1.png',
#  'Bohrs_Atomic_Model_Energy_by_the_Spoonful_0005_fig_1.2.png',
#  'Bohrs_Atomic_Model_Modeling_the_Atom_0004_fig_1.1.png',
#  'Bond_Polarity_Polar_and_Nonpolar_Covalent_Bonds_0004_fig_1.1.png',
#  'Bond_Polarity_Polar_and_Nonpolar_Covalent_Bonds_0004_fig_1.2.png',
#  'Bond_Polarity_Polar_and_Nonpolar_Covalent_Compounds_0005_fig_1.3.png',
#  'Bony_Fish_Bony_Fish_0003_fig_1.1.png',
#  'Bony_Fish_How_Big_Are_Bony_Fish_0004_fig_1.2.png',
#  'Boyles_Law_Its_Crowded_in_Here_0004_fig_1.1.png',
#  'Boyles_Law_Review_0006_fig_1.3.png',
#  'Boyles_Law_You_Go_Up_and_Ill_Go_Down_0005_fig_1.2.png',
#  'Branches_of_Earth_Science_Astronomy_0005_fig_1.3.png',
#  'Branches_of_Earth_Science_Climatology_and_Meteorology_0004_fig_1.2.png',
#  'Branches_of_Earth_Science_Geology_0004_fig_1.1.png',
#  'Buoyancy_Density_and_Buoyant_Force_0005_fig_1.3.png',
#  'Buoyancy_Weight_and_Buoyant_Force_0004_fig_1.1.png',
#  'Buoyancy_Weight_and_Buoyant_Force_0004_fig_1.2.png',
#  'Calculating_Acceleration_from_Force_and_Mass_Calculating_Force_0004_fig_1.1.png',
#  'Calculating_Acceleration_from_Force_and_Mass_Review_0005_fig_1.2.png',
#  'Calculating_Acceleration_from_Velocity_and_Time_Accelerating_on_a_Bike_0004_fig_1.1.png',
#  'Calculating_Work_Calculating_Force_or_Distance_When_Work_Is_Known_0004_fig_1.1.png',
#  'Cancer_Chemicals_0004_fig_1.1.png',
#  'Cancer_Chemicals_0004_fig_1.2.png',
#  'Cancer_Common_Types_of_Cancer_0005_fig_1.3.png',
#  'Carbon_Bonding_CarbonCarbon_Bonds_0005_fig_1.3.png',
#  'Carbon_Bonding_How_Carbon_Forms_Bonds_0004_fig_1.2.png',
#  'Carbon_Bonding_Valence_Electrons_in_Carbon_0004_fig_1.1.png',
#  'Carbon_Cycle_and_Climate_Atmospheric_Carbon_Dioxide_0005_fig_1.2.png',
#  'Carbon_Cycle_and_Climate_Human_Actions_Impact_the_Carbon_Cycle_0006_fig_1.3.png',
#  'Carbon_Cycle_and_Climate_Respiration_0004_fig_1.1.png',
#  'Carbon_Monomers_and_Polymers_Natural_Carbon_Polymers_0004_fig_1.1.png',
#  'Carbon_Monomers_and_Polymers_Natural_Carbon_Polymers_0004_fig_1.2.png',
#  'Carbon_Monomers_and_Polymers_Synthetic_Carbon_Polymers_0005_fig_1.3.png',
#  'Carbon_Monomers_and_Polymers_Synthetic_Carbon_Polymers_0005_fig_1.4.png',
#  'Cardiovascular_Diseases_Cardiovascular_Diseases_0004_fig_1.1.png',
#  'Cardiovascular_Diseases_Summary_0005_fig_1.2.png',
#  'Cardiovascular_System_Functions_of_the_Cardiovascular_System_0004_fig_1.1.png',
#  'Cardiovascular_System_Health_Keeping_Your_Cardiovascular_System_Healthy_0004_fig_1.1.png',
#  'Cardiovascular_System_Health_What_is_bad_cholesterol_0005_fig_1.2.png',
#  'Cartilaginous_Fish_Explore_More_I_0005_fig_1.1.png',
#  'Catalysts_Catalysts_in_Living_Things_0004_fig_1.2.png',
#  'Catalysts_How_Catalysts_Work_0004_fig_1.1.png',
#  'Causes_Of_Air_Pollution_Evaporation_0005_fig_1.2.png',
#  'Causes_Of_Air_Pollution_Evaporation_0005_fig_1.3.png',
#  'Causes_Of_Air_Pollution_Fossil_Fuels_0004_fig_1.1.png',
#  'Cell_Biology_Levels_of_Organization_0005_fig_1.4.png',
#  'Cell_Biology_Observing_Cells_0004_fig_1.1.png',
#  'Cell_Biology_Observing_Cells_0004_fig_1.2.png',
#  'Cell_Biology_Specialized_Cells_0005_fig_1.3.png',
#  'Cell_Cycle_Cell_Cycle_0004_fig_1.1.png',
#  'Cell_Division_Why_Cells_Divide_0004_fig_1.1.png',
#  'Cell_Membrane_The_Plasma_Membrane_0004_fig_1.1.png',
#  'Cell_Nucleus_Nucleolus_0004_fig_1.1.png',
#  'Cell_Transport_Composition_of_the_Cell_Membrane_0004_fig_1.1.png',
#  'Cellular_Respiration_ATP_0004_fig_1.1.png',
#  'Cellular_Respiration_Reactions_What_is_Cellular_Respiration_0004_fig_1.1.png',
#  'Cenozoic_Plate_Tectonics_Evolution_of_the_San_Andreas_Fault_0004_fig_1.1.png',
#  'Cenozoic_Plate_Tectonics_Ice_Ages_0005_fig_1.2.png',
#  'Centipedes_and_Millipedes_Centipedes_0004_fig_1.1.png',
#  'Central_Nervous_System_The_Brain_0004_fig_1.1.png',
#  'Central_Nervous_System_The_Brain_0005_fig_1.2.png',
#  'Changes_of_State_The_Role_of_Energy_in_Changes_of_State_0004_fig_1.1.png',
#  'Changes_of_State_The_Role_of_Energy_in_Changes_of_State_0004_fig_1.2.png',
#  'Characteristics_and_Origins_of_Life_MillerUrey_Experiment_0005_fig_1.1.png',
#  'Characteristics_and_Origins_of_Life_MillerUrey_Experiment_0005_fig_1.2.png',
#  'Characteristics_of_Life_Living_Things_Are_Made_of_Cells_0005_fig_1.2.png',
#  'Characteristics_of_Life_Living_Things_Are_Made_of_Cells_0005_fig_1.3.png',
#  'Characteristics_of_Life_Living_Things_Grow_and_Reproduce_0006_fig_1.4.png',
#  'Characteristics_of_Life_Living_Things_Maintain_Stable_Internal_Conditions_0006_fig_1.5.png',
#  'Characteristics_of_Life_Living_Things_Need_Resources_and_Energy_0004_fig_1.1.png',
#  'Charles_Law_References_0005_fig_1.1.png',
#  'Charless_Law_Review_0004_fig_1.1.png',
#  'Chemical_Bond_Summary_0005_fig_1.2.png',
#  'Chemical_Bond_Why_Bonds_Form_0004_fig_1.1.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.1.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.2.png',
#  'Chemical_Bonding_Chemical_Bonding_0005_fig_1.3.png',
#  'Chemical_Bonding_Chemical_Bonding_0005_fig_1.4.png',
#  'Chemical_Change_Identifying_Chemical_Changes_0004_fig_1.1.png',
#  'Chemical_Equations_Using_Chemical_Symbols_and_Formulas_0004_fig_1.1.png',
#  'Chemical_Properties_of_Matter_Flammability_0004_fig_1.1.png',
#  'Chemical_Reaction_Overview_Same_Atoms_New_Bonds_0004_fig_1.2.png',
#  'Chemical_Reaction_Overview_What_Is_a_Chemical_Reaction_0004_fig_1.1.png',
#  'Chemical_Reaction_Rate_Concentration_of_Reactants_0004_fig_1.2.png',
#  'Chemical_Reaction_Rate_Surface_Area_of_Reactants_0005_fig_1.3.png',
#  'Chemical_Reaction_Rate_Temperature_of_Reactants_0004_fig_1.1.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Carbonic_Acid_0005_fig_1.3.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Oxygen_0005_fig_1.4.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Water_0004_fig_1.2.png',
#  'Chemical_Weathering_Clay_0004_fig_1.1.png',
#  'Chemical_Weathering_Mechanical_and_Chemical_Weathering_0006_fig_1.5.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.1.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.2.png',
#  'Chemistry_of_Compounds_Same_Elements_Different_Compounds_0004_fig_1.2.png',
#  'Chemistry_of_Compounds_Same_Elements_Different_Compounds_0005_fig_1.3.png',
#  'Chemistry_of_Compounds_What_Are_Compounds_0004_fig_1.1.png',
#  'Chemistry_of_Life_Chemical_Reactions_0005_fig_1.2.png',
#  'Chemistry_of_Life_The_Elements_0004_fig_1.1.png',
#  'Choosing_Healthy_Foods_Explore_More_0008_fig_1.4.png',
#  'Choosing_Healthy_Foods_MyPlate_0005_fig_1.2.png',
#  'Choosing_Healthy_Foods_MyPyramid_0004_fig_1.1.png',
#  'Choosing_Healthy_Foods_Using_Nutrition_Facts_Labels_0006_fig_1.3.png',
#  'Chordates_Characteristics_of_the_Chordates_0004_fig_1.1.png',
#  'Chordates_Classification_of_the_Chordates_0004_fig_1.2.png',
#  'Chromosomal_Disorders_Extra_Chromosomes_0004_fig_1.1.png',
#  'Chromosomal_Disorders_Extra_Chromosomes_0004_fig_1.2.png',
#  'Circulation_and_the_Lymphatic_System_Role_of_the_Lymphatic_System_in_Circulation_0005_fig_1.2.png',
#  'Circulation_and_the_Lymphatic_System_The_Lymphatic_System_and_Circulation_0004_fig_1.1.png',
#  'Circulation_in_the_Atmosphere_Air_Pressure_Zones_0004_fig_1.1.png',
#  'Circulation_in_the_Atmosphere_Plus_Coriolis_Effect_0005_fig_1.2.png',
#  'Cleaning_Up_Groundwater_Monitoring_the_Extent_of_the_Pollutant_0004_fig_1.1.png',
#  'Climate_Change_in_Earth_History_Climate_Change_in_Earth_History_0004_fig_1.1.png',
#  'Climate_Change_in_Earth_History_Climate_Change_in_Earth_History_0005_fig_1.2.png',
#  'Climate_Zones_and_Biomes_Major_Climate_Groups_0004_fig_1.1.png',
#  'Cloning_Cloning_0004_fig_1.1.png',
#  'Clouds_Fog_0006_fig_1.3.png',
#  'Clouds_Humidity_0004_fig_1.1.png',
#  'Clouds_Types_of_Clouds_0005_fig_1.2.png',
#  'Cnidarians_Cnidarian_Colonies_0004_fig_1.1.png',
#  'Coal_Power_Coal_0004_fig_1.1.png',
#  'Coal_Power_Consequences_of_Coal_Use_0005_fig_1.2.png',
#  'Coal_Power_Explore_More_0007_fig_1.4.png',
#  'Coal_Power_Summary_0006_fig_1.3.png',
#  'Coastal_Pollution_Ocean_Pollution_0004_fig_1.1.png',
#  'Coastal_Pollution_Review_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Radar_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Satellites_0006_fig_1.3.png',
#  'Collecting_Weather_Data_Weather_Stations_0004_fig_1.1.png',
#  'Color_Colors_of_Objects_0004_fig_1.3.png',
#  'Color_Colors_of_Objects_0005_fig_1.4.png',
#  'Color_Review_0006_fig_1.6.png',
#  'Color_Separating_Colors_of_Light_0004_fig_1.1.png',
#  'Color_Separating_Colors_of_Light_0004_fig_1.2.png',
#  'Color_The_Colors_We_See_0005_fig_1.5.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0004_fig_1.1.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0004_fig_1.2.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0005_fig_1.3.png',
#  'Combining_Forces_Forces_Acting_in_the_Same_Direction_0005_fig_1.4.png',
#  'Combining_Forces_Review_0006_fig_1.5.png',
#  'Combustion_Reactions_Combustion_of_Hydrocarbons_0004_fig_1.2.png',
#  'Combustion_Reactions_What_Is_A_Combustion_Reaction_0004_fig_1.1.png',
#  'Comets_Comets_0004_fig_1.1.png',
#  'Communication_in_Science_How_Scientists_Communicate_0004_fig_1.1.png',
#  'Competition_Competition_0004_fig_1.1.png',
#  'Components_of_Blood_Components_of_Blood_0004_fig_1.1.png',
#  'Components_of_Blood_Red_Blood_Cells_0004_fig_1.2.png',
#  'Components_of_Blood_Summary_0006_fig_1.4.png',
#  'Components_of_Blood_White_Blood_Cells_0005_fig_1.3.png',
#  'Composition_of_the_Atmosphere_Nitrogen_and_Oxygen_0004_fig_1.1.png',
#  'Composition_of_the_Atmosphere_Particulates_0005_fig_1.2.png',
#  'Compound_Machine_Corkscrew_0004_fig_1.1.png',
#  'Compound_Machine_Corkscrew_0004_fig_1.2.png',
#  'Compound_Machine_Review_0005_fig_1.3.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.2.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.3.png',
#  'Compounds_What_Is_a_Compound_0004_fig_1.1.png',
#  'Condensation_Dew_Point_0004_fig_1.1.png',
#  'Condensation_Dew_Point_0004_fig_1.2.png',
#  'Condensation_Summary_0005_fig_1.3.png',
#  'Connecting_Cellular_Respiration_and_Photosynthesis_Connecting_Cellular_Respiration_and_Photosynthesis_0004_fig_1.1.png',
#  'Conservation_of_Energy_in_Chemical_Reactions_Conservation_of_Energy_0004_fig_1.1.png',
#  'Conservation_of_Mass_Law_of_Conservation_of_Mass_0004_fig_1.1.png',
#  'Conservation_of_Mass_in_Chemical_Reactions_Lavoisier_and_Conservation_of_Mass_0004_fig_1.1.png',
#  'Conserving_Water_How_You_Can_Conserve_Water_0004_fig_1.1.png',
#  'Consumers_and_Decomposers_Consumers_and_Decomposers_0004_fig_1.1.png',
#  'Consumers_and_Decomposers_Decomposers_and_Stability_0004_fig_1.2.png',
#  'ContinentContinent_Convergent_Plate_Boundaries_ContinentContinent_Convergence_0004_fig_1.1.png',
#  'Continental_Drift_Wegeners_Evidence_0004_fig_1.1.png',
#  'Continental_Drift_Wegeners_Evidence_0005_fig_1.2.png',
#  'Control_of_Insects_Biological_Control_0004_fig_1.1.png',
#  'Convection_Examples_of_Convection_0005_fig_1.2.png',
#  'Convection_How_Does_Convection_Occur_0004_fig_1.1.png',
#  'Convection_References_0006_fig_1.3.png',
#  'Cooling_Systems_The_Refrigerant_0004_fig_1.1.png',
#  'Coriolis_Effect_Coriolis_Effect_0004_fig_1.1.png',
#  'Correlation_Using_Relative_Ages_Index_Fossils_0004_fig_1.1.png',
#  'Correlation_Using_Relative_Ages_Key_Beds_0005_fig_1.2.png',
#  'Correlation_and_Causation_Causation_0004_fig_1.1.png',
#  'Covalent_Bonding_Covalent_Compounds_and_Diatomic_Elements_0004_fig_1.1.png',
#  'Covalent_Bonding_Covalent_Compounds_and_Diatomic_Elements_0004_fig_1.2.png',
#  'Crustaceans_Can_Crustaceans_Move_0005_fig_1.2.png',
#  'Crustaceans_Classes_of_Crustaceans_0005_fig_1.1.png',
#  'Crystalline_Carbon_Diamond_0004_fig_1.1.png',
#  'Crystalline_Carbon_Diamond_0005_fig_1.2.png',
#  'Crystalline_Carbon_Fullerene_0006_fig_1.4.png',
#  'Crystalline_Carbon_Graphite_0005_fig_1.3.png',
#  'Cyclic_Behavior_of_Animals_Daily_Cycles_0005_fig_1.2.png',
#  'Cyclic_Behavior_of_Animals_Yearly_Cycles_0004_fig_1.1.png',
#  'DNA_Structure_and_Replication_DNA_Replication_0004_fig_1.1.png',
#  'DNA_the_Genetic_Material_BasePairing_0005_fig_1.2.png',
#  'DNA_the_Genetic_Material_The_Genetic_Code_0004_fig_1.1.png',
#  'Daltons_Atomic_Theory_Daltons_Experiments_0004_fig_1.1.png',
#  'Daltons_Atomic_Theory_The_Billiard_Ball_Model_0005_fig_1.2.png',
#  'Dangers_and_Uses_of_Radiation_Detecting_Radiation_0004_fig_1.1.png',
#  'Dangers_and_Uses_of_Radiation_Summary_0005_fig_1.2.png',
#  'Dark_Matter_Dark_Energy_0005_fig_1.2.png',
#  'Dark_Matter_Dark_Matter_0004_fig_1.1.png',
#  'Decomposition_Reactions_Other_Examples_of_Decomposition_Reactions_0004_fig_1.1.png',
#  'Deep_Ocean_Currents_Downwelling_0004_fig_1.1.png',
#  'Deep_Ocean_Currents_Upwelling_0005_fig_1.2.png',
#  'Democritus_Idea_of_the_Atom_Cutting_the_Cheese_0004_fig_1.1.png',
#  'Democritus_Idea_of_the_Atom_Keep_on_Moving_0005_fig_1.2.png',
#  'Democrituss_Idea_of_the_Atom_Just_a_Guess_0004_fig_1.1.png',
#  'Democrituss_Idea_of_the_Atom_Why_Matter_Varies_0005_fig_1.2.png',
#  'Density_Defining_Density_0004_fig_1.1.png',
#  'Deposition_Examples_of_Deposition_in_Nature_0004_fig_1.1.png',
#  'Deposition_Examples_of_Deposition_in_Nature_0004_fig_1.2.png',
#  'Deposition_Review_0005_fig_1.3.png',
#  'Determining_Relative_Ages_Determining_the_Relative_Ages_of_Rocks_0004_fig_1.1.png',
#  'Development_of_Theories_Explore_More_0005_fig_1.1.png',
#  'Diabetes_Type_1_Diabetes_0004_fig_1.1.png',
#  'Diffusion_Applications_of_Osmosis_0005_fig_1.2.png',
#  'Diffusion_Diffusion_0004_fig_1.1.png',
#  'Digestive_System_Organs_Mouth_Esophagus_and_Stomach_0005_fig_1.2.png',
#  'Digestive_System_Organs_Organs_of_the_Digestive_System_0004_fig_1.1.png',
#  'Digestive_System_Organs_Small_Intestine_0006_fig_1.3.png',
#  'Direction_Why_Direction_Is_Important_0004_fig_1.1.png',
#  'Discovery_of_Electromagnetism_Electricity_and_Magnetism_0004_fig_1.1.png',
#  'Discovery_of_Electromagnetism_Summary_0005_fig_1.2.png',
#  'Diseases_of_the_Nervous_System_Encephalitis_0004_fig_1.1.png',
#  'Diseases_of_the_Nervous_System_Meningitis_0005_fig_1.2.png',
#  'Diseases_of_the_Nervous_System_Other_Nervous_System_Diseases_0006_fig_1.4.png',
#  'Diseases_of_the_Nervous_System_Reyes_Syndrome_0005_fig_1.3.png',
#  'Distance_Between_Stars_Parallax_0004_fig_1.1.png',
#  'Distance_Using_Maps_to_Measure_Distance_0004_fig_1.1.png',
#  'Distribution_of_Water_on_Earth_Distribution_of_Water_0004_fig_1.1.png',
#  'Divergent_Plate_Boundaries_Plate_Divergence_on_Land_0004_fig_1.1.png',
#  'Divergent_Plate_Boundaries_References_0006_fig_1.3.png',
#  'Divergent_Plate_Boundaries_References_0007_fig_1.4.png',
#  'Divergent_Plate_Boundaries_Summary_0005_fig_1.2.png',
#  'Divergent_Plate_Boundaries_in_the_Oceans_Plate_Divergence_in_the_Ocean_0004_fig_1.1.png',
#  'Diversity_of_Birds_Beaks_0004_fig_1.1.png',
#  'Diversity_of_Birds_Feet_0005_fig_1.2.png',
#  'Domains_of_Life_Archaea_and_Bacteria_0004_fig_1.1.png',
#  'Domains_of_Life_Eukarya_0005_fig_1.2.png',
#  'Doppler_Effect_Experiencing_the_Doppler_Effect_0004_fig_1.1.png',
#  'Dwarf_Planets_Ceres_0005_fig_1.2.png',
#  'Dwarf_Planets_Makemake_0006_fig_1.3.png',
#  'Dwarf_Planets_Pluto_0004_fig_1.1.png',
#  'Early_Atmosphere_and_Oceans_Earths_First_Atmosphere_0004_fig_1.1.png',
#  'Early_Atmosphere_and_Oceans_UV_Protection_0006_fig_1.2.png',
#  'Earth_Science_Field_Work_California_0004_fig_1.1.png',
#  'Earth_Science_Field_Work_Glacier_National_Park_0007_fig_1.5.png',
#  'Earth_Science_Field_Work_Glacier_National_Park_0007_fig_1.6.png',
#  'Earth_Science_Field_Work_Grand_Canyon_0009_fig_1.10.png',
#  'Earth_Science_Field_Work_Hawaiian_Islands_0010_fig_1.11.png',
#  'Earth_Science_Field_Work_Idaho_Montana_Wyoming_0006_fig_1.4.png',
#  'Earth_Science_Field_Work_Pacific_Northwest_0005_fig_1.2.png',
#  'Earth_Science_Field_Work_Pacific_Northwest_0006_fig_1.3.png',
#  'Earth_Science_Field_Work_Southwest_0009_fig_1.9.png',
#  'Earth_Science_Field_Work_Yellowstone_National_Park_0008_fig_1.7.png',
#  'Earth_Science_Field_Work_Yellowstone_National_Park_0008_fig_1.8.png',
#  'Earth_as_a_Magnet_Earths_Magnetic_Field_0005_fig_1.3.png',
#  'Earth_as_a_Magnet_Two_North_Poles_0004_fig_1.1.png',
#  'Earth_as_a_Magnet_Two_North_Poles_0004_fig_1.2.png',
#  'Earthquake_Characteristics_Elastic_Rebound_Theory_0004_fig_1.1.png',
#  'Earthquake_Characteristics_Focus_and_Epicenter_0004_fig_1.2.png',
#  'Earthquake_Damage_City_Planning_0005_fig_1.3.png',
#  'Earthquake_Damage_What_Makes_an_Earthquake_Deadly_0004_fig_1.1.png',
#  'Earthquake_Damage_What_Makes_an_Earthquake_Deadly_0004_fig_1.2.png',
#  'Earthquake_Safe_Structures_Cost_Considerations_0005_fig_1.3.png',
#  'Earthquake_Safe_Structures_New_Construction_0004_fig_1.1.png',
#  'Earthquake_Safe_Structures_Retrofitting_0004_fig_1.2.png',
#  'Earthquake_Zones_Annual_Earthquakes_0004_fig_1.1.png',
#  'Earthquake_Zones_Earthquake_Zones_0004_fig_1.2.png',
#  'Earthquakes_at_Convergent_Plate_Boundaries_ContinentContinent_Asia_0005_fig_1.3.png',
#  'Earthquakes_at_Convergent_Plate_Boundaries_OceanOcean_Japan_0004_fig_1.1.png',
#  'Earthquakes_at_Convergent_Plate_Boundaries_OceanOcean_Japan_0004_fig_1.2.png',
#  'Earthquakes_at_Transform_Plate_Boundaries_California_0004_fig_1.1.png',
#  'Earths_Core_Core_0004_fig_1.1.png',
#  'Earths_Crust_Continental_Crust_0005_fig_1.2.png',
#  'Earths_Crust_Oceanic_Crust_0004_fig_1.1.png',
#  'Earths_Crust_Review_0006_fig_1.3.png',
#  'Earths_Interior_Material_Other_Clues_About_Earths_Interior_0004_fig_1.1.png',
#  'Earths_Layers_Layers_by_Mechanical_Properties_0004_fig_1.1.png',
#  'Earths_Magnetic_Field_Magnetic_Reversals_0004_fig_1.1.png',
#  'Earths_Mantle_Heat_Flow_0004_fig_1.1.png',
#  'Earths_Mantle_Heat_Flow_0004_fig_1.2.png',
#  'Earths_Shape_Summary_0004_fig_1.1.png',
#  'Earths_Tectonic_Plates_How_Plates_Move_0005_fig_1.2.png',
#  'Earths_Tectonic_Plates_Summary_0006_fig_1.3.png',
#  'Earths_Tectonic_Plates_What_is_a_Plate_0004_fig_1.1.png',
#  'Echinoderms_Characteristics_of_Echinoderms_0004_fig_1.1.png',
#  'Echinoderms_Characteristics_of_Echinoderms_0004_fig_1.2.png',
#  'Eclipses_Lunar_Eclipse_0005_fig_1.3.png',
#  'Eclipses_Lunar_Eclipse_0005_fig_1.4.png',
#  'Eclipses_Solar_Eclipses_0004_fig_1.1.png',
#  'Eclipses_Solar_Eclipses_0004_fig_1.2.png',
#  'Eclipses_Summary_0006_fig_1.5.png',
#  'Ecosystems_What_is_an_Ecosystem_0004_fig_1.1.png',
#  'Effect_of_Altitude_and_Mountains_on_Climate_Altitude_and_Mountain_Ranges_0003_fig_1.1.png',
#  'Effect_of_Atmospheric_Circulation_on_Climate_The_ITCZ_0004_fig_1.1.png',
#  'Effect_of_Atmospheric_Circulation_on_Climate_The_ITCZ_0004_fig_1.2.png',
#  'Effect_of_Atmospheric_Circulation_on_Climate_The_ITCZ_0005_fig_1.3.png',
#  'Effect_of_Continental_Position_on_Climate_Continental_Position_0004_fig_1.1.png',
#  'Effect_of_Latitude_on_Climate_Temperature_with_Latitude_0004_fig_1.1.png',
#  'Effects_of_Air_Pollution_on_Human_Health_Human_Illnesses_from_Air_Pollution_0004_fig_1.1.png',
#  'Effects_of_Air_Pollution_on_the_Environment_Oxides_0005_fig_1.2.png',
#  'Effects_of_Air_Pollution_on_the_Environment_Particulates_0004_fig_1.1.png',
#  'Effects_of_Water_Pollution_Aquatic_Debris_0005_fig_1.2.png',
#  'Effects_of_Water_Pollution_Eutrophication_0004_fig_1.1.png',
#  'Efficiency_Machine_Efficiency_0004_fig_1.1.png',
#  'Effusive_Eruptions_Effusive_Eruptions_0004_fig_1.1.png',
#  'Effusive_Eruptions_Effusive_Eruptions_Damage_0005_fig_1.3.png',
#  'Effusive_Eruptions_Types_of_Lava_0004_fig_1.2.png',
#  'Einsteins_Concept_of_Gravity_Visualizing_Einsteins_Ideas_0004_fig_1.1.png',
#  'Elastic_Force_Using_Elastic_Force_0004_fig_1.1.png',
#  'Elastic_Force_Using_Elastic_Force_0005_fig_1.2.png',
#  'Electric_Charge_and_Electric_Force_Electric_Force_0004_fig_1.1.png',
#  'Electric_Charge_and_Electric_Force_Electric_Force_0004_fig_1.2.png',
#  'Electric_Circuits_Circuit_Diagrams_0004_fig_1.2.png',
#  'Electric_Circuits_Parts_of_an_Electric_Circuit_0004_fig_1.1.png',
#  'Electric_Conductors_and_Insulators_The_Path_of_Least_Resistance_0004_fig_1.1.png',
#  'Electric_Current_Voltage_0004_fig_1.1.png',
#  'Electric_Fields_Interacting_Electric_Fields_0004_fig_1.1.png',
#  'Electric_Fields_Interacting_Electric_Fields_0004_fig_1.2.png',
#  'Electric_Generators_From_Kinetic_to_Electrical_Energy_0004_fig_1.1.png',
#  'Electric_Generators_From_Kinetic_to_Electrical_Energy_0004_fig_1.2.png',
#  'Electric_Resistance_References_0005_fig_1.1.png',
#  'Electric_Safety_Electric_Safety_Features_0004_fig_1.2.png',
#  'Electric_Safety_How_a_Short_Circuit_Occurs_0004_fig_1.1.png',
#  'Electric_Transformers_Stepping_Up_or_Stepping_Down_0004_fig_1.2.png',
#  'Electric_Transformers_Stepping_Up_or_Stepping_Down_0005_fig_1.3.png',
#  'Electric_Transformers_What_Is_an_Electric_Transformer_0004_fig_1.1.png',
#  'Electrical_Grid_Electric_Substations_0004_fig_1.2.png',
#  'Electrical_Grid_Transmission_Lines_0004_fig_1.1.png',
#  'Electromagnet_Easy_OnOff_0004_fig_1.1.png',
#  'Electromagnetic_Devices_How_a_Doorbell_Works_0004_fig_1.1.png',
#  'Electromagnetic_Devices_Summary_0005_fig_1.2.png',
#  'Electromagnetic_Energy_in_the_Atmosphere_Energy_0004_fig_1.1.png',
#  'Electromagnetic_Energy_in_the_Atmosphere_Energy_0005_fig_1.2.png',
#  'Electromagnetic_Induction_The_Current_Produced_by_a_Magnet_0004_fig_1.1.png',
#  'Electromagnetic_Induction_The_Current_Produced_by_a_Magnet_0004_fig_1.2.png',
#  'Electromagnetic_Spectrum_A_Spectrum_of_Electromagnetic_Waves_0004_fig_1.1.png',
#  'Electromagnetic_Waves_How_an_Electromagnetic_Wave_Begins_0005_fig_1.2.png',
#  'Electromagnetic_Waves_How_an_Electromagnetic_Wave_Begins_0005_fig_1.3.png',
#  'Electromagnetic_Waves_May_the_Force_Be_With_You_0004_fig_1.1.png',
#  'Electromagnetism_Right_Hand_Rule_0004_fig_1.1.png',
#  'Electron_Cloud_Atomic_Model_A_Fuzzy_Cloud_0005_fig_1.3.png',
#  'Electron_Cloud_Atomic_Model_What_Are_the_Chances_0004_fig_1.1.png',
#  'Electron_Cloud_Atomic_Model_What_Are_the_Chances_0004_fig_1.2.png',
#  'Electronic_Component_Diode_0004_fig_1.2.png',
#  'Electronic_Component_Integrated_Circuit_0005_fig_1.4.png',
#  'Electronic_Component_Semiconductors_0004_fig_1.1.png',
#  'Electronic_Component_Transistor_0005_fig_1.3.png',
#  'Electronic_Device_Focus_on_the_Computer_0004_fig_1.1.png',
#  'Electronic_Signal_Digital_Signals_0004_fig_1.1.png',
#  'Electronic_Signal_Digital_Signals_0004_fig_1.2.png',
#  'Electrons_Orbitals_0005_fig_1.2.png',
#  'Electrons_Whats_Your_Energy_Level_0006_fig_1.3.png',
#  'Electrons_Where_Are_Electrons_0004_fig_1.1.png',
#  'Elements_Elemental_Properties_0004_fig_1.1.png',
#  'Elements_History_of_Elements_0005_fig_1.2.png',
#  'Elements_Particles_of_Elements_0005_fig_1.3.png',
#  'Endothermic_Reactions_Energy_Change_in_Endothermic_Reactions_0004_fig_1.1.png',
#  'Endothermic_Reactions_Summary_0005_fig_1.2.png',
#  'Energy_Conservation_Conserving_Energy_at_Home_0004_fig_1.2.png',
#  'Energy_Conservation_Conserving_Energy_at_Home_0005_fig_1.3.png',
#  'Energy_Conservation_Conserving_Energy_in_Transportation_0004_fig_1.1.png',
#  'Energy_Conservation_Energy_Conservation_0005_fig_1.1.png',
#  'Energy_Conversion_How_Energy_Changes_Form_0004_fig_1.1.png',
#  'Energy_Conversion_KineticPotential_Energy_Changes_0005_fig_1.2.png',
#  'Energy_Level_Energy_Levels_and_Orbitals_0004_fig_1.2.png',
#  'Energy_Level_The_Outermost_Level_0005_fig_1.3.png',
#  'Energy_Level_The_Outermost_Level_0005_fig_1.4.png',
#  'Energy_Level_What_Are_Energy_Levels_0004_fig_1.1.png',
#  'Energy_Pyramids_Energy_Pyramids_0004_fig_1.1.png',
#  'Energy_SI_Unit_for_Energy_0004_fig_1.1.png',
#  'Energy_Use_Oil_Use_by_Nation_0004_fig_1.1.png',
#  'Energy_Use_Oil_Use_by_Nation_0004_fig_1.2.png',
#  'Energy_from_Biomass_Biomass_0004_fig_1.1.png',
#  'Environmental_Impacts_of_Mining_Mining_and_the_Environment_0004_fig_1.1.png',
#  'Enzymes_as_Catalysts_Digestive_Enzymes_0004_fig_1.2.png',
#  'Enzymes_as_Catalysts_How_Enzymes_Work_0004_fig_1.1.png',
#  'Enzymes_in_the_Digestive_System_The_Role_of_Enzymes_in_the_Digestive_System_0004_fig_1.1.png',
#  'Ethics_in_Science_Ethical_Rules_in_Science_0004_fig_1.1.png',
#  'Evaporation_Evaporative_Cooling_0004_fig_1.2.png',
#  'Evaporation_From_Liquid_to_Gas_Without_Boiling_0003_fig_1.1.png',
#  'Evolution_Acts_on_the_Phenotype_Carriers_0004_fig_1.1.png',
#  'Evolution_Plate_Tectonics_and_Climate_Change_The_Theory_of_Evolution_0004_fig_1.1.png',
#  'Evolution_of_Eukaryotes_to_Multicellular_Life_Ediacara_Fauna_0004_fig_1.1.png',
#  'Evolution_of_Simple_Cells_Cyanobacteria_0006_fig_1.4.png',
#  'Evolution_of_Simple_Cells_Cyanobacteria_0007_fig_1.5.png',
#  'Evolution_of_Simple_Cells_Photosynthesis_0005_fig_1.2.png',
#  'Evolution_of_Simple_Cells_Photosynthesis_0005_fig_1.3.png',
#  'Evolution_of_Simple_Cells_Simple_Cells_Evolve_0004_fig_1.1.png',
#  'Exoplanets_Extrasolar_Planets_or_Exoplanets_0004_fig_1.1.png',
#  'Exothermic_Reactions_Energy_Change_in_Exothermic_Reactions_0004_fig_1.1.png',
#  'Exothermic_Reactions_Review_0005_fig_1.2.png',
#  'Expansion_of_the_Universe_Redshift_0004_fig_1.1.png',
#  'Expansion_of_the_Universe_The_Expanding_Universe_0005_fig_1.2.png',
#  'Explosive_Eruptions_Cascades_Volcanoes_0005_fig_1.4.png',
#  'Explosive_Eruptions_Causes_of_the_Explosion_0004_fig_1.1.png',
#  'Explosive_Eruptions_Pyroclastic_Material_0004_fig_1.2.png',
#  'Explosive_Eruptions_Pyroclastic_Material_0005_fig_1.3.png',
#  'Explosive_Eruptions_Volcanic_Gases_0006_fig_1.5.png',
#  'External_Combustion_Engines_How_External_Combustion_Engines_Work_0004_fig_1.1.png',
#  'Extinction_and_Radiation_of_Life_Adaptive_Radiation_0004_fig_1.1.png',
#  'Faults_DipSlip_Faults_0005_fig_1.3.png',
#  'Faults_DipSlip_Faults_0005_fig_1.4.png',
#  'Faults_Faults_0004_fig_1.2.png',
#  'Faults_Joints_0004_fig_1.1.png',
#  'Faults_StrikeSlip_Faults_0006_fig_1.5.png',
#  'Features_of_Populations_What_is_a_Population_0004_fig_1.1.png',
#  'Features_of_Populations_What_is_a_Population_0004_fig_1.2.png',
#  'Female_Reproductive_Structures_Female_Reproductive_Organs_0004_fig_1.1.png',
#  'Female_Reproductive_System_The_Female_Reproductive_System_Functions_0004_fig_1.1.png',
#  'Fermentation_Fermentation_0004_fig_1.1.png',
#  'Ferromagnetic_Material_Magnetite_0006_fig_1.4.png',
#  'Ferromagnetic_Material_Temporary_and_Permanent_Magnets_0005_fig_1.2.png',
#  'Ferromagnetic_Material_Temporary_and_Permanent_Magnets_0005_fig_1.3.png',
#  'Ferromagnetic_Material_What_Makes_a_Material_Magnetic_0004_fig_1.1.png',
#  'Fertilization_Fertilization_and_Implantation_0004_fig_1.1.png',
#  'Fields_in_the_Life_Sciences_Evolution_of_Living_Organisms_0005_fig_1.1.png',
#  'Fields_in_the_Life_Sciences_Evolution_of_Living_Organisms_0005_fig_1.2.png',
#  'Finding_and_Mining_Ores_Finding_and_Mining_Minerals_0004_fig_1.1.png',
#  'Finding_and_Mining_Ores_Summary_0006_fig_1.4.png',
#  'Finding_and_Mining_Ores_Summary_0006_fig_1.5.png',
#  'Finding_and_Mining_Ores_Surface_Mining_0004_fig_1.2.png',
#  'Finding_and_Mining_Ores_Underground_Mining_0005_fig_1.3.png',
#  'Fish_Characteristics_of_Fish_0004_fig_1.1.png',
#  'Fish_How_Big_Are_Fish_0005_fig_1.3.png',
#  'Fish_How_do_Fish_Breathe_0004_fig_1.2.png',
#  'Fish_Summary_0006_fig_1.4.png',
#  'Fish_Summary_0006_fig_1.5.png',
#  'Flatworms_Explore_More_0005_fig_1.2.png',
#  'Flatworms_Features_of_Flatworms_0004_fig_1.1.png',
#  'Flooding_Causes_of_Floods_0004_fig_1.1.png',
#  'Flooding_Causes_of_Floods_0004_fig_1.2.png',
#  'Flooding_Effects_of_Floods_0006_fig_1.4.png',
#  'Flooding_Flash_Floods_0005_fig_1.3.png',
#  'Flow_of_Energy_in_Ecosystems_Food_Chains_0005_fig_1.2.png',
#  'Flow_of_Energy_in_Ecosystems_Food_Chains_0005_fig_1.3.png',
#  'Flow_of_Energy_in_Ecosystems_Food_Webs_0006_fig_1.4.png',
#  'Flow_of_Energy_in_Ecosystems_Food_Webs_0006_fig_1.5.png',
#  'Flow_of_Energy_in_Ecosystems_Trophic_Levels_0004_fig_1.1.png',
#  'Flow_of_Matter_in_Ecosystems_Nutrients_0004_fig_1.1.png',
#  'Folds_Monocline_0004_fig_1.1.png',
#  'Folds_Syncline_0005_fig_1.2.png',
#  'Folds_Syncline_0005_fig_1.3.png',
#  'Folds_Syncline_0006_fig_1.4.png',
#  'Folds_Syncline_0006_fig_1.5.png',
#  'Food_Webs_Food_Webs_0004_fig_1.1.png',
#  'Food_Webs_Summary_0005_fig_1.2.png',
#  'Food_and_Nutrients_Why_We_Need_Food_0004_fig_1.1.png',
#  'Force_Force_and_Motion_0004_fig_1.1.png',
#  'Force_Force_as_a_Vector_0005_fig_1.2.png',
#  'Formation_of_Earth_Differentiation_0004_fig_1.1.png',
#  'Formation_of_Earth_Early_Solar_System_Materials_0005_fig_1.2.png',
#  'Formation_of_the_Moon_Moons_Birth_Story_0004_fig_1.1.png',
#  'Formation_of_the_Sun_and_Planets_Formation_of_the_Sun_and_Planets_0004_fig_1.1.png',
#  'Forms_of_Energy_Resources_0007_fig_1.5.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0004_fig_1.1.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0004_fig_1.2.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0005_fig_1.3.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0005_fig_1.4.png',
#  'Fossil_Fuel_Formation_Formation_of_Fossil_Fuels_0004_fig_1.1.png',
#  'Fossil_Fuel_Formation_Formation_of_Fossil_Fuels_0004_fig_1.2.png',
#  'Fossil_Fuel_Reserves_Alternative_Fossil_Fuels_0004_fig_1.1.png',
#  'Fossil_Fuel_Reserves_Alternative_Fossil_Fuels_0004_fig_1.2.png',
#  'Fossils_Rock_Layers_and_the_Age_of_Fossils_0004_fig_1.1.png',
#  'Fossils_Rock_Layers_and_the_Age_of_Fossils_0005_fig_1.2.png',
#  'Fossils_Rock_Layers_and_the_Age_of_Fossils_0005_fig_1.3.png',
#  'Freezing_Freezing_Point_0004_fig_1.1.png',
#  'Frequency_and_Pitch_of_Sound_Can_You_Hear_It_0004_fig_1.1.png',
#  'Frequency_and_Pitch_of_Sound_Can_You_Hear_It_0004_fig_1.2.png',
#  'Fresh_Water_Ecosystems_Ecological_Role_of_Wetlands_0006_fig_1.3.png',
#  'Fresh_Water_Ecosystems_Lake_Ecosystems_0004_fig_1.1.png',
#  'Fresh_Water_Ecosystems_Marshes_0005_fig_1.2.png',
#  'Friction_Factors_That_Affect_Friction_0005_fig_1.3.png',
#  'Friction_Factors_That_Affect_Friction_0005_fig_1.4.png',
#  'Friction_Summary_0006_fig_1.5.png',
#  'Friction_Why_Friction_Occurs_0004_fig_1.1.png',
#  'Friction_Why_Friction_Occurs_0004_fig_1.2.png',
#  'Frogs_and_Toads_Characteristics_of_Frogs_0004_fig_1.1.png',
#  'Frogs_and_Toads_How_Do_Frogs_Eat_0005_fig_1.2.png',
#  'Fundamental_Particles_Leptons_and_Quarks_and_Bosons_Oh_My_0006_fig_1.1.png',
#  'Fungi_Fungi_are_Good_Eaters_0005_fig_1.2.png',
#  'Fungi_Reproduction_Asexual_Reproduction_0004_fig_1.1.png',
#  'Fungi_Reproduction_Sexual_Reproduction_0004_fig_1.2.png',
#  'Fungi_Structure_Body_Parts_of_Fungi_0004_fig_1.1.png',
#  'Fungi_Structure_Body_Parts_of_Fungi_0004_fig_1.2.png',
#  'Fungi_What_are_Fungi_0004_fig_1.1.png',
#  'Funguslike_Protists_Slime_Molds_0004_fig_1.1.png',
#  'Galaxies_Elliptical_Galaxies_0005_fig_1.3.png',
#  'Galaxies_Elliptical_Galaxies_0005_fig_1.4.png',
#  'Galaxies_Irregular_Galaxies_0006_fig_1.5.png',
#  'Galaxies_Spiral_Galaxies_0004_fig_1.1.png',
#  'Galaxies_Spiral_Galaxies_0004_fig_1.2.png',
#  'Gamma_Decay_Gamma_Rays_and_Radioactive_Decay_0004_fig_1.1.png',
#  'Gamma_Rays_Sources_of_Gamma_Rays_0004_fig_1.1.png',
#  'Gases_Explore_More_0006_fig_1.4.png',
#  'Gases_Pressure_in_the_Atmosphere_0005_fig_1.3.png',
#  'Gases_Pressure_of_Gases_0004_fig_1.1.png',
#  'Gases_Pressure_of_Gases_0004_fig_1.2.png',
#  'Gene_Therapy_In_Vivo_Gene_Therapy_0004_fig_1.1.png',
#  'Geologic_Time_Scale_The_Geologic_Time_Scale_0004_fig_1.1.png',
#  'Geological_Stresses_Causes_and_Types_of_Stress_0004_fig_1.1.png',
#  'Geological_Stresses_Causes_and_Types_of_Stress_0004_fig_1.2.png',
#  'Geological_Stresses_Responses_to_Stress_0005_fig_1.3.png',
#  'Geothermal_Power_Geothermal_Energy_0004_fig_1.1.png',
#  'Glaciers_Glacier_National_Park_0005_fig_1.3.png',
#  'Glaciers_Movement_0005_fig_1.2.png',
#  'Glaciers_Types_of_Glaciers_0004_fig_1.1.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0004_fig_1.2.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0005_fig_1.3.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0005_fig_1.4.png',
#  'Global_Warming_Increasing_Temperatures_0004_fig_1.1.png',
#  'Global_Wind_Belts_Jet_Stream_0005_fig_1.2.png',
#  'Global_Wind_Belts_The_Global_Winds_0004_fig_1.1.png',
#  'Gravity_Gravity_and_Weight_0004_fig_1.1.png',
#  'Gravity_in_the_Solar_System_The_Role_of_Gravity_0004_fig_1.1.png',
#  'Greenhouse_Effect_Greenhouse_Gases_0004_fig_1.1.png',
#  'Groundwater_Aquifers_Features_of_an_Aquifer_0004_fig_1.1.png',
#  'Groundwater_Aquifers_Wells_0005_fig_1.2.png',
#  'Groundwater_Aquifers_Wells_0005_fig_1.3.png',
#  'Groundwater_Aquifers_Wells_0006_fig_1.4.png',
#  'Groundwater_Depletion_Ogallala_Aquifer_0004_fig_1.1.png',
#  'Groundwater_Depletion_Review_0006_fig_1.4.png',
#  'Groundwater_Depletion_Summary_0005_fig_1.2.png',
#  'Groundwater_Depletion_Summary_0005_fig_1.3.png',
#  'Groundwater_Pollution_Filtered_Water_0004_fig_1.1.png',
#  'Groups_with_Metalloids_Group_15_Nitrogen_Group_0005_fig_1.2.png',
#  'Groups_with_Metalloids_Group_15_Nitrogen_Group_0005_fig_1.3.png',
#  'Groups_with_Metalloids_Group_16_Oxygen_Group_0006_fig_1.4.png',
#  'Groups_with_Metalloids_Group_16_Oxygen_Group_0006_fig_1.5.png',
#  'Groups_with_Metalloids_What_Are_Metalloids_0004_fig_1.1.png',
#  'Growth_of_Human_Populations_The_Rate_of_Growth_0004_fig_1.1.png',
#  'Growth_of_Human_Populations_The_Rate_of_Growth_0004_fig_1.2.png',
#  'Gymnosperms_Conifers_0004_fig_1.1.png',
#  'Gymnosperms_Cycads_0005_fig_1.2.png',
#  'Gymnosperms_Cycads_0005_fig_1.3.png',
#  'Gymnosperms_Ginkgoes_0006_fig_1.4.png',
#  'Gymnosperms_Gnetophytes_0006_fig_1.5.png',
#  'HIV_and_AIDS_HIV_and_the_Immune_System_0004_fig_1.1.png',
#  'Habitat_Destruction_Examples_of_Habitat_Destruction_0006_fig_1.4.png',
#  'Habitat_Destruction_Examples_of_Habitat_Destruction_0006_fig_1.5.png',
#  'Habitat_Destruction_Explore_More_0007_fig_1.6.png',
#  'Habitat_Destruction_Land_Loss_0004_fig_1.1.png',
#  'Habitat_Destruction_Land_Loss_0004_fig_1.2.png',
#  'Habitat_Destruction_SlashandBurn_Agriculture_0005_fig_1.3.png',
#  'Habitat_and_Niche_Explore_More_0006_fig_1.4.png',
#  'Habitat_and_Niche_Habitat_0005_fig_1.2.png',
#  'Habitat_and_Niche_Habitat_0005_fig_1.3.png',
#  'Habitat_and_Niche_Niche_0004_fig_1.1.png',
#  'Halflife_and_Radioactive_Dating_Focus_on_Carbon14_Dating_0005_fig_1.2.png',
#  'Halflife_and_Radioactive_Dating_Radioisotopes_and_Radioactive_Decay_0004_fig_1.1.png',
#  'Halogens_Chemical_Properties_of_Halogens_0004_fig_1.1.png',
#  'Halogens_Physical_Properties_of_Halogens_0005_fig_1.2.png',
#  'Halogens_Review_0006_fig_1.3.png',
#  'Harmful_Bacteria_Diseases_0004_fig_1.1.png',
#  'Health_Hazards_of_Air_Pollution_Air_Pollution_in_Cities_0004_fig_1.1.png',
#  'Health_of_the_Digestive_System_Food_Allergies_0005_fig_1.1.png',
#  'Hearing_Loss_Loud_Sounds_0004_fig_1.1.png',
#  'Hearing_Loss_Summary_0005_fig_1.2.png',
#  'Hearing_Loss_Summary_0005_fig_1.3.png',
#  'How_the_Eye_Works_How_the_Eye_Works_0004_fig_1.1.png',
#  'How_the_Eye_Works_How_the_Eye_Works_0004_fig_1.2.png',
#  'Human_Causes_of_Extinction_Pollution_0004_fig_1.1.png',
#  'Human_Causes_of_Extinction_Summary_0005_fig_1.2.png',
#  'Human_Digestive_System_Function_of_the_Digestive_System_0004_fig_1.1.png',
#  'Human_Egg_Cells_Egg_Production_0004_fig_1.1.png',
#  'Human_Evolution_Hominids_0004_fig_1.1.png',
#  'Human_Evolution_Hominids_0005_fig_1.2.png',
#  'Human_Genome_Project_Human_Genome_Project_0004_fig_1.1.png',
#  'Human_Population_Human_Population_0004_fig_1.1.png',
#  'Human_Skeletal_System_Functions_of_Bones_0004_fig_1.1.png',
#  'Human_Skeletal_System_Structure_of_Bones_0005_fig_1.2.png',
#  'Human_Sperm_Sperm_0004_fig_1.1.png',
#  'Human_Uses_of_Fungi_Edible_and_Poisonous_Fungi_0004_fig_1.2.png',
#  'Human_Uses_of_Fungi_Importance_of_Fungi_for_Human_Use_0004_fig_1.1.png',
#  'Human_Vision_Seeing_in_Color_0005_fig_1.3.png',
#  'Human_Vision_Seeing_in_Color_0005_fig_1.4.png',
#  'Human_Vision_Seeing_in_Three_Dimensions_0004_fig_1.2.png',
#  'Human_Vision_Summary_0006_fig_1.5.png',
#  'Human_Vision_The_Nature_of_Human_Vision_0004_fig_1.1.png',
#  'Humans_and_Primates_Characteristics_0004_fig_1.1.png',
#  'Humans_and_Primates_Characteristics_0004_fig_1.2.png',
#  'Hurricanes_Formation_0004_fig_1.1.png',
#  'Hurricanes_Review_0006_fig_1.2.png',
#  'Hydrocarbons_Sources_of_Hydrocarbons_0005_fig_1.2.png',
#  'Hydrocarbons_Uses_of_Hydrocarbons_0004_fig_1.1.png',
#  'Hydroelectric_Power_Hydroelectric_Power_0004_fig_1.1.png',
#  'Hydroelectric_Power_Ocean_Water_Power_0005_fig_1.2.png',
#  'Hydrogen_Bonding_Hydrogen_Bonding_0004_fig_1.1.png',
#  'Hydrogen_and_Alkali_Metals_A_Closer_Look_0006_fig_1.2.png',
#  'Hydrogen_and_Alkali_Metals_A_Closer_Look_0006_fig_1.3.png',
#  'Hydrogen_and_Alkali_Metals_A_Closer_Look_0007_fig_1.4.png',
#  'Hydrogen_and_Alkali_Metals_Other_Properties_of_Alkali_Metals_0005_fig_1.1.png',
#  'Hypothesis_Summary_0005_fig_1.1.png',
#  'Igneous_Rocks_What_Melts_and_What_Crystallizes_0005_fig_1.1.png',
#  'Impact_of_Continued_Global_Warming_Global_Changes_0005_fig_1.2.png',
#  'Impact_of_Continued_Global_Warming_Global_Changes_0005_fig_1.3.png',
#  'Impact_of_Continued_Global_Warming_Temperature_Scenarios_0004_fig_1.1.png',
#  'Impacts_of_Hazardous_Waste_Love_Canal_0004_fig_1.1.png',
#  'Impacts_of_Hazardous_Waste_Toxic_Metals_0005_fig_1.2.png',
#  'Importance_of_Arthropods_Arthropods_as_Food_0004_fig_1.1.png',
#  'Importance_of_Biodiversity_Biodiversity_and_Technology_0005_fig_1.3.png',
#  'Importance_of_Biodiversity_Ecological_Importance_0006_fig_1.4.png',
#  'Importance_of_Biodiversity_Economic_Importance_0004_fig_1.2.png',
#  'Importance_of_Biodiversity_Importance_of_Biodiversity_0004_fig_1.1.png',
#  'Importance_of_Birds_Birds_and_the_Ecosystem_0004_fig_1.1.png',
#  'Importance_of_Insects_Ecological_Importance_0004_fig_1.1.png',
#  'Importance_of_Mammals_Importance_to_Ecosystems_0004_fig_1.1.png',
#  'Importance_of_Mammals_Importance_to_Humans_0005_fig_1.2.png',
#  'Importance_of_Mollusks_Mollusks_as_Food_0004_fig_1.1.png',
#  'Importance_of_Protists_Summary_0004_fig_1.1.png',
#  'Importance_of_Reptiles_Summary_0005_fig_1.1.png',
#  'Importance_of_Seedless_Plants_Current_Uses_0004_fig_1.1.png',
#  'Importance_of_the_Atmosphere_Crucial_Part_of_the_Water_Cycle_0005_fig_1.2.png',
#  'Importance_of_the_Atmosphere_Gases_Indispensable_for_Life_on_Earth_0004_fig_1.1.png',
#  'Importance_of_the_Oceans_Biologically_Rich_0004_fig_1.1.png',
#  'Inclined_Plane_Mechanical_Advantage_Of_An_Inclined_Plane_0004_fig_1.1.png',
#  'Inclined_Plane_Mechanical_Advantage_Of_An_Inclined_Plane_0004_fig_1.2.png',
#  'Indoor_Air_Pollution_Indoor_Air_Pollution_0004_fig_1.1.png',
#  'Inertia_Overcoming_Inertia_0005_fig_1.2.png',
#  'Inertia_Review_0006_fig_1.3.png',
#  'Inertia_What_Is_Inertia_0004_fig_1.1.png',
#  'Infancy_and_Childhood_Early_Childhood_Development_0005_fig_1.2.png',
#  'Infancy_and_Childhood_Infancy_and_Childhood_0004_fig_1.1.png',
#  'Inflammatory_Response_Inflammation_0004_fig_1.1.png',
#  'Influences_on_Darwin_Darwins_Influences_0004_fig_1.1.png',
#  'Influences_on_Weathering_Resources_from_Weathering_0005_fig_1.2.png',
#  'Influences_on_Weathering_Rock_and_Mineral_Type_0004_fig_1.1.png',
#  'Injuries_of_the_Nervous_System_Spinal_Cord_Injuries_0005_fig_1.1.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_0004_fig_1.1.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_0004_fig_1.2.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_in_Human_Beings_0005_fig_1.3.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_in_Human_Beings_0005_fig_1.4.png',
#  'Inner_versus_Outer_Planets_The_Outer_Planets_0004_fig_1.1.png',
#  'Inner_versus_Outer_Planets_The_Outer_Planets_0004_fig_1.2.png',
#  'Inner_vs._Outer_Planets_The_Inner_Planets_0004_fig_1.1.png',
#  'Inner_vs._Outer_Planets_The_Outer_Planets_0005_fig_1.2.png',
#  'Insect_Food_How_do_Insects_Eat_0004_fig_1.1.png',
#  'Insect_Food_How_do_Insects_Eat_0004_fig_1.2.png',
#  'Insect_Reproduction_and_Life_Cycle_Three_Types_of_Metamorphosis_0006_fig_1.1.png',
#  'Insects_Characteristics_of_Insects_0004_fig_1.1.png',
#  'Insects_Characteristics_of_Insects_0004_fig_1.2.png',
#  'Insects_Characteristics_of_Insects_0005_fig_1.4.png',
#  'Insects_Insects_are_Social_0006_fig_1.5.png',
#  'Intensity_and_Loudness_of_Sound_Decibel_Levels_0004_fig_1.1.png',
#  'Intensity_and_Loudness_of_Sound_Summary_0005_fig_1.2.png',
#  'Interior_of_the_Sun_Internal_Structure_0004_fig_1.1.png',
#  'Interior_of_the_Sun_Review_0006_fig_1.3.png',
#  'Interior_of_the_Sun_The_Outer_Layers_0005_fig_1.2.png',
#  'Internal_Combustion_Engines_How_Internal_Combustion_Engines_Work_0004_fig_1.1.png',
#  'Intraplate_Activity_Intraplate_Activity_in_the_Oceans_0004_fig_1.1.png',
#  'Intraplate_Activity_Intraplate_Activity_in_the_Oceans_0004_fig_1.2.png',
#  'Intraplate_Activity_Intraplate_Activity_on_the_Continents_0005_fig_1.3.png',
#  'Intraplate_Earthquakes_Review_0005_fig_1.1.png',
#  'Introduction_to_Ecology_Research_in_Ecology_0004_fig_1.1.png',
#  'Introduction_to_Energy_Resources_Heat_0005_fig_1.1.png',
#  'Introduction_to_Groundwater_Fossil_Water_0004_fig_1.1.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Extrusive_Igneous_Rocks_0005_fig_1.3.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Extrusive_Igneous_Rocks_0005_fig_1.4.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Extrusive_Igneous_Rocks_0006_fig_1.5.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Intrusive_Igneous_Rocks_0004_fig_1.1.png',
#  'Intrusive_and_Extrusive_Igneous_Rocks_Intrusive_Igneous_Rocks_0004_fig_1.2.png',
#  'Invertebrates_What_Are_Invertebrates_0004_fig_1.1.png',
#  'Ionic_Bonding_How_Ionic_Bonds_Form_0004_fig_1.1.png',
#  'Ionic_Bonding_Why_Ionic_Bonds_Form_0004_fig_1.2.png',
#  'Ionic_Compounds_Crystals_0004_fig_1.1.png',
#  'Ionic_Compounds_Summary_0006_fig_1.2.png',
#  'Ions_Atoms_to_Ions_0004_fig_1.1.png',
#  'Isomers_How_Many_Isomers_0004_fig_1.1.png',
#  'Isomers_How_Many_Isomers_0004_fig_1.2.png',
#  'Isomers_How_Many_Isomers_0004_fig_1.3.png',
#  'Isomers_How_Many_Isomers_0005_fig_1.4.png',
#  'Isotopes_Naming_Isotopes_0005_fig_1.1.png',
#  'Jawless_Fish_Classification_of_Jawless_Fish_0004_fig_1.1.png',
#  'Jupiter_A_Ball_of_Gas_and_Liquid_0004_fig_1.1.png',
#  'Jupiter_A_Ball_of_Gas_and_Liquid_0004_fig_1.2.png',
#  'Jupiter_A_Stormy_Atmosphere_0005_fig_1.3.png',
#  'Jupiter_Jupiters_Moons_and_Rings_0006_fig_1.4.png',
#  'Jupiter_Summary_0007_fig_1.5.png',
#  'Light_Let_There_Be_Light_0004_fig_1.1.png',
#  'Light_Reactions_of_Photosynthesis_In_the_Presence_of_Sunlight_Carbon_Dioxide_0004_fig_1.1.png',
#  'Light_Reactions_of_Photosynthesis_The_Calvin_Cycle_0006_fig_1.3.png',
#  'Light_Reactions_of_Photosynthesis_The_Chemical_Reaction_0005_fig_1.2.png',
#  'Light_Ultraviolet_Light_0005_fig_1.3.png',
#  'Light_Visible_Light_0004_fig_1.2.png',
#  'Limiting_Factors_to_Population_Growth_Limiting_Factors_to_Population_Growth_0004_fig_1.1.png',
#  'Lipid_Classification_Fatty_Acids_0004_fig_1.1.png',
#  'Lipid_Classification_Fatty_Acids_0004_fig_1.2.png',
#  'Lipid_Classification_Phospholipids_0005_fig_1.3.png',
#  'Liquids_Review_0005_fig_1.4.png',
#  'Liquids_Surface_Tension_and_Viscosity_0004_fig_1.2.png',
#  'Liquids_Surface_Tension_and_Viscosity_0004_fig_1.3.png',
#  'Liquids_Water_and_Other_Liquids_0004_fig_1.1.png',
#  'Lithification_of_Sedimentary_Rocks_Sedimentary_Rock_Formation_0004_fig_1.1.png',
#  'Lizards_and_Snakes_Characteristics_of_Lizards_0004_fig_1.1.png',
#  'Lizards_and_Snakes_Characteristics_of_Lizards_0004_fig_1.2.png',
#  'Lizards_and_Snakes_Characteristics_of_Snakes_0006_fig_1.4.png',
#  'Lizards_and_Snakes_Characteristics_of_Snakes_0006_fig_1.5.png',
#  'Lizards_and_Snakes_How_do_Snakes_Eat_0007_fig_1.6.png',
#  'Lizards_and_Snakes_Lizard_Behavior_0005_fig_1.3.png',
#  'Local_Winds_Chinook_Winds_Foehn_Winds_0005_fig_1.3.png',
#  'Local_Winds_Desert_Winds_0007_fig_1.6.png',
#  'Local_Winds_Land_and_Sea_Breezes_0004_fig_1.1.png',
#  'Local_Winds_Monsoon_Winds_0004_fig_1.2.png',
#  'Local_Winds_Santa_Ana_Winds_0006_fig_1.4.png',
#  'Local_Winds_Santa_Ana_Winds_0006_fig_1.5.png',
#  'Locating_Earthquake_Epicenters_Finding_the_Epicenter_0004_fig_1.1.png',
#  'Location_and_Direction_Direction_0005_fig_1.2.png',
#  'Location_and_Direction_Location_0004_fig_1.1.png',
#  'LongTerm_Climate_Change_Changes_in_Atmospheric_Greenhouse_Gas_Levels_0006_fig_1.3.png',
#  'LongTerm_Climate_Change_Milankovitch_Cycles_0005_fig_1.2.png',
#  'LongTerm_Climate_Change_Solar_Variation_0004_fig_1.1.png',
#  'Longitudinal_Wave_P_Waves_0004_fig_1.2.png',
#  'Longitudinal_Wave_What_Is_a_Longitudinal_Wave_0004_fig_1.1.png',
#  'Lymphatic_System_Lymph_Organs_0005_fig_1.2.png',
#  'Lymphatic_System_Lymphocytes_0006_fig_1.3.png',
#  'Lymphatic_System_The_Lymphatic_System_and_the_Immune_Response_0004_fig_1.1.png',
#  'Magnetic_Evidence_for_Seafloor_Spreading_Seafloor_Age_0005_fig_1.2.png',
#  'Magnetic_Evidence_for_Seafloor_Spreading_Seafloor_Magnetism_0004_fig_1.1.png',
#  'Magnetic_Field_Reversal_Changing_Places_0003_fig_1.1.png',
#  'Magnetic_Field_Reversal_Fact_Not_Fiction_0004_fig_1.2.png',
#  'Magnetic_Polarity_Evidence_for_Continental_Drift_Magnetic_Polarity_Evidence_0004_fig_1.1.png',
#  'Magnetic_Polarity_Evidence_for_Continental_Drift_Magnetic_Polarity_on_the_Same_Continent_with_Rocks_of_Different_Ages_0005_fig_1.2.png',
#  'Magnetic_Polarity_Evidence_for_Continental_Drift_Magnetic_Polarity_on_the_Same_Continent_with_Rocks_of_Different_Ages_0005_fig_1.3.png',
#  'Magnetic_Polarity_Evidence_for_Continental_Drift_Wegener_Was_Right_0006_fig_1.4.png',
#  'Magnets_Magnetic_Force_and_Magnetic_Field_0004_fig_1.1.png',
#  'Magnets_Magnetic_Force_and_Magnetic_Field_0004_fig_1.2.png',
#  'Magnets_Magnetic_Force_and_Magnetic_Field_0005_fig_1.3.png',
#  'Male_Reproductive_Structures_Male_Reproductive_Organs_0004_fig_1.1.png',
#  'Male_Reproductive_System_The_Male_Reproductive_System_Functions_0004_fig_1.1.png',
#  'Mammal_Characteristics_Characteristics_of_Mammals_0004_fig_1.1.png',
#  'Mammal_Classification_Groups_of_Mammals_0004_fig_1.1.png',
#  'Mammal_Classification_Groups_of_Mammals_0004_fig_1.2.png',
#  'Mammal_Classification_Groups_of_Mammals_0005_fig_1.3.png',
#  'Mammal_Reproduction_Mammal_Reproduction_0004_fig_1.1.png',
#  'Mammal_Reproduction_Mammal_Reproduction_0004_fig_1.2.png',
#  'Mammal_Reproduction_Summary_0005_fig_1.3.png',
#  'Maps_Bathymetric_Maps_0004_fig_1.2.png',
#  'Maps_Bathymetric_Maps_0005_fig_1.3.png',
#  'Maps_Topographic_Maps_0004_fig_1.1.png',
#  'Mars_Characteristics_0004_fig_1.1.png',
#  'Mars_Is_There_Water_on_Mars_0005_fig_1.2.png',
#  'Mars_Is_There_Water_on_Mars_0005_fig_1.3.png',
#  'Mars_Is_There_Water_on_Mars_0006_fig_1.4.png',
#  'Mars_Two_Martian_Moons_0006_fig_1.5.png',
#  'Mass_Extinctions_Mass_Extinctions_0004_fig_1.1.png',
#  'Mass_Extinctions_Mass_Extinctions_0004_fig_1.2.png',
#  'Mass_Extinctions_Mass_Extinctions_0005_fig_1.3.png',
#  'Mass_vs_Weight_Review_0004_fig_1.1.png',
#  'Matter_Mass_and_Volume_Advanced_Topic_Defining_Density_0007_fig_1.1.png',
#  'Measuring_Earthquake_Magnitude_Interpreting_a_Seismogram_0004_fig_1.1.png',
#  'Mechanical_Advantage_A_Simple_Example_0004_fig_1.1.png',
#  'Mechanical_Wave_Types_of_Mechanical_Waves_0004_fig_1.1.png',
#  'Mechanical_Weathering_Abrasion_0004_fig_1.2.png',
#  'Mechanical_Weathering_Humans_0005_fig_1.3.png',
#  'Mechanical_Weathering_Ice_Wedging_0004_fig_1.1.png',
#  'Meiosis_Meiosis_I_0005_fig_1.2.png',
#  ...]

# %%
record_image_name_changes_name_only[ '9.3_Carbon_and_Living_Things_Structure_of_Nucleic_Acids_0215_fig_9.23.png']
# Out:
# 'carbon_and_living_things_22646.png'

# %%
len(record_image_name_changes)
# Out:
# 3176

# %%
old_original_image_names
# Out:
# ['1_Carbohydrate_Classification_Cellulose_0005_fig_1.2.png',
#  '1_Carbohydrate_Classification_Cellulose_0005_fig_1.3.png',
#  '1_Carbohydrate_Classification_Sugars_0004_fig_1.1.png',
#  '1_Excretory_System_Problems_Kidney_Stones_0004_fig_1.1.png',
#  '1_Excretory_System_Problems_Kidney_failure_0004_fig_1.2.png',
#  '1_Igneous_Rock_Classification_Igneous_Rock_Classification_0004_fig_1.1.png',
#  '1_Importance_of_Echinoderms_Ecological_Role_0004_fig_1.1.png',
#  '1_Seasonal_Changes_in_Plants_Seasonal_Changes_0004_fig_1.1.png',
#  '1_ShortTerm_Climate_Change_El_Nio_0004_fig_1.1.png',
#  '1_ShortTerm_Climate_Change_El_Nio_0004_fig_1.2.png',
#  '1_ShortTerm_Climate_Change_La_Nia_0005_fig_1.3.png',
#  '1_Surface_Features_of_the_Sun_Solar_Flares_0004_fig_1.1.png',
#  '1_Surface_Features_of_the_Sun_Solar_Flares_0004_fig_1.2.png',
#  '1_Surface_Features_of_the_Sun_Solar_Prominences_0005_fig_1.3.png',
#  '1_Transform_Plate_Boundaries_Transform_Faults_On_Land_0004_fig_1.1.png',
#  '21st_Century_Tsunami_Boxing_Day_Tsunami_2004_0004_fig_1.1.png',
#  '21st_Century_Tsunami_Japan_Tsunami_2011_0004_fig_1.2.png',
#  '21st_Century_Tsunami_Japan_Tsunami_2011_0005_fig_1.3.png',
#  '21st_Century_Tsunami_Tsunami_Warning_Systems_0005_fig_1.4.png',
#  'Acceleration_Due_to_Gravity_Mass_and_Acceleration_Due_to_Gravity_0004_fig_1.1.png',
#  'Acceleration_Examples_of_Acceleration_0004_fig_1.1.png',
#  'Accuracy_and_Precision_Resources_0005_fig_1.1.png',
#  'AcidBase_Neutralization_Reactions_of_Acids_and_Bases_0004_fig_1.1.png',
#  'Acid_Rain_Effects_of_Acid_Rain_0006_fig_1.4.png',
#  'Acid_Rain_pH_and_Acid_Rain_0004_fig_1.1.png',
#  'Acid_Rain_pH_and_Acid_Rain_0004_fig_1.2.png',
#  'Acid_Rain_pH_and_Acid_Rain_0005_fig_1.3.png',
#  'Activation_Energy_Activating_Endothermic_and_Exothermic_Reactions_0004_fig_1.1.png',
#  'Active_Transport_Active_Transport_0004_fig_1.1.png',
#  'Adulthood_and_Aging_Late_Adulthood_0004_fig_1.1.png',
#  'Ages_Index_Fossils_0004_fig_1.1.png',
#  'Ages_Key_Beds_0005_fig_1.2.png',
#  'Agriculture_Biotechnology_in_Agriculture_0004_fig_1.1.png',
#  'Air_Masses_Air_Mass_Formation_0004_fig_1.1.png',
#  'Air_Pressure_and_Altitude_Explaining_Changes_in_Air_Pressure_with_Altitude_0004_fig_1.1.png',
#  'Air_Pressure_and_Altitude_How_We_Use_Air_Pressure_0004_fig_1.2.png',
#  'Air_Pressure_and_Altitude_How_We_Use_Air_Pressure_0005_fig_1.3.png',
#  'Air_Quality_Photochemical_Smog_0004_fig_1.2.png',
#  'Air_Quality_Smog_0004_fig_1.1.png',
#  'Alkaline_Earth_Metals_Summary_0005_fig_1.1.png',
#  'Alkaline_Earth_Metals_Summary_0006_fig_1.2.png',
#  'Alligators_and_Crocodiles_Characteristics_of_Crocodiles_0004_fig_1.1.png',
#  'Alloys_Examples_of_Alloys_0004_fig_1.1.png',
#  'Alpha_Decay_Equations_for_Alpha_Decay_0004_fig_1.1.png',
#  'Alternative_Energy_Sources_Alternative_Energy_Sources_0004_fig_1.1.png',
#  'Alternative_Energy_Sources_Alternative_Energy_Sources_0004_fig_1.2.png',
#  'Alternative_Energy_Sources_Alternative_Energy_Sources_0005_fig_1.3.png',
#  'Alternative_Energy_Sources_Alternative_Energy_Sources_0005_fig_1.4.png',
#  'Amontons_Law_References_0006_fig_1.1.png',
#  'Amontonss_Law_Explore_More_0005_fig_1.1.png',
#  'Amphibians_How_did_Amphibians_Adapt_to_Living_on_Land_0004_fig_1.1.png',
#  'Angiosperms_The_Parts_of_a_Flower_0004_fig_1.1.png',
#  'Angiosperms_The_Parts_of_a_Flower_0004_fig_1.2.png',
#  'Angiosperms_The_Parts_of_a_Flower_0006_fig_1.3.png',
#  'Animal_Behaviors_Examples_of_Animal_Behavior_0004_fig_1.1.png',
#  'Animal_Communication_Communication_with_Sight_0004_fig_1.1.png',
#  'Animal_Communication_Communication_with_Sight_0004_fig_1.2.png',
#  'Animal_Communication_Human_Communication_0005_fig_1.3.png',
#  'Animallike_Protists_Different_Kinds_of_Animallike_Protists_0004_fig_1.1.png',
#  'Animals_Caring_for_the_Young_0004_fig_1.1.png',
#  'Animals_Defending_Territory_0005_fig_1.2.png',
#  'Animals_Insight_Learning_0007_fig_1.4.png',
#  'Animals_Learning_by_Playing_0006_fig_1.2.png',
#  'Animals_Learning_by_Playing_0006_fig_1.3.png',
#  'Animals_Observational_Learning_0005_fig_1.1.png',
#  'Aquatic_Biomes_Freshwater_Biomes_0005_fig_1.2.png',
#  'Aquatic_Biomes_Marine_Biomes_0004_fig_1.1.png',
#  'Arachnids_Characteristics_of_Arachnids_0004_fig_1.1.png',
#  'Archaea_What_are_Archaea_0004_fig_1.1.png',
#  'Archimedes_Law_Floating_Objects_and_Archimedes_Law_0004_fig_1.1.png',
#  'Arthropods_Characteristics_of_Arthropods_0005_fig_1.2.png',
#  'Arthropods_Types_of_Arthropods_0004_fig_1.1.png',
#  'Artificial_Light_Fluorescent_Light_0004_fig_1.1.png',
#  'Artificial_Light_Fluorescent_Light_0004_fig_1.2.png',
#  'Artificial_Light_Neon_Light_0005_fig_1.3.png',
#  'Artificial_Light_Summary_0006_fig_1.5.png',
#  'Artificial_Light_Vapor_Light_0005_fig_1.4.png',
#  'Asteroids_Asteroid_Missions_0006_fig_1.4.png',
#  'Asteroids_NearEarth_Asteroids_0005_fig_1.3.png',
#  'Asteroids_The_Asteroid_Belt_0004_fig_1.1.png',
#  'Asteroids_The_Asteroid_Belt_0004_fig_1.2.png',
#  'Atmosphere_Air_Pressure_Zones_0004_fig_1.1.png',
#  'Atmosphere_Crucial_Part_of_the_Water_Cycle_0005_fig_1.2.png',
#  'Atmosphere_Gases_Indispensable_for_Life_on_Earth_0004_fig_1.1.png',
#  'Atmosphere_Heat_Transfer_in_the_Atmosphere_0004_fig_1.1.png',
#  'Atmosphere_Layers_0004_fig_1.2.png',
#  'Atmosphere_Nitrogen_and_Oxygen_0004_fig_1.1.png',
#  'Atmosphere_Particulates_0005_fig_1.2.png',
#  'Atmosphere_Plus_Coriolis_Effect_0005_fig_1.2.png',
#  'Atmosphere_Pressure_0004_fig_1.1.png',
#  'Atmosphere_Warm_Air_Rises_0004_fig_1.1.png',
#  'Atom_Cutting_the_Cheese_0004_fig_1.1.png',
#  'Atom_Just_a_Guess_0004_fig_1.1.png',
#  'Atom_Keep_on_Moving_0005_fig_1.2.png',
#  'Atom_Why_Matter_Varies_0005_fig_1.2.png',
#  'Atomic_Forces_Electromagnetic_Force_0004_fig_1.1.png',
#  'Atomic_Forces_Strong_Nuclear_Force_0005_fig_1.2.png',
#  'Atomic_Forces_Weak_Nuclear_Force_0005_fig_1.3.png',
#  'Atomic_Nucleus_Size_and_Mass_of_the_Nucleus_0004_fig_1.1.png',
#  'Atomic_Number_Atomic_Number_0005_fig_1.2.png',
#  'Atomic_Number_Telling_Atoms_Apart_0004_fig_1.1.png',
#  'Atoms_Neutrons_0005_fig_1.2.png',
#  'Atoms_Parts_of_the_Atom_0004_fig_1.1.png',
#  'Atoms_Review_0006_fig_1.3.png',
#  'Atoms_Size_of_Atoms_0004_fig_1.1.png',
#  'Atoms_Subatomic_Particles_0005_fig_1.2.png',
#  'Atoms_to_Molecules_Parts_of_an_Atom_0004_fig_1.1.png',
#  'Autoimmune_Diseases_Allergies_0004_fig_1.1.png',
#  'Autoimmune_Diseases_Summary_0005_fig_1.2.png',
#  'Avoiding_Soil_Loss_Preventing_Soil_Erosion_0005_fig_1.2.png',
#  'Avoiding_Soil_Loss_Preventing_Soil_Erosion_0005_fig_1.3.png',
#  'Avoiding_Soil_Loss_Soil_Erosion_0004_fig_1.1.png',
#  'B_and_T_Cell_Response_B_Cell_Response_0004_fig_1.1.png',
#  'B_and_T_Cell_Response_T_Cell_Response_0005_fig_1.2.png',
#  'Bacteria_Characteristics_Flagella_0005_fig_1.3.png',
#  'Bacteria_Characteristics_Similarities_to_Eukaryotes_0004_fig_1.2.png',
#  'Bacteria_Characteristics_Size_and_Shape_0004_fig_1.1.png',
#  'Bacteria_Nutrition_Mutualism_0004_fig_1.1.png',
#  'Bacteria_Reproduction_Exchanging_DNA_0004_fig_1.1.png',
#  'Barriers_to_Pathogens_Chemicals_0005_fig_1.2.png',
#  'Barriers_to_Pathogens_Skin_and_Mucous_Membranes_0004_fig_1.1.png',
#  'Basic_and_Applied_Science_Basic_and_Applied_Science_0004_fig_1.1.png',
#  'Basic_and_Applied_Science_Basic_and_Applied_Science_0004_fig_1.2.png',
#  'Bernoullis_Law_Using_Air_Pressure_to_Fly_0004_fig_1.1.png',
#  'Beta_Decay_What_Is_Beta_Decay_0004_fig_1.1.png',
#  'Big_Bang_Background_Radiation_0005_fig_1.2.png',
#  'Big_Bang_Review_0006_fig_1.3.png',
#  'Big_Bang_The_Big_Bang_Theory_0004_fig_1.1.png',
#  'Biological_Communities_Ecosystems_0004_fig_1.1.png',
#  'Biological_Communities_Habitat_0005_fig_1.3.png',
#  'Biological_Communities_Niches_0005_fig_1.2.png',
#  'Bird_Reproduction_Parental_Care_0005_fig_1.2.png',
#  'Bird_Reproduction_Protecting_Offspring_0004_fig_1.1.png',
#  'Birds_Adaptations_for_Flight_0005_fig_1.2.png',
#  'Birds_Adaptations_for_Flight_0005_fig_1.3.png',
#  'Birds_Adaptations_for_Flight_0006_fig_1.4.png',
#  'Birds_Characteristics_of_Birds_0004_fig_1.1.png',
#  'Blizzards_Formation_0004_fig_1.1.png',
#  'Blizzards_Formation_0004_fig_1.2.png',
#  'Blizzards_LakeEffect_Snow_0005_fig_1.3.png',
#  'Blood_Diseases_SickleCell_Anemia_0004_fig_1.1.png',
#  'Blood_Pressure_Healthy_Blood_Pressure_Ranges_0004_fig_1.1.png',
#  'Blood_Types_Blood_Types_0004_fig_1.1.png',
#  'Blood_Vessels_Blood_Vessels_and_Blood_Circulation_0004_fig_1.1.png',
#  'Body_Groups_of_Tissues_Form_Organs_0005_fig_1.2.png',
#  'Body_Organization_of_Your_Body_Cells_Tissues_Organs_0004_fig_1.1.png',
#  'Bohrs_Atomic_Model_Energy_by_the_Spoonful_0005_fig_1.2.png',
#  'Bohrs_Atomic_Model_Modeling_the_Atom_0004_fig_1.1.png',
#  'Bond_Polarity_Polar_and_Nonpolar_Covalent_Bonds_0004_fig_1.1.png',
#  'Bond_Polarity_Polar_and_Nonpolar_Covalent_Bonds_0004_fig_1.2.png',
#  'Bond_Polarity_Polar_and_Nonpolar_Covalent_Compounds_0005_fig_1.3.png',
#  'Bony_Fish_Bony_Fish_0003_fig_1.1.png',
#  'Bony_Fish_How_Big_Are_Bony_Fish_0004_fig_1.2.png',
#  'Boundaries_Continental_Rifting_0005_fig_1.1.png',
#  'Boundaries_Explore_More_0007_fig_1.4.png',
#  'Boundaries_Review_0006_fig_1.2.png',
#  'Boundaries_Review_0006_fig_1.3.png',
#  'Boyles_Law_Its_Crowded_in_Here_0004_fig_1.1.png',
#  'Boyles_Law_Review_0006_fig_1.3.png',
#  'Boyles_Law_You_Go_Up_and_Ill_Go_Down_0005_fig_1.2.png',
#  'Branches_of_Earth_Science_Astronomy_0005_fig_1.3.png',
#  'Branches_of_Earth_Science_Climatology_and_Meteorology_0004_fig_1.2.png',
#  'Branches_of_Earth_Science_Geology_0004_fig_1.1.png',
#  'Buoyancy_Density_and_Buoyant_Force_0005_fig_1.3.png',
#  'Buoyancy_Weight_and_Buoyant_Force_0004_fig_1.1.png',
#  'Buoyancy_Weight_and_Buoyant_Force_0004_fig_1.2.png',
#  'Calculating_Work_Calculating_Force_or_Distance_When_Work_Is_Known_0004_fig_1.1.png',
#  'Cancer_Chemicals_0004_fig_1.1.png',
#  'Cancer_Chemicals_0004_fig_1.2.png',
#  'Cancer_Common_Types_of_Cancer_0005_fig_1.3.png',
#  'Carbon_Bonding_CarbonCarbon_Bonds_0005_fig_1.3.png',
#  'Carbon_Bonding_How_Carbon_Forms_Bonds_0004_fig_1.2.png',
#  'Carbon_Bonding_Valence_Electrons_in_Carbon_0004_fig_1.1.png',
#  'Carbon_Cycle_and_Climate_Atmospheric_Carbon_Dioxide_0005_fig_1.2.png',
#  'Carbon_Cycle_and_Climate_Human_Actions_Impact_the_Carbon_Cycle_0006_fig_1.3.png',
#  'Carbon_Cycle_and_Climate_Respiration_0004_fig_1.1.png',
#  'Cardiac_Muscles_Types_of_Muscles_0004_fig_1.1.png',
#  'Cardiovascular_Diseases_Cardiovascular_Diseases_0004_fig_1.1.png',
#  'Cardiovascular_Diseases_Summary_0005_fig_1.2.png',
#  'Cardiovascular_System_Functions_of_the_Cardiovascular_System_0004_fig_1.1.png',
#  'Cartilaginous_Fish_Explore_More_I_0005_fig_1.1.png',
#  'Catalysts_Catalysts_in_Living_Things_0004_fig_1.2.png',
#  'Catalysts_How_Catalysts_Work_0004_fig_1.1.png',
#  'Causes_Of_Air_Pollution_Evaporation_0005_fig_1.2.png',
#  'Causes_Of_Air_Pollution_Evaporation_0005_fig_1.3.png',
#  'Causes_Of_Air_Pollution_Fossil_Fuels_0004_fig_1.1.png',
#  'Cell_Biology_Levels_of_Organization_0005_fig_1.4.png',
#  'Cell_Biology_Observing_Cells_0004_fig_1.1.png',
#  'Cell_Biology_Observing_Cells_0004_fig_1.2.png',
#  'Cell_Biology_Specialized_Cells_0005_fig_1.3.png',
#  'Cell_Cycle_Cell_Cycle_0004_fig_1.1.png',
#  'Cell_Division_Why_Cells_Divide_0004_fig_1.1.png',
#  'Cell_Membrane_The_Plasma_Membrane_0004_fig_1.1.png',
#  'Cell_Nucleus_Nucleolus_0004_fig_1.1.png',
#  'Cell_Transport_Composition_of_the_Cell_Membrane_0004_fig_1.1.png',
#  'Cells_Eukaryotic_Cells_0004_fig_1.1.png',
#  'Cells_Prokaryotic_Cells_0005_fig_1.2.png',
#  'Cellular_Respiration_ATP_0004_fig_1.1.png',
#  'Cenozoic_Plate_Tectonics_Evolution_of_the_San_Andreas_Fault_0004_fig_1.1.png',
#  'Cenozoic_Plate_Tectonics_Ice_Ages_0005_fig_1.2.png',
#  'Centipedes_and_Millipedes_Centipedes_0004_fig_1.1.png',
#  'Central_Nervous_System_The_Brain_0004_fig_1.1.png',
#  'Central_Nervous_System_The_Brain_0005_fig_1.2.png',
#  'Changes_of_State_The_Role_of_Energy_in_Changes_of_State_0004_fig_1.1.png',
#  'Changes_of_State_The_Role_of_Energy_in_Changes_of_State_0004_fig_1.2.png',
#  'Characteristics_of_Life_Living_Things_Are_Made_of_Cells_0005_fig_1.2.png',
#  'Characteristics_of_Life_Living_Things_Are_Made_of_Cells_0005_fig_1.3.png',
#  'Characteristics_of_Life_Living_Things_Grow_and_Reproduce_0006_fig_1.4.png',
#  'Characteristics_of_Life_Living_Things_Maintain_Stable_Internal_Conditions_0006_fig_1.5.png',
#  'Characteristics_of_Life_Living_Things_Need_Resources_and_Energy_0004_fig_1.1.png',
#  'Charles_Law_References_0005_fig_1.1.png',
#  'Charless_Law_Review_0004_fig_1.1.png',
#  'Chemical_Bond_Summary_0005_fig_1.2.png',
#  'Chemical_Bond_Why_Bonds_Form_0004_fig_1.1.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.1.png',
#  'Chemical_Bonding_Chemical_Bonding_0004_fig_1.2.png',
#  'Chemical_Bonding_Chemical_Bonding_0005_fig_1.3.png',
#  'Chemical_Bonding_Chemical_Bonding_0005_fig_1.4.png',
#  'Chemical_Change_Identifying_Chemical_Changes_0004_fig_1.1.png',
#  'Chemical_Equations_Using_Chemical_Symbols_and_Formulas_0004_fig_1.1.png',
#  'Chemical_Reaction_Rate_Concentration_of_Reactants_0004_fig_1.2.png',
#  'Chemical_Reaction_Rate_Surface_Area_of_Reactants_0005_fig_1.3.png',
#  'Chemical_Reaction_Rate_Temperature_of_Reactants_0004_fig_1.1.png',
#  'Chemical_Reactions_Conservation_of_Energy_0004_fig_1.1.png',
#  'Chemical_Reactions_Lavoisier_and_Conservation_of_Mass_0004_fig_1.1.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Carbonic_Acid_0005_fig_1.3.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Oxygen_0005_fig_1.4.png',
#  'Chemical_Weathering_Chemical_Weathering_by_Water_0004_fig_1.2.png',
#  'Chemical_Weathering_Clay_0004_fig_1.1.png',
#  'Chemical_Weathering_Mechanical_and_Chemical_Weathering_0006_fig_1.5.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.1.png',
#  'Chemical_and_Solar_Cells_Solar_Cells_0004_fig_1.2.png',
#  'Chemistry_Photosynthesis_and_Cellular_Respiration_0004_fig_1.1.png',
#  'Chemistry_of_Compounds_Same_Elements_Different_Compounds_0004_fig_1.2.png',
#  'Chemistry_of_Compounds_Same_Elements_Different_Compounds_0005_fig_1.3.png',
#  'Chemistry_of_Compounds_What_Are_Compounds_0004_fig_1.1.png',
#  'Chemistry_of_Life_Chemical_Reactions_0005_fig_1.2.png',
#  'Chemistry_of_Life_The_Elements_0004_fig_1.1.png',
#  'Choosing_Healthy_Foods_Explore_More_0008_fig_1.4.png',
#  'Choosing_Healthy_Foods_MyPlate_0005_fig_1.2.png',
#  'Choosing_Healthy_Foods_MyPyramid_0004_fig_1.1.png',
#  'Choosing_Healthy_Foods_Using_Nutrition_Facts_Labels_0006_fig_1.3.png',
#  'Chordates_Characteristics_of_the_Chordates_0004_fig_1.1.png',
#  'Chordates_Classification_of_the_Chordates_0004_fig_1.2.png',
#  'Chromosomal_Disorders_Extra_Chromosomes_0004_fig_1.1.png',
#  'Chromosomal_Disorders_Extra_Chromosomes_0004_fig_1.2.png',
#  'Circulation_on_Climate_The_ITCZ_0004_fig_1.1.png',
#  'Circulation_on_Climate_The_ITCZ_0004_fig_1.2.png',
#  'Circulation_on_Climate_The_ITCZ_0005_fig_1.3.png',
#  'Classification_Introduction_to_Biochemical_Compounds_0004_fig_1.1.png',
#  'Classification_Types_of_Sedimentary_Rocks_0004_fig_1.1.png',
#  'Classification_Types_of_Sedimentary_Rocks_0004_fig_1.2.png',
#  'Cleaning_Up_Groundwater_Monitoring_the_Extent_of_the_Pollutant_0004_fig_1.1.png',
#  'Climate_Temperature_with_Latitude_0004_fig_1.1.png',
#  'Climate_Zones_and_Biomes_Major_Climate_Groups_0004_fig_1.1.png',
#  'Cloning_Cloning_0004_fig_1.1.png',
#  'Clouds_Fog_0006_fig_1.3.png',
#  'Clouds_Humidity_0004_fig_1.1.png',
#  'Clouds_Types_of_Clouds_0005_fig_1.2.png',
#  'Cnidarians_Cnidarian_Colonies_0004_fig_1.1.png',
#  'Coal_Power_Coal_0004_fig_1.1.png',
#  'Coal_Power_Consequences_of_Coal_Use_0005_fig_1.2.png',
#  'Coal_Power_Explore_More_0007_fig_1.4.png',
#  'Coal_Power_Summary_0006_fig_1.3.png',
#  'Coastal_Pollution_Ocean_Pollution_0004_fig_1.1.png',
#  'Coastal_Pollution_Review_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Radar_0005_fig_1.2.png',
#  'Collecting_Weather_Data_Satellites_0006_fig_1.3.png',
#  'Collecting_Weather_Data_Weather_Stations_0004_fig_1.1.png',
#  'Color_Colors_of_Objects_0004_fig_1.3.png',
#  'Color_Colors_of_Objects_0005_fig_1.4.png',
#  'Color_Review_0006_fig_1.6.png',
#  'Color_Separating_Colors_of_Light_0004_fig_1.1.png',
#  'Color_Separating_Colors_of_Light_0004_fig_1.2.png',
#  'Color_The_Colors_We_See_0005_fig_1.5.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0004_fig_1.1.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0004_fig_1.2.png',
#  'Combining_Forces_Forces_Acting_in_Opposite_Directions_0005_fig_1.3.png',
#  'Combining_Forces_Forces_Acting_in_the_Same_Direction_0005_fig_1.4.png',
#  'Combining_Forces_Review_0006_fig_1.5.png',
#  'Combustion_Reactions_Combustion_of_Hydrocarbons_0004_fig_1.2.png',
#  'Combustion_Reactions_What_Is_A_Combustion_Reaction_0004_fig_1.1.png',
#  'Comets_Comets_0004_fig_1.1.png',
#  'Communication_in_Science_How_Scientists_Communicate_0004_fig_1.1.png',
#  'Competition_Competition_0004_fig_1.1.png',
#  'Components_of_Blood_Components_of_Blood_0004_fig_1.1.png',
#  'Components_of_Blood_Red_Blood_Cells_0004_fig_1.2.png',
#  'Components_of_Blood_Summary_0006_fig_1.4.png',
#  'Components_of_Blood_White_Blood_Cells_0005_fig_1.3.png',
#  'Compound_Machine_Corkscrew_0004_fig_1.1.png',
#  'Compound_Machine_Corkscrew_0004_fig_1.2.png',
#  'Compound_Machine_Review_0005_fig_1.3.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.2.png',
#  'Compounds_Structure_of_Compounds_0005_fig_1.3.png',
#  'Compounds_What_Is_a_Compound_0004_fig_1.1.png',
#  'Condensation_Dew_Point_0004_fig_1.1.png',
#  'Condensation_Dew_Point_0004_fig_1.2.png',
#  'Condensation_Summary_0005_fig_1.3.png',
#  'Conservation_Conserving_Natural_Resources_0004_fig_1.1.png',
#  'Conservation_of_Mass_Law_of_Conservation_of_Mass_0004_fig_1.1.png',
#  'Conserving_Water_How_You_Can_Conserve_Water_0004_fig_1.1.png',
#  'Continental_Drift_Hypothesis_Mantle_Convection_0005_fig_1.3.png',
#  'Continental_Drift_Hypothesis_The_Problem_with_the_Hypothesis_0004_fig_1.1.png',
#  'Continental_Drift_Hypothesis_The_Problem_with_the_Hypothesis_0004_fig_1.2.png',
#  'Continental_Drift_Wegeners_Evidence_0004_fig_1.1.png',
#  'Continental_Drift_Wegeners_Evidence_0005_fig_1.2.png',
#  'Control_of_Insects_Biological_Control_0004_fig_1.1.png',
#  'Convection_Examples_of_Convection_0005_fig_1.2.png',
#  'Convection_How_Does_Convection_Occur_0004_fig_1.1.png',
#  'Convection_References_0006_fig_1.3.png',
#  'Convergent_Plate_Boundaries_Cascades_Volcanoes_0005_fig_1.2.png',
#  'Convergent_Plate_Boundaries_ContinentContinent_Convergence_0004_fig_1.1.png',
#  'Convergent_Plate_Boundaries_Intrusions_at_a_Convergent_Boundary_0006_fig_1.3.png',
#  'Convergent_Plate_Boundaries_OceanContinent_Convergence_0004_fig_1.1.png',
#  'Cooling_Systems_The_Refrigerant_0004_fig_1.1.png',
#  'Coriolis_Effect_Coriolis_Effect_0004_fig_1.1.png',
#  'Corrective_Lenses_Farsightedness_0004_fig_1.2.png',
#  'Corrective_Lenses_Nearsightedness_0004_fig_1.1.png',
#  'Correlation_and_Causation_Causation_0004_fig_1.1.png',
#  'Covalent_Bonding_Covalent_Compounds_and_Diatomic_Elements_0004_fig_1.1.png',
#  'Covalent_Bonding_Covalent_Compounds_and_Diatomic_Elements_0004_fig_1.2.png',
#  'Crustaceans_Can_Crustaceans_Move_0005_fig_1.2.png',
#  'Crustaceans_Classes_of_Crustaceans_0005_fig_1.1.png',
#  'Crystalline_Carbon_Diamond_0004_fig_1.1.png',
#  'Crystalline_Carbon_Diamond_0005_fig_1.2.png',
#  'Crystalline_Carbon_Fullerene_0006_fig_1.4.png',
#  'Crystalline_Carbon_Graphite_0005_fig_1.3.png',
#  'Cycle_Human_Uses_0006_fig_1.3.png',
#  'Cycle_Human_Uses_0006_fig_1.4.png',
#  'Cycle_Oceans_0004_fig_1.1.png',
#  'Cycle_Plant_Reproduction_and_Life_Cycle_0004_fig_1.1.png',
#  'Cycle_Soil_0005_fig_1.2.png',
#  'Cyclic_Behavior_of_Animals_Daily_Cycles_0005_fig_1.2.png',
#  'Cyclic_Behavior_of_Animals_Yearly_Cycles_0004_fig_1.1.png',
#  'DNA_the_Genetic_Material_BasePairing_0005_fig_1.2.png',
#  'DNA_the_Genetic_Material_The_Genetic_Code_0004_fig_1.1.png',
#  'Daltons_Atomic_Theory_Daltons_Experiments_0004_fig_1.1.png',
#  'Daltons_Atomic_Theory_The_Billiard_Ball_Model_0005_fig_1.2.png',
#  'Dark_Matter_Dark_Energy_0005_fig_1.2.png',
#  'Dark_Matter_Dark_Matter_0004_fig_1.1.png',
#  'Dating_Focus_on_Carbon14_Dating_0005_fig_1.2.png',
#  'Dating_More_Principles_of_Relative_Dating_0005_fig_1.2.png',
#  'Dating_Radioisotopes_and_Radioactive_Decay_0004_fig_1.1.png',
#  'Dating_Stenos_Laws_0004_fig_1.1.png',
#  'Dating_Summary_0006_fig_1.3.png',
#  'Decomposers_Consumers_and_Decomposers_0004_fig_1.1.png',
#  'Decomposers_Decomposers_and_Stability_0004_fig_1.2.png',
#  'Decomposition_Reactions_Other_Examples_of_Decomposition_Reactions_0004_fig_1.1.png',
#  'Deep_Ocean_Currents_Downwelling_0004_fig_1.1.png',
#  'Deep_Ocean_Currents_Upwelling_0005_fig_1.2.png',
#  'Density_Defining_Density_0004_fig_1.1.png',
#  'Deposition_Examples_of_Deposition_in_Nature_0004_fig_1.1.png',
#  'Deposition_Examples_of_Deposition_in_Nature_0004_fig_1.2.png',
#  'Deposition_Review_0005_fig_1.3.png',
#  'Destruction_The_Montreal_Protocol_0004_fig_1.1.png',
#  'Determining_Relative_Ages_Determining_the_Relative_Ages_of_Rocks_0004_fig_1.1.png',
#  'Development_of_Theories_Explore_More_0005_fig_1.1.png',
#  'Devices_Measuring_Mass_with_a_Balance_0004_fig_1.1.png',
#  'Devices_Measuring_Mass_with_a_Balance_0005_fig_1.2.png',
#  'Devices_Measuring_Mass_with_a_Balance_0005_fig_1.3.png',
#  'Diabetes_Type_1_Diabetes_0004_fig_1.1.png',
#  'Diffusion_Applications_of_Osmosis_0005_fig_1.2.png',
#  'Diffusion_Diffusion_0004_fig_1.1.png',
#  'Digestive_System_Organs_Mouth_Esophagus_and_Stomach_0005_fig_1.2.png',
#  'Digestive_System_Organs_Organs_of_the_Digestive_System_0004_fig_1.1.png',
#  'Digestive_System_Organs_Small_Intestine_0006_fig_1.3.png',
#  'Direction_Why_Direction_Is_Important_0004_fig_1.1.png',
#  'Discharge_How_Lightning_Occurs_0004_fig_1.1.png',
#  'Diseases_Avoiding_Pathogens_0004_fig_1.1.png',
#  'Diseases_Causes_of_Respiratory_Diseases_0007_fig_1.5.png',
#  'Diseases_Causes_of_Respiratory_Diseases_0007_fig_1.6.png',
#  'Diseases_Diseases_of_the_Respiratory_System_0004_fig_1.1.png',
#  'Diseases_Lung_Cancer_0006_fig_1.4.png',
#  'Diseases_Pneumonia_0005_fig_1.2.png',
#  'Diseases_Preventing_Noninfectious_Diseases_0004_fig_1.1.png',
#  'Diseases_Tuberculosis_0005_fig_1.3.png',
#  'Distance_Between_Stars_Parallax_0004_fig_1.1.png',
#  'Distance_Using_Maps_to_Measure_Distance_0004_fig_1.1.png',
#  'Divergent_Plate_Boundaries_Plate_Divergence_on_Land_0004_fig_1.1.png',
#  'Divergent_Plate_Boundaries_References_0006_fig_1.3.png',
#  'Divergent_Plate_Boundaries_References_0007_fig_1.4.png',
#  'Divergent_Plate_Boundaries_Summary_0005_fig_1.2.png',
#  'Diversity_of_Birds_Beaks_0004_fig_1.1.png',
#  'Diversity_of_Birds_Feet_0005_fig_1.2.png',
#  'Domains_of_Life_Archaea_and_Bacteria_0004_fig_1.1.png',
#  'Domains_of_Life_Eukarya_0005_fig_1.2.png',
#  'Doppler_Effect_Experiencing_the_Doppler_Effect_0004_fig_1.1.png',
#  'Dwarf_Planets_Ceres_0005_fig_1.2.png',
#  'Dwarf_Planets_Makemake_0006_fig_1.3.png',
#  'Dwarf_Planets_Pluto_0004_fig_1.1.png',
#  'Earth_Distribution_of_Water_0004_fig_1.1.png',
#  'Earth_History_Supercontinent_Cycle_0004_fig_1.1.png',
#  'Earth_History_Supercontinent_Cycle_0005_fig_1.2.png',
#  'Earth_Science_Field_Work_California_0004_fig_1.1.png',
#  'Earth_Science_Field_Work_Glacier_National_Park_0007_fig_1.5.png',
#  'Earth_Science_Field_Work_Glacier_National_Park_0007_fig_1.6.png',
#  'Earth_Science_Field_Work_Grand_Canyon_0009_fig_1.10.png',
#  'Earth_Science_Field_Work_Hawaiian_Islands_0010_fig_1.11.png',
#  'Earth_Science_Field_Work_Idaho_Montana_Wyoming_0006_fig_1.4.png',
#  'Earth_Science_Field_Work_Pacific_Northwest_0005_fig_1.2.png',
#  'Earth_Science_Field_Work_Pacific_Northwest_0006_fig_1.3.png',
#  'Earth_Science_Field_Work_Southwest_0009_fig_1.9.png',
#  'Earth_Science_Field_Work_Yellowstone_National_Park_0008_fig_1.7.png',
#  'Earth_Science_Field_Work_Yellowstone_National_Park_0008_fig_1.8.png',
#  'Earth_as_a_Magnet_Earths_Magnetic_Field_0005_fig_1.3.png',
#  'Earth_as_a_Magnet_Two_North_Poles_0004_fig_1.1.png',
#  'Earth_as_a_Magnet_Two_North_Poles_0004_fig_1.2.png',
#  'Earthquake_Characteristics_Elastic_Rebound_Theory_0004_fig_1.1.png',
#  'Earthquake_Characteristics_Focus_and_Epicenter_0004_fig_1.2.png',
#  'Earthquake_Damage_City_Planning_0005_fig_1.3.png',
#  'Earthquake_Damage_What_Makes_an_Earthquake_Deadly_0004_fig_1.1.png',
#  'Earthquake_Damage_What_Makes_an_Earthquake_Deadly_0004_fig_1.2.png',
#  'Earthquake_Safe_Structures_Cost_Considerations_0005_fig_1.3.png',
#  'Earthquake_Safe_Structures_New_Construction_0004_fig_1.1.png',
#  'Earthquake_Safe_Structures_Retrofitting_0004_fig_1.2.png',
#  'Earthquake_Zones_Annual_Earthquakes_0004_fig_1.1.png',
#  'Earthquake_Zones_Earthquake_Zones_0004_fig_1.2.png',
#  'Earths_Core_Core_0004_fig_1.1.png',
#  'Earths_Crust_Continental_Crust_0005_fig_1.2.png',
#  'Earths_Crust_Oceanic_Crust_0004_fig_1.1.png',
#  'Earths_Crust_Review_0006_fig_1.3.png',
#  'Earths_Interior_Material_Other_Clues_About_Earths_Interior_0004_fig_1.1.png',
#  'Earths_Layers_Layers_by_Mechanical_Properties_0004_fig_1.1.png',
#  'Earths_Magnetic_Field_Magnetic_Reversals_0004_fig_1.1.png',
#  'Earths_Mantle_Heat_Flow_0004_fig_1.1.png',
#  'Earths_Mantle_Heat_Flow_0004_fig_1.2.png',
#  'Earths_Shape_Summary_0004_fig_1.1.png',
#  'Earths_Tectonic_Plates_How_Plates_Move_0005_fig_1.2.png',
#  'Earths_Tectonic_Plates_Summary_0006_fig_1.3.png',
#  'Earths_Tectonic_Plates_What_is_a_Plate_0004_fig_1.1.png',
#  'Echinoderms_Characteristics_of_Echinoderms_0004_fig_1.1.png',
#  'Echinoderms_Characteristics_of_Echinoderms_0004_fig_1.2.png',
#  'Eclipses_Lunar_Eclipse_0005_fig_1.3.png',
#  'Eclipses_Lunar_Eclipse_0005_fig_1.4.png',
#  'Eclipses_Solar_Eclipses_0004_fig_1.1.png',
#  'Eclipses_Solar_Eclipses_0004_fig_1.2.png',
#  'Eclipses_Summary_0006_fig_1.5.png',
#  'Ecosystems_Food_Chains_0005_fig_1.2.png',
#  'Ecosystems_Food_Chains_0005_fig_1.3.png',
#  'Ecosystems_Food_Webs_0006_fig_1.4.png',
#  'Ecosystems_Food_Webs_0006_fig_1.5.png',
#  'Ecosystems_Nitrogen_Fixing_0004_fig_1.1.png',
#  'Ecosystems_Nitrogen_Fixing_0004_fig_1.2.png',
#  'Ecosystems_Nutrients_0004_fig_1.1.png',
#  'Ecosystems_Trophic_Levels_0004_fig_1.1.png',
#  'Ecosystems_What_is_an_Ecosystem_0004_fig_1.1.png',
#  'Effects_of_Water_Pollution_Aquatic_Debris_0005_fig_1.2.png',
#  'Effects_of_Water_Pollution_Eutrophication_0004_fig_1.1.png',
#  'Efficiency_Machine_Efficiency_0004_fig_1.1.png',
#  'Effusive_Eruptions_Effusive_Eruptions_0004_fig_1.1.png',
#  'Effusive_Eruptions_Effusive_Eruptions_Damage_0005_fig_1.3.png',
#  'Effusive_Eruptions_Types_of_Lava_0004_fig_1.2.png',
#  'Elastic_Force_Using_Elastic_Force_0004_fig_1.1.png',
#  'Elastic_Force_Using_Elastic_Force_0005_fig_1.2.png',
#  'Electric_Circuits_Circuit_Diagrams_0004_fig_1.2.png',
#  'Electric_Circuits_Parts_of_an_Electric_Circuit_0004_fig_1.1.png',
#  'Electric_Current_Voltage_0004_fig_1.1.png',
#  'Electric_Fields_Interacting_Electric_Fields_0004_fig_1.1.png',
#  'Electric_Fields_Interacting_Electric_Fields_0004_fig_1.2.png',
#  'Electric_Generators_From_Kinetic_to_Electrical_Energy_0004_fig_1.1.png',
#  'Electric_Generators_From_Kinetic_to_Electrical_Energy_0004_fig_1.2.png',
#  'Electric_Resistance_References_0005_fig_1.1.png',
#  'Electric_Safety_Electric_Safety_Features_0004_fig_1.2.png',
#  'Electric_Safety_How_a_Short_Circuit_Occurs_0004_fig_1.1.png',
#  'Electric_Transformers_Stepping_Up_or_Stepping_Down_0004_fig_1.2.png',
#  'Electric_Transformers_Stepping_Up_or_Stepping_Down_0005_fig_1.3.png',
#  'Electric_Transformers_What_Is_an_Electric_Transformer_0004_fig_1.1.png',
#  'Electrical_Grid_Electric_Substations_0004_fig_1.2.png',
#  'Electrical_Grid_Transmission_Lines_0004_fig_1.1.png',
#  'Electromagnet_Easy_OnOff_0004_fig_1.1.png',
#  'Electromagnetic_Devices_How_a_Doorbell_Works_0004_fig_1.1.png',
#  'Electromagnetic_Devices_Summary_0005_fig_1.2.png',
#  'Electromagnetic_Induction_The_Current_Produced_by_a_Magnet_0004_fig_1.1.png',
#  'Electromagnetic_Induction_The_Current_Produced_by_a_Magnet_0004_fig_1.2.png',
#  'Electromagnetic_Spectrum_A_Spectrum_of_Electromagnetic_Waves_0004_fig_1.1.png',
#  'Electromagnetic_Waves_How_an_Electromagnetic_Wave_Begins_0005_fig_1.2.png',
#  'Electromagnetic_Waves_How_an_Electromagnetic_Wave_Begins_0005_fig_1.3.png',
#  'Electromagnetic_Waves_May_the_Force_Be_With_You_0004_fig_1.1.png',
#  'Electromagnetic_Waves_Wavelength_and_Frequency_of_Electromagnetic_Waves_0004_fig_1.1.png',
#  'Electromagnetism_Electricity_and_Magnetism_0004_fig_1.1.png',
#  'Electromagnetism_Right_Hand_Rule_0004_fig_1.1.png',
#  'Electromagnetism_Summary_0005_fig_1.2.png',
#  'Electronic_Component_Diode_0004_fig_1.2.png',
#  'Electronic_Component_Integrated_Circuit_0005_fig_1.4.png',
#  'Electronic_Component_Semiconductors_0004_fig_1.1.png',
#  'Electronic_Component_Transistor_0005_fig_1.3.png',
#  'Electronic_Device_Focus_on_the_Computer_0004_fig_1.1.png',
#  'Electronic_Signal_Digital_Signals_0004_fig_1.1.png',
#  'Electronic_Signal_Digital_Signals_0004_fig_1.2.png',
#  'Electrons_Orbitals_0005_fig_1.2.png',
#  'Electrons_Whats_Your_Energy_Level_0006_fig_1.3.png',
#  'Electrons_Where_Are_Electrons_0004_fig_1.1.png',
#  'Elements_Elemental_Properties_0004_fig_1.1.png',
#  'Elements_History_of_Elements_0005_fig_1.2.png',
#  'Elements_Particles_of_Elements_0005_fig_1.3.png',
#  'Endothermic_Reactions_Energy_Change_in_Endothermic_Reactions_0004_fig_1.1.png',
#  'Endothermic_Reactions_Summary_0005_fig_1.2.png',
#  'Energy_Conservation_Conserving_Energy_at_Home_0004_fig_1.2.png',
#  'Energy_Conservation_Conserving_Energy_at_Home_0005_fig_1.3.png',
#  'Energy_Conservation_Conserving_Energy_in_Transportation_0004_fig_1.1.png',
#  'Energy_Conservation_Energy_Conservation_0005_fig_1.1.png',
#  'Energy_Conversion_How_Energy_Changes_Form_0004_fig_1.1.png',
#  'Energy_Conversion_KineticPotential_Energy_Changes_0005_fig_1.2.png',
#  'Energy_Level_Energy_Levels_and_Orbitals_0004_fig_1.2.png',
#  'Energy_Level_The_Outermost_Level_0005_fig_1.3.png',
#  'Evolution_Explore_More_0005_fig_1.2.png',
#  'Evolution_Molecular_Evidence_0004_fig_1.1.png',
#  'Evolution_Vestigial_Structures_0004_fig_1.1.png',
#  'Evolution_of_Simple_Cells_Cyanobacteria_0006_fig_1.4.png',
#  'Evolution_of_Simple_Cells_Cyanobacteria_0007_fig_1.5.png',
#  'Evolution_of_Simple_Cells_Photosynthesis_0005_fig_1.2.png',
#  'Evolution_of_Simple_Cells_Photosynthesis_0005_fig_1.3.png',
#  'Evolution_of_Simple_Cells_Simple_Cells_Evolve_0004_fig_1.1.png',
#  'Exoplanets_Extrasolar_Planets_or_Exoplanets_0004_fig_1.1.png',
#  'Exothermic_Reactions_Energy_Change_in_Exothermic_Reactions_0004_fig_1.1.png',
#  'Exothermic_Reactions_Review_0005_fig_1.2.png',
#  'Expansion_of_the_Universe_Redshift_0004_fig_1.1.png',
#  'Expansion_of_the_Universe_The_Expanding_Universe_0005_fig_1.2.png',
#  'Experiments_Observations_0004_fig_1.1.png',
#  'Experiments_Observations_0004_fig_1.2.png',
#  'Explosive_Eruptions_Cascades_Volcanoes_0005_fig_1.4.png',
#  'Explosive_Eruptions_Causes_of_the_Explosion_0004_fig_1.1.png',
#  'Explosive_Eruptions_Pyroclastic_Material_0004_fig_1.2.png',
#  'Explosive_Eruptions_Pyroclastic_Material_0005_fig_1.3.png',
#  'Explosive_Eruptions_Volcanic_Gases_0006_fig_1.5.png',
#  'Expression_Cells_Can_Turn_Genes_On_or_Off_0004_fig_1.1.png',
#  'Extinction_Pollution_0004_fig_1.1.png',
#  'Extinction_Summary_0005_fig_1.2.png',
#  'Faults_DipSlip_Faults_0005_fig_1.3.png',
#  'Faults_DipSlip_Faults_0005_fig_1.4.png',
#  'Faults_Faults_0004_fig_1.2.png',
#  'Faults_Joints_0004_fig_1.1.png',
#  'Faults_StrikeSlip_Faults_0006_fig_1.5.png',
#  'Features_of_Populations_What_is_a_Population_0004_fig_1.1.png',
#  'Features_of_Populations_What_is_a_Population_0004_fig_1.2.png',
#  'Fermentation_Fermentation_0004_fig_1.1.png',
#  'Ferromagnetic_Material_Magnetite_0006_fig_1.4.png',
#  'Ferromagnetic_Material_Temporary_and_Permanent_Magnets_0005_fig_1.2.png',
#  'Ferromagnetic_Material_Temporary_and_Permanent_Magnets_0005_fig_1.3.png',
#  'Ferromagnetic_Material_What_Makes_a_Material_Magnetic_0004_fig_1.1.png',
#  'Fertilization_Fertilization_and_Implantation_0004_fig_1.1.png',
#  'Field_Finding_the_Way_0004_fig_1.2.png',
#  'Field_Like_an_Umbrella_0004_fig_1.1.png',
#  'Fields_in_the_Life_Sciences_Evolution_of_Living_Organisms_0005_fig_1.1.png',
#  'Fields_in_the_Life_Sciences_Evolution_of_Living_Organisms_0005_fig_1.2.png',
#  'Finding_and_Mining_Ores_Finding_and_Mining_Minerals_0004_fig_1.1.png',
#  'Finding_and_Mining_Ores_Summary_0006_fig_1.4.png',
#  'Finding_and_Mining_Ores_Summary_0006_fig_1.5.png',
#  'Finding_and_Mining_Ores_Surface_Mining_0004_fig_1.2.png',
#  'Finding_and_Mining_Ores_Underground_Mining_0005_fig_1.3.png',
#  'Fish_Characteristics_of_Fish_0004_fig_1.1.png',
#  'Fish_How_Big_Are_Fish_0005_fig_1.3.png',
#  'Fish_How_do_Fish_Breathe_0004_fig_1.2.png',
#  'Fish_Summary_0006_fig_1.4.png',
#  'Fish_Summary_0006_fig_1.5.png',
#  'Flatworms_Explore_More_0005_fig_1.2.png',
#  'Flatworms_Features_of_Flatworms_0004_fig_1.1.png',
#  'Flooding_Causes_of_Floods_0004_fig_1.1.png',
#  'Flooding_Causes_of_Floods_0004_fig_1.2.png',
#  'Flooding_Effects_of_Floods_0006_fig_1.4.png',
#  'Flooding_Flash_Floods_0005_fig_1.3.png',
#  'Folds_Monocline_0004_fig_1.1.png',
#  'Folds_Syncline_0005_fig_1.2.png',
#  'Folds_Syncline_0005_fig_1.3.png',
#  'Folds_Syncline_0006_fig_1.4.png',
#  'Folds_Syncline_0006_fig_1.5.png',
#  'Food_Webs_Food_Webs_0004_fig_1.1.png',
#  'Food_Webs_Summary_0005_fig_1.2.png',
#  'Food_and_Nutrients_Why_We_Need_Food_0004_fig_1.1.png',
#  'Force_Electric_Force_0004_fig_1.1.png',
#  'Force_Electric_Force_0004_fig_1.2.png',
#  'Force_Force_and_Motion_0004_fig_1.1.png',
#  'Force_Force_as_a_Vector_0005_fig_1.2.png',
#  'Formation_of_Earth_Differentiation_0004_fig_1.1.png',
#  'Formation_of_Earth_Early_Solar_System_Materials_0005_fig_1.2.png',
#  'Formation_of_the_Moon_Moons_Birth_Story_0004_fig_1.1.png',
#  'Forms_of_Energy_Resources_0007_fig_1.5.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0004_fig_1.1.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0004_fig_1.2.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0005_fig_1.3.png',
#  'Forms_of_Energy_Seven_Forms_of_Energy_0005_fig_1.4.png',
#  'Fossil_Fuel_Formation_Formation_of_Fossil_Fuels_0004_fig_1.1.png',
#  'Fossil_Fuel_Formation_Formation_of_Fossil_Fuels_0004_fig_1.2.png',
#  'Fossil_Fuel_Reserves_Alternative_Fossil_Fuels_0004_fig_1.1.png',
#  'Fossil_Fuel_Reserves_Alternative_Fossil_Fuels_0004_fig_1.2.png',
#  'Fossils_Conditions_That_Create_Fossils_0006_fig_1.4.png',
#  'Fossils_Exceptional_Preservation_0008_fig_1.8.png',
#  'Fossils_Fossilization_is_Rare_0005_fig_1.2.png',
#  'Fossils_Fossilization_is_Rare_0005_fig_1.3.png',
#  'Fossils_Fossils_Were_Parts_of_Living_Organisms_0004_fig_1.1.png',
#  'Fossils_Quick_Burial_0006_fig_1.5.png',
#  'Fossils_Quick_Burial_0007_fig_1.6.png',
#  'Fossils_Rock_Layers_and_the_Age_of_Fossils_0004_fig_1.1.png',
#  'Fossils_Rock_Layers_and_the_Age_of_Fossils_0005_fig_1.2.png',
#  'Fossils_Rock_Layers_and_the_Age_of_Fossils_0005_fig_1.3.png',
#  'Fossils_Unusual_Circumstances_0007_fig_1.7.png',
#  'Freezing_Freezing_Point_0004_fig_1.1.png',
#  'Fresh_Water_Ecosystems_Ecological_Role_of_Wetlands_0006_fig_1.3.png',
#  'Fresh_Water_Ecosystems_Lake_Ecosystems_0004_fig_1.1.png',
#  'Fresh_Water_Ecosystems_Marshes_0005_fig_1.2.png',
#  'Friction_Factors_That_Affect_Friction_0005_fig_1.3.png',
#  'Friction_Factors_That_Affect_Friction_0005_fig_1.4.png',
#  'Friction_Summary_0006_fig_1.5.png',
#  'Friction_Why_Friction_Occurs_0004_fig_1.1.png',
#  'Friction_Why_Friction_Occurs_0004_fig_1.2.png',
#  'Frogs_and_Toads_Characteristics_of_Frogs_0004_fig_1.1.png',
#  'Frogs_and_Toads_How_Do_Frogs_Eat_0005_fig_1.2.png',
#  'Fundamental_Particles_Leptons_and_Quarks_and_Bosons_Oh_My_0006_fig_1.1.png',
#  'Fungi_Fungi_and_Insects_0005_fig_1.2.png',
#  'Fungi_Fungi_and_Plants_0004_fig_1.1.png',
#  'Fungi_Fungi_are_Good_Eaters_0005_fig_1.2.png',
#  'Fungi_Reproduction_Asexual_Reproduction_0004_fig_1.1.png',
#  'Fungi_Reproduction_Sexual_Reproduction_0004_fig_1.2.png',
#  'Fungi_Structure_Body_Parts_of_Fungi_0004_fig_1.1.png',
#  'Fungi_Structure_Body_Parts_of_Fungi_0004_fig_1.2.png',
#  'Fungi_What_are_Fungi_0004_fig_1.1.png',
#  'Funguslike_Protists_Slime_Molds_0004_fig_1.1.png',
#  'Galaxies_Elliptical_Galaxies_0005_fig_1.3.png',
#  'Galaxies_Elliptical_Galaxies_0005_fig_1.4.png',
#  'Galaxies_Irregular_Galaxies_0006_fig_1.5.png',
#  'Galaxies_Spiral_Galaxies_0004_fig_1.1.png',
#  'Galaxies_Spiral_Galaxies_0004_fig_1.2.png',
#  'Gamma_Decay_Gamma_Rays_and_Radioactive_Decay_0004_fig_1.1.png',
#  'Gamma_Rays_Sources_of_Gamma_Rays_0004_fig_1.1.png',
#  'Gases_Explore_More_0006_fig_1.4.png',
#  'Gases_Pressure_in_the_Atmosphere_0005_fig_1.3.png',
#  'Gases_Pressure_of_Gases_0004_fig_1.1.png',
#  'Gases_Pressure_of_Gases_0004_fig_1.2.png',
#  'Gene_Therapy_In_Vivo_Gene_Therapy_0004_fig_1.1.png',
#  'Genetics_The_Law_of_Segregation_0004_fig_1.1.png',
#  'Geologic_Time_Scale_The_Geologic_Time_Scale_0004_fig_1.1.png',
#  'Geological_Stresses_Causes_and_Types_of_Stress_0004_fig_1.1.png',
#  'Geological_Stresses_Causes_and_Types_of_Stress_0004_fig_1.2.png',
#  'Geological_Stresses_Responses_to_Stress_0005_fig_1.3.png',
#  'Geothermal_Power_Geothermal_Energy_0004_fig_1.1.png',
#  'Glaciers_Glacier_National_Park_0005_fig_1.3.png',
#  'Glaciers_Movement_0005_fig_1.2.png',
#  'Glaciers_Types_of_Glaciers_0004_fig_1.1.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0004_fig_1.2.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0005_fig_1.3.png',
#  'Global_Warming_Changes_Due_to_Warming_Temperatures_0005_fig_1.4.png',
#  'Global_Warming_Increasing_Temperatures_0004_fig_1.1.png',
#  'Global_Wind_Belts_Jet_Stream_0005_fig_1.2.png',
#  'Global_Wind_Belts_The_Global_Winds_0004_fig_1.1.png',
#  'Gravity_Gravity_and_Weight_0004_fig_1.1.png',
#  'Gravity_Visualizing_Einsteins_Ideas_0004_fig_1.1.png',
#  'Gravity_in_the_Solar_System_The_Role_of_Gravity_0004_fig_1.1.png',
#  'Greenhouse_Effect_Greenhouse_Gases_0004_fig_1.1.png',
#  'Groundwater_Aquifers_Features_of_an_Aquifer_0004_fig_1.1.png',
#  'Groundwater_Aquifers_Wells_0005_fig_1.2.png',
#  'Groundwater_Aquifers_Wells_0005_fig_1.3.png',
#  'Groundwater_Aquifers_Wells_0006_fig_1.4.png',
#  'Groundwater_Depletion_Ogallala_Aquifer_0004_fig_1.1.png',
#  'Groundwater_Depletion_Review_0006_fig_1.4.png',
#  'Groundwater_Depletion_Summary_0005_fig_1.2.png',
#  'Groundwater_Depletion_Summary_0005_fig_1.3.png',
#  'Groundwater_Erosion_and_Deposition_Groundwater_Deposition_0005_fig_1.3.png',
#  'Groundwater_Erosion_and_Deposition_Groundwater_Deposition_0005_fig_1.4.png',
#  'Groundwater_Erosion_and_Deposition_Sinkholes_0004_fig_1.1.png',
#  'Groundwater_Erosion_and_Deposition_Sinkholes_0004_fig_1.2.png',
#  'Groundwater_Fossil_Water_0004_fig_1.1.png',
#  'Groundwater_Pollution_Filtered_Water_0004_fig_1.1.png',
#  'Groups_with_Metalloids_Group_15_Nitrogen_Group_0005_fig_1.2.png',
#  'Groups_with_Metalloids_Group_15_Nitrogen_Group_0005_fig_1.3.png',
#  'Groups_with_Metalloids_Group_16_Oxygen_Group_0006_fig_1.4.png',
#  'Groups_with_Metalloids_Group_16_Oxygen_Group_0006_fig_1.5.png',
#  'Groups_with_Metalloids_What_Are_Metalloids_0004_fig_1.1.png',
#  'Gymnosperms_Conifers_0004_fig_1.1.png',
#  'Gymnosperms_Cycads_0005_fig_1.2.png',
#  'Gymnosperms_Cycads_0005_fig_1.3.png',
#  'Gymnosperms_Ginkgoes_0006_fig_1.4.png',
#  'Gymnosperms_Gnetophytes_0006_fig_1.5.png',
#  'HIV_and_AIDS_HIV_and_the_Immune_System_0004_fig_1.1.png',
#  'Habitat_Destruction_Examples_of_Habitat_Destruction_0006_fig_1.4.png',
#  'Habitat_Destruction_Examples_of_Habitat_Destruction_0006_fig_1.5.png',
#  'Habitat_Destruction_Explore_More_0007_fig_1.6.png',
#  'Habitat_Destruction_Land_Loss_0004_fig_1.1.png',
#  'Habitat_Destruction_Land_Loss_0004_fig_1.2.png',
#  'Habitat_Destruction_SlashandBurn_Agriculture_0005_fig_1.3.png',
#  'Habitat_and_Niche_Explore_More_0006_fig_1.4.png',
#  'Habitat_and_Niche_Habitat_0005_fig_1.2.png',
#  'Habitat_and_Niche_Habitat_0005_fig_1.3.png',
#  'Habitat_and_Niche_Niche_0004_fig_1.1.png',
#  'Halogens_Chemical_Properties_of_Halogens_0004_fig_1.1.png',
#  'Halogens_Physical_Properties_of_Halogens_0005_fig_1.2.png',
#  'Halogens_Review_0006_fig_1.3.png',
#  'Harmful_Bacteria_Diseases_0004_fig_1.1.png',
#  'Health_Keeping_Your_Cardiovascular_System_Healthy_0004_fig_1.1.png',
#  'Health_What_is_bad_cholesterol_0005_fig_1.2.png',
#  'Healthy_Bone_Fractures_0005_fig_1.2.png',
#  'Healthy_Eating_Well_0004_fig_1.1.png',
#  'Hearing_Loss_Loud_Sounds_0004_fig_1.1.png',
#  'Hearing_Loss_Summary_0005_fig_1.2.png',
#  'Hearing_Loss_Summary_0005_fig_1.3.png',
#  'Hearing_and_Balance_Balance_0005_fig_1.3.png',
#  'Hearing_and_Balance_Explore_More_0006_fig_1.4.png',
#  'Hearing_and_Balance_Hearing_0004_fig_1.1.png',
#  'Hearing_and_Balance_Hearing_0004_fig_1.2.png',
#  'Hearing_and_the_Ear_Outer_Ear_0004_fig_1.1.png',
#  'Hearing_and_the_Ear_Summary_0005_fig_1.2.png',
#  'Heart_Summary_0005_fig_1.2.png',
#  'Heart_The_Heart_0004_fig_1.1.png',
#  'Heat_Conduction_Examples_of_Conduction_0004_fig_1.1.png',
#  'Heat_Cooling_Down_by_Heating_Up_0004_fig_1.1.png',
#  'Heat_Cooling_Down_by_Heating_Up_0004_fig_1.2.png',
#  'Heat_Waves_and_Droughts_Causes_0004_fig_1.1.png',
#  'Heating_Systems_HotWater_Heating_System_0004_fig_1.1.png',
#  'Heating_Systems_How_a_Thermostat_Works_0005_fig_1.2.png',
#  'Heating_Systems_How_a_Thermostat_Works_0005_fig_1.3.png',
#  'Helpful_Bacteria_Foods_0004_fig_1.1.png',
#  'History_Climate_Change_in_Earth_History_0004_fig_1.1.png',
#  'History_Climate_Change_in_Earth_History_0005_fig_1.2.png',
#  'History_of_Cenozoic_Life_Pleistocene_Megafauna_0004_fig_1.1.png',
#  'History_of_Mesozoic_Life_Dinosaurs_0004_fig_1.1.png',
#  'History_of_Mesozoic_Life_Summary_0005_fig_1.2.png',
#  'History_of_Mesozoic_Life_Summary_0005_fig_1.3.png',
#  'History_of_Mesozoic_Life_Summary_0006_fig_1.4.png',
#  'History_of_Mesozoic_Life_Summary_0006_fig_1.5.png',
#  'History_of_Paleozoic_Life_Paleozoic_Evolution_0004_fig_1.1.png',
#  'History_of_Paleozoic_Life_Paleozoic_Evolution_0004_fig_1.2.png',
#  'History_of_Science_In_the_Beginning_0004_fig_1.1.png',
#  'History_of_Science_Modern_Western_Science_Emerges_0005_fig_1.2.png',
#  'Homeostasis_Maintaining_Homeostasis_0004_fig_1.1.png',
#  'Hot_Springs_and_Geysers_Geysers_0005_fig_1.2.png',
#  'Hot_Springs_and_Geysers_Hot_Springs_0004_fig_1.1.png',
#  'How_the_Eye_Works_How_the_Eye_Works_0004_fig_1.1.png',
#  'How_the_Eye_Works_How_the_Eye_Works_0004_fig_1.2.png',
#  'Human_Digestive_System_Function_of_the_Digestive_System_0004_fig_1.1.png',
#  'Human_Egg_Cells_Egg_Production_0004_fig_1.1.png',
#  'Human_Evolution_Hominids_0004_fig_1.1.png',
#  'Human_Evolution_Hominids_0005_fig_1.2.png',
#  'Human_Genome_Project_Human_Genome_Project_0004_fig_1.1.png',
#  'Human_Health_Human_Illnesses_from_Air_Pollution_0004_fig_1.1.png',
#  'Human_Population_Human_Population_0004_fig_1.1.png',
#  'Human_Skeletal_System_Functions_of_Bones_0004_fig_1.1.png',
#  'Human_Skeletal_System_Structure_of_Bones_0005_fig_1.2.png',
#  'Human_Sperm_Sperm_0004_fig_1.1.png',
#  'Human_Uses_of_Fungi_Edible_and_Poisonous_Fungi_0004_fig_1.2.png',
#  'Human_Uses_of_Fungi_Importance_of_Fungi_for_Human_Use_0004_fig_1.1.png',
#  'Human_Vision_Seeing_in_Color_0005_fig_1.3.png',
#  'Human_Vision_Seeing_in_Color_0005_fig_1.4.png',
#  'Human_Vision_Seeing_in_Three_Dimensions_0004_fig_1.2.png',
#  'Human_Vision_Summary_0006_fig_1.5.png',
#  'Human_Vision_The_Nature_of_Human_Vision_0004_fig_1.1.png',
#  'Humans_and_Primates_Characteristics_0004_fig_1.1.png',
#  'Humans_and_Primates_Characteristics_0004_fig_1.2.png',
#  'Hurricanes_Formation_0004_fig_1.1.png',
#  'Hurricanes_Review_0006_fig_1.2.png',
#  'Hydrocarbons_Sources_of_Hydrocarbons_0005_fig_1.2.png',
#  'Hydrocarbons_Uses_of_Hydrocarbons_0004_fig_1.1.png',
#  'Hydroelectric_Power_Hydroelectric_Power_0004_fig_1.1.png',
#  'Hydroelectric_Power_Ocean_Water_Power_0005_fig_1.2.png',
#  'Hydrogen_Bonding_Hydrogen_Bonding_0004_fig_1.1.png',
#  'Hydrogen_and_Alkali_Metals_A_Closer_Look_0006_fig_1.2.png',
#  'Hydrogen_and_Alkali_Metals_A_Closer_Look_0006_fig_1.3.png',
#  'Hydrogen_and_Alkali_Metals_A_Closer_Look_0007_fig_1.4.png',
#  'Hydrogen_and_Alkali_Metals_Other_Properties_of_Alkali_Metals_0005_fig_1.1.png',
#  'Hypothesis_Seafloor_Spreading_0004_fig_1.1.png',
#  'Hypothesis_Summary_0005_fig_1.1.png',
#  'Igneous_Rocks_Extrusive_Igneous_Rocks_0005_fig_1.3.png',
#  'Igneous_Rocks_Extrusive_Igneous_Rocks_0005_fig_1.4.png',
#  'Igneous_Rocks_Extrusive_Igneous_Rocks_0006_fig_1.5.png',
#  'Igneous_Rocks_Intrusive_Igneous_Rocks_0004_fig_1.1.png',
#  'Igneous_Rocks_Intrusive_Igneous_Rocks_0004_fig_1.2.png',
#  'Igneous_Rocks_What_Melts_and_What_Crystallizes_0005_fig_1.1.png',
#  'Importance_of_Arthropods_Arthropods_as_Food_0004_fig_1.1.png',
#  'Importance_of_Biodiversity_Biodiversity_and_Technology_0005_fig_1.3.png',
#  'Importance_of_Biodiversity_Ecological_Importance_0006_fig_1.4.png',
#  'Importance_of_Biodiversity_Economic_Importance_0004_fig_1.2.png',
#  'Importance_of_Biodiversity_Importance_of_Biodiversity_0004_fig_1.1.png',
#  'Importance_of_Birds_Birds_and_the_Ecosystem_0004_fig_1.1.png',
#  'Importance_of_Insects_Ecological_Importance_0004_fig_1.1.png',
#  'Importance_of_Mammals_Importance_to_Ecosystems_0004_fig_1.1.png',
#  'Importance_of_Mammals_Importance_to_Humans_0005_fig_1.2.png',
#  'Importance_of_Mollusks_Mollusks_as_Food_0004_fig_1.1.png',
#  'Importance_of_Protists_Summary_0004_fig_1.1.png',
#  'Importance_of_Reptiles_Summary_0005_fig_1.1.png',
#  'Importance_of_the_Oceans_Biologically_Rich_0004_fig_1.1.png',
#  'Impulses_Neurons_and_Nerve_Impulses_0004_fig_1.1.png',
#  'Impulses_The_Synapse_0005_fig_1.2.png',
#  'Inclined_Plane_Mechanical_Advantage_Of_An_Inclined_Plane_0004_fig_1.1.png',
#  'Inclined_Plane_Mechanical_Advantage_Of_An_Inclined_Plane_0004_fig_1.2.png',
#  'Indoor_Air_Pollution_Indoor_Air_Pollution_0004_fig_1.1.png',
#  'Inertia_Overcoming_Inertia_0005_fig_1.2.png',
#  'Inertia_Review_0006_fig_1.3.png',
#  'Inertia_What_Is_Inertia_0004_fig_1.1.png',
#  'Infancy_and_Childhood_Early_Childhood_Development_0005_fig_1.2.png',
#  'Infancy_and_Childhood_Infancy_and_Childhood_0004_fig_1.1.png',
#  'Infections_Bacterial_STIs_0004_fig_1.1.png',
#  'Infections_Viral_STIs_0005_fig_1.2.png',
#  'Inflammatory_Response_Inflammation_0004_fig_1.1.png',
#  'Influences_on_Darwin_Darwins_Influences_0004_fig_1.1.png',
#  'Influences_on_Weathering_Resources_from_Weathering_0005_fig_1.2.png',
#  'Influences_on_Weathering_Rock_and_Mineral_Type_0004_fig_1.1.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_0004_fig_1.1.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_0004_fig_1.2.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_in_Human_Beings_0005_fig_1.3.png',
#  'Innate_Behavior_of_Animals_Innate_Behavior_in_Human_Beings_0005_fig_1.4.png',
#  'Inner_versus_Outer_Planets_The_Outer_Planets_0004_fig_1.1.png',
#  'Inner_versus_Outer_Planets_The_Outer_Planets_0004_fig_1.2.png',
#  'Inner_vs._Outer_Planets_The_Inner_Planets_0004_fig_1.1.png',
#  'Inner_vs._Outer_Planets_The_Outer_Planets_0005_fig_1.2.png',
#  'Insect_Food_How_do_Insects_Eat_0004_fig_1.1.png',
#  'Insect_Food_How_do_Insects_Eat_0004_fig_1.2.png',
#  'Insects_Characteristics_of_Insects_0004_fig_1.1.png',
#  'Insects_Characteristics_of_Insects_0004_fig_1.2.png',
#  'Insects_Characteristics_of_Insects_0005_fig_1.4.png',
#  'Insects_Insects_are_Social_0006_fig_1.5.png',
#  'Insulators_The_Path_of_Least_Resistance_0004_fig_1.1.png',
#  'Insulators_Thermal_Conductors_0004_fig_1.1.png',
#  'Insulators_Thermal_Insulators_0004_fig_1.2.png',
#  'Insulators_Thermal_Insulators_0005_fig_1.3.png',
#  'Interior_of_the_Sun_Internal_Structure_0004_fig_1.1.png',
#  'Interior_of_the_Sun_Review_0006_fig_1.3.png',
#  'Interior_of_the_Sun_The_Outer_Layers_0005_fig_1.2.png',
#  'Interpretations_An_Analysis_0005_fig_1.2.png',
#  'Interpretations_Facts_Observations_Opinions_0004_fig_1.1.png',
#  'Intraplate_Activity_Intraplate_Activity_in_the_Oceans_0004_fig_1.1.png',
#  'Intraplate_Activity_Intraplate_Activity_in_the_Oceans_0004_fig_1.2.png',
#  'Intraplate_Activity_Intraplate_Activity_on_the_Continents_0005_fig_1.3.png',
#  'Intraplate_Earthquakes_Review_0005_fig_1.1.png',
#  'Introduction_to_Ecology_Research_in_Ecology_0004_fig_1.1.png',
#  'Invertebrates_What_Are_Invertebrates_0004_fig_1.1.png',
#  'Ionic_Bonding_How_Ionic_Bonds_Form_0004_fig_1.1.png',
#  'Ionic_Bonding_Why_Ionic_Bonds_Form_0004_fig_1.2.png',
#  'Ionic_Compounds_Crystals_0004_fig_1.1.png',
#  'Ionic_Compounds_Summary_0006_fig_1.2.png',
#  'Ions_Atoms_to_Ions_0004_fig_1.1.png',
#  'Isomers_How_Many_Isomers_0004_fig_1.1.png',
#  'Isomers_How_Many_Isomers_0004_fig_1.2.png',
#  'Isomers_How_Many_Isomers_0004_fig_1.3.png',
#  'Isomers_How_Many_Isomers_0005_fig_1.4.png',
#  'Isotopes_Naming_Isotopes_0005_fig_1.1.png',
#  'Jawless_Fish_Classification_of_Jawless_Fish_0004_fig_1.1.png',
#  'Jupiter_A_Ball_of_Gas_and_Liquid_0004_fig_1.1.png',
#  'Jupiter_A_Ball_of_Gas_and_Liquid_0004_fig_1.2.png',
#  'Jupiter_A_Stormy_Atmosphere_0005_fig_1.3.png',
#  'Jupiter_Jupiters_Moons_and_Rings_0006_fig_1.4.png',
#  'Jupiter_Summary_0007_fig_1.5.png',
#  'Keeping_Skin_Healthy_Avoiding_Sunburn_0004_fig_1.1.png',
#  'Kidneys_Explore_More_0006_fig_1.3.png',
#  'Kidneys_Formation_of_Urine_0005_fig_1.2.png',
#  'Kidneys_The_Kidneys_0004_fig_1.1.png',
#  'Kinetic_Energy_Calculating_Kinetic_Energy_0004_fig_1.1.png',
#  'Kinetic_Energy_Resources_0005_fig_1.2.png',
#  'Kinetic_Theory_of_Matter_Kinetic_Energy_and_States_of_Matter_0004_fig_1.1.png',
#  'Law_of_Reflection_References_0006_fig_1.5.png',
#  'Law_of_Reflection_Regular_and_Diffuse_Reflection_0004_fig_1.1.png',
#  'Law_of_Reflection_Regular_and_Diffuse_Reflection_0004_fig_1.2.png',
#  'Law_of_Reflection_Review_0005_fig_1.4.png',
#  'Law_of_Reflection_Summary_0005_fig_1.3.png',
#  'Lens_Concave_Lens_0004_fig_1.1.png',
#  'Lens_References_0005_fig_1.2.png',
#  'Lever_Advantage_of_Third_Class_Levers_0005_fig_1.1.png',
#  'Life_Adaptive_Radiation_0004_fig_1.1.png',
#  'Life_Cycle_Three_Types_of_Metamorphosis_0006_fig_1.1.png',
#  'Life_Cycles_of_Stars_Neutron_Stars_0007_fig_1.7.png',
#  'Life_Cycles_of_Stars_Red_Giants_and_White_Dwarfs_0004_fig_1.1.png',
#  'Life_Cycles_of_Stars_Red_Giants_and_White_Dwarfs_0004_fig_1.2.png',
#  'Life_Cycles_of_Stars_Supergiants_and_Supernovas_0005_fig_1.3.png',
#  'Life_Cycles_of_Stars_Supergiants_and_Supernovas_0005_fig_1.4.png',
#  'Life_Cycles_of_Stars_Supergiants_and_Supernovas_0006_fig_1.5.png',
#  'Life_Cycles_of_Stars_Supergiants_and_Supernovas_0006_fig_1.6.png',
#  'Light_Let_There_Be_Light_0004_fig_1.1.png',
#  'Light_Ultraviolet_Light_0005_fig_1.3.png',
#  'Light_Visible_Light_0004_fig_1.2.png',
#  'Lipid_Classification_Fatty_Acids_0004_fig_1.1.png',
#  'Lipid_Classification_Fatty_Acids_0004_fig_1.2.png',
#  'Lipid_Classification_Phospholipids_0005_fig_1.3.png',
#  'Liquids_Review_0005_fig_1.4.png',
#  'Liquids_Surface_Tension_and_Viscosity_0004_fig_1.2.png',
#  'Liquids_Surface_Tension_and_Viscosity_0004_fig_1.3.png',
#  'Liquids_Water_and_Other_Liquids_0004_fig_1.1.png',
#  'Lizards_and_Snakes_Characteristics_of_Lizards_0004_fig_1.1.png',
#  'Lizards_and_Snakes_Characteristics_of_Lizards_0004_fig_1.2.png',
#  'Lizards_and_Snakes_Characteristics_of_Snakes_0006_fig_1.4.png',
#  'Lizards_and_Snakes_Characteristics_of_Snakes_0006_fig_1.5.png',
#  'Lizards_and_Snakes_How_do_Snakes_Eat_0007_fig_1.6.png',
#  'Lizards_and_Snakes_Lizard_Behavior_0005_fig_1.3.png',
#  'Local_Winds_Chinook_Winds_Foehn_Winds_0005_fig_1.3.png',
#  'Local_Winds_Desert_Winds_0007_fig_1.6.png',
#  'Local_Winds_Land_and_Sea_Breezes_0004_fig_1.1.png',
#  'Local_Winds_Monsoon_Winds_0004_fig_1.2.png',
#  'Local_Winds_Santa_Ana_Winds_0006_fig_1.4.png',
#  'Local_Winds_Santa_Ana_Winds_0006_fig_1.5.png',
#  'Location_and_Direction_Direction_0005_fig_1.2.png',
#  'Location_and_Direction_Location_0004_fig_1.1.png',
#  'LongTerm_Climate_Change_Changes_in_Atmospheric_Greenhouse_Gas_Levels_0006_fig_1.3.png',
#  'LongTerm_Climate_Change_Milankovitch_Cycles_0005_fig_1.2.png',
#  'LongTerm_Climate_Change_Solar_Variation_0004_fig_1.1.png',
#  'Longitudinal_Wave_P_Waves_0004_fig_1.2.png',
#  'Longitudinal_Wave_What_Is_a_Longitudinal_Wave_0004_fig_1.1.png',
#  'Lymphatic_System_Lymph_Organs_0005_fig_1.2.png',
#  'Lymphatic_System_Lymphocytes_0006_fig_1.3.png',
#  'Lymphatic_System_Role_of_the_Lymphatic_System_in_Circulation_0005_fig_1.2.png',
#  'Lymphatic_System_The_Lymphatic_System_and_Circulation_0004_fig_1.1.png',
#  'Lymphatic_System_The_Lymphatic_System_and_the_Immune_Response_0004_fig_1.1.png',
#  'Macroevolution_Microevolution_and_Macroevolution_0004_fig_1.1.png',
#  'Magnetic_Field_Reversal_Changing_Places_0003_fig_1.1.png',
#  'Magnetic_Field_Reversal_Fact_Not_Fiction_0004_fig_1.2.png',
#  'Magnets_Magnetic_Force_and_Magnetic_Field_0004_fig_1.1.png',
#  'Magnets_Magnetic_Force_and_Magnetic_Field_0004_fig_1.2.png',
#  'Magnets_Magnetic_Force_and_Magnetic_Field_0005_fig_1.3.png',
#  'Magnitude_Interpreting_a_Seismogram_0004_fig_1.1.png',
#  'Male_Reproductive_System_The_Male_Reproductive_System_Functions_0004_fig_1.1.png',
#  'Mammal_Characteristics_Characteristics_of_Mammals_0004_fig_1.1.png',
#  'Mammal_Classification_Groups_of_Mammals_0004_fig_1.1.png',
#  'Mammal_Classification_Groups_of_Mammals_0004_fig_1.2.png',
#  'Mammal_Classification_Groups_of_Mammals_0005_fig_1.3.png',
#  'Mammal_Reproduction_Mammal_Reproduction_0004_fig_1.1.png',
#  'Mammal_Reproduction_Mammal_Reproduction_0004_fig_1.2.png',
#  'Mammal_Reproduction_Summary_0005_fig_1.3.png',
#  'Maps_Bathymetric_Maps_0004_fig_1.2.png',
#  'Maps_Bathymetric_Maps_0005_fig_1.3.png',
#  'Maps_Topographic_Maps_0004_fig_1.1.png',
#  'Mars_Characteristics_0004_fig_1.1.png',
#  'Mars_Is_There_Water_on_Mars_0005_fig_1.2.png',
#  'Mars_Is_There_Water_on_Mars_0005_fig_1.3.png',
#  'Mars_Is_There_Water_on_Mars_0006_fig_1.4.png',
#  'Mars_Two_Martian_Moons_0006_fig_1.5.png',
#  'Mass_Extinctions_Mass_Extinctions_0004_fig_1.1.png',
#  'Mass_Extinctions_Mass_Extinctions_0004_fig_1.2.png',
#  'Mass_Extinctions_Mass_Extinctions_0005_fig_1.3.png',
#  'Mass_vs_Weight_Review_0004_fig_1.1.png',
#  'Matter_Additional_Physical_Properties_0004_fig_1.1.png',
#  'Matter_Additional_Physical_Properties_0004_fig_1.2.png',
#  'Matter_Additional_Physical_Properties_0005_fig_1.3.png',
#  'Matter_Examples_of_Physical_Properties_0004_fig_1.1.png',
#  'Matter_Flammability_0004_fig_1.1.png',
#  'Matter_Mass_and_Volume_Advanced_Topic_Defining_Density_0007_fig_1.1.png',
#  'Matter_References_0006_fig_1.4.png',
#  'Measure_of_Age_HalfLives_0005_fig_1.2.png',
#  'Measure_of_Age_Radioactive_Isotopes_0004_fig_1.1.png',
#  'Mechanical_Advantage_A_Simple_Example_0004_fig_1.1.png',
#  'Mechanical_Wave_Types_of_Mechanical_Waves_0004_fig_1.1.png',
#  'Mechanical_Weathering_Abrasion_0004_fig_1.2.png',
#  'Mechanical_Weathering_Humans_0005_fig_1.3.png',
#  'Mechanical_Weathering_Ice_Wedging_0004_fig_1.1.png',
#  'Meiosis_Meiosis_I_0005_fig_1.2.png',
#  'Meiosis_Overview_of_Meiosis_0004_fig_1.1.png',
#  'Meiosis_Summary_0006_fig_1.3.png',
#  'Melting_From_Solid_to_Liquid_0004_fig_1.1.png',
#  'Mendeleevs_Periodic_Table_Groups_and_Periods_0004_fig_1.2.png',
#  'Mendeleevs_Periodic_Table_Organizing_Elements_0004_fig_1.1.png',
#  'Mendels_Pea_Plants_Mendels_Experiments_0004_fig_1.1.png',
#  'Mendels_Pea_Plants_Mendels_Experiments_0004_fig_1.2.png',
#  'Mendels_Pea_Plants_Mendels_First_Experiment_0005_fig_1.3.png',
#  'Menstrual_Cycle_The_Female_Monthly_Cycle_0004_fig_1.1.png',
#  'Mercury_A_Liquid_Metal_Core_0005_fig_1.3.png',
#  'Mercury_Extreme_Temperatures_0005_fig_1.2.png',
#  'Mercury_Mercury_0004_fig_1.1.png',
#  'Mercury_Pollution_Bioaccumulation_0004_fig_1.1.png',
#  'Mercury_Pollution_Mad_As_a_Hatter_0005_fig_1.2.png',
#  'Mercury_Pollution_Summary_0006_fig_1.3.png',
#  'Mesosphere_Air_Density_0004_fig_1.1.png',
#  'Mesozoic_Plate_Tectonics_Growth_of_Continents_0004_fig_1.1.png',
#  'Mesozoic_Plate_Tectonics_Growth_of_Continents_0004_fig_1.2.png',
#  ...]

# %%
# set(new_original_image_names).difference(set(old_original_image_names))

# %%
len(set(old_original_image_name).intersection(set(new_original_image_name)))
# Out:
# 1454

# %%
images_present = !ls /Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/textbook_images

# %%
renamed_images = [new_name.split('/')[-1] for new_name in record_image_name_changes.values()]
for image_n in images_present:
    if image_n not in renamed_images:
        print(image_n)
# Out:
# biotechnology_in_agriculture_21731.png
# how_the_eye_works_21884.png
# how_the_eye_works_21885.png

# %%
# for old_name, new_name in list(record_image_name_changes.items()):
#     new_name.split('/')[-1]

# %%
with open('textbook_image_renaming_lookup.pkl', 'wb') as f:
    pickle.dump(record_image_name_changes_name_only, f)

# %%
missing
# Out:
# []

# %%
record_image_name_changes_name_only = {k.split('/')[-1]:v.split('/')[-1] for k,v in record_image_name_changes.items()}

# %%
d_image in record_image_name_changes.keys()
# Out:
# False

# %% [markdown]
# # End

# %%
# flexbook_glossary.keys()

# %%
# print(list(diagram_lesson_lookup.values()))

# %%
test_lesson = ck12_combined_dataset['earth-science']['24.1 Planet Earth']

# %%
# pprint.pprint(test_lesson['instructionalDiagrams'])

# %%
list(test_lesson['instructionalDiagrams'].values())[0]['processedText']

# %%
test_lesson['topics'].keys()

# %%
test_vocab = test_lesson['topics']['Vocabulary']['content']['text'].split('\n')

# %%
for word in test_vocab:
    if word in flexbook_glossary:
        print(flexbook_glossary[word])
        print()

# %%
# write_file('ck12_v4_5.json', ck12_combined_dataset, 'experimental_output')
