# %%
# %%capture
from __future__ import division
import numpy as np
import pandas as pd
import scipy.stats as st
import itertools
import math
from collections import Counter, defaultdict
# %load_ext autoreload
# %autoreload 2

import json
import os
from copy import deepcopy
from tqa_utils import Evaluator

# %%
all_headers = ["id","parentId","isArchived","questionText","answerText","points","isTest","isMultipleChoice","hasDiagram","examName","examGrade","examYear","notes","tags","legacyId","importedQuestionId"]
headers = ["questionText","answerText","points","isTest","isMultipleChoice","hasDiagram","examName","examGrade","examYear", "notes", "legacyId", "lessonName", "importedQuestionId"]

# %%
dataset_root_dir = '/Users/schwenk/wrk/stb/dataset_releases/data_release_beta6/'
file_name = 'tqa_dataset_beta7_5.json'
data_file =  dataset_root_dir + file_name
quest_evaluator = Evaluator(data_file)

# %%
with open(os.path.join(dataset_root_dir, file_name), 'r') as f:
    ck12_combined_dataset_raw = json.load(f)
ck12_combined_dataset = deepcopy(ck12_combined_dataset_raw)

# %%
all_ndqs = quest_evaluator.build_question_lookup(by_type=True)['nonDiagramQuestions']
mc_questions = quest_evaluator.build_questions_by_subtype(all_ndqs)['Multiple Choice']
all_diagram_qs = quest_evaluator.build_question_lookup(by_type=True)['diagramQuestions']

# %%
all_questions = []
for lesson in ck12_combined_dataset:
    for question in list(lesson['questions']['nonDiagramQuestions'].values()) + list(lesson['questions']['diagramQuestions'].values()):
        question['lessonName'] = lesson['lessonName']
        question['lessonID'] = lesson['globalID']
        all_questions.append(question)

# %%
len(all_questions)
# Out:
# 31496

# %%
build_frame = []
s3_prefix = 'https://s3.amazonaws.com/aristo-data/images/TQA/'
for question in all_questions:

    if 'imagePath' in question.keys():
        has_diagram = True
        image_name = question['imagePath'].split('/')[-1]
        image_prefix = '{' + s3_prefix + image_name + '}'
    else:
        has_diagram = False
        image_prefix = ''
    if 'answerChoices' in question.keys():
         answer_choices = ['(' + sid.upper() + ') ' + ac['processedText'] for sid, ac in sorted(question['answerChoices'].items())]
    else:
        answer_choices = []
    
    if 'questionSubType' not in question.keys():
        q_sub_type = question['questionType']
    else:
        q_sub_type = question['questionSubType']
    
    new_question_row = {
        "questionText": ' '.join([image_prefix, question['beingAsked']['processedText']] + answer_choices),
        "answerText": question['correctAnswer']['processedText'],
        "points": 1,
        "isTest": False,
        "isMultipleChoice": question['questionType'] in ['Multiple Choice', 'Diagram Multiple Choice'],
        "hasDiagram": has_diagram,
        "examName": "TQA",
        "examGrade": "8",
        "examYear": "2016",
        "legacyId": '_'.join(["TQA", question['lessonID'], question['globalID']]),
        "lessonName": question['lessonName'],
        "importedQuestionId": question['globalID'],
        "notes": q_sub_type
    }
    build_frame.append(new_question_row)
qdf = pd.DataFrame(build_frame)
ndqdf = qdf[headers]

# %%
ndqdf.head(300).tail(200).to_csv('tqa_aristo_format_v1.csv', index=False)

# %%
ndqdf.to_csv('tqa_aristo_format_v2.csv', index=False)

# %%
ndqdf.head(300).tail(200)
# Out:
#                                           questionText answerText  points  \
# 100   Erosion is always followed by (A) deposition....          a       1
# 101   Large curves eroded in the channel of a slow-...   meanders       1
# 102   hole on the surface of the ground that forms ...          f       1
# 103   When flowing water slows down, which of the f...          a       1
# 104   Which statement about stalactites is false? (...          a       1
# 105   Floodplains are poor places for growing crops...          b       1
# 106   Sinkholes are caused by groundwater erosion. ...          a       1
# 107  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 108  {https://s3.amazonaws.com/aristo-data/images/T...          d       1
# 109  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 110  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 111  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 112  {https://s3.amazonaws.com/aristo-data/images/T...          a       1
# 113  {https://s3.amazonaws.com/aristo-data/images/T...          d       1
# 114  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 115  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 116  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 117  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 118  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 119  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 120  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 121  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 122  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 123  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 124  {https://s3.amazonaws.com/aristo-data/images/T...          d       1
# 125  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 126  {https://s3.amazonaws.com/aristo-data/images/T...          a       1
# 127  {https://s3.amazonaws.com/aristo-data/images/T...          c       1
# 128  {https://s3.amazonaws.com/aristo-data/images/T...          a       1
# 129  {https://s3.amazonaws.com/aristo-data/images/T...          d       1
# ..                                                 ...        ...     ...
# 270  {https://s3.amazonaws.com/aristo-data/images/T...          b       1
# 271   Undercutting can cause the ground to become u...          a       1
# 272   Mudslides occur where the soil consists mostl...       clay       1
# 273   During creep, soil moves downhill when it tha...          a       1
# 274   Landslides rarely cause much damage. (A) true...          b       1
# 275   any type of erosion and deposition caused dir...          c       1
# 276   A large block that moves along a curved surfa...      slump       1
# 277   Mass movement can occur (A) suddenly. (B) ver...          d       1
# 278   A landslide may carry away an entire village....          a       1
# 279   sudden flow of a large amount of wet, slipper...          d       1
# 280         The slowest mass movement is ____________.      creep       1
# 281   Gravity pulls soil and rocks downhill. (A) tr...          a       1
# 282   Slump is more destructive than a landslide. (...          b       1
# 283   The rate of erosion by gravity (A) is sudden ...          d       1
# 284   A slump is the sudden (A) fall of rock and so...          c       1
# 285   Downhill creep (A) results in curved tree tru...          a       1
# 286   Curved tree trunks are a sign of land creep. ...          a       1
# 287   Mass movement is always a very slow process. ...          b       1
# 288   sudden movement of a large amount of soil and...          b       1
# 289   An earthquake is a type of mass movement. (A)...          b       1
# 290   If a landslide flows into the ocean, it may c...    tsunami       1
# 291   Gravity causes erosion by all of the followin...          b       1
# 292   A hillside that has slumped may display a cre...       scar       1
# 293   The type of mass movement that occurs very sl...      creep       1
# 294   Creep usually takes place where the ground (A...          c       1
# 295    Wet __________ beneath a slope may cause slump.       clay       1
# 296   Mudslides occur where soil consists mostly of...          b       1
# 297   force that indirectly causes erosion by movin...          f       1
# 298   Rock and soil are pulled downhill by ________...    gravity       1
# 299   Landslides can cause earthquakes. (A) true (B...          b       1
#
#     isTest isMultipleChoice hasDiagram examName examGrade examYear  \
# 100  False             True      False      TQA         8     2016
# 101  False            False      False      TQA         8     2016
# 102  False             True      False      TQA         8     2016
# 103  False             True      False      TQA         8     2016
# 104  False             True      False      TQA         8     2016
# 105  False             True      False      TQA         8     2016
# 106  False             True      False      TQA         8     2016
# 107  False             True       True      TQA         8     2016
# 108  False             True       True      TQA         8     2016
# 109  False             True       True      TQA         8     2016
# 110  False             True       True      TQA         8     2016
# 111  False             True       True      TQA         8     2016
# 112  False             True       True      TQA         8     2016
# 113  False             True       True      TQA         8     2016
# 114  False             True       True      TQA         8     2016
# 115  False             True       True      TQA         8     2016
# 116  False             True       True      TQA         8     2016
# 117  False             True       True      TQA         8     2016
# 118  False             True       True      TQA         8     2016
# 119  False             True       True      TQA         8     2016
# 120  False             True       True      TQA         8     2016
# 121  False             True       True      TQA         8     2016
# 122  False             True       True      TQA         8     2016
# 123  False             True       True      TQA         8     2016
# 124  False             True       True      TQA         8     2016
# 125  False             True       True      TQA         8     2016
# 126  False             True       True      TQA         8     2016
# 127  False             True       True      TQA         8     2016
# 128  False             True       True      TQA         8     2016
# 129  False             True       True      TQA         8     2016
# ..     ...              ...        ...      ...       ...      ...
# 270  False             True       True      TQA         8     2016
# 271  False             True      False      TQA         8     2016
# 272  False            False      False      TQA         8     2016
# 273  False             True      False      TQA         8     2016
# 274  False             True      False      TQA         8     2016
# 275  False             True      False      TQA         8     2016
# 276  False            False      False      TQA         8     2016
# 277  False             True      False      TQA         8     2016
# 278  False             True      False      TQA         8     2016
# 279  False             True      False      TQA         8     2016
# 280  False            False      False      TQA         8     2016
# 281  False             True      False      TQA         8     2016
# 282  False             True      False      TQA         8     2016
# 283  False             True      False      TQA         8     2016
# 284  False             True      False      TQA         8     2016
# 285  False             True      False      TQA         8     2016
# 286  False             True      False      TQA         8     2016
# 287  False             True      False      TQA         8     2016
# 288  False             True      False      TQA         8     2016
# 289  False             True      False      TQA         8     2016
# 290  False            False      False      TQA         8     2016
# 291  False             True      False      TQA         8     2016
# 292  False            False      False      TQA         8     2016
# 293  False            False      False      TQA         8     2016
# 294  False             True      False      TQA         8     2016
# 295  False            False      False      TQA         8     2016
# 296  False             True      False      TQA         8     2016
# 297  False             True      False      TQA         8     2016
# 298  False            False      False      TQA         8     2016
# 299  False             True      False      TQA         8     2016
#
#                        notes               legacyId  \
# 100          Multiple Choice  TQA_L_0003_NDQ_000102
# 101        Fill in the Blank  TQA_L_0003_NDQ_000093
# 102                 Matching  TQA_L_0003_NDQ_000098
# 103          Multiple Choice  TQA_L_0003_NDQ_000105
# 104          Multiple Choice  TQA_L_0003_NDQ_000106
# 105            True or False  TQA_L_0003_NDQ_000084
# 106            True or False  TQA_L_0003_NDQ_000086
# 107  Diagram Multiple Choice   TQA_L_0003_DQ_000026
# 108  Diagram Multiple Choice   TQA_L_0003_DQ_000002
# 109  Diagram Multiple Choice   TQA_L_0003_DQ_000015
# 110  Diagram Multiple Choice   TQA_L_0003_DQ_000007
# 111  Diagram Multiple Choice   TQA_L_0003_DQ_000016
# 112  Diagram Multiple Choice   TQA_L_0003_DQ_000019
# 113  Diagram Multiple Choice   TQA_L_0003_DQ_000008
# 114  Diagram Multiple Choice   TQA_L_0003_DQ_000005
# 115  Diagram Multiple Choice   TQA_L_0003_DQ_000031
# 116  Diagram Multiple Choice   TQA_L_0003_DQ_000017
# 117  Diagram Multiple Choice   TQA_L_0003_DQ_000006
# 118  Diagram Multiple Choice   TQA_L_0003_DQ_000029
# 119  Diagram Multiple Choice   TQA_L_0003_DQ_000004
# 120  Diagram Multiple Choice   TQA_L_0003_DQ_000027
# 121  Diagram Multiple Choice   TQA_L_0003_DQ_000037
# 122  Diagram Multiple Choice   TQA_L_0003_DQ_000032
# 123  Diagram Multiple Choice   TQA_L_0003_DQ_000010
# 124  Diagram Multiple Choice   TQA_L_0003_DQ_000003
# 125  Diagram Multiple Choice   TQA_L_0003_DQ_000030
# 126  Diagram Multiple Choice   TQA_L_0003_DQ_000021
# 127  Diagram Multiple Choice   TQA_L_0003_DQ_000024
# 128  Diagram Multiple Choice   TQA_L_0003_DQ_000018
# 129  Diagram Multiple Choice   TQA_L_0003_DQ_000009
# ..                       ...                    ...
# 270  Diagram Multiple Choice   TQA_L_0006_DQ_000069
# 271            True or False  TQA_L_0007_NDQ_000224
# 272        Fill in the Blank  TQA_L_0007_NDQ_000240
# 273            True or False  TQA_L_0007_NDQ_000231
# 274            True or False  TQA_L_0007_NDQ_000229
# 275                 Matching  TQA_L_0007_NDQ_000236
# 276        Fill in the Blank  TQA_L_0007_NDQ_000212
# 277          Multiple Choice  TQA_L_0007_NDQ_000206
# 278            True or False  TQA_L_0007_NDQ_000218
# 279                 Matching  TQA_L_0007_NDQ_000237
# 280        Fill in the Blank  TQA_L_0007_NDQ_000213
# 281            True or False  TQA_L_0007_NDQ_000214
# 282            True or False  TQA_L_0007_NDQ_000223
# 283          Multiple Choice  TQA_L_0007_NDQ_000202
# 284          Multiple Choice  TQA_L_0007_NDQ_000208
# 285          Multiple Choice  TQA_L_0007_NDQ_000205
# 286            True or False  TQA_L_0007_NDQ_000222
# 287            True or False  TQA_L_0007_NDQ_000215
# 288                 Matching  TQA_L_0007_NDQ_000234
# 289            True or False  TQA_L_0007_NDQ_000228
# 290        Fill in the Blank  TQA_L_0007_NDQ_000239
# 291          Multiple Choice  TQA_L_0007_NDQ_000201
# 292        Fill in the Blank  TQA_L_0007_NDQ_000217
# 293        Fill in the Blank  TQA_L_0007_NDQ_000242
# 294          Multiple Choice  TQA_L_0007_NDQ_000209
# 295        Fill in the Blank  TQA_L_0007_NDQ_000219
# 296            True or False  TQA_L_0007_NDQ_000220
# 297                 Matching  TQA_L_0007_NDQ_000233
# 298        Fill in the Blank  TQA_L_0007_NDQ_000216
# 299            True or False  TQA_L_0007_NDQ_000227
#
#                                   lessonName importedQuestionId
# 100  erosion and deposition by flowing water         NDQ_000102
# 101  erosion and deposition by flowing water         NDQ_000093
# 102  erosion and deposition by flowing water         NDQ_000098
# 103  erosion and deposition by flowing water         NDQ_000105
# 104  erosion and deposition by flowing water         NDQ_000106
# 105  erosion and deposition by flowing water         NDQ_000084
# 106  erosion and deposition by flowing water         NDQ_000086
# 107  erosion and deposition by flowing water          DQ_000026
# 108  erosion and deposition by flowing water          DQ_000002
# 109  erosion and deposition by flowing water          DQ_000015
# 110  erosion and deposition by flowing water          DQ_000007
# 111  erosion and deposition by flowing water          DQ_000016
# 112  erosion and deposition by flowing water          DQ_000019
# 113  erosion and deposition by flowing water          DQ_000008
# 114  erosion and deposition by flowing water          DQ_000005
# 115  erosion and deposition by flowing water          DQ_000031
# 116  erosion and deposition by flowing water          DQ_000017
# 117  erosion and deposition by flowing water          DQ_000006
# 118  erosion and deposition by flowing water          DQ_000029
# 119  erosion and deposition by flowing water          DQ_000004
# 120  erosion and deposition by flowing water          DQ_000027
# 121  erosion and deposition by flowing water          DQ_000037
# 122  erosion and deposition by flowing water          DQ_000032
# 123  erosion and deposition by flowing water          DQ_000010
# 124  erosion and deposition by flowing water          DQ_000003
# 125  erosion and deposition by flowing water          DQ_000030
# 126  erosion and deposition by flowing water          DQ_000021
# 127  erosion and deposition by flowing water          DQ_000024
# 128  erosion and deposition by flowing water          DQ_000018
# 129  erosion and deposition by flowing water          DQ_000009
# ..                                       ...                ...
# 270       erosion and deposition by glaciers          DQ_000069
# 271        erosion and deposition by gravity         NDQ_000224
# 272        erosion and deposition by gravity         NDQ_000240
# 273        erosion and deposition by gravity         NDQ_000231
# 274        erosion and deposition by gravity         NDQ_000229
# 275        erosion and deposition by gravity         NDQ_000236
# 276        erosion and deposition by gravity         NDQ_000212
# 277        erosion and deposition by gravity         NDQ_000206
# 278        erosion and deposition by gravity         NDQ_000218
# 279        erosion and deposition by gravity         NDQ_000237
# 280        erosion and deposition by gravity         NDQ_000213
# 281        erosion and deposition by gravity         NDQ_000214
# 282        erosion and deposition by gravity         NDQ_000223
# 283        erosion and deposition by gravity         NDQ_000202
# 284        erosion and deposition by gravity         NDQ_000208
# 285        erosion and deposition by gravity         NDQ_000205
# 286        erosion and deposition by gravity         NDQ_000222
# 287        erosion and deposition by gravity         NDQ_000215
# 288        erosion and deposition by gravity         NDQ_000234
# 289        erosion and deposition by gravity         NDQ_000228
# 290        erosion and deposition by gravity         NDQ_000239
# 291        erosion and deposition by gravity         NDQ_000201
# 292        erosion and deposition by gravity         NDQ_000217
# 293        erosion and deposition by gravity         NDQ_000242
# 294        erosion and deposition by gravity         NDQ_000209
# 295        erosion and deposition by gravity         NDQ_000219
# 296        erosion and deposition by gravity         NDQ_000220
# 297        erosion and deposition by gravity         NDQ_000233
# 298        erosion and deposition by gravity         NDQ_000216
# 299        erosion and deposition by gravity         NDQ_000227
#
# [200 rows x 13 columns]

# %%
count = 0
for question in all_ndqs.values():
    count += question['questionSubType'] == 'Multiple Choice'

# %%
count + len(all_diagram_qs)
# Out:
# 19149

# %%
ndqdf.shape
# Out:
# (31496, 13)
